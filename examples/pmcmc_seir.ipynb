# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
from particle_filter import particlefilter
from models import SEIR_model,SEIR_Obs
from pmcmc import particlemcmc
from scipy.stats import norm

# %%
'''Simulated Data, setting up the SIR model'''

rng = np.random.default_rng(0)

gamma = 1/14
eta = 1/7
q = 0.1
mu = 0.004
rho = 0.1

T = 120
dt = 1.
t_vec = np.arange(0,T,dt)

N = 100_000
I = 5
E = 5


beta_par = {'b_0':0.4,'b_inf': 0.1, 'tau': 5,'T':20}

def beta_sim(par,t):
    if(t < par['T']):
        return 0.4
    
    return par['b_inf'] + (par['b_0'] - par['b_inf']) * np.exp(-(t - par['T'])/par['tau'])

betas = np.array([beta_sim(beta_par,t) for t in t_vec])

state = np.zeros((5,len(t_vec)))
state[:,0] = np.array([N - I - E,E, I, 0,0])

plt.title('Generative $\\beta_t$')
plt.xlabel('Time (Days)')
plt.plot(t_vec,betas)

for time_index in range(1,len(t_vec)):

    #new_E = rng.poisson((betas[time_index - 1] * (state[1,time_index -1] + q * state[2,time_index - 1]) * state[0,time_index - 1]/np.sum(state[:,time_index-1])) * dt)
    # new_I = rng.poisson((eta * state[1,time_index - 1]) * dt)
    # new_ER = rng.poisson((gamma * state[1,time_index -1]) * dt)
    # new_IR = rng.poisson((gamma * state[2,time_index - 1]) * dt)
    # new_D = rng.poisson((mu * state[2,time_index - 1]) * dt)

    new_E = ((betas[time_index - 1] * (state[1,time_index -1] + q * state[2,time_index - 1]) * state[0,time_index - 1]/np.sum(state[:,time_index-1])) * dt)
    new_I = ((eta * state[1,time_index - 1]) * dt)
    new_ER = ((gamma * state[1,time_index -1]) * dt)
    new_IR = ((gamma * state[2,time_index - 1]) * dt)
    new_D = ((mu * state[2,time_index - 1]) * dt)


    state[0,time_index] = np.maximum(0.,state[0,time_index - 1] - new_E) #S 
    state[1,time_index] = np.maximum(0.,state[1,time_index - 1] + new_E - new_I - new_ER) #E
    state[2,time_index] = np.maximum(0.,state[2,time_index-1] + new_I - new_IR - new_D) #I
    state[3,time_index] = np.maximum(0.,state[3,time_index - 1] + new_ER + new_IR)
    state[4,time_index] = state[4,time_index - 1] + new_I

# %%
plt.yscale('log')
plt.title('Plot of SEIR Model')
plt.xlabel('Time (Days)')
plt.plot(t_vec,state.T)
# Out:
# [<matplotlib.lines.Line2D at 0x2b9d25e5b50>,
#  <matplotlib.lines.Line2D at 0x2b9e903a6d0>,
#  <matplotlib.lines.Line2D at 0x2b9eb2bda10>,
#  <matplotlib.lines.Line2D at 0x2b9eb2bf550>,
#  <matplotlib.lines.Line2D at 0x2b9eb2bf810>]

# %%
n = 100
sigma = 0.1
rho = 0.4

data = np.expand_dims(rng.poisson(state[2,::int(1/dt)]),0)

plt.title('Plot of Generative Data')
plt.xlabel('Time (Days)')
plt.ylabel('Case Count')
plt.plot(data.T)

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,eta = model_params

    '''OU Process'''
    sig = 0.5
    lam = 1/100
    mu = -2.0

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((eta * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())#beta_sim(beta_par,t)#

        observations[index,0,t] = particles[index,2,t]#new_E#particles[:,1,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    var = 15**2
    return -((((data_point - particle_observations[:,0])**2)/(2 * var)) + np.log(np.sqrt(2 * np.pi * var)))

# %%
#(0.06547914,0.28245005)
#(1/14 = 0.07,1/7 = 0.14)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(0,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,eta),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 7.136036799987778

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -503.63348477463285
# Root Mean Squared Error for the Data 148.42164786721466

# %%
pmcmc_rng = np.random.default_rng(0)

num_particles = 1000

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 1/15.,max_val = 1/3)

pmcmc_params = {'iterations':10_000,
                'init_params':np.array([0.1,0.1]),
                'prior':seir_prior,
                'init_cov':0.05 * np.eye(2),
                'burn_in':100}

pf_params = {'num_particles':10_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -500.2637426662909| Proposal [0.1 0.1]
# iteration: 20| Acceptance rate: 0.05| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 30| Acceptance rate: 0.03333333333333333| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 40| Acceptance rate: 0.025| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 50| Acceptance rate: 0.02| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 60| Acceptance rate: 0.016666666666666666| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 70| Acceptance rate: 0.014285714285714285| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 80| Acceptance rate: 0.0125| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 90| Acceptance rate: 0.011111111111111112| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 100| Acceptance rate: 0.01| Log-Likelihood: -498.9367387488371| Proposal [0.10743236 0.12406999]
# iteration: 110| Acceptance rate: 0.01818181818181818| Log-Likelihood: -499.5177676783479| Proposal [0.07055365 0.16538333]
# iteration: 120| Acceptance rate: 0.05| Log-Likelihood: -498.2885689794356| Proposal [0.07366151 0.15717073]
# iteration: 130| Acceptance rate: 0.1| Log-Likelihood: -497.900109524319| Proposal [0.06685086 0.16742317]
# iteration: 140| Acceptance rate: 0.12142857142857143| Log-Likelihood: -499.7025399233065| Proposal [0.05761854 0.16524506]
# iteration: 150| Acceptance rate: 0.14| Log-Likelihood: -499.4946128711093| Proposal [0.06618351 0.16520264]
# iteration: 160| Acceptance rate: 0.18125| Log-Likelihood: -499.09664949589387| Proposal [0.0757782  0.16133893]
# iteration: 170| Acceptance rate: 0.2| Log-Likelihood: -498.6554060310875| Proposal [0.07022378 0.16317993]
# iteration: 180| Acceptance rate: 0.22777777777777777| Log-Likelihood: -498.1383176086332| Proposal [0.09081806 0.16056233]
# iteration: 190| Acceptance rate: 0.25263157894736843| Log-Likelihood: -498.4238032548008| Proposal [0.08336695 0.15485537]
# iteration: 200| Acceptance rate: 0.28| Log-Likelihood: -498.68673264744444| Proposal [0.08483772 0.1600096 ]
# iteration: 210| Acceptance rate: 0.29523809523809524| Log-Likelihood: -497.58394820754756| Proposal [0.06872995 0.1774096 ]
# iteration: 220| Acceptance rate: 0.30454545454545456| Log-Likelihood: -499.6596045801831| Proposal [0.13337053 0.11138667]
# iteration: 230| Acceptance rate: 0.3173913043478261| Log-Likelihood: -497.8581837116823| Proposal [0.07862884 0.17157922]
# iteration: 240| Acceptance rate: 0.32916666666666666| Log-Likelihood: -499.1857785530307| Proposal [0.13100299 0.13588365]
# iteration: 250| Acceptance rate: 0.336| Log-Likelihood: -498.77213186436137| Proposal [0.10076075 0.15999249]
# iteration: 260| Acceptance rate: 0.3423076923076923| Log-Likelihood: -498.74326795867455| Proposal [0.11553914 0.14942159]
# iteration: 270| Acceptance rate: 0.35555555555555557| Log-Likelihood: -498.1898735281329| Proposal [0.09535796 0.22776016]
# iteration: 280| Acceptance rate: 0.36428571428571427| Log-Likelihood: -497.8013524555399| Proposal [0.07758494 0.19227647]
# iteration: 290| Acceptance rate: 0.3793103448275862| Log-Likelihood: -497.8175380092882| Proposal [0.09647978 0.23775897]
# iteration: 300| Acceptance rate: 0.38666666666666666| Log-Likelihood: -497.67205106781364| Proposal [0.09303936 0.27454982]
# iteration: 310| Acceptance rate: 0.38387096774193546| Log-Likelihood: -498.28795065484485| Proposal [0.10117653 0.27510293]
# iteration: 320| Acceptance rate: 0.3875| Log-Likelihood: -497.417590620183| Proposal [0.07674278 0.30483407]
# iteration: 330| Acceptance rate: 0.3787878787878788| Log-Likelihood: -497.17552984399356| Proposal [0.0886362  0.31396852]
# iteration: 340| Acceptance rate: 0.38529411764705884| Log-Likelihood: -497.336468862047| Proposal [0.09043869 0.30898235]
# iteration: 350| Acceptance rate: 0.39714285714285713| Log-Likelihood: -496.7536242870711| Proposal [0.07724273 0.2752504 ]
# iteration: 360| Acceptance rate: 0.4027777777777778| Log-Likelihood: -496.8264110092398| Proposal [0.07492512 0.31505955]
# iteration: 370| Acceptance rate: 0.41081081081081083| Log-Likelihood: -498.26426259978666| Proposal [0.10063696 0.29035922]
# iteration: 380| Acceptance rate: 0.4236842105263158| Log-Likelihood: -498.8498941336853| Proposal [0.05661661 0.27128076]
# iteration: 390| Acceptance rate: 0.4282051282051282| Log-Likelihood: -497.5789377558976| Proposal [0.06264855 0.29792374]
# iteration: 400| Acceptance rate: 0.425| Log-Likelihood: -496.4889145866435| Proposal [0.07050018 0.27774923]
# iteration: 410| Acceptance rate: 0.4292682926829268| Log-Likelihood: -497.63559564309975| Proposal [0.09643255 0.25074425]
# iteration: 420| Acceptance rate: 0.43333333333333335| Log-Likelihood: -497.1337149252936| Proposal [0.09025299 0.30903746]
# iteration: 430| Acceptance rate: 0.4325581395348837| Log-Likelihood: -496.2136118069858| Proposal [0.06863601 0.33311164]
# iteration: 440| Acceptance rate: 0.42272727272727273| Log-Likelihood: -496.2136118069858| Proposal [0.06863601 0.33311164]
# iteration: 450| Acceptance rate: 0.42444444444444446| Log-Likelihood: -496.65855347539923| Proposal [0.072643   0.32645646]
# iteration: 460| Acceptance rate: 0.4217391304347826| Log-Likelihood: -496.5282533440532| Proposal [0.07360131 0.32629531]
# iteration: 470| Acceptance rate: 0.41702127659574467| Log-Likelihood: -496.6317692569973| Proposal [0.07263998 0.32319679]
# iteration: 480| Acceptance rate: 0.42291666666666666| Log-Likelihood: -496.77351182293| Proposal [0.07100684 0.30656097]
# iteration: 490| Acceptance rate: 0.42448979591836733| Log-Likelihood: -496.78554708985035| Proposal [0.08023278 0.28402126]
# iteration: 500| Acceptance rate: 0.43| Log-Likelihood: -497.39674907120275| Proposal [0.06814196 0.30415574]
# iteration: 510| Acceptance rate: 0.43333333333333335| Log-Likelihood: -497.0751454574144| Proposal [0.08498182 0.27324386]
# iteration: 520| Acceptance rate: 0.43846153846153846| Log-Likelihood: -496.5917238676981| Proposal [0.08098311 0.32513229]
# iteration: 530| Acceptance rate: 0.4339622641509434| Log-Likelihood: -496.6222274737506| Proposal [0.07835946 0.2850136 ]
# iteration: 540| Acceptance rate: 0.43333333333333335| Log-Likelihood: -496.71412727319114| Proposal [0.07125264 0.30379299]
# iteration: 550| Acceptance rate: 0.4309090909090909| Log-Likelihood: -497.2177764234102| Proposal [0.08802082 0.30542688]
# iteration: 560| Acceptance rate: 0.4303571428571429| Log-Likelihood: -496.7443765119134| Proposal [0.08057594 0.28662474]
# iteration: 570| Acceptance rate: 0.4298245614035088| Log-Likelihood: -496.50324794351593| Proposal [0.07030891 0.33312814]
# iteration: 580| Acceptance rate: 0.43448275862068964| Log-Likelihood: -497.6817734586584| Proposal [0.09507711 0.29254097]
# iteration: 590| Acceptance rate: 0.43559322033898307| Log-Likelihood: -496.6813849275394| Proposal [0.07875769 0.32163285]
# iteration: 600| Acceptance rate: 0.43| Log-Likelihood: -496.5956683436634| Proposal [0.0817925  0.30627705]
# iteration: 610| Acceptance rate: 0.4311475409836066| Log-Likelihood: -496.8483609272208| Proposal [0.06821845 0.24459715]
# iteration: 620| Acceptance rate: 0.432258064516129| Log-Likelihood: -497.99369617350885| Proposal [0.0576064  0.31758485]
# iteration: 630| Acceptance rate: 0.43174603174603177| Log-Likelihood: -496.84699375421866| Proposal [0.07004891 0.29352557]
# iteration: 640| Acceptance rate: 0.4296875| Log-Likelihood: -497.5300062070415| Proposal [0.08204346 0.19970943]
# iteration: 650| Acceptance rate: 0.4276923076923077| Log-Likelihood: -497.08175948650444| Proposal [0.07137858 0.32233384]
# iteration: 660| Acceptance rate: 0.42727272727272725| Log-Likelihood: -496.58872124349887| Proposal [0.06648647 0.30799936]
# iteration: 670| Acceptance rate: 0.4253731343283582| Log-Likelihood: -496.90351734724004| Proposal [0.08235486 0.25492722]
# iteration: 680| Acceptance rate: 0.4264705882352941| Log-Likelihood: -496.6065575057884| Proposal [0.06908461 0.29476691]
# iteration: 690| Acceptance rate: 0.427536231884058| Log-Likelihood: -497.0393186773923| Proposal [0.08508868 0.32653172]
# iteration: 700| Acceptance rate: 0.42714285714285716| Log-Likelihood: -498.26001419271824| Proposal [0.06625312 0.20579489]
# iteration: 710| Acceptance rate: 0.4253521126760563| Log-Likelihood: -497.20197922073567| Proposal [0.08182221 0.21072954]
# iteration: 720| Acceptance rate: 0.4263888888888889| Log-Likelihood: -497.913456458949| Proposal [0.06214928 0.26546977]
# iteration: 730| Acceptance rate: 0.4273972602739726| Log-Likelihood: -497.8404233764269| Proposal [0.06102269 0.2745263 ]
# iteration: 740| Acceptance rate: 0.42162162162162165| Log-Likelihood: -497.8404233764269| Proposal [0.06102269 0.2745263 ]
# iteration: 750| Acceptance rate: 0.42| Log-Likelihood: -496.89188527256124| Proposal [0.07108177 0.29178839]
# iteration: 760| Acceptance rate: 0.42236842105263156| Log-Likelihood: -500.81015300878926| Proposal [0.05492822 0.27213296]
# iteration: 770| Acceptance rate: 0.42077922077922075| Log-Likelihood: -496.8316504180835| Proposal [0.07129268 0.21485734]
# iteration: 780| Acceptance rate: 0.41794871794871796| Log-Likelihood: -497.09786550671| Proposal [0.07215226 0.22586837]
# iteration: 790| Acceptance rate: 0.4139240506329114| Log-Likelihood: -497.19087344881063| Proposal [0.07227462 0.22189186]
# iteration: 800| Acceptance rate: 0.4175| Log-Likelihood: -497.03704601029773| Proposal [0.07314183 0.27394853]
# iteration: 810| Acceptance rate: 0.4185185185185185| Log-Likelihood: -497.12914060903813| Proposal [0.0790192  0.21954841]
# iteration: 820| Acceptance rate: 0.4195121951219512| Log-Likelihood: -497.23636477011564| Proposal [0.09091885 0.303042  ]
# iteration: 830| Acceptance rate: 0.42289156626506025| Log-Likelihood: -498.22616159984045| Proposal [0.1017872  0.25065747]
# iteration: 840| Acceptance rate: 0.4226190476190476| Log-Likelihood: -497.50965541002853| Proposal [0.09162373 0.31304719]
# iteration: 850| Acceptance rate: 0.4258823529411765| Log-Likelihood: -497.1022995881938| Proposal [0.07501529 0.25999169]
# iteration: 860| Acceptance rate: 0.4255813953488372| Log-Likelihood: -496.7103782593306| Proposal [0.07326313 0.3112445 ]
# iteration: 870| Acceptance rate: 0.4264367816091954| Log-Likelihood: -498.2408129613433| Proposal [0.10721537 0.24667966]
# iteration: 880| Acceptance rate: 0.42727272727272725| Log-Likelihood: -497.3129259102646| Proposal [0.09128155 0.32657058]
# iteration: 890| Acceptance rate: 0.4258426966292135| Log-Likelihood: -496.7892322821823| Proposal [0.06811321 0.32178583]
# iteration: 900| Acceptance rate: 0.42777777777777776| Log-Likelihood: -496.6915301611393| Proposal [0.07427814 0.30350273]
# iteration: 910| Acceptance rate: 0.4230769230769231| Log-Likelihood: -496.6915301611393| Proposal [0.07427814 0.30350273]
# iteration: 920| Acceptance rate: 0.42391304347826086| Log-Likelihood: -498.5881968919565| Proposal [0.07711362 0.15298947]
# iteration: 930| Acceptance rate: 0.42258064516129035| Log-Likelihood: -497.88163246976796| Proposal [0.08987932 0.2133822 ]
# iteration: 940| Acceptance rate: 0.42446808510638295| Log-Likelihood: -499.69904797044467| Proposal [0.13067821 0.20374954]
# iteration: 950| Acceptance rate: 0.4242105263157895| Log-Likelihood: -497.3956578258343| Proposal [0.08679422 0.23936863]
# iteration: 960| Acceptance rate: 0.42291666666666666| Log-Likelihood: -499.23606737455475| Proposal [0.05432319 0.28012234]
# iteration: 970| Acceptance rate: 0.4216494845360825| Log-Likelihood: -497.240568931052| Proposal [0.07161974 0.26040672]
# iteration: 980| Acceptance rate: 0.4204081632653061| Log-Likelihood: -498.39775610784744| Proposal [0.10702728 0.22426593]
# iteration: 990| Acceptance rate: 0.41919191919191917| Log-Likelihood: -498.6419657515897| Proposal [0.10868499 0.26994173]
# iteration: 1000| Acceptance rate: 0.421| Log-Likelihood: -497.61905491291543| Proposal [0.09121931 0.26010596]
# iteration: 1010| Acceptance rate: 0.4198019801980198| Log-Likelihood: -496.94933676315827| Proposal [0.07832838 0.3070466 ]
# iteration: 1020| Acceptance rate: 0.4166666666666667| Log-Likelihood: -496.6897291604612| Proposal [0.07236343 0.2546178 ]
# iteration: 1030| Acceptance rate: 0.41650485436893203| Log-Likelihood: -497.24293605003487| Proposal [0.0857761  0.32149842]
# iteration: 1040| Acceptance rate: 0.4182692307692308| Log-Likelihood: -497.72355805145514| Proposal [0.09489494 0.26233511]
# iteration: 1050| Acceptance rate: 0.41904761904761906| Log-Likelihood: -497.2233513900179| Proposal [0.06413334 0.24383875]
# iteration: 1060| Acceptance rate: 0.4179245283018868| Log-Likelihood: -496.9858464658468| Proposal [0.07748084 0.27078423]
# iteration: 1070| Acceptance rate: 0.4177570093457944| Log-Likelihood: -497.90470395591785| Proposal [0.07905777 0.22955162]
# iteration: 1080| Acceptance rate: 0.4185185185185185| Log-Likelihood: -497.8330896357541| Proposal [0.09665113 0.26871482]
# iteration: 1090| Acceptance rate: 0.41651376146788993| Log-Likelihood: -496.7628658944744| Proposal [0.08379357 0.29524641]
# iteration: 1100| Acceptance rate: 0.41454545454545455| Log-Likelihood: -501.4568821323754| Proposal [0.05220037 0.23288999]
# iteration: 1110| Acceptance rate: 0.4144144144144144| Log-Likelihood: -497.9951756771382| Proposal [0.07665129 0.21491592]
# iteration: 1120| Acceptance rate: 0.4160714285714286| Log-Likelihood: -496.8551577697716| Proposal [0.07265006 0.28778297]
# iteration: 1130| Acceptance rate: 0.4150442477876106| Log-Likelihood: -498.2672684558414| Proposal [0.09571085 0.1912243 ]
# iteration: 1140| Acceptance rate: 0.41754385964912283| Log-Likelihood: -497.21977042458553| Proposal [0.08305809 0.30748101]
# iteration: 1150| Acceptance rate: 0.4147826086956522| Log-Likelihood: -497.03506878143696| Proposal [0.0847929  0.31724768]
# iteration: 1160| Acceptance rate: 0.4163793103448276| Log-Likelihood: -499.6579842816028| Proposal [0.14013594 0.14165191]
# iteration: 1170| Acceptance rate: 0.41452991452991456| Log-Likelihood: -496.3398536905034| Proposal [0.0773793  0.31399889]
# iteration: 1180| Acceptance rate: 0.411864406779661| Log-Likelihood: -496.8652872701598| Proposal [0.08823527 0.33244901]
# iteration: 1190| Acceptance rate: 0.4117647058823529| Log-Likelihood: -499.1014574233697| Proposal [0.11600922 0.15018034]
# iteration: 1200| Acceptance rate: 0.4125| Log-Likelihood: -496.7920797067039| Proposal [0.08513822 0.28275562]
# iteration: 1210| Acceptance rate: 0.4132231404958678| Log-Likelihood: -497.84339463903257| Proposal [0.09905069 0.2820712 ]
# iteration: 1220| Acceptance rate: 0.4122950819672131| Log-Likelihood: -497.9976001089562| Proposal [0.10838888 0.19695713]
# iteration: 1230| Acceptance rate: 0.4138211382113821| Log-Likelihood: -498.08871416293596| Proposal [0.10478567 0.30409547]
# iteration: 1240| Acceptance rate: 0.4129032258064516| Log-Likelihood: -497.1534042627577| Proposal [0.07625523 0.27772295]
# iteration: 1250| Acceptance rate: 0.412| Log-Likelihood: -498.13842459804533| Proposal [0.08924163 0.22666606]
# iteration: 1260| Acceptance rate: 0.4150793650793651| Log-Likelihood: -496.9117469977363| Proposal [0.08027426 0.25458276]
# iteration: 1270| Acceptance rate: 0.41653543307086616| Log-Likelihood: -497.3592300308099| Proposal [0.0766909  0.21136778]
# iteration: 1280| Acceptance rate: 0.41796875| Log-Likelihood: -498.8415208100356| Proposal [0.11008227 0.15428016]
# iteration: 1290| Acceptance rate: 0.4186046511627907| Log-Likelihood: -496.83295746997726| Proposal [0.07349712 0.25485799]
# iteration: 1300| Acceptance rate: 0.4169230769230769| Log-Likelihood: -497.2857923045001| Proposal [0.08882121 0.19698804]
# iteration: 1310| Acceptance rate: 0.41603053435114506| Log-Likelihood: -497.7460672630144| Proposal [0.10144469 0.31218711]
# iteration: 1320| Acceptance rate: 0.41439393939393937| Log-Likelihood: -498.797356507454| Proposal [0.12001294 0.16224357]
# iteration: 1330| Acceptance rate: 0.41353383458646614| Log-Likelihood: -499.1043406975556| Proposal [0.12644131 0.1830918 ]
# iteration: 1340| Acceptance rate: 0.41194029850746267| Log-Likelihood: -497.71103734408587| Proposal [0.09979112 0.30739855]
# iteration: 1350| Acceptance rate: 0.4096296296296296| Log-Likelihood: -496.48981197719104| Proposal [0.08041139 0.32829352]
# iteration: 1360| Acceptance rate: 0.40955882352941175| Log-Likelihood: -496.37346467588975| Proposal [0.0697222  0.33246434]
# iteration: 1370| Acceptance rate: 0.40875912408759124| Log-Likelihood: -497.05159181483623| Proposal [0.07158294 0.32585269]
# iteration: 1380| Acceptance rate: 0.4057971014492754| Log-Likelihood: -497.05159181483623| Proposal [0.07158294 0.32585269]
# iteration: 1390| Acceptance rate: 0.4064748201438849| Log-Likelihood: -496.68804777545625| Proposal [0.08213636 0.28738188]
# iteration: 1400| Acceptance rate: 0.40785714285714286| Log-Likelihood: -498.8739005711683| Proposal [0.11503987 0.22667143]
# iteration: 1410| Acceptance rate: 0.40709219858156026| Log-Likelihood: -497.01430134362874| Proposal [0.08319364 0.314444  ]
# iteration: 1420| Acceptance rate: 0.4091549295774648| Log-Likelihood: -496.87645319960365| Proposal [0.07866167 0.31243739]
# iteration: 1430| Acceptance rate: 0.4083916083916084| Log-Likelihood: -497.0391051293461| Proposal [0.072288   0.27987938]
# iteration: 1440| Acceptance rate: 0.4097222222222222| Log-Likelihood: -496.8012437444794| Proposal [0.07991977 0.28499739]
# iteration: 1450| Acceptance rate: 0.4110344827586207| Log-Likelihood: -496.8719991114874| Proposal [0.06634842 0.32261851]
# iteration: 1460| Acceptance rate: 0.41164383561643836| Log-Likelihood: -497.0266090508802| Proposal [0.06888181 0.24710433]
# iteration: 1470| Acceptance rate: 0.41156462585034015| Log-Likelihood: -497.4361075779588| Proposal [0.06673058 0.25892648]
# iteration: 1480| Acceptance rate: 0.41216216216216217| Log-Likelihood: -497.2830291584162| Proposal [0.07722995 0.24758197]
# iteration: 1490| Acceptance rate: 0.4134228187919463| Log-Likelihood: -497.33211217416215| Proposal [0.09097815 0.23773957]
# iteration: 1500| Acceptance rate: 0.41333333333333333| Log-Likelihood: -497.7879775753232| Proposal [0.08959103 0.25770506]
# iteration: 1510| Acceptance rate: 0.4152317880794702| Log-Likelihood: -496.8070886316732| Proposal [0.08311413 0.31105923]
# iteration: 1520| Acceptance rate: 0.4151315789473684| Log-Likelihood: -496.77690925110323| Proposal [0.07671319 0.30723666]
# iteration: 1530| Acceptance rate: 0.4143790849673203| Log-Likelihood: -497.52454091272307| Proposal [0.06134559 0.33218529]
# iteration: 1540| Acceptance rate: 0.41233766233766234| Log-Likelihood: -497.18449427923076| Proposal [0.06538726 0.26460666]
# iteration: 1550| Acceptance rate: 0.412258064516129| Log-Likelihood: -497.2337583295949| Proposal [0.06260176 0.22353931]
# iteration: 1560| Acceptance rate: 0.41025641025641024| Log-Likelihood: -497.3283419166718| Proposal [0.08052252 0.22210421]
# iteration: 1570| Acceptance rate: 0.41146496815286626| Log-Likelihood: -496.85361116863817| Proposal [0.07636286 0.28536229]
# iteration: 1580| Acceptance rate: 0.4107594936708861| Log-Likelihood: -496.41344853134177| Proposal [0.08270338 0.3086663 ]
# iteration: 1590| Acceptance rate: 0.4088050314465409| Log-Likelihood: -497.19647370231365| Proposal [0.07209779 0.23477328]
# iteration: 1600| Acceptance rate: 0.40875| Log-Likelihood: -497.61056715953833| Proposal [0.09441583 0.27978723]
# iteration: 1610| Acceptance rate: 0.4080745341614907| Log-Likelihood: -496.80785083075716| Proposal [0.06331468 0.31790903]
# iteration: 1620| Acceptance rate: 0.408641975308642| Log-Likelihood: -497.2814018874683| Proposal [0.08290459 0.24830311]
# iteration: 1630| Acceptance rate: 0.40736196319018403| Log-Likelihood: -497.4443409335946| Proposal [0.08772221 0.29588391]
# iteration: 1640| Acceptance rate: 0.41036585365853656| Log-Likelihood: -498.8049551825502| Proposal [0.09217388 0.16093633]
# iteration: 1650| Acceptance rate: 0.4115151515151515| Log-Likelihood: -497.10843689989974| Proposal [0.0638898  0.25347979]
# iteration: 1660| Acceptance rate: 0.41204819277108434| Log-Likelihood: -499.10271050409926| Proposal [0.12410173 0.16436803]
# iteration: 1670| Acceptance rate: 0.411377245508982| Log-Likelihood: -498.5401809375541| Proposal [0.11369392 0.32983502]
# iteration: 1680| Acceptance rate: 0.4101190476190476| Log-Likelihood: -496.9021972693228| Proposal [0.06779128 0.25329237]
# iteration: 1690| Acceptance rate: 0.4076923076923077| Log-Likelihood: -496.9021972693228| Proposal [0.06779128 0.25329237]
# iteration: 1700| Acceptance rate: 0.4082352941176471| Log-Likelihood: -497.6094479116812| Proposal [0.08831942 0.22918478]
# iteration: 1710| Acceptance rate: 0.4087719298245614| Log-Likelihood: -496.93296769978434| Proposal [0.07919735 0.30432616]
# iteration: 1720| Acceptance rate: 0.40813953488372096| Log-Likelihood: -498.13520999290347| Proposal [0.0879381  0.16166627]
# iteration: 1730| Acceptance rate: 0.40809248554913297| Log-Likelihood: -496.72954104076916| Proposal [0.08292456 0.31319596]
# iteration: 1740| Acceptance rate: 0.4086206896551724| Log-Likelihood: -497.4914701223007| Proposal [0.09666137 0.19494859]
# iteration: 1750| Acceptance rate: 0.4102857142857143| Log-Likelihood: -496.7824906407425| Proposal [0.07036053 0.30092307]
# iteration: 1760| Acceptance rate: 0.4090909090909091| Log-Likelihood: -497.8671248810939| Proposal [0.10366211 0.2773768 ]
# iteration: 1770| Acceptance rate: 0.40790960451977404| Log-Likelihood: -497.0807750701091| Proposal [0.07098196 0.28534075]
# iteration: 1780| Acceptance rate: 0.40786516853932586| Log-Likelihood: -498.56703567774| Proposal [0.11212358 0.19149347]
# iteration: 1790| Acceptance rate: 0.4100558659217877| Log-Likelihood: -498.1003805923982| Proposal [0.09309096 0.205866  ]
# iteration: 1800| Acceptance rate: 0.4116666666666667| Log-Likelihood: -497.9614780326227| Proposal [0.09741575 0.22730145]
# iteration: 1810| Acceptance rate: 0.41104972375690607| Log-Likelihood: -496.71007400524076| Proposal [0.07689092 0.28851985]
# iteration: 1820| Acceptance rate: 0.40934065934065933| Log-Likelihood: -496.67320675842217| Proposal [0.07117701 0.2864511 ]
# iteration: 1830| Acceptance rate: 0.4087431693989071| Log-Likelihood: -498.4382210744494| Proposal [0.10360658 0.30567064]
# iteration: 1840| Acceptance rate: 0.4092391304347826| Log-Likelihood: -498.97755389599524| Proposal [0.11651813 0.2882248 ]
# iteration: 1850| Acceptance rate: 0.4081081081081081| Log-Likelihood: -500.381354839227| Proposal [0.13897738 0.3031953 ]
# iteration: 1860| Acceptance rate: 0.40860215053763443| Log-Likelihood: -497.06051818090424| Proposal [0.08645802 0.3145609 ]
# iteration: 1870| Acceptance rate: 0.40855614973262033| Log-Likelihood: -497.9173566989627| Proposal [0.07087099 0.21352396]
# iteration: 1880| Acceptance rate: 0.40797872340425534| Log-Likelihood: -499.1190685935593| Proposal [0.09641318 0.13543874]
# iteration: 1890| Acceptance rate: 0.40793650793650793| Log-Likelihood: -497.14194681521633| Proposal [0.08093354 0.27346022]
# iteration: 1900| Acceptance rate: 0.4068421052631579| Log-Likelihood: -496.75302832325985| Proposal [0.08628504 0.31561715]
# iteration: 1910| Acceptance rate: 0.406282722513089| Log-Likelihood: -498.1811179612004| Proposal [0.10350565 0.27111786]
# iteration: 1920| Acceptance rate: 0.40677083333333336| Log-Likelihood: -498.1459779324065| Proposal [0.10411001 0.21455606]
# iteration: 1930| Acceptance rate: 0.4067357512953368| Log-Likelihood: -497.5629882518316| Proposal [0.09700986 0.22766061]
# iteration: 1940| Acceptance rate: 0.4077319587628866| Log-Likelihood: -496.17505407773365| Proposal [0.071589   0.30741808]
# iteration: 1950| Acceptance rate: 0.40717948717948715| Log-Likelihood: -499.3809412987939| Proposal [0.1226663  0.29315516]
# iteration: 1960| Acceptance rate: 0.40561224489795916| Log-Likelihood: -498.8687209196087| Proposal [0.11321493 0.24714724]
# iteration: 1970| Acceptance rate: 0.40609137055837563| Log-Likelihood: -499.60698626795227| Proposal [0.13370999 0.25409677]
# iteration: 1980| Acceptance rate: 0.40606060606060607| Log-Likelihood: -498.0453023015906| Proposal [0.08639154 0.18275847]
# iteration: 1990| Acceptance rate: 0.4050251256281407| Log-Likelihood: -498.1423291435183| Proposal [0.08374408 0.15344653]
# iteration: 2000| Acceptance rate: 0.4045| Log-Likelihood: -498.4106310189735| Proposal [0.10407393 0.15940425]
# iteration: 2010| Acceptance rate: 0.4059701492537313| Log-Likelihood: -497.946943773432| Proposal [0.10128978 0.22712199]
# iteration: 2020| Acceptance rate: 0.404950495049505| Log-Likelihood: -498.5701842144938| Proposal [0.1126305  0.16355527]
# iteration: 2030| Acceptance rate: 0.40492610837438425| Log-Likelihood: -499.00896596072215| Proposal [0.1077614  0.11327577]
# iteration: 2040| Acceptance rate: 0.40490196078431373| Log-Likelihood: -496.5741574501898| Proposal [0.07378424 0.28768611]
# iteration: 2050| Acceptance rate: 0.40487804878048783| Log-Likelihood: -498.49111324078933| Proposal [0.1162178  0.20174998]
# iteration: 2060| Acceptance rate: 0.40388349514563104| Log-Likelihood: -496.2496734587449| Proposal [0.06920027 0.31777026]
# iteration: 2070| Acceptance rate: 0.40193236714975844| Log-Likelihood: -496.2496734587449| Proposal [0.06920027 0.31777026]
# iteration: 2080| Acceptance rate: 0.4009615384615385| Log-Likelihood: -497.72750699569457| Proposal [0.09269013 0.22814168]
# iteration: 2090| Acceptance rate: 0.4019138755980861| Log-Likelihood: -497.27726820595853| Proposal [0.08978274 0.21917482]
# iteration: 2100| Acceptance rate: 0.4014285714285714| Log-Likelihood: -497.38056209886736| Proposal [0.06404965 0.30355493]
# iteration: 2110| Acceptance rate: 0.4018957345971564| Log-Likelihood: -497.8648798009955| Proposal [0.07777555 0.17275658]
# iteration: 2120| Acceptance rate: 0.4018867924528302| Log-Likelihood: -496.95440597768936| Proposal [0.06785485 0.29201505]
# iteration: 2130| Acceptance rate: 0.4028169014084507| Log-Likelihood: -499.59485631092207| Proposal [0.13740368 0.153173  ]
# iteration: 2140| Acceptance rate: 0.40186915887850466| Log-Likelihood: -498.5199250715922| Proposal [0.11092809 0.27035762]
# iteration: 2150| Acceptance rate: 0.40093023255813953| Log-Likelihood: -499.5452641510858| Proposal [0.13424475 0.1009483 ]
# iteration: 2160| Acceptance rate: 0.40046296296296297| Log-Likelihood: -498.09599876925284| Proposal [0.10446145 0.30441788]
# iteration: 2170| Acceptance rate: 0.40046082949308753| Log-Likelihood: -497.28294244245114| Proposal [0.0624512  0.28554388]
# iteration: 2180| Acceptance rate: 0.3995412844036697| Log-Likelihood: -496.86805661172576| Proposal [0.06809071 0.31099706]
# iteration: 2190| Acceptance rate: 0.39771689497716894| Log-Likelihood: -496.86805661172576| Proposal [0.06809071 0.31099706]
# iteration: 2200| Acceptance rate: 0.3968181818181818| Log-Likelihood: -497.19373248394146| Proposal [0.07097394 0.26634158]
# iteration: 2210| Acceptance rate: 0.39592760180995473| Log-Likelihood: -497.03732682898965| Proposal [0.07756213 0.25475544]
# iteration: 2220| Acceptance rate: 0.3954954954954955| Log-Likelihood: -498.4985695340001| Proposal [0.05790255 0.29026168]
# iteration: 2230| Acceptance rate: 0.39417040358744393| Log-Likelihood: -497.37316198386293| Proposal [0.08696524 0.24270205]
# iteration: 2240| Acceptance rate: 0.39553571428571427| Log-Likelihood: -498.78009273291053| Proposal [0.11279198 0.19065712]
# iteration: 2250| Acceptance rate: 0.39555555555555555| Log-Likelihood: -498.8582868210604| Proposal [0.12733519 0.17361259]
# iteration: 2260| Acceptance rate: 0.39557522123893807| Log-Likelihood: -497.6001299061683| Proposal [0.07996795 0.24965167]
# iteration: 2270| Acceptance rate: 0.39559471365638765| Log-Likelihood: -498.11172656207054| Proposal [0.06946171 0.21637913]
# iteration: 2280| Acceptance rate: 0.39473684210526316| Log-Likelihood: -497.69484030638523| Proposal [0.08562596 0.20370199]
# iteration: 2290| Acceptance rate: 0.3951965065502183| Log-Likelihood: -496.7787465156605| Proposal [0.08066692 0.2794009 ]
# iteration: 2300| Acceptance rate: 0.39521739130434785| Log-Likelihood: -498.1729292553215| Proposal [0.05815488 0.27445575]
# iteration: 2310| Acceptance rate: 0.3939393939393939| Log-Likelihood: -498.7217274382334| Proposal [0.07359101 0.16596674]
# iteration: 2320| Acceptance rate: 0.39439655172413796| Log-Likelihood: -497.8593270713006| Proposal [0.09925032 0.24923264]
# iteration: 2330| Acceptance rate: 0.39527896995708156| Log-Likelihood: -498.68641329234066| Proposal [0.09208153 0.1738938 ]
# iteration: 2340| Acceptance rate: 0.3952991452991453| Log-Likelihood: -498.44172599642195| Proposal [0.1084769  0.21944372]
# iteration: 2350| Acceptance rate: 0.3953191489361702| Log-Likelihood: -497.03710903006186| Proposal [0.06873792 0.25937594]
# iteration: 2360| Acceptance rate: 0.3961864406779661| Log-Likelihood: -499.43874082399947| Proposal [0.05556549 0.2646266 ]
# iteration: 2370| Acceptance rate: 0.3957805907172996| Log-Likelihood: -497.154291688425| Proposal [0.08550378 0.23479028]
# iteration: 2380| Acceptance rate: 0.3953781512605042| Log-Likelihood: -498.23136036922085| Proposal [0.09142529 0.17982424]
# iteration: 2390| Acceptance rate: 0.396234309623431| Log-Likelihood: -498.3631699991554| Proposal [0.11434763 0.17807186]
# iteration: 2400| Acceptance rate: 0.3954166666666667| Log-Likelihood: -497.6326583151378| Proposal [0.08431108 0.22184881]
# iteration: 2410| Acceptance rate: 0.3946058091286307| Log-Likelihood: -496.7594061797316| Proposal [0.07618507 0.27050356]
# iteration: 2420| Acceptance rate: 0.3933884297520661| Log-Likelihood: -497.40250059197746| Proposal [0.07148141 0.27807089]
# iteration: 2430| Acceptance rate: 0.39382716049382716| Log-Likelihood: -496.73060420098716| Proposal [0.08920411 0.30281091]
# iteration: 2440| Acceptance rate: 0.3930327868852459| Log-Likelihood: -496.91865998560445| Proposal [0.08092033 0.2605171 ]
# iteration: 2450| Acceptance rate: 0.39387755102040817| Log-Likelihood: -497.42807899589246| Proposal [0.09003939 0.28235485]
# iteration: 2460| Acceptance rate: 0.3943089430894309| Log-Likelihood: -497.6515837983987| Proposal [0.09416294 0.24191294]
# iteration: 2470| Acceptance rate: 0.3951417004048583| Log-Likelihood: -497.7188963004775| Proposal [0.09122447 0.25551289]
# iteration: 2480| Acceptance rate: 0.39556451612903226| Log-Likelihood: -497.07696092609| Proposal [0.07093567 0.26471761]
# iteration: 2490| Acceptance rate: 0.39598393574297186| Log-Likelihood: -496.5794805565687| Proposal [0.07495474 0.28986574]
# iteration: 2500| Acceptance rate: 0.3972| Log-Likelihood: -496.96316363074686| Proposal [0.07253374 0.28204928]
# iteration: 2510| Acceptance rate: 0.398804780876494| Log-Likelihood: -498.555144149758| Proposal [0.11867666 0.17742775]
# iteration: 2520| Acceptance rate: 0.3984126984126984| Log-Likelihood: -497.9479622107931| Proposal [0.06745998 0.24916317]
# iteration: 2530| Acceptance rate: 0.39881422924901183| Log-Likelihood: -499.11981164229525| Proposal [0.10769    0.11220285]
# iteration: 2540| Acceptance rate: 0.39960629921259844| Log-Likelihood: -497.18952940381695| Proposal [0.06490486 0.32941712]
# iteration: 2550| Acceptance rate: 0.3988235294117647| Log-Likelihood: -496.98340774477765| Proposal [0.06313229 0.31340487]
# iteration: 2560| Acceptance rate: 0.398046875| Log-Likelihood: -497.2497553790167| Proposal [0.09067568 0.28493265]
# iteration: 2570| Acceptance rate: 0.39727626459143967| Log-Likelihood: -497.2965767822906| Proposal [0.08301172 0.31303692]
# iteration: 2580| Acceptance rate: 0.39767441860465114| Log-Likelihood: -497.96447136747736| Proposal [0.10112913 0.26668849]
# iteration: 2590| Acceptance rate: 0.3992277992277992| Log-Likelihood: -497.28750358228257| Proposal [0.06495361 0.27468405]
# iteration: 2600| Acceptance rate: 0.3984615384615385| Log-Likelihood: -498.9210811959933| Proposal [0.0558715  0.28551278]
# iteration: 2610| Acceptance rate: 0.3992337164750958| Log-Likelihood: -497.31128166360634| Proposal [0.08713424 0.27033725]
# iteration: 2620| Acceptance rate: 0.39923664122137403| Log-Likelihood: -496.7459126483906| Proposal [0.07204763 0.30272408]
# iteration: 2630| Acceptance rate: 0.3988593155893536| Log-Likelihood: -497.3520225363387| Proposal [0.06762102 0.27978082]
# iteration: 2640| Acceptance rate: 0.39924242424242423| Log-Likelihood: -496.45158675099526| Proposal [0.07538633 0.29096407]
# iteration: 2650| Acceptance rate: 0.3992452830188679| Log-Likelihood: -498.08441411377675| Proposal [0.06469346 0.22545023]
# iteration: 2660| Acceptance rate: 0.40075187969924814| Log-Likelihood: -499.3600807288203| Proposal [0.12495305 0.2584085 ]
# iteration: 2670| Acceptance rate: 0.400374531835206| Log-Likelihood: -497.2981712645851| Proposal [0.07503393 0.22499016]
# iteration: 2680| Acceptance rate: 0.40186567164179104| Log-Likelihood: -496.9179068358406| Proposal [0.08596564 0.31111995]
# iteration: 2690| Acceptance rate: 0.40111524163568774| Log-Likelihood: -497.4082380774339| Proposal [0.0610631  0.30798744]
# iteration: 2700| Acceptance rate: 0.4011111111111111| Log-Likelihood: -497.333234587732| Proposal [0.08606647 0.2237616 ]
# iteration: 2710| Acceptance rate: 0.4011070110701107| Log-Likelihood: -500.06962297634834| Proposal [0.14219945 0.23181956]
# iteration: 2720| Acceptance rate: 0.40147058823529413| Log-Likelihood: -497.27780891004284| Proposal [0.08356683 0.290671  ]
# iteration: 2730| Acceptance rate: 0.4014652014652015| Log-Likelihood: -496.7714953444677| Proposal [0.06882552 0.28370584]
# iteration: 2740| Acceptance rate: 0.40072992700729926| Log-Likelihood: -497.227289176888| Proposal [0.09063962 0.27453661]
# iteration: 2750| Acceptance rate: 0.3996363636363636| Log-Likelihood: -497.1968650272533| Proposal [0.08841656 0.32684437]
# iteration: 2760| Acceptance rate: 0.39891304347826084| Log-Likelihood: -497.40576731763974| Proposal [0.08688376 0.28513223]
# iteration: 2770| Acceptance rate: 0.3989169675090253| Log-Likelihood: -497.7504317766667| Proposal [0.08138299 0.19955104]
# iteration: 2780| Acceptance rate: 0.3989208633093525| Log-Likelihood: -497.8019907973929| Proposal [0.09500461 0.18535833]
# iteration: 2790| Acceptance rate: 0.3985663082437276| Log-Likelihood: -497.8746147286139| Proposal [0.0994131  0.25813295]
# iteration: 2800| Acceptance rate: 0.3985714285714286| Log-Likelihood: -498.4641571327598| Proposal [0.10239068 0.20634383]
# iteration: 2810| Acceptance rate: 0.398576512455516| Log-Likelihood: -498.1360383205494| Proposal [0.1030928  0.19286732]
# iteration: 2820| Acceptance rate: 0.4| Log-Likelihood: -497.3558602019342| Proposal [0.08358011 0.30310313]
# iteration: 2830| Acceptance rate: 0.4| Log-Likelihood: -500.2736362742787| Proposal [0.13506058 0.30085232]
# iteration: 2840| Acceptance rate: 0.4007042253521127| Log-Likelihood: -496.5290768503652| Proposal [0.07624377 0.2792118 ]
# iteration: 2850| Acceptance rate: 0.39964912280701753| Log-Likelihood: -496.39140419694013| Proposal [0.07321573 0.28372427]
# iteration: 2860| Acceptance rate: 0.39895104895104894| Log-Likelihood: -497.62157139373477| Proposal [0.0701784  0.21160523]
# iteration: 2870| Acceptance rate: 0.3979094076655052| Log-Likelihood: -496.94867785796134| Proposal [0.0734765  0.27773028]
# iteration: 2880| Acceptance rate: 0.39826388888888886| Log-Likelihood: -497.1823398581725| Proposal [0.09293469 0.22483607]
# iteration: 2890| Acceptance rate: 0.3986159169550173| Log-Likelihood: -496.73401649435516| Proposal [0.07493289 0.25414305]
# iteration: 2900| Acceptance rate: 0.3986206896551724| Log-Likelihood: -499.5083780333339| Proposal [0.12611875 0.15777066]
# iteration: 2910| Acceptance rate: 0.39862542955326463| Log-Likelihood: -496.4031794461991| Proposal [0.07904624 0.28485243]
# iteration: 2920| Acceptance rate: 0.39794520547945206| Log-Likelihood: -497.13824421867207| Proposal [0.08751944 0.24623234]
# iteration: 2930| Acceptance rate: 0.39761092150170646| Log-Likelihood: -496.65267497039906| Proposal [0.07893448 0.24040601]
# iteration: 2940| Acceptance rate: 0.39693877551020407| Log-Likelihood: -496.7645178327192| Proposal [0.06982275 0.28520052]
# iteration: 2950| Acceptance rate: 0.39728813559322035| Log-Likelihood: -498.0134275400429| Proposal [0.05690299 0.33081525]
# iteration: 2960| Acceptance rate: 0.3972972972972973| Log-Likelihood: -497.3252903061673| Proposal [0.07972919 0.20233469]
# iteration: 2970| Acceptance rate: 0.397979797979798| Log-Likelihood: -498.8347315373292| Proposal [0.06246289 0.16918561]
# iteration: 2980| Acceptance rate: 0.39798657718120806| Log-Likelihood: -498.2779300384937| Proposal [0.07791737 0.1688938 ]
# iteration: 2990| Acceptance rate: 0.3986622073578595| Log-Likelihood: -496.8312201103756| Proposal [0.06824332 0.29473622]
# iteration: 3000| Acceptance rate: 0.39866666666666667| Log-Likelihood: -498.71226798596973| Proposal [0.06354947 0.16587483]
# iteration: 3010| Acceptance rate: 0.39867109634551495| Log-Likelihood: -497.96374862750315| Proposal [0.08040863 0.22270328]
# iteration: 3020| Acceptance rate: 0.3980132450331126| Log-Likelihood: -497.4609367220273| Proposal [0.0701869  0.20751638]
# iteration: 3030| Acceptance rate: 0.39900990099009903| Log-Likelihood: -496.738100134148| Proposal [0.09240787 0.30548366]
# iteration: 3040| Acceptance rate: 0.3986842105263158| Log-Likelihood: -497.3145308691548| Proposal [0.06874492 0.23676064]
# iteration: 3050| Acceptance rate: 0.3980327868852459| Log-Likelihood: -496.88816011517935| Proposal [0.06725315 0.27647141]
# iteration: 3060| Acceptance rate: 0.39869281045751637| Log-Likelihood: -497.8428401176814| Proposal [0.08752698 0.20864869]
# iteration: 3070| Acceptance rate: 0.398371335504886| Log-Likelihood: -497.60035384423355| Proposal [0.09886547 0.32624659]
# iteration: 3080| Acceptance rate: 0.3977272727272727| Log-Likelihood: -498.69363690465605| Proposal [0.06728634 0.17077903]
# iteration: 3090| Acceptance rate: 0.3977346278317152| Log-Likelihood: -497.7215318553817| Proposal [0.06188406 0.30635066]
# iteration: 3100| Acceptance rate: 0.39838709677419354| Log-Likelihood: -497.1182025876474| Proposal [0.07827351 0.23513428]
# iteration: 3110| Acceptance rate: 0.3990353697749196| Log-Likelihood: -498.56310099008095| Proposal [0.11346335 0.17929877]
# iteration: 3120| Acceptance rate: 0.3993589743589744| Log-Likelihood: -497.1702093905935| Proposal [0.07510194 0.25061021]
# iteration: 3130| Acceptance rate: 0.3987220447284345| Log-Likelihood: -496.6258044684841| Proposal [0.08218816 0.31047779]
# iteration: 3140| Acceptance rate: 0.39840764331210193| Log-Likelihood: -497.03679735460213| Proposal [0.0862047  0.27470642]
# iteration: 3150| Acceptance rate: 0.3977777777777778| Log-Likelihood: -496.98180587933416| Proposal [0.06737365 0.31961279]
# iteration: 3160| Acceptance rate: 0.3977848101265823| Log-Likelihood: -497.8393993423517| Proposal [0.08177286 0.22661446]
# iteration: 3170| Acceptance rate: 0.39747634069400634| Log-Likelihood: -498.34115109066715| Proposal [0.10636221 0.22132234]
# iteration: 3180| Acceptance rate: 0.3977987421383648| Log-Likelihood: -497.2811295001491| Proposal [0.0728529  0.25346351]
# iteration: 3190| Acceptance rate: 0.3978056426332288| Log-Likelihood: -496.86104297480426| Proposal [0.07596165 0.30492956]
# iteration: 3200| Acceptance rate: 0.3971875| Log-Likelihood: -496.90569217210873| Proposal [0.08835894 0.28522825]
# iteration: 3210| Acceptance rate: 0.39626168224299063| Log-Likelihood: -497.25855374815785| Proposal [0.06634098 0.26444353]
# iteration: 3220| Acceptance rate: 0.39658385093167703| Log-Likelihood: -497.2623632886949| Proposal [0.08707646 0.28001903]
# iteration: 3230| Acceptance rate: 0.39690402476780184| Log-Likelihood: -497.604190580387| Proposal [0.08961128 0.28953568]
# iteration: 3240| Acceptance rate: 0.3966049382716049| Log-Likelihood: -497.3820647013405| Proposal [0.07837635 0.25095642]
# iteration: 3250| Acceptance rate: 0.39692307692307693| Log-Likelihood: -497.5110088038315| Proposal [0.08624809 0.26471142]
# iteration: 3260| Acceptance rate: 0.39723926380368096| Log-Likelihood: -498.8997505226199| Proposal [0.10790249 0.14964733]
# iteration: 3270| Acceptance rate: 0.39694189602446484| Log-Likelihood: -496.7610244339861| Proposal [0.07238833 0.24421857]
# iteration: 3280| Acceptance rate: 0.39634146341463417| Log-Likelihood: -497.39869260316823| Proposal [0.05965898 0.33290364]
# iteration: 3290| Acceptance rate: 0.396048632218845| Log-Likelihood: -497.5909072446133| Proposal [0.08647178 0.20874449]
# iteration: 3300| Acceptance rate: 0.39606060606060606| Log-Likelihood: -497.49128493658833| Proposal [0.08894361 0.31356705]
# iteration: 3310| Acceptance rate: 0.3957703927492447| Log-Likelihood: -497.28813947892183| Proposal [0.08160017 0.25902281]
# iteration: 3320| Acceptance rate: 0.3960843373493976| Log-Likelihood: -496.63762894603576| Proposal [0.07433873 0.31194128]
# iteration: 3330| Acceptance rate: 0.3960960960960961| Log-Likelihood: -497.23301824916734| Proposal [0.0887963  0.31872054]
# iteration: 3340| Acceptance rate: 0.39580838323353296| Log-Likelihood: -496.739108830089| Proposal [0.07168115 0.25481204]
# iteration: 3350| Acceptance rate: 0.3946268656716418| Log-Likelihood: -496.739108830089| Proposal [0.07168115 0.25481204]
# iteration: 3360| Acceptance rate: 0.3952380952380952| Log-Likelihood: -497.08773668777235| Proposal [0.07002283 0.2790309 ]
# iteration: 3370| Acceptance rate: 0.39465875370919884| Log-Likelihood: -498.38675657009| Proposal [0.05944138 0.32056135]
# iteration: 3380| Acceptance rate: 0.3946745562130177| Log-Likelihood: -496.6221868957758| Proposal [0.0818698  0.27395778]
# iteration: 3390| Acceptance rate: 0.3952802359882006| Log-Likelihood: -498.663429193676| Proposal [0.11351885 0.24144455]
# iteration: 3400| Acceptance rate: 0.3952941176470588| Log-Likelihood: -498.0449763167509| Proposal [0.10199538 0.2708406 ]
# iteration: 3410| Acceptance rate: 0.39501466275659824| Log-Likelihood: -496.9456504444312| Proposal [0.0806612  0.32959307]
# iteration: 3420| Acceptance rate: 0.393859649122807| Log-Likelihood: -496.9456504444312| Proposal [0.0806612  0.32959307]
# iteration: 3430| Acceptance rate: 0.3932944606413994| Log-Likelihood: -497.7402126522362| Proposal [0.07132214 0.18130436]
# iteration: 3440| Acceptance rate: 0.3944767441860465| Log-Likelihood: -498.44988271577574| Proposal [0.06885423 0.18765711]
# iteration: 3450| Acceptance rate: 0.3944927536231884| Log-Likelihood: -497.9484322193962| Proposal [0.09515176 0.24188135]
# iteration: 3460| Acceptance rate: 0.3945086705202312| Log-Likelihood: -496.25512563262464| Proposal [0.07437936 0.3293234 ]
# iteration: 3470| Acceptance rate: 0.39337175792507206| Log-Likelihood: -496.25512563262464| Proposal [0.07437936 0.3293234 ]
# iteration: 3480| Acceptance rate: 0.392816091954023| Log-Likelihood: -496.9087074441003| Proposal [0.08427826 0.30149366]
# iteration: 3490| Acceptance rate: 0.392836676217765| Log-Likelihood: -497.4510376446125| Proposal [0.08927281 0.32145981]
# iteration: 3500| Acceptance rate: 0.39285714285714285| Log-Likelihood: -497.43231124379713| Proposal [0.08773    0.31657972]
# iteration: 3510| Acceptance rate: 0.39373219373219376| Log-Likelihood: -497.27764405493735| Proposal [0.06611204 0.2623125 ]
# iteration: 3520| Acceptance rate: 0.39375| Log-Likelihood: -497.4158413023959| Proposal [0.09256967 0.3247999 ]
# iteration: 3530| Acceptance rate: 0.3943342776203966| Log-Likelihood: -497.6003261652089| Proposal [0.09777224 0.27668729]
# iteration: 3540| Acceptance rate: 0.3940677966101695| Log-Likelihood: -497.08088115200604| Proposal [0.08399408 0.3065647 ]
# iteration: 3550| Acceptance rate: 0.3946478873239437| Log-Likelihood: -498.41587958614537| Proposal [0.09609271 0.17452069]
# iteration: 3560| Acceptance rate: 0.3946629213483146| Log-Likelihood: -499.071684894461| Proposal [0.12708201 0.21346084]
# iteration: 3570| Acceptance rate: 0.3938375350140056| Log-Likelihood: -497.80586014190544| Proposal [0.09640685 0.27823437]
# iteration: 3580| Acceptance rate: 0.3935754189944134| Log-Likelihood: -496.54281093180293| Proposal [0.07961887 0.32021576]
# iteration: 3590| Acceptance rate: 0.3935933147632312| Log-Likelihood: -498.7215903312857| Proposal [0.11613539 0.16580586]
# iteration: 3600| Acceptance rate: 0.39361111111111113| Log-Likelihood: -498.02961783910007| Proposal [0.08115187 0.16235495]
# iteration: 3610| Acceptance rate: 0.39362880886426593| Log-Likelihood: -498.529678129275| Proposal [0.11192132 0.15417614]
# iteration: 3620| Acceptance rate: 0.3930939226519337| Log-Likelihood: -497.3663863049136| Proposal [0.07323438 0.22937769]
# iteration: 3630| Acceptance rate: 0.3928374655647383| Log-Likelihood: -497.71714647526295| Proposal [0.08886939 0.28239938]
# iteration: 3640| Acceptance rate: 0.3931318681318681| Log-Likelihood: -497.8169065517241| Proposal [0.10300017 0.2672762 ]
# iteration: 3650| Acceptance rate: 0.39315068493150684| Log-Likelihood: -498.8822327166612| Proposal [0.11804362 0.14490924]
# iteration: 3660| Acceptance rate: 0.39344262295081966| Log-Likelihood: -498.26234315887984| Proposal [0.1029715  0.22061699]
# iteration: 3670| Acceptance rate: 0.39291553133514984| Log-Likelihood: -497.6648112866976| Proposal [0.06209438 0.25726891]
# iteration: 3680| Acceptance rate: 0.39293478260869563| Log-Likelihood: -496.48906457644523| Proposal [0.07046727 0.32225935]
# iteration: 3690| Acceptance rate: 0.3932249322493225| Log-Likelihood: -499.73668048355194| Proposal [0.1229903  0.08491627]
# iteration: 3700| Acceptance rate: 0.3927027027027027| Log-Likelihood: -496.8394264154361| Proposal [0.08302431 0.30002987]
# iteration: 3710| Acceptance rate: 0.3921832884097035| Log-Likelihood: -498.0248344252517| Proposal [0.06417722 0.25198917]
# iteration: 3720| Acceptance rate: 0.3922043010752688| Log-Likelihood: -498.67449722306606| Proposal [0.10341249 0.19220586]
# iteration: 3730| Acceptance rate: 0.39195710455764077| Log-Likelihood: -496.83483157037716| Proposal [0.07188156 0.31243631]
# iteration: 3740| Acceptance rate: 0.3911764705882353| Log-Likelihood: -496.5525843923572| Proposal [0.06621178 0.28827253]
# iteration: 3750| Acceptance rate: 0.3917333333333333| Log-Likelihood: -498.9831846922355| Proposal [0.10785609 0.14635018]
# iteration: 3760| Acceptance rate: 0.39095744680851063| Log-Likelihood: -496.9167909051205| Proposal [0.06874402 0.22803274]
# iteration: 3770| Acceptance rate: 0.39098143236074273| Log-Likelihood: -498.5371515363118| Proposal [0.10472304 0.24310512]
# iteration: 3780| Acceptance rate: 0.3917989417989418| Log-Likelihood: -497.109447614487| Proposal [0.06994116 0.23732559]
# iteration: 3790| Acceptance rate: 0.39155672823218995| Log-Likelihood: -496.7296135377941| Proposal [0.07327872 0.28507149]
# iteration: 3800| Acceptance rate: 0.391578947368421| Log-Likelihood: -498.471842172841| Proposal [0.06184081 0.25110779]
# iteration: 3810| Acceptance rate: 0.39133858267716537| Log-Likelihood: -498.0260483824385| Proposal [0.06143713 0.25950448]
# iteration: 3820| Acceptance rate: 0.3913612565445026| Log-Likelihood: -497.7106164307554| Proposal [0.09432003 0.25627373]
# iteration: 3830| Acceptance rate: 0.3908616187989556| Log-Likelihood: -497.1247297956387| Proposal [0.07023811 0.30055717]
# iteration: 3840| Acceptance rate: 0.39010416666666664| Log-Likelihood: -496.4429853502392| Proposal [0.07334276 0.31386571]
# iteration: 3850| Acceptance rate: 0.38961038961038963| Log-Likelihood: -497.6447462346084| Proposal [0.07002795 0.20793879]
# iteration: 3860| Acceptance rate: 0.3893782383419689| Log-Likelihood: -497.9126861007673| Proposal [0.06948814 0.2029169 ]
# iteration: 3870| Acceptance rate: 0.39018087855297157| Log-Likelihood: -497.48075930601976| Proposal [0.07894209 0.21780518]
# iteration: 3880| Acceptance rate: 0.3904639175257732| Log-Likelihood: -497.22574028316774| Proposal [0.09003345 0.28124881]
# iteration: 3890| Acceptance rate: 0.390745501285347| Log-Likelihood: -500.6798688362063| Proposal [0.05431385 0.23980137]
# iteration: 3900| Acceptance rate: 0.3912820512820513| Log-Likelihood: -496.862723788797| Proposal [0.07645869 0.31923765]
# iteration: 3910| Acceptance rate: 0.3907928388746803| Log-Likelihood: -497.14520445384943| Proposal [0.09078438 0.30226817]
# iteration: 3920| Acceptance rate: 0.39132653061224487| Log-Likelihood: -498.6149252245731| Proposal [0.11272263 0.20655972]
# ...
# iteration: 8710| Acceptance rate: 0.38025258323765787| Log-Likelihood: -498.24459989596903| Proposal [0.10349043 0.2896955 ]
# iteration: 8720| Acceptance rate: 0.3801605504587156| Log-Likelihood: -497.7776925207063| Proposal [0.07934852 0.23613265]
# iteration: 8730| Acceptance rate: 0.38006872852233675| Log-Likelihood: -497.3678115527963| Proposal [0.09510412 0.32247778]
# iteration: 8740| Acceptance rate: 0.38009153318077804| Log-Likelihood: -498.0202320550413| Proposal [0.10427297 0.28095539]
# iteration: 8750| Acceptance rate: 0.3802285714285714| Log-Likelihood: -499.8068596334929| Proposal [0.13746767 0.24488662]
# iteration: 8760| Acceptance rate: 0.38036529680365294| Log-Likelihood: -497.6887114779475| Proposal [0.0957058  0.28871904]
# iteration: 8770| Acceptance rate: 0.38038768529076394| Log-Likelihood: -499.3716988028981| Proposal [0.11320442 0.12760529]
# iteration: 8780| Acceptance rate: 0.3804100227790433| Log-Likelihood: -497.2631811958521| Proposal [0.09129302 0.27413362]
# iteration: 8790| Acceptance rate: 0.3802047781569966| Log-Likelihood: -496.44530373049474| Proposal [0.07462385 0.32522297]
# iteration: 8800| Acceptance rate: 0.3801136363636364| Log-Likelihood: -497.45987019309746| Proposal [0.08896096 0.29082261]
# iteration: 8810| Acceptance rate: 0.3800227014755959| Log-Likelihood: -497.0047949496154| Proposal [0.07922345 0.25095325]
# iteration: 8820| Acceptance rate: 0.3800453514739229| Log-Likelihood: -497.32129370416135| Proposal [0.08693694 0.2604906 ]
# iteration: 8830| Acceptance rate: 0.38029445073612683| Log-Likelihood: -497.16342457292757| Proposal [0.07802738 0.23829583]
# iteration: 8840| Acceptance rate: 0.38020361990950224| Log-Likelihood: -497.08085226419547| Proposal [0.06695631 0.3269384 ]
# iteration: 8850| Acceptance rate: 0.3801129943502825| Log-Likelihood: -498.9402550990648| Proposal [0.11457932 0.21939883]
# iteration: 8860| Acceptance rate: 0.37990970654627537| Log-Likelihood: -499.0515577843747| Proposal [0.07549584 0.1634273 ]
# iteration: 8870| Acceptance rate: 0.37993235625704624| Log-Likelihood: -499.0931885043391| Proposal [0.12251786 0.22088367]
# iteration: 8880| Acceptance rate: 0.37995495495495496| Log-Likelihood: -497.83665519951387| Proposal [0.08703842 0.21192692]
# iteration: 8890| Acceptance rate: 0.38020247469066365| Log-Likelihood: -496.9672550200653| Proposal [0.0859536  0.29530843]
# iteration: 8900| Acceptance rate: 0.38033707865168537| Log-Likelihood: -497.3813445817841| Proposal [0.09480546 0.31426895]
# iteration: 8910| Acceptance rate: 0.38002244668911334| Log-Likelihood: -496.2991387176826| Proposal [0.07572736 0.31730015]
# iteration: 8920| Acceptance rate: 0.3797085201793722| Log-Likelihood: -497.5684299584996| Proposal [0.08102888 0.20975664]
# iteration: 8930| Acceptance rate: 0.3795072788353863| Log-Likelihood: -498.7843883598289| Proposal [0.12017397 0.19017899]
# iteration: 8940| Acceptance rate: 0.3794183445190157| Log-Likelihood: -497.2575197029719| Proposal [0.09153712 0.32444942]
# iteration: 8950| Acceptance rate: 0.3793296089385475| Log-Likelihood: -498.5682970579953| Proposal [0.10734598 0.31151212]
# iteration: 8960| Acceptance rate: 0.37924107142857144| Log-Likelihood: -497.43443345853143| Proposal [0.07303223 0.23303853]
# iteration: 8970| Acceptance rate: 0.3793756967670011| Log-Likelihood: -498.93570640358956| Proposal [0.0803025  0.16546321]
# iteration: 8980| Acceptance rate: 0.3792873051224944| Log-Likelihood: -498.1028294756856| Proposal [0.07538739 0.19179765]
# iteration: 8990| Acceptance rate: 0.3789766407119021| Log-Likelihood: -500.34694089086656| Proposal [0.09638294 0.11327769]
# iteration: 9000| Acceptance rate: 0.3788888888888889| Log-Likelihood: -499.01408838006705| Proposal [0.12085147 0.22628812]
# iteration: 9010| Acceptance rate: 0.37891231964483907| Log-Likelihood: -496.5786480620234| Proposal [0.06481033 0.32400517]
# iteration: 9020| Acceptance rate: 0.3784922394678492| Log-Likelihood: -496.5786480620234| Proposal [0.06481033 0.32400517]
# iteration: 9030| Acceptance rate: 0.37829457364341085| Log-Likelihood: -498.524687114774| Proposal [0.0918474  0.22735985]
# iteration: 9040| Acceptance rate: 0.37831858407079644| Log-Likelihood: -498.2695299296642| Proposal [0.07062174 0.20594463]
# iteration: 9050| Acceptance rate: 0.378232044198895| Log-Likelihood: -496.86235020213405| Proposal [0.07751174 0.31573235]
# iteration: 9060| Acceptance rate: 0.3781456953642384| Log-Likelihood: -497.42028509549846| Proposal [0.08986003 0.20486015]
# iteration: 9070| Acceptance rate: 0.37805953693495037| Log-Likelihood: -497.6939318305515| Proposal [0.0632446  0.21954396]
# iteration: 9080| Acceptance rate: 0.37808370044052864| Log-Likelihood: -497.207762728376| Proposal [0.08072788 0.2503845 ]
# iteration: 9090| Acceptance rate: 0.37777777777777777| Log-Likelihood: -497.8516623138911| Proposal [0.08225017 0.20710639]
# iteration: 9100| Acceptance rate: 0.3778021978021978| Log-Likelihood: -498.76753984522907| Proposal [0.10608919 0.30013868]
# iteration: 9110| Acceptance rate: 0.3777167947310648| Log-Likelihood: -496.87850558993205| Proposal [0.08185873 0.30533104]
# iteration: 9120| Acceptance rate: 0.37763157894736843| Log-Likelihood: -496.43990750920096| Proposal [0.07246421 0.31743362]
# iteration: 9130| Acceptance rate: 0.37765607886089814| Log-Likelihood: -498.61488530074325| Proposal [0.1287405  0.13796906]
# iteration: 9140| Acceptance rate: 0.3773522975929978| Log-Likelihood: -496.576156251363| Proposal [0.07885039 0.30850812]
# iteration: 9150| Acceptance rate: 0.37726775956284153| Log-Likelihood: -498.48259647612383| Proposal [0.10758515 0.18424184]
# iteration: 9160| Acceptance rate: 0.377292576419214| Log-Likelihood: -496.85725267127003| Proposal [0.08434138 0.32944049]
# iteration: 9170| Acceptance rate: 0.37688113413304253| Log-Likelihood: -496.85725267127003| Proposal [0.08434138 0.32944049]
# iteration: 9180| Acceptance rate: 0.37668845315904137| Log-Likelihood: -497.84658002161564| Proposal [0.09268991 0.26805925]
# iteration: 9190| Acceptance rate: 0.376822633297062| Log-Likelihood: -497.2418363362975| Proposal [0.07811762 0.28821628]
# iteration: 9200| Acceptance rate: 0.3765217391304348| Log-Likelihood: -497.5405615649091| Proposal [0.09205678 0.24340357]
# iteration: 9210| Acceptance rate: 0.37654723127035833| Log-Likelihood: -496.5301539894056| Proposal [0.07404134 0.32424156]
# iteration: 9220| Acceptance rate: 0.37613882863340564| Log-Likelihood: -496.5301539894056| Proposal [0.07404134 0.32424156]
# iteration: 9230| Acceptance rate: 0.376056338028169| Log-Likelihood: -496.79597256828396| Proposal [0.06938732 0.25682357]
# iteration: 9240| Acceptance rate: 0.3762987012987013| Log-Likelihood: -498.2543547070651| Proposal [0.08653595 0.17425152]
# iteration: 9250| Acceptance rate: 0.37654054054054054| Log-Likelihood: -497.0680544134633| Proposal [0.06618327 0.33326147]
# iteration: 9260| Acceptance rate: 0.3765658747300216| Log-Likelihood: -497.2125919103472| Proposal [0.08867974 0.29670713]
# iteration: 9270| Acceptance rate: 0.37648327939590076| Log-Likelihood: -496.90495910357265| Proposal [0.0850155  0.25160518]
# iteration: 9280| Acceptance rate: 0.3762931034482759| Log-Likelihood: -497.0906646838057| Proposal [0.08274661 0.27939523]
# iteration: 9290| Acceptance rate: 0.37642626480086117| Log-Likelihood: -497.70461906634546| Proposal [0.09504257 0.28371324]
# iteration: 9300| Acceptance rate: 0.37655913978494626| Log-Likelihood: -497.1196749979147| Proposal [0.06424872 0.32622177]
# iteration: 9310| Acceptance rate: 0.3762620837808808| Log-Likelihood: -497.1813575043459| Proposal [0.06749804 0.2474352 ]
# iteration: 9320| Acceptance rate: 0.3765021459227468| Log-Likelihood: -499.47734704885| Proposal [0.13815089 0.17277997]
# iteration: 9330| Acceptance rate: 0.3766345123258307| Log-Likelihood: -497.8286015685096| Proposal [0.1025341  0.22010605]
# iteration: 9340| Acceptance rate: 0.3764453961456103| Log-Likelihood: -497.4237384583902| Proposal [0.09201267 0.30467611]
# iteration: 9350| Acceptance rate: 0.3765775401069519| Log-Likelihood: -498.51430538144723| Proposal [0.10589244 0.32588158]
# iteration: 9360| Acceptance rate: 0.3766025641025641| Log-Likelihood: -497.6912594534097| Proposal [0.0980033  0.32314203]
# iteration: 9370| Acceptance rate: 0.3766275346851654| Log-Likelihood: -499.7399742855828| Proposal [0.13516907 0.07091885]
# iteration: 9380| Acceptance rate: 0.37665245202558634| Log-Likelihood: -496.78013646954105| Proposal [0.06643772 0.26924461]
# iteration: 9390| Acceptance rate: 0.37635782747603835| Log-Likelihood: -498.41310136919833| Proposal [0.10687389 0.17208757]
# iteration: 9400| Acceptance rate: 0.37627659574468086| Log-Likelihood: -497.940508642613| Proposal [0.05876836 0.314745  ]
# iteration: 9410| Acceptance rate: 0.3763018065887354| Log-Likelihood: -498.2153743286317| Proposal [0.10690596 0.27451326]
# iteration: 9420| Acceptance rate: 0.37622080679405523| Log-Likelihood: -498.2401499973572| Proposal [0.10880071 0.17576573]
# iteration: 9430| Acceptance rate: 0.37613997879109223| Log-Likelihood: -499.4800795506378| Proposal [0.10607221 0.12392909]
# iteration: 9440| Acceptance rate: 0.3763771186440678| Log-Likelihood: -499.32995244895835| Proposal [0.09489545 0.13302983]
# iteration: 9450| Acceptance rate: 0.3764021164021164| Log-Likelihood: -497.9317474653343| Proposal [0.09979427 0.31586598]
# iteration: 9460| Acceptance rate: 0.37621564482029596| Log-Likelihood: -498.01931464339214| Proposal [0.09249991 0.19123046]
# iteration: 9470| Acceptance rate: 0.37602956705385426| Log-Likelihood: -497.6577092535455| Proposal [0.08541865 0.19883877]
# iteration: 9480| Acceptance rate: 0.3758438818565401| Log-Likelihood: -496.7480165539945| Proposal [0.07939933 0.25676684]
# iteration: 9490| Acceptance rate: 0.3759747102212856| Log-Likelihood: -498.4732608900344| Proposal [0.07553302 0.17606034]
# iteration: 9500| Acceptance rate: 0.3758947368421053| Log-Likelihood: -497.9813077401849| Proposal [0.09152086 0.20099524]
# iteration: 9510| Acceptance rate: 0.37570977917981074| Log-Likelihood: -497.1105433318899| Proposal [0.07829814 0.26025793]
# iteration: 9520| Acceptance rate: 0.3754201680672269| Log-Likelihood: -496.78113087779604| Proposal [0.07716255 0.3305448 ]
# iteration: 9530| Acceptance rate: 0.37544596012591813| Log-Likelihood: -498.11186108693806| Proposal [0.10402534 0.31256399]
# iteration: 9540| Acceptance rate: 0.3752620545073375| Log-Likelihood: -496.8137129237495| Proposal [0.06716848 0.27488736]
# iteration: 9550| Acceptance rate: 0.374869109947644| Log-Likelihood: -496.8137129237495| Proposal [0.06716848 0.27488736]
# iteration: 9560| Acceptance rate: 0.3747907949790795| Log-Likelihood: -496.9854361729389| Proposal [0.06542351 0.31495823]
# iteration: 9570| Acceptance rate: 0.3748171368861024| Log-Likelihood: -497.3575829319916| Proposal [0.08473914 0.28018767]
# iteration: 9580| Acceptance rate: 0.3747390396659708| Log-Likelihood: -499.0573980248674| Proposal [0.06178369 0.20752447]
# iteration: 9590| Acceptance rate: 0.37476538060479664| Log-Likelihood: -496.71286769098094| Proposal [0.07338704 0.27481408]
# iteration: 9600| Acceptance rate: 0.3746875| Log-Likelihood: -497.77219623324845| Proposal [0.09081205 0.23948717]
# iteration: 9610| Acceptance rate: 0.37502601456815815| Log-Likelihood: -496.93809065536504| Proposal [0.08528945 0.29819275]
# iteration: 9620| Acceptance rate: 0.37484407484407484| Log-Likelihood: -497.39423636299045| Proposal [0.06302127 0.28552432]
# iteration: 9630| Acceptance rate: 0.3749740394600208| Log-Likelihood: -497.2128695787685| Proposal [0.06724005 0.29109074]
# iteration: 9640| Acceptance rate: 0.375103734439834| Log-Likelihood: -496.90973388537367| Proposal [0.07627513 0.2619064 ]
# iteration: 9650| Acceptance rate: 0.37523316062176165| Log-Likelihood: -497.1492138091416| Proposal [0.06313271 0.24817399]
# iteration: 9660| Acceptance rate: 0.3749482401656315| Log-Likelihood: -497.03706861061744| Proposal [0.07474324 0.27151305]
# iteration: 9670| Acceptance rate: 0.3750775594622544| Log-Likelihood: -496.5692293526696| Proposal [0.07430732 0.320023  ]
# iteration: 9680| Acceptance rate: 0.37541322314049586| Log-Likelihood: -497.52089539231144| Proposal [0.08711561 0.28571304]
# iteration: 9690| Acceptance rate: 0.37554179566563467| Log-Likelihood: -498.35020348026944| Proposal [0.07644565 0.16602877]
# iteration: 9700| Acceptance rate: 0.3756701030927835| Log-Likelihood: -496.8844298975238| Proposal [0.07738374 0.31520531]
# iteration: 9710| Acceptance rate: 0.3757981462409887| Log-Likelihood: -496.61388638423904| Proposal [0.0763895  0.30207184]
# iteration: 9720| Acceptance rate: 0.3758230452674897| Log-Likelihood: -496.5860266373284| Proposal [0.07407825 0.3283147 ]
# iteration: 9730| Acceptance rate: 0.37574511819116135| Log-Likelihood: -496.29751254292637| Proposal [0.07081136 0.33000949]
# iteration: 9740| Acceptance rate: 0.3760780287474333| Log-Likelihood: -496.91416153218677| Proposal [0.07865456 0.28219149]
# iteration: 9750| Acceptance rate: 0.3762051282051282| Log-Likelihood: -496.82248761347387| Proposal [0.06377621 0.31290963]
# iteration: 9760| Acceptance rate: 0.37633196721311474| Log-Likelihood: -497.8213790107884| Proposal [0.07507192 0.19348671]
# iteration: 9770| Acceptance rate: 0.37645854657113614| Log-Likelihood: -496.5468401063362| Proposal [0.06924047 0.33083828]
# iteration: 9780| Acceptance rate: 0.37648261758691204| Log-Likelihood: -498.02791641667255| Proposal [0.09847615 0.24457758]
# iteration: 9790| Acceptance rate: 0.376608784473953| Log-Likelihood: -496.90647590729895| Proposal [0.07204059 0.3035291 ]
# iteration: 9800| Acceptance rate: 0.3766326530612245| Log-Likelihood: -496.769444135071| Proposal [0.07792835 0.27727852]
# iteration: 9810| Acceptance rate: 0.3766564729867482| Log-Likelihood: -496.6738600751924| Proposal [0.06666026 0.31692879]
# iteration: 9820| Acceptance rate: 0.3769857433808554| Log-Likelihood: -497.64461782244774| Proposal [0.09202303 0.21364361]
# iteration: 9830| Acceptance rate: 0.3768056968463886| Log-Likelihood: -497.82719287395696| Proposal [0.10236302 0.32384676]
# iteration: 9840| Acceptance rate: 0.3773373983739837| Log-Likelihood: -498.61477779519566| Proposal [0.10914105 0.20776447]
# iteration: 9850| Acceptance rate: 0.37725888324873097| Log-Likelihood: -497.3794945846959| Proposal [0.07244534 0.25552934]
# iteration: 9860| Acceptance rate: 0.3772819472616633| Log-Likelihood: -496.83818747001203| Proposal [0.07729335 0.28857132]
# iteration: 9870| Acceptance rate: 0.3772036474164134| Log-Likelihood: -497.47119777138687| Proposal [0.08139135 0.22903527]
# iteration: 9880| Acceptance rate: 0.3770242914979757| Log-Likelihood: -496.77201595750466| Proposal [0.08779842 0.30236562]
# iteration: 9890| Acceptance rate: 0.37684529828109203| Log-Likelihood: -497.2899531259313| Proposal [0.08384276 0.26818297]
# iteration: 9900| Acceptance rate: 0.37707070707070706| Log-Likelihood: -497.47700732882106| Proposal [0.08301917 0.27075844]
# iteration: 9910| Acceptance rate: 0.3771947527749748| Log-Likelihood: -496.74648508220366| Proposal [0.07806552 0.30610803]
# iteration: 9920| Acceptance rate: 0.37691532258064514| Log-Likelihood: -496.6304438961312| Proposal [0.07511853 0.31741638]
# iteration: 9930| Acceptance rate: 0.3766364551863041| Log-Likelihood: -496.80418609930837| Proposal [0.08667081 0.30870295]
# iteration: 9940| Acceptance rate: 0.37645875251509053| Log-Likelihood: -497.64638991967706| Proposal [0.09582243 0.30373329]
# iteration: 9950| Acceptance rate: 0.37668341708542713| Log-Likelihood: -499.1225493831523| Proposal [0.11938703 0.26049819]
# iteration: 9960| Acceptance rate: 0.37690763052208837| Log-Likelihood: -497.3206380063403| Proposal [0.0872493  0.19659752]
# iteration: 9970| Acceptance rate: 0.37683049147442327| Log-Likelihood: -497.1288531311665| Proposal [0.07754576 0.2596191 ]
# iteration: 9980| Acceptance rate: 0.37675350701402804| Log-Likelihood: -497.9475825413052| Proposal [0.09952809 0.32514254]
# iteration: 9990| Acceptance rate: 0.3768768768768769| Log-Likelihood: -497.24130906566245| Proposal [0.08665884 0.30911588]
# 3444.7189156000386

# %%
burn_in = 0

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'])
# Out:
# -496.09774416571963
# The Maximum Likelihood Estimate is [0.07169028 0.33202457] w/ LL of -496.09774416571963

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\eta$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[2,burn_in:])} and std: {np.std(theta[2,burn_in:])}")
# plt.hist(theta[2,burn_in:],density=True,bins = 50)
# plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[3,burn_in:])} and std: {np.std(theta[3,burn_in:])}")
# plt.hist(theta[3,burn_in:],density=True,bins = 50)
# plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 148.41620533199142
# Root Mean Squared Error for beta 0.1429199774690791

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
'''Pair plots'''

plt.title('Pairwise Plot of $\\gamma$ and $\\eta$')
plt.xlabel('$\\eta$')
plt.ylabel('$\\gamma$')
plt.scatter(pmcmc_output['accepted_params'][0,burn_in:],pmcmc_output['accepted_params'][1,burn_in:],s=0.1)
