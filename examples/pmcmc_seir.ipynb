# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import gammaln_nr
from scipy.stats import poisson,nbinom,norm

# %%
'''Simulated Data, setting up the SIR model'''

rng = np.random.default_rng(0)

gamma = 1/14
eta = 1/7
q = 0.1
mu = 0.004
rho = 0.1

T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

N = 100_000
I = 5
E = 5


beta_par = {'b_0':0.4,'b_inf': 0.1, 'tau': 5,'T':20}

def beta_sim(par,t):
    if(t < par['T']):
        return 0.4
    
    return par['b_inf'] + (par['b_0'] - par['b_inf']) * np.exp(-(t - par['T'])/par['tau'])

betas = np.array([beta_sim(beta_par,t) for t in t_vec])

state = np.zeros((5,len(t_vec)))
state[:,0] = np.array([N - I - E,E, I, 0,0])

plt.title('Generative $\\beta_t$')
plt.xlabel('Time (Days)')
plt.plot(t_vec,betas)

for time_index in range(1,len(t_vec)):

    new_E = (betas[time_index - 1] * (state[1,time_index -1] + q * state[2,time_index - 1]) * state[0,time_index - 1]/np.sum(state[:,time_index-1])) * dt
    new_I = (eta * state[1,time_index - 1]) * dt
    new_ER = (gamma * state[1,time_index -1]) * dt
    new_IR = (gamma * state[2,time_index - 1]) * dt
    new_D = (mu * state[2,time_index - 1]) * dt


    state[0,time_index] = state[0,time_index - 1] - new_E #S 
    state[1,time_index] = state[1,time_index - 1] + new_E - new_I - new_ER
    state[2,time_index] = state[2,time_index-1] + new_I - new_IR - new_D
    state[3,time_index] = state[3,time_index - 1] + new_ER + new_IR #R
    state[4,time_index] = new_I

# %%
plt.yscale('log')
plt.title('Plot of SEIR Model')
plt.xlabel('Time (Days)')
plt.plot(state.T[:])
# Out:
# [<matplotlib.lines.Line2D at 0x12caec550>,
#  <matplotlib.lines.Line2D at 0x12cb204d0>,
#  <matplotlib.lines.Line2D at 0x12cb205d0>,
#  <matplotlib.lines.Line2D at 0x12cb20990>,
#  <matplotlib.lines.Line2D at 0x12cb04590>]

# %%
r = 50

data = np.expand_dims(rng.negative_binomial(n = r,p = r/(r + state[2,::int(1/dt)] + 0.005)),0)

#data = np.expand_dims(state[2,::int(1/dt)],0)

plt.title('Plot of Generative Data')
plt.xlabel('Time (Days)')
plt.ylabel('Case Count')
plt.plot(t_vec[::int(1/dt)],data.T)

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,eta,_ = model_params

    '''OU Process'''
    sig = 1.0
    mu = -2.0
    lam = 1/100

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((eta * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    #return norm.logpdf(data_point,loc = particle_observations[:,0],scale = np.sqrt(var))
    r = 1/model_params[2]
    weights = nbinom.logpmf(k = data_point,p = r/(r + particle_observations[:,0]),n = r)
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
#(0.06547914,0.28245005)
#(1/14 = 0.07,1/7 = 0.14)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':1000, 
                      'dt':0.1,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,eta,1/50),
        pf_params = pf_params,
        rng = rng,
        req_jit=False
        )

print(perf_counter() - t)
# Out:
# 22.611519730009604

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10532.963884408031
# Root Mean Squared Error for the Data 192.13417431682993

# %%
pmcmc_rng = np.random.default_rng(10)

num_particles = 1000

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 1/15.,max_val = 1/3) + uniform_numba_logpdf(theta[2],min_val = 0.,max_val = 1.)

pmcmc_params = {'iterations':2_000,
                'init_params':np.array([0.1,0.1,0.01]),
                'prior':seir_prior,
                'init_cov': np.diag([0.01,0.01,0.01]),
                'burn_in':100}

pf_params = {'num_particles':1_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=False
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -10539.448964870882| Proposal [0.1  0.1  0.01]
# iteration: 20| Acceptance rate: 0.05| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 30| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 40| Acceptance rate: 0.025| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 50| Acceptance rate: 0.02| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 60| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 70| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 80| Acceptance rate: 0.0125| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 90| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 100| Acceptance rate: 0.01| Log-Likelihood: -10533.590651417922| Proposal [0.07092807 0.1850572  0.03733039]
# iteration: 110| Acceptance rate: 0.01818181818181818| Log-Likelihood: -10528.677928931636| Proposal [0.05181918 0.12172659 0.02124115]
# iteration: 120| Acceptance rate: 0.05| Log-Likelihood: -10528.342409592928| Proposal [0.06689116 0.12412754 0.02068592]
# iteration: 130| Acceptance rate: 0.07692307692307693| Log-Likelihood: -10529.168176664916| Proposal [0.06298479 0.12276998 0.020238  ]
# iteration: 140| Acceptance rate: 0.14285714285714285| Log-Likelihood: -10529.516641101818| Proposal [0.06137109 0.12214274 0.02052226]
# iteration: 150| Acceptance rate: 0.18666666666666668| Log-Likelihood: -10529.712713604034| Proposal [0.06503924 0.12413279 0.02039567]
# iteration: 160| Acceptance rate: 0.21875| Log-Likelihood: -10530.097712635323| Proposal [0.0659125  0.1246672  0.02031924]
# iteration: 170| Acceptance rate: 0.2647058823529412| Log-Likelihood: -10529.670112223788| Proposal [0.0682252  0.12584968 0.02019731]
# iteration: 180| Acceptance rate: 0.2777777777777778| Log-Likelihood: -10530.106786282437| Proposal [0.06884622 0.12619101 0.02024679]
# iteration: 190| Acceptance rate: 0.3105263157894737| Log-Likelihood: -10531.092204936387| Proposal [0.07135282 0.12772808 0.02018086]
# iteration: 200| Acceptance rate: 0.32| Log-Likelihood: -10528.725883697038| Proposal [0.06895179 0.12627002 0.02009459]
# iteration: 210| Acceptance rate: 0.3142857142857143| Log-Likelihood: -10528.620807121251| Proposal [0.06463757 0.12375792 0.02015066]
# iteration: 220| Acceptance rate: 0.3181818181818182| Log-Likelihood: -10529.626602145625| Proposal [0.05607027 0.11874109 0.02026964]
# iteration: 230| Acceptance rate: 0.3391304347826087| Log-Likelihood: -10528.542825334105| Proposal [0.05996706 0.12094156 0.02011088]
# iteration: 240| Acceptance rate: 0.35833333333333334| Log-Likelihood: -10530.248454643512| Proposal [0.07149791 0.12779237 0.02003615]
# iteration: 250| Acceptance rate: 0.356| Log-Likelihood: -10529.742159931076| Proposal [0.05370892 0.11726335 0.02021233]
# iteration: 260| Acceptance rate: 0.3576923076923077| Log-Likelihood: -10531.086400162547| Proposal [0.04875465 0.11434684 0.02028419]
# iteration: 270| Acceptance rate: 0.362962962962963| Log-Likelihood: -10529.463741694815| Proposal [0.06288561 0.12265717 0.02012134]
# iteration: 280| Acceptance rate: 0.37142857142857144| Log-Likelihood: -10528.479186265105| Proposal [0.05773663 0.1195351  0.02016023]
# iteration: 290| Acceptance rate: 0.3620689655172414| Log-Likelihood: -10528.244516759823| Proposal [0.06201186 0.12202007 0.02010921]
# iteration: 300| Acceptance rate: 0.3566666666666667| Log-Likelihood: -10529.137278371925| Proposal [0.06571719 0.12421906 0.02007396]
# iteration: 310| Acceptance rate: 0.3709677419354839| Log-Likelihood: -10530.161086063426| Proposal [0.06561755 0.12402245 0.02004394]
# iteration: 320| Acceptance rate: 0.378125| Log-Likelihood: -10530.498891090625| Proposal [0.07517622 0.12947764 0.01990696]
# iteration: 330| Acceptance rate: 0.38181818181818183| Log-Likelihood: -10531.432246082308| Proposal [0.07413742 0.12901606 0.01995323]
# iteration: 340| Acceptance rate: 0.37941176470588234| Log-Likelihood: -10530.541454245733| Proposal [0.08298376 0.13404787 0.01981941]
# iteration: 350| Acceptance rate: 0.38285714285714284| Log-Likelihood: -10529.697046756137| Proposal [0.06529521 0.1239947  0.02008809]
# iteration: 360| Acceptance rate: 0.39444444444444443| Log-Likelihood: -10529.18705534234| Proposal [0.05823536 0.12003864 0.02020901]
# iteration: 370| Acceptance rate: 0.4| Log-Likelihood: -10529.038293835581| Proposal [0.05984245 0.12028041 0.0200181 ]
# iteration: 380| Acceptance rate: 0.4| Log-Likelihood: -10529.365649995507| Proposal [0.05493736 0.11619337 0.01977076]
# iteration: 390| Acceptance rate: 0.4076923076923077| Log-Likelihood: -10529.433349179793| Proposal [0.05278765 0.11327862 0.01938426]
# iteration: 400| Acceptance rate: 0.41| Log-Likelihood: -10529.285622016985| Proposal [0.05916143 0.11842759 0.01966547]
# iteration: 410| Acceptance rate: 0.4146341463414634| Log-Likelihood: -10529.664270095951| Proposal [0.0601763  0.12132312 0.02022494]
# iteration: 420| Acceptance rate: 0.4238095238095238| Log-Likelihood: -10530.075726036732| Proposal [0.06556397 0.11929357 0.01888123]
# iteration: 430| Acceptance rate: 0.4232558139534884| Log-Likelihood: -10529.731817644779| Proposal [0.06271306 0.11616706 0.01855124]
# iteration: 440| Acceptance rate: 0.42954545454545456| Log-Likelihood: -10529.23384005104| Proposal [0.06174131 0.11566071 0.01857616]
# iteration: 450| Acceptance rate: 0.4266666666666667| Log-Likelihood: -10529.133697277352| Proposal [0.05564658 0.11966362 0.02051889]
# iteration: 460| Acceptance rate: 0.4282608695652174| Log-Likelihood: -10530.122940623967| Proposal [0.05441819 0.11917261 0.02058754]
# iteration: 470| Acceptance rate: 0.4297872340425532| Log-Likelihood: -10529.322393095708| Proposal [0.05873756 0.1143952  0.01872818]
# iteration: 480| Acceptance rate: 0.43333333333333335| Log-Likelihood: -10528.728685450442| Proposal [0.05497032 0.11452829 0.01935228]
# iteration: 490| Acceptance rate: 0.4387755102040816| Log-Likelihood: -10530.219933383423| Proposal [0.0642292  0.12691984 0.02098136]
# iteration: 500| Acceptance rate: 0.438| Log-Likelihood: -10529.4481972368| Proposal [0.0592928  0.11868221 0.01970634]
# iteration: 510| Acceptance rate: 0.4411764705882353| Log-Likelihood: -10532.196833582722| Proposal [0.06464633 0.09715412 0.01352816]
# iteration: 520| Acceptance rate: 0.4442307692307692| Log-Likelihood: -10529.230094577817| Proposal [0.05918371 0.14542828 0.02636137]
# iteration: 530| Acceptance rate: 0.44339622641509435| Log-Likelihood: -10529.235602665383| Proposal [0.06340035 0.11881469 0.01909846]
# iteration: 540| Acceptance rate: 0.4444444444444444| Log-Likelihood: -10529.76374290524| Proposal [0.0594557  0.14295947 0.02570635]
# iteration: 550| Acceptance rate: 0.44545454545454544| Log-Likelihood: -10529.45454569012| Proposal [0.06302641 0.13024397 0.02199339]
# iteration: 560| Acceptance rate: 0.45357142857142857| Log-Likelihood: -10529.381290325806| Proposal [0.05953969 0.14954268 0.02732675]
# iteration: 570| Acceptance rate: 0.4543859649122807| Log-Likelihood: -10530.454033450103| Proposal [0.05670981 0.14446777 0.02650879]
# iteration: 580| Acceptance rate: 0.46206896551724136| Log-Likelihood: -10529.808111912233| Proposal [0.06601704 0.11961318 0.01888766]
# iteration: 590| Acceptance rate: 0.46440677966101696| Log-Likelihood: -10530.624832267227| Proposal [0.05172832 0.13294862 0.02442864]
# iteration: 600| Acceptance rate: 0.4683333333333333| Log-Likelihood: -10530.1543529149| Proposal [0.06435665 0.11148922 0.01713131]
# iteration: 610| Acceptance rate: 0.46885245901639344| Log-Likelihood: -10531.223949808926| Proposal [0.04804558 0.1586019  0.03136998]
# iteration: 620| Acceptance rate: 0.4693548387096774| Log-Likelihood: -10529.075850631243| Proposal [0.05030747 0.13866303 0.02606897]
# iteration: 630| Acceptance rate: 0.46825396825396826| Log-Likelihood: -10529.52595845493| Proposal [0.05268606 0.1480927  0.02803762]
# iteration: 640| Acceptance rate: 0.4609375| Log-Likelihood: -10529.52595845493| Proposal [0.05268606 0.1480927  0.02803762]
# iteration: 650| Acceptance rate: 0.46153846153846156| Log-Likelihood: -10529.36130429058| Proposal [0.06122457 0.11395488 0.01823321]
# iteration: 660| Acceptance rate: 0.4621212121212121| Log-Likelihood: -10528.94048741254| Proposal [0.06418314 0.12185563 0.01973152]
# iteration: 670| Acceptance rate: 0.4582089552238806| Log-Likelihood: -10529.364708145224| Proposal [0.05787882 0.13408696 0.02375097]
# iteration: 680| Acceptance rate: 0.4588235294117647| Log-Likelihood: -10528.924455346241| Proposal [0.05524094 0.13889749 0.02535675]
# iteration: 690| Acceptance rate: 0.45652173913043476| Log-Likelihood: -10528.936694422488| Proposal [0.0569572  0.13812585 0.02489766]
# iteration: 700| Acceptance rate: 0.45714285714285713| Log-Likelihood: -10529.207924359827| Proposal [0.05946247 0.14428442 0.02603507]
# iteration: 710| Acceptance rate: 0.4563380281690141| Log-Likelihood: -10529.394949176769| Proposal [0.05842947 0.13186836 0.02311466]
# iteration: 720| Acceptance rate: 0.46111111111111114| Log-Likelihood: -10530.156785353942| Proposal [0.05625795 0.13631168 0.02455641]
# iteration: 730| Acceptance rate: 0.4657534246575342| Log-Likelihood: -10529.361740219243| Proposal [0.05436038 0.14202166 0.02626998]
# iteration: 740| Acceptance rate: 0.4635135135135135| Log-Likelihood: -10529.142339725062| Proposal [0.06190535 0.13495228 0.02333748]
# iteration: 750| Acceptance rate: 0.4653333333333333| Log-Likelihood: -10529.571307939477| Proposal [0.06187237 0.14178216 0.02503758]
# iteration: 760| Acceptance rate: 0.46710526315789475| Log-Likelihood: -10530.37669915342| Proposal [0.05846794 0.15111177 0.0278835 ]
# iteration: 770| Acceptance rate: 0.4688311688311688| Log-Likelihood: -10528.834408077715| Proposal [0.06527024 0.12855972 0.02122612]
# iteration: 780| Acceptance rate: 0.47307692307692306| Log-Likelihood: -10529.911963633112| Proposal [0.07148434 0.14836859 0.02517082]
# iteration: 790| Acceptance rate: 0.4759493670886076| Log-Likelihood: -10530.87667590854| Proposal [0.0847026  0.14582981 0.02247655]
# iteration: 800| Acceptance rate: 0.47875| Log-Likelihood: -10531.913681440445| Proposal [0.07342648 0.16653247 0.02937474]
# iteration: 810| Acceptance rate: 0.4740740740740741| Log-Likelihood: -10529.042734185732| Proposal [0.06740518 0.14672219 0.02539979]
# iteration: 820| Acceptance rate: 0.474390243902439| Log-Likelihood: -10529.916833740577| Proposal [0.07764103 0.14160888 0.02253189]
# iteration: 830| Acceptance rate: 0.4746987951807229| Log-Likelihood: -10529.798643676382| Proposal [0.06760455 0.11378329 0.01719567]
# iteration: 840| Acceptance rate: 0.475| Log-Likelihood: -10530.045757316662| Proposal [0.05197229 0.11896048 0.02092094]
# iteration: 850| Acceptance rate: 0.4752941176470588| Log-Likelihood: -10529.63887316543| Proposal [0.06654758 0.14446353 0.02497206]
# iteration: 860| Acceptance rate: 0.47790697674418603| Log-Likelihood: -10529.11874531186| Proposal [0.05390615 0.12639855 0.02246471]
# iteration: 870| Acceptance rate: 0.47586206896551725| Log-Likelihood: -10530.2809942015| Proposal [0.06062307 0.1123011  0.01791907]
# iteration: 880| Acceptance rate: 0.4772727272727273| Log-Likelihood: -10530.000713976015| Proposal [0.05551851 0.1171602  0.01992134]
# iteration: 890| Acceptance rate: 0.4752808988764045| Log-Likelihood: -10529.763679803706| Proposal [0.06314464 0.13772539 0.02383249]
# iteration: 900| Acceptance rate: 0.47555555555555556| Log-Likelihood: -10531.6396475367| Proposal [0.07511527 0.12715254 0.01934064]
# iteration: 910| Acceptance rate: 0.4758241758241758| Log-Likelihood: -10529.395352963464| Proposal [0.06465495 0.12059192 0.01934649]
# iteration: 920| Acceptance rate: 0.47608695652173916| Log-Likelihood: -10529.296618034483| Proposal [0.06874497 0.13420656 0.02208709]
# iteration: 930| Acceptance rate: 0.47419354838709676| Log-Likelihood: -10529.790216057856| Proposal [0.06377235 0.11941103 0.01919132]
# iteration: 940| Acceptance rate: 0.4787234042553192| Log-Likelihood: -10532.021818052372| Proposal [0.07969293 0.17347163 0.03012484]
# iteration: 950| Acceptance rate: 0.47789473684210526| Log-Likelihood: -10529.7107477081| Proposal [0.06176066 0.1134829  0.01803342]
# iteration: 960| Acceptance rate: 0.48125| Log-Likelihood: -10529.990776758337| Proposal [0.06594246 0.12069522 0.01917262]
# iteration: 970| Acceptance rate: 0.4793814432989691| Log-Likelihood: -10529.777442976863| Proposal [0.05769932 0.10944804 0.01767374]
# iteration: 980| Acceptance rate: 0.4785714285714286| Log-Likelihood: -10528.985400167465| Proposal [0.05691172 0.12166737 0.02084001]
# iteration: 990| Acceptance rate: 0.47575757575757577| Log-Likelihood: -10530.690263135224| Proposal [0.07746065 0.12464425 0.01834967]
# iteration: 1000| Acceptance rate: 0.479| Log-Likelihood: -10531.4894676542| Proposal [0.05545548 0.09998512 0.01565934]
# iteration: 1010| Acceptance rate: 0.4792079207920792| Log-Likelihood: -10528.738834464897| Proposal [0.05903063 0.11663939 0.01925941]
# iteration: 1020| Acceptance rate: 0.4803921568627451| Log-Likelihood: -10528.57188740226| Proposal [0.06028343 0.13751328 0.0242751 ]
# iteration: 1030| Acceptance rate: 0.4796116504854369| Log-Likelihood: -10528.628897855175| Proposal [0.06378724 0.13356734 0.02273341]
# iteration: 1040| Acceptance rate: 0.4798076923076923| Log-Likelihood: -10531.600249864005| Proposal [0.07540626 0.14475185 0.02369606]
# iteration: 1050| Acceptance rate: 0.48| Log-Likelihood: -10528.98054246811| Proposal [0.05674558 0.12001834 0.0204631 ]
# iteration: 1060| Acceptance rate: 0.480188679245283| Log-Likelihood: -10530.395876069857| Proposal [0.07567044 0.15410078 0.02599612]
# iteration: 1070| Acceptance rate: 0.4822429906542056| Log-Likelihood: -10529.111473249688| Proposal [0.06122733 0.13776393 0.02418585]
# iteration: 1080| Acceptance rate: 0.48333333333333334| Log-Likelihood: -10530.016587282451| Proposal [0.06892049 0.15774109 0.02796957]
# iteration: 1090| Acceptance rate: 0.48256880733944957| Log-Likelihood: -10531.808363245087| Proposal [0.08914856 0.15770065 0.02477295]
# iteration: 1100| Acceptance rate: 0.4818181818181818| Log-Likelihood: -10529.726394714557| Proposal [0.06049192 0.13696945 0.02411148]
# iteration: 1110| Acceptance rate: 0.4837837837837838| Log-Likelihood: -10531.886326024329| Proposal [0.08011561 0.1210657  0.0170615 ]
# iteration: 1120| Acceptance rate: 0.48482142857142857| Log-Likelihood: -10531.000288914885| Proposal [0.08008248 0.1383408  0.02136266]
# iteration: 1130| Acceptance rate: 0.4831858407079646| Log-Likelihood: -10529.656663331385| Proposal [0.06305142 0.13209278 0.02248211]
# iteration: 1140| Acceptance rate: 0.4807017543859649| Log-Likelihood: -10530.684984103656| Proposal [0.06938918 0.12209513 0.01899416]
# iteration: 1150| Acceptance rate: 0.48| Log-Likelihood: -10528.867713392596| Proposal [0.0537982  0.13017368 0.0234604 ]
# iteration: 1160| Acceptance rate: 0.47844827586206895| Log-Likelihood: -10530.04816214014| Proposal [0.05354991 0.13731768 0.02528291]
# iteration: 1170| Acceptance rate: 0.4794871794871795| Log-Likelihood: -10532.307469717294| Proposal [0.06721962 0.18234862 0.03434706]
# iteration: 1180| Acceptance rate: 0.47796610169491527| Log-Likelihood: -10530.889640655563| Proposal [0.06364866 0.1716477  0.03223222]
# iteration: 1190| Acceptance rate: 0.4773109243697479| Log-Likelihood: -10529.698623284212| Proposal [0.05854255 0.12445537 0.02126174]
# iteration: 1200| Acceptance rate: 0.47583333333333333| Log-Likelihood: -10529.047110961044| Proposal [0.06185411 0.13888897 0.02435896]
# iteration: 1210| Acceptance rate: 0.4727272727272727| Log-Likelihood: -10529.589859414802| Proposal [0.06525802 0.1524992  0.02722456]
# iteration: 1220| Acceptance rate: 0.4713114754098361| Log-Likelihood: -10529.533484291547| Proposal [0.05922667 0.15277024 0.02823649]
# iteration: 1230| Acceptance rate: 0.46991869918699186| Log-Likelihood: -10529.570422180319| Proposal [0.05446888 0.14274312 0.02649491]
# iteration: 1240| Acceptance rate: 0.47096774193548385| Log-Likelihood: -10530.848405376606| Proposal [0.05568988 0.17493112 0.03432472]
# iteration: 1250| Acceptance rate: 0.4712| Log-Likelihood: -10529.311498533332| Proposal [0.0551933  0.110977   0.01845515]
# iteration: 1260| Acceptance rate: 0.46904761904761905| Log-Likelihood: -10529.393599867783| Proposal [0.05189731 0.11668632 0.02039782]
# iteration: 1270| Acceptance rate: 0.46771653543307085| Log-Likelihood: -10529.639251082432| Proposal [0.05728164 0.11519319 0.01916703]
# iteration: 1280| Acceptance rate: 0.4671875| Log-Likelihood: -10529.84628781029| Proposal [0.05796148 0.11855022 0.01990057]
# iteration: 1290| Acceptance rate: 0.4697674418604651| Log-Likelihood: -10531.124673999544| Proposal [0.05266674 0.09680859 0.01532813]
# iteration: 1300| Acceptance rate: 0.4684615384615385| Log-Likelihood: -10529.871154715218| Proposal [0.06413694 0.14497324 0.02550747]
# iteration: 1310| Acceptance rate: 0.47022900763358777| Log-Likelihood: -10530.34952762135| Proposal [0.05993949 0.11295464 0.01819537]
# iteration: 1320| Acceptance rate: 0.4712121212121212| Log-Likelihood: -10530.34934580303| Proposal [0.06287121 0.16410264 0.03047465]
# iteration: 1330| Acceptance rate: 0.4691729323308271| Log-Likelihood: -10530.550437271897| Proposal [0.07109539 0.16495281 0.0293694 ]
# iteration: 1340| Acceptance rate: 0.4701492537313433| Log-Likelihood: -10531.767022975062| Proposal [0.06031013 0.18459066 0.03601483]
# iteration: 1350| Acceptance rate: 0.4703703703703704| Log-Likelihood: -10529.029010398508| Proposal [0.05983288 0.13234854 0.02301104]
# iteration: 1360| Acceptance rate: 0.4713235294117647| Log-Likelihood: -10529.546230627913| Proposal [0.05927706 0.14238894 0.02563291]
# iteration: 1370| Acceptance rate: 0.47226277372262776| Log-Likelihood: -10530.611272661901| Proposal [0.04987417 0.10895519 0.01878985]
# iteration: 1380| Acceptance rate: 0.4717391304347826| Log-Likelihood: -10530.972463409638| Proposal [0.06876601 0.15968967 0.02843391]
# iteration: 1390| Acceptance rate: 0.47050359712230216| Log-Likelihood: -10532.97281399941| Proposal [0.05780416 0.09412136 0.01379344]
# iteration: 1400| Acceptance rate: 0.4692857142857143| Log-Likelihood: -10529.67289021079| Proposal [0.06837967 0.1269857  0.02035053]
# iteration: 1410| Acceptance rate: 0.46879432624113476| Log-Likelihood: -10528.78051117216| Proposal [0.06542675 0.13046952 0.02169579]
# iteration: 1420| Acceptance rate: 0.46549295774647886| Log-Likelihood: -10528.78051117216| Proposal [0.06542675 0.13046952 0.02169579]
# iteration: 1430| Acceptance rate: 0.46293706293706294| Log-Likelihood: -10528.945532525086| Proposal [0.06794646 0.14357033 0.02456374]
# iteration: 1440| Acceptance rate: 0.4638888888888889| Log-Likelihood: -10529.04158223025| Proposal [0.06381794 0.13149712 0.02220824]
# iteration: 1450| Acceptance rate: 0.463448275862069| Log-Likelihood: -10529.318079866634| Proposal [0.05752041 0.12502072 0.0215903 ]
# iteration: 1460| Acceptance rate: 0.4623287671232877| Log-Likelihood: -10530.11343908055| Proposal [0.05002536 0.11576257 0.02047321]
# iteration: 1470| Acceptance rate: 0.46258503401360546| Log-Likelihood: -10529.677849154043| Proposal [0.0656069  0.15079465 0.0267802 ]
# iteration: 1480| Acceptance rate: 0.46283783783783783| Log-Likelihood: -10529.425877447553| Proposal [0.06145699 0.14401551 0.02571787]
# iteration: 1490| Acceptance rate: 0.46308724832214765| Log-Likelihood: -10530.48107859849| Proposal [0.06085184 0.1697264  0.03231638]
# iteration: 1500| Acceptance rate: 0.46266666666666667| Log-Likelihood: -10529.660881748412| Proposal [0.06654604 0.11761652 0.01838071]
# iteration: 1510| Acceptance rate: 0.46357615894039733| Log-Likelihood: -10529.509151681665| Proposal [0.0710548  0.12136485 0.01861062]
# iteration: 1520| Acceptance rate: 0.4664473684210526| Log-Likelihood: -10531.339798416224| Proposal [0.05547415 0.18086417 0.03603029]
# iteration: 1530| Acceptance rate: 0.4666666666666667| Log-Likelihood: -10529.979428754512| Proposal [0.06778592 0.14338038 0.02464792]
# iteration: 1540| Acceptance rate: 0.4668831168831169| Log-Likelihood: -10528.724360375862| Proposal [0.06141325 0.13132864 0.02263445]
# iteration: 1550| Acceptance rate: 0.46516129032258063| Log-Likelihood: -10528.666885434503| Proposal [0.05479007 0.11657295 0.01976461]
# iteration: 1560| Acceptance rate: 0.4634615384615385| Log-Likelihood: -10529.562196491393| Proposal [0.05992022 0.14150239 0.02545852]
# iteration: 1570| Acceptance rate: 0.4636942675159236| Log-Likelihood: -10528.929097100756| Proposal [0.05555704 0.12131176 0.02085028]
# iteration: 1580| Acceptance rate: 0.4626582278481013| Log-Likelihood: -10529.750031056432| Proposal [0.06236953 0.12252045 0.02028371]
# iteration: 1590| Acceptance rate: 0.46226415094339623| Log-Likelihood: -10529.56175221834| Proposal [0.06267391 0.14728558 0.02641964]
# iteration: 1600| Acceptance rate: 0.4625| Log-Likelihood: -10530.158213328074| Proposal [0.06642745 0.15952634 0.02894456]
# iteration: 1610| Acceptance rate: 0.4645962732919255| Log-Likelihood: -10528.38092191276| Proposal [0.05654407 0.13951398 0.02542781]
# iteration: 1620| Acceptance rate: 0.4641975308641975| Log-Likelihood: -10530.54983000714| Proposal [0.05841159 0.14835428 0.02742681]
# iteration: 1630| Acceptance rate: 0.46503067484662575| Log-Likelihood: -10528.904026810813| Proposal [0.05964593 0.1285276  0.02206406]
# iteration: 1640| Acceptance rate: 0.4652439024390244| Log-Likelihood: -10531.040749670503| Proposal [0.0736392  0.15812811 0.02755734]
# iteration: 1650| Acceptance rate: 0.46484848484848484| Log-Likelihood: -10530.799446458186| Proposal [0.06826494 0.10717031 0.0149977 ]
# iteration: 1660| Acceptance rate: 0.46325301204819275| Log-Likelihood: -10529.530817115137| Proposal [0.06398242 0.11765952 0.01813411]
# iteration: 1670| Acceptance rate: 0.4616766467065868| Log-Likelihood: -10530.066049162135| Proposal [0.06811537 0.15609242 0.0270892 ]
# iteration: 1680| Acceptance rate: 0.4636904761904762| Log-Likelihood: -10529.685198264417| Proposal [0.06160091 0.14805442 0.02652671]
# iteration: 1690| Acceptance rate: 0.46272189349112425| Log-Likelihood: -10530.311009200459| Proposal [0.07026385 0.14869301 0.02456805]
# iteration: 1700| Acceptance rate: 0.46176470588235297| Log-Likelihood: -10529.288732087694| Proposal [0.0636965  0.12329146 0.02011886]
# iteration: 1710| Acceptance rate: 0.4614035087719298| Log-Likelihood: -10530.562206901159| Proposal [0.07173783 0.14771785 0.02425185]
# iteration: 1720| Acceptance rate: 0.4622093023255814| Log-Likelihood: -10530.086535820683| Proposal [0.06304968 0.13770038 0.02295613]
# iteration: 1730| Acceptance rate: 0.461271676300578| Log-Likelihood: -10530.677418714646| Proposal [0.06094632 0.16341531 0.03033449]
# iteration: 1740| Acceptance rate: 0.46206896551724136| Log-Likelihood: -10529.290381235242| Proposal [0.06164393 0.14379404 0.02534503]
# iteration: 1750| Acceptance rate: 0.46114285714285713| Log-Likelihood: -10529.51040925729| Proposal [0.06796772 0.11454715 0.0168555 ]
# iteration: 1760| Acceptance rate: 0.46079545454545456| Log-Likelihood: -10528.28847195259| Proposal [0.05805302 0.1301654  0.02292477]
# iteration: 1770| Acceptance rate: 0.4610169491525424| Log-Likelihood: -10529.73439503943| Proposal [0.07333095 0.14436638 0.02333007]
# iteration: 1780| Acceptance rate: 0.46179775280898877| Log-Likelihood: -10530.402030137224| Proposal [0.07883547 0.13949247 0.02052973]
# iteration: 1790| Acceptance rate: 0.46145251396648046| Log-Likelihood: -10529.217216021185| Proposal [0.06951427 0.10897058 0.01581875]
# iteration: 1800| Acceptance rate: 0.4627777777777778| Log-Likelihood: -10533.25029417055| Proposal [0.06677325 0.0899311  0.01238471]
# iteration: 1810| Acceptance rate: 0.46187845303867403| Log-Likelihood: -10529.609614698513| Proposal [0.05736149 0.10858964 0.01752668]
# iteration: 1820| Acceptance rate: 0.460989010989011| Log-Likelihood: -10528.990770750148| Proposal [0.05870467 0.11710097 0.02008926]
# iteration: 1830| Acceptance rate: 0.460655737704918| Log-Likelihood: -10530.118216145267| Proposal [0.07142353 0.13002056 0.02031966]
# iteration: 1840| Acceptance rate: 0.4603260869565217| Log-Likelihood: -10530.2214868901| Proposal [0.06530736 0.15256266 0.0263573 ]
# iteration: 1850| Acceptance rate: 0.46054054054054056| Log-Likelihood: -10530.733783419177| Proposal [0.080312   0.13869745 0.02006669]
# iteration: 1860| Acceptance rate: 0.46182795698924733| Log-Likelihood: -10529.05501191937| Proposal [0.05686878 0.12122961 0.01991537]
# iteration: 1870| Acceptance rate: 0.46203208556149733| Log-Likelihood: -10529.125475050969| Proposal [0.06393043 0.15278745 0.02510579]
# iteration: 1880| Acceptance rate: 0.46170212765957447| Log-Likelihood: -10529.188765866289| Proposal [0.07365359 0.15458683 0.02267304]
# iteration: 1890| Acceptance rate: 0.4624338624338624| Log-Likelihood: -10532.255845824098| Proposal [0.086227   0.1762079  0.02227205]
# iteration: 1900| Acceptance rate: 0.4626315789473684| Log-Likelihood: -10529.452417649014| Proposal [0.05808469 0.10938751 0.01861482]
# iteration: 1910| Acceptance rate: 0.46230366492146596| Log-Likelihood: -10530.179042597465| Proposal [0.05949993 0.14363589 0.02456918]
# iteration: 1920| Acceptance rate: 0.4630208333333333| Log-Likelihood: -10529.06248999515| Proposal [0.05752558 0.14714302 0.02563567]
# iteration: 1930| Acceptance rate: 0.46424870466321244| Log-Likelihood: -10529.997928884268| Proposal [0.0563204  0.12949859 0.02435816]
# iteration: 1940| Acceptance rate: 0.4639175257731959| Log-Likelihood: -10529.542966333604| Proposal [0.04931437 0.14835365 0.02336608]
# iteration: 1950| Acceptance rate: 0.46307692307692305| Log-Likelihood: -10529.79807339366| Proposal [0.05073761 0.11393004 0.01684062]
# iteration: 1960| Acceptance rate: 0.46224489795918366| Log-Likelihood: -10528.65611711285| Proposal [0.05676982 0.1228641  0.01911546]
# iteration: 1970| Acceptance rate: 0.45989847715736043| Log-Likelihood: -10528.65611711285| Proposal [0.05676982 0.1228641  0.01911546]
# iteration: 1980| Acceptance rate: 0.46060606060606063| Log-Likelihood: -10530.0114666435| Proposal [0.05612968 0.10544838 0.01867614]
# iteration: 1990| Acceptance rate: 0.46080402010050253| Log-Likelihood: -10529.447098425348| Proposal [0.0656913  0.14307478 0.0226445 ]
# 4547.180472918

# %%
burn_in = 0

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'])
# Out:
# -10528.117026291775
# The Maximum Likelihood Estimate is [0.0615399  0.12213093 0.02048169] w/ LL of -10528.117026291775

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\eta$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[2,burn_in:])} and std: {np.std(theta[2,burn_in:])}")
# plt.hist(theta[2,burn_in:],density=True,bins = 50)
# plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[3,burn_in:])} and std: {np.std(theta[3,burn_in:])}")
# plt.hist(theta[3,burn_in:],density=True,bins = 50)
# plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 192.15016679975415
# Root Mean Squared Error for beta 0.11540937941750222

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
'''Pair plots'''

plt.title('Pairwise Plot of $\\gamma$ and $\\eta$')
plt.xlabel('$\\gamma$')
plt.ylabel('$\\eta$')
plt.scatter(pmcmc_output['accepted_params'][0,burn_in:],pmcmc_output['accepted_params'][1,burn_in:],s=0.1)

# %%
'''Pair plots'''

plt.title('Trace Plot of $\\eta$')
plt.xlabel('Iteration')
plt.ylabel('$\\eta$')
plt.plot(pmcmc_output['accepted_params'][1,burn_in:])
