# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import gammaln_nr
from scipy.stats import poisson,nbinom,norm

# %%
'''Simulated Data, setting up the SIR model'''

rng = np.random.default_rng(0)

gamma = 1/14
eta = 1/7
q = 0.1
mu = 0.004
rho = 0.1

T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

N = 100_000
I = 5
E = 5


beta_par = {'b_0':0.4,'b_inf': 0.1, 'tau': 5,'T':20}

def beta_sim(par,t):
    if(t < par['T']):
        return 0.4
    
    return par['b_inf'] + (par['b_0'] - par['b_inf']) * np.exp(-(t - par['T'])/par['tau'])

betas = np.array([beta_sim(beta_par,t) for t in t_vec])

state = np.zeros((5,len(t_vec)))
state[:,0] = np.array([N - I - E,E, I, 0,0])

plt.title('Generative $\\beta_t$')
plt.xlabel('Time (Days)')
plt.plot(t_vec,betas)

for time_index in range(1,len(t_vec)):

    new_E = (betas[time_index - 1] * (state[1,time_index -1] + q * state[2,time_index - 1]) * state[0,time_index - 1]/np.sum(state[:,time_index-1])) * dt
    new_I = (eta * state[1,time_index - 1]) * dt
    new_ER = (gamma * state[1,time_index -1]) * dt
    new_IR = (gamma * state[2,time_index - 1]) * dt
    new_D = (mu * state[2,time_index - 1]) * dt


    state[0,time_index] = state[0,time_index - 1] - new_E #S 
    state[1,time_index] = state[1,time_index - 1] + new_E - new_I - new_ER
    state[2,time_index] = state[2,time_index-1] + new_I - new_IR - new_D
    state[3,time_index] = state[3,time_index - 1] + new_ER + new_IR #R
    state[4,time_index] = new_I

# %%
plt.yscale('log')
plt.title('Plot of SEIR Model')
plt.xlabel('Time (Days)')
plt.plot(state.T[:])
# Out:
# [<matplotlib.lines.Line2D at 0x130ce1e50>,
#  <matplotlib.lines.Line2D at 0x130e4ce90>,
#  <matplotlib.lines.Line2D at 0x130e605d0>,
#  <matplotlib.lines.Line2D at 0x130e608d0>,
#  <matplotlib.lines.Line2D at 0x130e60bd0>]

# %%
r = 50

data = np.expand_dims(rng.negative_binomial(n = r,p = r/(r + state[2,::int(1/dt)] + 0.005)),0)

#data = np.expand_dims(state[2,::int(1/dt)],0)

plt.title('Plot of Generative Data')
plt.xlabel('Time (Days)')
plt.ylabel('Case Count')
plt.plot(t_vec[::int(1/dt)],data.T)

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,eta,_ = model_params

    '''OU Process'''
    sig = 1.0
    mu = -2.0
    lam = 1/100

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((eta * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    #return norm.logpdf(data_point,loc = particle_observations[:,0],scale = np.sqrt(var))
    r = 1/model_params[2]
    weights = nbinom.logpmf(k = data_point,p = r/(r + particle_observations[:,0]),n = r)
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
#(0.06547914,0.28245005)
#(1/14 = 0.07,1/7 = 0.14)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':1000, 
                      'dt':0.1,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,eta,1/50),
        pf_params = pf_params,
        rng = rng,
        req_jit=False
        )

print(perf_counter() - t)
# Out:
# 22.0679237239965

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10532.963884408031
# Root Mean Squared Error for the Data 192.13417431682993

# %%
pmcmc_rng = np.random.default_rng(0)

num_particles = 1000

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 1/15.,max_val = 1/3) + uniform_numba_logpdf(theta[2],min_val = 0.,max_val = 1.)

pmcmc_params = {'iterations':5_000,
                'init_params':np.array([0.1,0.1,0.01]),
                'prior':seir_prior,
                'init_cov':0.005 * np.eye(3),
                'burn_in':100}

pf_params = {'num_particles':1_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=False
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.1| Log-Likelihood: -10539.167985048645| Proposal [0.13204929 0.0968196  0.0386691 ]
# iteration: 20| Acceptance rate: 0.05| Log-Likelihood: -10539.167985048645| Proposal [0.13204929 0.0968196  0.0386691 ]
# iteration: 30| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10539.167985048645| Proposal [0.13204929 0.0968196  0.0386691 ]
# iteration: 40| Acceptance rate: 0.05| Log-Likelihood: -10535.166862031514| Proposal [0.10796261 0.19396472 0.01326827]
# iteration: 50| Acceptance rate: 0.06| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 60| Acceptance rate: 0.05| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 70| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 80| Acceptance rate: 0.0375| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 90| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 100| Acceptance rate: 0.03| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 110| Acceptance rate: 0.02727272727272727| Log-Likelihood: -10528.86355739933| Proposal [0.0718178  0.18661148 0.01548039]
# iteration: 120| Acceptance rate: 0.058333333333333334| Log-Likelihood: -10527.971119395308| Proposal [0.0658533  0.1835956  0.01920818]
# iteration: 130| Acceptance rate: 0.1076923076923077| Log-Likelihood: -10527.998089124223| Proposal [0.06755852 0.18544384 0.01788799]
# iteration: 140| Acceptance rate: 0.15| Log-Likelihood: -10527.349326278008| Proposal [0.06474026 0.18034023 0.02169961]
# iteration: 150| Acceptance rate: 0.18666666666666668| Log-Likelihood: -10527.808847799899| Proposal [0.0675296  0.18510184 0.01808807]
# iteration: 160| Acceptance rate: 0.21875| Log-Likelihood: -10528.614319266322| Proposal [0.06879259 0.18469258 0.01922684]
# iteration: 170| Acceptance rate: 0.24705882352941178| Log-Likelihood: -10527.645473653743| Proposal [0.06776379 0.18496734 0.0184843 ]
# iteration: 180| Acceptance rate: 0.2722222222222222| Log-Likelihood: -10528.476301519371| Proposal [0.0683781  0.1831663  0.02087266]
# iteration: 190| Acceptance rate: 0.30526315789473685| Log-Likelihood: -10528.06134967523| Proposal [0.06821993 0.18357155 0.02042446]
# iteration: 200| Acceptance rate: 0.34| Log-Likelihood: -10528.39290047552| Proposal [0.06904792 0.1844116  0.01985522]
# iteration: 210| Acceptance rate: 0.35714285714285715| Log-Likelihood: -10528.623176871963| Proposal [0.07103704 0.18566657 0.01943952]
# iteration: 220| Acceptance rate: 0.38636363636363635| Log-Likelihood: -10528.24756814977| Proposal [0.06812162 0.18261425 0.02170058]
# iteration: 230| Acceptance rate: 0.391304347826087| Log-Likelihood: -10528.102090426135| Proposal [0.07156969 0.18676438 0.01824881]
# iteration: 240| Acceptance rate: 0.4041666666666667| Log-Likelihood: -10527.931870870269| Proposal [0.06874314 0.18075678 0.02446943]
# iteration: 250| Acceptance rate: 0.42| Log-Likelihood: -10528.650450508583| Proposal [0.07253961 0.18746898 0.0179285 ]
# iteration: 260| Acceptance rate: 0.41923076923076924| Log-Likelihood: -10529.254553523735| Proposal [0.0682543  0.17980754 0.02540549]
# iteration: 270| Acceptance rate: 0.4222222222222222| Log-Likelihood: -10529.31275396213| Proposal [0.06720429 0.17838783 0.02668194]
# iteration: 280| Acceptance rate: 0.425| Log-Likelihood: -10529.201280034673| Proposal [0.06676283 0.17726199 0.02788243]
# iteration: 290| Acceptance rate: 0.42758620689655175| Log-Likelihood: -10528.945948238286| Proposal [0.0701863  0.18379558 0.0213433 ]
# iteration: 300| Acceptance rate: 0.44| Log-Likelihood: -10527.898022810685| Proposal [0.07082806 0.18471278 0.020491  ]
# iteration: 310| Acceptance rate: 0.44516129032258067| Log-Likelihood: -10528.394806794395| Proposal [0.07056552 0.18462841 0.02047195]
# iteration: 320| Acceptance rate: 0.453125| Log-Likelihood: -10529.19042296566| Proposal [0.06741478 0.1779044  0.02740442]
# iteration: 330| Acceptance rate: 0.4636363636363636| Log-Likelihood: -10528.630093773303| Proposal [0.07077958 0.18363413 0.02182465]
# iteration: 340| Acceptance rate: 0.47352941176470587| Log-Likelihood: -10527.988673597303| Proposal [0.06741672 0.17857236 0.02656369]
# iteration: 350| Acceptance rate: 0.4714285714285714| Log-Likelihood: -10528.200109379377| Proposal [0.07239433 0.18765745 0.01754232]
# iteration: 360| Acceptance rate: 0.475| Log-Likelihood: -10528.590158156674| Proposal [0.07174026 0.18674821 0.01837284]
# iteration: 370| Acceptance rate: 0.4756756756756757| Log-Likelihood: -10529.664526910958| Proposal [0.06698319 0.18028517 0.02420306]
# iteration: 380| Acceptance rate: 0.4763157894736842| Log-Likelihood: -10528.905427422029| Proposal [0.07083724 0.18422336 0.02110941]
# iteration: 390| Acceptance rate: 0.4794871794871795| Log-Likelihood: -10529.065395038322| Proposal [0.07285166 0.18950473 0.01543707]
# iteration: 400| Acceptance rate: 0.4825| Log-Likelihood: -10528.310754132735| Proposal [0.07099965 0.18489187 0.02034828]
# iteration: 410| Acceptance rate: 0.4902439024390244| Log-Likelihood: -10529.146817612364| Proposal [0.06976392 0.18075349 0.02496486]
# iteration: 420| Acceptance rate: 0.49047619047619045| Log-Likelihood: -10528.265052727078| Proposal [0.06940323 0.18147467 0.02387162]
# iteration: 430| Acceptance rate: 0.4883720930232558| Log-Likelihood: -10527.489425257509| Proposal [0.06583364 0.18341799 0.01971203]
# iteration: 440| Acceptance rate: 0.49318181818181817| Log-Likelihood: -10526.911762705173| Proposal [0.0527745  0.17849529 0.01961865]
# iteration: 450| Acceptance rate: 0.4866666666666667| Log-Likelihood: -10527.40328733953| Proposal [0.06534958 0.18481279 0.01773199]
# iteration: 460| Acceptance rate: 0.4891304347826087| Log-Likelihood: -10529.692988839435| Proposal [0.06229915 0.18689183 0.01365385]
# iteration: 470| Acceptance rate: 0.48723404255319147| Log-Likelihood: -10527.938476933326| Proposal [0.06495552 0.18047846 0.02298728]
# iteration: 480| Acceptance rate: 0.4895833333333333| Log-Likelihood: -10528.771435793009| Proposal [0.06455309 0.17698268 0.02718663]
# iteration: 490| Acceptance rate: 0.4897959183673469| Log-Likelihood: -10529.351240137634| Proposal [0.06209965 0.18493017 0.01602143]
# iteration: 500| Acceptance rate: 0.49| Log-Likelihood: -10528.094228645885| Proposal [0.05044687 0.17218968 0.02643291]
# iteration: 510| Acceptance rate: 0.48823529411764705| Log-Likelihood: -10529.555520537255| Proposal [0.04833167 0.17046308 0.02758464]
# iteration: 520| Acceptance rate: 0.49230769230769234| Log-Likelihood: -10528.111576860234| Proposal [0.05285643 0.17873916 0.01936767]
# iteration: 530| Acceptance rate: 0.48867924528301887| Log-Likelihood: -10527.791948260223| Proposal [0.05736542 0.18166252 0.01787026]
# iteration: 540| Acceptance rate: 0.4888888888888889| Log-Likelihood: -10527.961002916705| Proposal [0.06412647 0.18256589 0.01998746]
# iteration: 550| Acceptance rate: 0.48363636363636364| Log-Likelihood: -10527.790491024476| Proposal [0.06676722 0.18543483 0.0176585 ]
# iteration: 560| Acceptance rate: 0.48928571428571427| Log-Likelihood: -10528.347408758405| Proposal [0.06809279 0.18568014 0.01798632]
# iteration: 570| Acceptance rate: 0.48947368421052634| Log-Likelihood: -10531.604413022022| Proposal [0.08310668 0.19478294 0.01375822]
# iteration: 580| Acceptance rate: 0.4896551724137931| Log-Likelihood: -10527.452707656155| Proposal [0.06867759 0.18635452 0.01741239]
# iteration: 590| Acceptance rate: 0.48983050847457626| Log-Likelihood: -10531.83492612798| Proposal [0.08194891 0.19478341 0.01319524]
# iteration: 600| Acceptance rate: 0.49| Log-Likelihood: -10527.230833822108| Proposal [0.05639796 0.17826734 0.02168209]
# iteration: 610| Acceptance rate: 0.4934426229508197| Log-Likelihood: -10527.041768749821| Proposal [0.06239535 0.18227426 0.01952209]
# iteration: 620| Acceptance rate: 0.4935483870967742| Log-Likelihood: -10528.706377107232| Proposal [0.0693533  0.18628803 0.0178148 ]
# iteration: 630| Acceptance rate: 0.4936507936507937| Log-Likelihood: -10528.37243020051| Proposal [0.0530704  0.17618564 0.02268925]
# iteration: 640| Acceptance rate: 0.4921875| Log-Likelihood: -10528.406883856662| Proposal [0.05183151 0.17848432 0.01921414]
# iteration: 650| Acceptance rate: 0.48923076923076925| Log-Likelihood: -10527.805391763293| Proposal [0.05439422 0.18205011 0.01596959]
# iteration: 660| Acceptance rate: 0.4893939393939394| Log-Likelihood: -10527.287632241594| Proposal [0.05750275 0.17816374 0.02233159]
# iteration: 670| Acceptance rate: 0.4880597014925373| Log-Likelihood: -10526.865560899727| Proposal [0.05816111 0.18029481 0.01997013]
# iteration: 680| Acceptance rate: 0.48823529411764705| Log-Likelihood: -10526.324225201015| Proposal [0.05718288 0.17904596 0.02107041]
# iteration: 690| Acceptance rate: 0.49130434782608695| Log-Likelihood: -10527.186502466348| Proposal [0.06113649 0.18121435 0.02024419]
# iteration: 700| Acceptance rate: 0.49142857142857144| Log-Likelihood: -10527.49824362033| Proposal [0.06274741 0.18142495 0.0207529 ]
# iteration: 710| Acceptance rate: 0.4943661971830986| Log-Likelihood: -10527.705966177395| Proposal [0.06306172 0.17884584 0.02413499]
# iteration: 720| Acceptance rate: 0.4930555555555556| Log-Likelihood: -10526.88494706158| Proposal [0.05670812 0.17846379 0.02157253]
# iteration: 730| Acceptance rate: 0.4904109589041096| Log-Likelihood: -10527.677909924052| Proposal [0.06444375 0.17884809 0.02479343]
# iteration: 740| Acceptance rate: 0.49324324324324326| Log-Likelihood: -10527.753756919134| Proposal [0.06075076 0.18006768 0.02149332]
# iteration: 750| Acceptance rate: 0.49466666666666664| Log-Likelihood: -10527.405287442174| Proposal [0.05892098 0.18022703 0.02042491]
# iteration: 760| Acceptance rate: 0.49473684210526314| Log-Likelihood: -10528.569097680656| Proposal [0.06921834 0.18525521 0.01905285]
# iteration: 770| Acceptance rate: 0.4961038961038961| Log-Likelihood: -10527.628327346181| Proposal [0.06305438 0.17823973 0.02489589]
# iteration: 780| Acceptance rate: 0.4948717948717949| Log-Likelihood: -10527.107352466028| Proposal [0.05487404 0.17676683 0.02283138]
# iteration: 790| Acceptance rate: 0.4962025316455696| Log-Likelihood: -10526.84289597146| Proposal [0.06036364 0.17949533 0.02204042]
# iteration: 800| Acceptance rate: 0.5| Log-Likelihood: -10527.796000984867| Proposal [0.06103326 0.18048259 0.02112535]
# iteration: 810| Acceptance rate: 0.49876543209876545| Log-Likelihood: -10528.373870169693| Proposal [0.05348961 0.17361475 0.02612374]
# iteration: 820| Acceptance rate: 0.4951219512195122| Log-Likelihood: -10530.553017482254| Proposal [0.04996731 0.16778156 0.03173883]
# iteration: 830| Acceptance rate: 0.4951807228915663| Log-Likelihood: -10528.789073993597| Proposal [0.06220531 0.18487311 0.01619074]
# iteration: 840| Acceptance rate: 0.49523809523809526| Log-Likelihood: -10527.221152199692| Proposal [0.05563881 0.17483939 0.02552893]
# iteration: 850| Acceptance rate: 0.49411764705882355| Log-Likelihood: -10527.555855344803| Proposal [0.05425919 0.17195505 0.02837582]
# iteration: 860| Acceptance rate: 0.4941860465116279| Log-Likelihood: -10527.261037173088| Proposal [0.06070885 0.18067494 0.02079814]
# iteration: 870| Acceptance rate: 0.4885057471264368| Log-Likelihood: -10527.261037173088| Proposal [0.06070885 0.18067494 0.02079814]
# iteration: 880| Acceptance rate: 0.4875| Log-Likelihood: -10526.887637568647| Proposal [0.05589068 0.17951385 0.01989639]
# iteration: 890| Acceptance rate: 0.4842696629213483| Log-Likelihood: -10527.577324817154| Proposal [0.05553197 0.17751519 0.02223964]
# iteration: 900| Acceptance rate: 0.48444444444444446| Log-Likelihood: -10527.563524591278| Proposal [0.05495522 0.18123139 0.0173496 ]
# iteration: 910| Acceptance rate: 0.4879120879120879| Log-Likelihood: -10528.528473295453| Proposal [0.05659939 0.18445482 0.01416452]
# iteration: 920| Acceptance rate: 0.4891304347826087| Log-Likelihood: -10528.46200857885| Proposal [0.0573022  0.17194226 0.02989104]
# iteration: 930| Acceptance rate: 0.4935483870967742| Log-Likelihood: -10527.081628863181| Proposal [0.05902748 0.1802988  0.02057689]
# iteration: 940| Acceptance rate: 0.49042553191489363| Log-Likelihood: -10526.941021823859| Proposal [0.06203758 0.18547897 0.01565007]
# iteration: 950| Acceptance rate: 0.48736842105263156| Log-Likelihood: -10527.681182282287| Proposal [0.06485586 0.18333705 0.01971048]
# iteration: 960| Acceptance rate: 0.4864583333333333| Log-Likelihood: -10527.51287745694| Proposal [0.06419448 0.17837457 0.02531025]
# iteration: 970| Acceptance rate: 0.4845360824742268| Log-Likelihood: -10526.846199116948| Proposal [0.05899159 0.17998749 0.02092989]
# iteration: 980| Acceptance rate: 0.4857142857142857| Log-Likelihood: -10527.636444517993| Proposal [0.05519076 0.18299521 0.01551194]
# iteration: 990| Acceptance rate: 0.48383838383838385| Log-Likelihood: -10527.046720846765| Proposal [0.0553591  0.17970309 0.01952087]
# iteration: 1000| Acceptance rate: 0.481| Log-Likelihood: -10526.970165623552| Proposal [0.05751779 0.18131308 0.01861469]
# iteration: 1010| Acceptance rate: 0.48118811881188117| Log-Likelihood: -10526.74042300332| Proposal [0.0601034  0.18093735 0.02035559]
# iteration: 1020| Acceptance rate: 0.4843137254901961| Log-Likelihood: -10526.656356194319| Proposal [0.05828063 0.17958702 0.02099049]
# iteration: 1030| Acceptance rate: 0.48349514563106794| Log-Likelihood: -10527.330953283621| Proposal [0.05288522 0.17726738 0.0212484 ]
# iteration: 1040| Acceptance rate: 0.48173076923076924| Log-Likelihood: -10527.182302653333| Proposal [0.05314784 0.17762153 0.02088391]
# iteration: 1050| Acceptance rate: 0.48095238095238096| Log-Likelihood: -10527.664666166234| Proposal [0.0646553  0.18063157 0.02302304]
# iteration: 1060| Acceptance rate: 0.4849056603773585| Log-Likelihood: -10527.89643422674| Proposal [0.05187924 0.17845959 0.01931701]
# iteration: 1070| Acceptance rate: 0.48411214953271026| Log-Likelihood: -10527.459365835803| Proposal [0.06071577 0.18302861 0.01809353]
# iteration: 1080| Acceptance rate: 0.48703703703703705| Log-Likelihood: -10528.453778229303| Proposal [0.06392599 0.18168347 0.02129099]
# iteration: 1090| Acceptance rate: 0.48807339449541287| Log-Likelihood: -10528.6504233228| Proposal [0.07208278 0.18435039 0.02216082]
# iteration: 1100| Acceptance rate: 0.49| Log-Likelihood: -10528.690181632455| Proposal [0.05078257 0.18126918 0.01512237]
# iteration: 1110| Acceptance rate: 0.4864864864864865| Log-Likelihood: -10527.80141824273| Proposal [0.05146888 0.17843619 0.0188877 ]
# iteration: 1120| Acceptance rate: 0.48660714285714285| Log-Likelihood: -10527.569939773453| Proposal [0.0588466  0.17770255 0.02348176]
# iteration: 1130| Acceptance rate: 0.48849557522123893| Log-Likelihood: -10527.628075881155| Proposal [0.05710181 0.18179595 0.01759259]
# iteration: 1140| Acceptance rate: 0.4885964912280702| Log-Likelihood: -10527.81170516541| Proposal [0.06216369 0.17938558 0.02322635]
# iteration: 1150| Acceptance rate: 0.4895652173913044| Log-Likelihood: -10527.426014348508| Proposal [0.05027494 0.17687561 0.02011026]
# iteration: 1160| Acceptance rate: 0.4896551724137931| Log-Likelihood: -10528.901824257793| Proposal [0.06311983 0.18625177 0.01527357]
# iteration: 1170| Acceptance rate: 0.4888888888888889| Log-Likelihood: -10527.679968336883| Proposal [0.0562985  0.17811946 0.021788  ]
# iteration: 1180| Acceptance rate: 0.48898305084745763| Log-Likelihood: -10528.612795577148| Proposal [0.06528162 0.18361412 0.01970461]
# iteration: 1190| Acceptance rate: 0.492436974789916| Log-Likelihood: -10528.23589918779| Proposal [0.06935549 0.18159979 0.02456736]
# iteration: 1200| Acceptance rate: 0.49083333333333334| Log-Likelihood: -10527.00027840697| Proposal [0.06082616 0.18351474 0.01740027]
# iteration: 1210| Acceptance rate: 0.4933884297520661| Log-Likelihood: -10527.704926635288| Proposal [0.06676317 0.18483398 0.01888931]
# iteration: 1220| Acceptance rate: 0.4934426229508197| Log-Likelihood: -10527.902781625751| Proposal [0.07022388 0.18520933 0.02055004]
# iteration: 1230| Acceptance rate: 0.4926829268292683| Log-Likelihood: -10527.267470427412| Proposal [0.06408243 0.1833183  0.01902182]
# iteration: 1240| Acceptance rate: 0.4935483870967742| Log-Likelihood: -10528.196940461288| Proposal [0.05204527 0.17765591 0.01928211]
# iteration: 1250| Acceptance rate: 0.4936| Log-Likelihood: -10526.933035176819| Proposal [0.05391368 0.17697455 0.02147156]
# iteration: 1260| Acceptance rate: 0.49126984126984125| Log-Likelihood: -10526.97181915484| Proposal [0.0577264  0.17722642 0.02287264]
# iteration: 1270| Acceptance rate: 0.4905511811023622| Log-Likelihood: -10528.68243636757| Proposal [0.0707925  0.18315146 0.02226741]
# iteration: 1280| Acceptance rate: 0.48984375| Log-Likelihood: -10527.062447140235| Proposal [0.05377765 0.18084408 0.017911  ]
# iteration: 1290| Acceptance rate: 0.4883720930232558| Log-Likelihood: -10528.91234823978| Proposal [0.05711532 0.18359493 0.01609827]
# iteration: 1300| Acceptance rate: 0.49| Log-Likelihood: -10527.085474155452| Proposal [0.06390028 0.18384539 0.01816178]
# iteration: 1310| Acceptance rate: 0.48854961832061067| Log-Likelihood: -10527.781186296468| Proposal [0.05514837 0.17537856 0.0235591 ]
# iteration: 1320| Acceptance rate: 0.49015151515151517| Log-Likelihood: -10527.486811579316| Proposal [0.05909599 0.18061814 0.01905921]
# iteration: 1330| Acceptance rate: 0.49022556390977445| Log-Likelihood: -10528.00414187313| Proposal [0.0572675  0.17963553 0.01726553]
# iteration: 1340| Acceptance rate: 0.49029850746268655| Log-Likelihood: -10528.906374830784| Proposal [0.07001467 0.1876014  0.02185839]
# iteration: 1350| Acceptance rate: 0.48814814814814816| Log-Likelihood: -10527.123389631122| Proposal [0.05884401 0.17215729 0.02463256]
# iteration: 1360| Acceptance rate: 0.4875| Log-Likelihood: -10528.351696208341| Proposal [0.05943245 0.15644851 0.02524402]
# iteration: 1370| Acceptance rate: 0.48905109489051096| Log-Likelihood: -10528.72582189887| Proposal [0.07243161 0.1754035  0.02373395]
# iteration: 1380| Acceptance rate: 0.4891304347826087| Log-Likelihood: -10527.028506110777| Proposal [0.05550191 0.16940372 0.01962341]
# iteration: 1390| Acceptance rate: 0.48776978417266187| Log-Likelihood: -10527.39707135735| Proposal [0.05463397 0.17435192 0.02197692]
# iteration: 1400| Acceptance rate: 0.48857142857142855| Log-Likelihood: -10527.448617990904| Proposal [0.05667672 0.18001618 0.0200751 ]
# iteration: 1410| Acceptance rate: 0.48936170212765956| Log-Likelihood: -10527.738464066631| Proposal [0.05892398 0.17040073 0.01958961]
# iteration: 1420| Acceptance rate: 0.4887323943661972| Log-Likelihood: -10527.432078356509| Proposal [0.06103989 0.19325081 0.01741103]
# iteration: 1430| Acceptance rate: 0.4888111888111888| Log-Likelihood: -10530.296905643465| Proposal [0.07852208 0.18833377 0.02494275]
# iteration: 1440| Acceptance rate: 0.4895833333333333| Log-Likelihood: -10527.827306089861| Proposal [0.06973679 0.19282256 0.01975275]
# iteration: 1450| Acceptance rate: 0.4910344827586207| Log-Likelihood: -10528.290841197291| Proposal [0.06417113 0.20159783 0.01853698]
# iteration: 1460| Acceptance rate: 0.4917808219178082| Log-Likelihood: -10528.749834107668| Proposal [0.06253827 0.12333645 0.02534895]
# iteration: 1470| Acceptance rate: 0.49047619047619045| Log-Likelihood: -10528.11485934602| Proposal [0.06002125 0.20811868 0.01580826]
# iteration: 1480| Acceptance rate: 0.4891891891891892| Log-Likelihood: -10528.247551946679| Proposal [0.06992069 0.18239474 0.01997644]
# iteration: 1490| Acceptance rate: 0.4906040268456376| Log-Likelihood: -10531.421027237098| Proposal [0.0887346  0.26957475 0.01583167]
# iteration: 1500| Acceptance rate: 0.49133333333333334| Log-Likelihood: -10527.2186480163| Proposal [0.06288617 0.16062895 0.02203251]
# iteration: 1510| Acceptance rate: 0.49072847682119203| Log-Likelihood: -10529.116926761591| Proposal [0.07372713 0.14586281 0.02374644]
# iteration: 1520| Acceptance rate: 0.48947368421052634| Log-Likelihood: -10528.71304574937| Proposal [0.07005264 0.17068981 0.01994437]
# iteration: 1530| Acceptance rate: 0.4895424836601307| Log-Likelihood: -10528.232921452201| Proposal [0.06666727 0.13802762 0.0217915 ]
# iteration: 1540| Acceptance rate: 0.488961038961039| Log-Likelihood: -10528.077759344797| Proposal [0.06474419 0.1423797  0.02117839]
# iteration: 1550| Acceptance rate: 0.4890322580645161| Log-Likelihood: -10528.51387669191| Proposal [0.0650974  0.15117084 0.02400396]
# iteration: 1560| Acceptance rate: 0.4891025641025641| Log-Likelihood: -10529.401900853398| Proposal [0.06900501 0.10150285 0.02517788]
# iteration: 1570| Acceptance rate: 0.49044585987261147| Log-Likelihood: -10528.960094841354| Proposal [0.06372126 0.18574685 0.02108946]
# iteration: 1580| Acceptance rate: 0.4917721518987342| Log-Likelihood: -10527.91706249597| Proposal [0.05990824 0.24499287 0.01511322]
# iteration: 1590| Acceptance rate: 0.4937106918238994| Log-Likelihood: -10526.166782078926| Proposal [0.05481132 0.33219625 0.02141578]
# iteration: 1600| Acceptance rate: 0.491875| Log-Likelihood: -10527.766883634997| Proposal [0.06622185 0.24600034 0.02214799]
# iteration: 1610| Acceptance rate: 0.4919254658385093| Log-Likelihood: -10527.304489934571| Proposal [0.05513233 0.33223243 0.01830174]
# iteration: 1620| Acceptance rate: 0.4901234567901235| Log-Likelihood: -10527.985934598615| Proposal [0.0712468  0.18075098 0.02048176]
# iteration: 1630| Acceptance rate: 0.4901840490797546| Log-Likelihood: -10527.549230427185| Proposal [0.05626594 0.21858455 0.02602964]
# iteration: 1640| Acceptance rate: 0.4896341463414634| Log-Likelihood: -10529.653559606599| Proposal [0.06607187 0.2186876  0.01405122]
# iteration: 1650| Acceptance rate: 0.48787878787878786| Log-Likelihood: -10526.931275668641| Proposal [0.05770142 0.2352292  0.01904511]
# iteration: 1660| Acceptance rate: 0.4867469879518072| Log-Likelihood: -10526.9505325137| Proposal [0.05202475 0.23270085 0.02410493]
# iteration: 1670| Acceptance rate: 0.48622754491017967| Log-Likelihood: -10528.67260397783| Proposal [0.05661366 0.30663237 0.01545727]
# iteration: 1680| Acceptance rate: 0.4857142857142857| Log-Likelihood: -10527.928527643331| Proposal [0.05159613 0.25035682 0.02688567]
# iteration: 1690| Acceptance rate: 0.4846153846153846| Log-Likelihood: -10526.226861943083| Proposal [0.05884181 0.30570945 0.0206466 ]
# iteration: 1700| Acceptance rate: 0.4852941176470588| Log-Likelihood: -10527.324106303508| Proposal [0.06140923 0.20445695 0.02257859]
# iteration: 1710| Acceptance rate: 0.4853801169590643| Log-Likelihood: -10526.837073290753| Proposal [0.05512091 0.17753701 0.01922288]
# iteration: 1720| Acceptance rate: 0.48604651162790696| Log-Likelihood: -10527.721572332222| Proposal [0.05044835 0.26895954 0.02433379]
# iteration: 1730| Acceptance rate: 0.484393063583815| Log-Likelihood: -10527.03008662698| Proposal [0.05086148 0.25562351 0.02003846]
# iteration: 1740| Acceptance rate: 0.4839080459770115| Log-Likelihood: -10527.615524558847| Proposal [0.05242079 0.2676237  0.0253829 ]
# iteration: 1750| Acceptance rate: 0.4828571428571429| Log-Likelihood: -10526.941078369216| Proposal [0.05522779 0.2538255  0.01698445]
# iteration: 1760| Acceptance rate: 0.48409090909090907| Log-Likelihood: -10527.22306871043| Proposal [0.06332989 0.2715667  0.01809721]
# iteration: 1770| Acceptance rate: 0.48361581920903957| Log-Likelihood: -10527.049017824736| Proposal [0.06075168 0.2616456  0.02109963]
# iteration: 1780| Acceptance rate: 0.4837078651685393| Log-Likelihood: -10527.734237216786| Proposal [0.06151504 0.23137452 0.02427254]
# iteration: 1790| Acceptance rate: 0.48435754189944136| Log-Likelihood: -10528.598488404232| Proposal [0.04996017 0.27936344 0.02578808]
# iteration: 1800| Acceptance rate: 0.48444444444444446| Log-Likelihood: -10527.051317046147| Proposal [0.06139967 0.30168348 0.01921299]
# iteration: 1810| Acceptance rate: 0.4845303867403315| Log-Likelihood: -10528.023641981541| Proposal [0.06556669 0.23415527 0.01604258]
# iteration: 1820| Acceptance rate: 0.48406593406593407| Log-Likelihood: -10526.876122616695| Proposal [0.05355093 0.23200663 0.02459867]
# iteration: 1830| Acceptance rate: 0.48415300546448087| Log-Likelihood: -10529.672472016333| Proposal [0.06003385 0.08475224 0.02494136]
# iteration: 1840| Acceptance rate: 0.483695652173913| Log-Likelihood: -10527.790530228916| Proposal [0.0645199  0.1704828  0.02207781]
# iteration: 1850| Acceptance rate: 0.48324324324324325| Log-Likelihood: -10527.191454473212| Proposal [0.05545691 0.22715504 0.02516071]
# iteration: 1860| Acceptance rate: 0.48333333333333334| Log-Likelihood: -10527.69772577674| Proposal [0.05128243 0.16719303 0.02620472]
# iteration: 1870| Acceptance rate: 0.4818181818181818| Log-Likelihood: -10530.047496916372| Proposal [0.04919201 0.25224554 0.03171897]
# iteration: 1880| Acceptance rate: 0.4819148936170213| Log-Likelihood: -10527.161293608215| Proposal [0.05675003 0.24979136 0.02399148]
# iteration: 1890| Acceptance rate: 0.482010582010582| Log-Likelihood: -10527.455495119795| Proposal [0.06569708 0.30494386 0.0210712 ]
# iteration: 1900| Acceptance rate: 0.48105263157894734| Log-Likelihood: -10528.17158578927| Proposal [0.05867968 0.14282171 0.01805751]
# iteration: 1910| Acceptance rate: 0.4806282722513089| Log-Likelihood: -10527.693846355294| Proposal [0.06452097 0.31250723 0.0218138 ]
# iteration: 1920| Acceptance rate: 0.48072916666666665| Log-Likelihood: -10527.011112964952| Proposal [0.05538494 0.22685275 0.02352101]
# iteration: 1930| Acceptance rate: 0.4803108808290155| Log-Likelihood: -10527.029257707476| Proposal [0.05880833 0.20650236 0.02452098]
# iteration: 1940| Acceptance rate: 0.4788659793814433| Log-Likelihood: -10527.008260778872| Proposal [0.05785552 0.25358133 0.02170901]
# iteration: 1950| Acceptance rate: 0.47897435897435897| Log-Likelihood: -10527.315041483704| Proposal [0.05430912 0.16981807 0.02447593]
# iteration: 1960| Acceptance rate: 0.47959183673469385| Log-Likelihood: -10527.627988600192| Proposal [0.05948612 0.15811858 0.01875382]
# iteration: 1970| Acceptance rate: 0.48071065989847717| Log-Likelihood: -10528.855087965501| Proposal [0.05255168 0.19314857 0.03063594]
# iteration: 1980| Acceptance rate: 0.4818181818181818| Log-Likelihood: -10528.895332043545| Proposal [0.06880581 0.30621479 0.024748  ]
# iteration: 1990| Acceptance rate: 0.48040201005025124| Log-Likelihood: -10528.637909647094| Proposal [0.05007917 0.16241027 0.02217277]
# iteration: 2000| Acceptance rate: 0.4795| Log-Likelihood: -10526.934704665062| Proposal [0.05623912 0.21865739 0.02307741]
# iteration: 2010| Acceptance rate: 0.47761194029850745| Log-Likelihood: -10527.665967958526| Proposal [0.06632909 0.25073317 0.01736211]
# iteration: 2020| Acceptance rate: 0.4777227722772277| Log-Likelihood: -10529.357325477302| Proposal [0.0751815  0.26645032 0.02550307]
# iteration: 2030| Acceptance rate: 0.47783251231527096| Log-Likelihood: -10529.52900363439| Proposal [0.05199623 0.13155224 0.01734047]
# iteration: 2040| Acceptance rate: 0.47794117647058826| Log-Likelihood: -10527.228727910673| Proposal [0.05797568 0.22658017 0.02206414]
# iteration: 2050| Acceptance rate: 0.47853658536585364| Log-Likelihood: -10526.911736488502| Proposal [0.06242285 0.27323434 0.02209732]
# iteration: 2060| Acceptance rate: 0.47815533980582525| Log-Likelihood: -10529.059319388954| Proposal [0.0786982  0.31998835 0.02165921]
# iteration: 2070| Acceptance rate: 0.4777777777777778| Log-Likelihood: -10527.08849433261| Proposal [0.05104359 0.22571356 0.02255715]
# iteration: 2080| Acceptance rate: 0.47836538461538464| Log-Likelihood: -10527.816779939101| Proposal [0.0662299  0.29113809 0.01960018]
# iteration: 2090| Acceptance rate: 0.4779904306220096| Log-Likelihood: -10529.008641281307| Proposal [0.07315689 0.31977317 0.01866551]
# iteration: 2100| Acceptance rate: 0.4780952380952381| Log-Likelihood: -10528.26933489371| Proposal [0.05874215 0.17943153 0.02560575]
# iteration: 2110| Acceptance rate: 0.4786729857819905| Log-Likelihood: -10528.524399279098| Proposal [0.07495439 0.11696932 0.02263224]
# iteration: 2120| Acceptance rate: 0.47830188679245284| Log-Likelihood: -10529.003149356819| Proposal [0.06926954 0.11096338 0.02076839]
# iteration: 2130| Acceptance rate: 0.4779342723004695| Log-Likelihood: -10526.971342334418| Proposal [0.05868751 0.27677004 0.02366692]
# iteration: 2140| Acceptance rate: 0.47897196261682246| Log-Likelihood: -10527.97414646469| Proposal [0.05835166 0.26974613 0.01539389]
# iteration: 2150| Acceptance rate: 0.4786046511627907| Log-Likelihood: -10527.216464385721| Proposal [0.06183906 0.20796135 0.01847677]
# iteration: 2160| Acceptance rate: 0.47685185185185186| Log-Likelihood: -10527.360088244022| Proposal [0.05656143 0.30480979 0.02484787]
# iteration: 2170| Acceptance rate: 0.47649769585253454| Log-Likelihood: -10528.301430262416| Proposal [0.05339617 0.31798362 0.02505839]
# iteration: 2180| Acceptance rate: 0.47522935779816516| Log-Likelihood: -10528.117278461597| Proposal [0.06991774 0.32389398 0.02245711]
# iteration: 2190| Acceptance rate: 0.4748858447488584| Log-Likelihood: -10529.765629909532| Proposal [0.06993477 0.13232017 0.02529728]
# iteration: 2200| Acceptance rate: 0.475| Log-Likelihood: -10528.04946131786| Proposal [0.06141263 0.25198949 0.02529   ]
# iteration: 2210| Acceptance rate: 0.47420814479638007| Log-Likelihood: -10529.151866808543| Proposal [0.05896047 0.26361685 0.01387515]
# iteration: 2220| Acceptance rate: 0.4743243243243243| Log-Likelihood: -10528.449033052071| Proposal [0.06270966 0.22803739 0.02213073]
# iteration: 2230| Acceptance rate: 0.473542600896861| Log-Likelihood: -10527.112495603973| Proposal [0.05609776 0.15805707 0.0203884 ]
# iteration: 2240| Acceptance rate: 0.47232142857142856| Log-Likelihood: -10527.412593822954| Proposal [0.0553632  0.13213283 0.02285682]
# iteration: 2250| Acceptance rate: 0.4711111111111111| Log-Likelihood: -10526.617770552102| Proposal [0.05661018 0.24055782 0.02181898]
# iteration: 2260| Acceptance rate: 0.46991150442477875| Log-Likelihood: -10527.144527757384| Proposal [0.05870229 0.29576999 0.0215263 ]
# iteration: 2270| Acceptance rate: 0.46960352422907486| Log-Likelihood: -10527.699608845825| Proposal [0.05648391 0.28108893 0.01645966]
# iteration: 2280| Acceptance rate: 0.4692982456140351| Log-Likelihood: -10526.562982542599| Proposal [0.06499257 0.26118131 0.01917637]
# iteration: 2290| Acceptance rate: 0.46855895196506553| Log-Likelihood: -10527.06153489435| Proposal [0.0537815  0.32912346 0.02306226]
# iteration: 2300| Acceptance rate: 0.46869565217391307| Log-Likelihood: -10527.675687221554| Proposal [0.06373649 0.16956442 0.01925744]
# iteration: 2310| Acceptance rate: 0.467965367965368| Log-Likelihood: -10530.194319736365| Proposal [0.0658618  0.21658316 0.01400628]
# iteration: 2320| Acceptance rate: 0.4676724137931034| Log-Likelihood: -10529.029044660469| Proposal [0.05880627 0.14187483 0.02933484]
# iteration: 2330| Acceptance rate: 0.4669527896995708| Log-Likelihood: -10526.488545286134| Proposal [0.05786057 0.2025848  0.01924232]
# iteration: 2340| Acceptance rate: 0.4666666666666667| Log-Likelihood: -10529.787711415323| Proposal [0.05480883 0.15557105 0.03025152]
# iteration: 2350| Acceptance rate: 0.46680851063829787| Log-Likelihood: -10529.157184580275| Proposal [0.04879521 0.19064948 0.0269983 ]
# iteration: 2360| Acceptance rate: 0.46652542372881356| Log-Likelihood: -10527.962618372327| Proposal [0.05634694 0.26510989 0.01499035]
# iteration: 2370| Acceptance rate: 0.46624472573839665| Log-Likelihood: -10527.401688992646| Proposal [0.05979343 0.30795896 0.01661376]
# iteration: 2380| Acceptance rate: 0.46638655462184875| Log-Likelihood: -10528.089169457031| Proposal [0.06274098 0.15727753 0.02376784]
# iteration: 2390| Acceptance rate: 0.46736401673640166| Log-Likelihood: -10529.230375670084| Proposal [0.06626025 0.20617234 0.01561795]
# iteration: 2400| Acceptance rate: 0.4675| Log-Likelihood: -10527.158552004943| Proposal [0.06461566 0.23904705 0.02350199]
# iteration: 2410| Acceptance rate: 0.46680497925311204| Log-Likelihood: -10526.964135750079| Proposal [0.06235419 0.31296114 0.01905552]
# iteration: 2420| Acceptance rate: 0.4669421487603306| Log-Likelihood: -10528.275743413918| Proposal [0.06541873 0.18782641 0.02695682]
# iteration: 2430| Acceptance rate: 0.46584362139917695| Log-Likelihood: -10527.091415500532| Proposal [0.0609755  0.31155306 0.01938719]
# iteration: 2440| Acceptance rate: 0.4651639344262295| Log-Likelihood: -10527.034638991201| Proposal [0.05426776 0.24711304 0.02125371]
# iteration: 2450| Acceptance rate: 0.4657142857142857| Log-Likelihood: -10526.644111314887| Proposal [0.05257487 0.32604612 0.01815763]
# iteration: 2460| Acceptance rate: 0.4666666666666667| Log-Likelihood: -10526.710772277082| Proposal [0.05685318 0.25809266 0.01830332]
# iteration: 2470| Acceptance rate: 0.4659919028340081| Log-Likelihood: -10527.176972247966| Proposal [0.06553992 0.30806055 0.02371043]
# iteration: 2480| Acceptance rate: 0.4669354838709677| Log-Likelihood: -10527.774391549116| Proposal [0.05165983 0.185581   0.01897605]
# iteration: 2490| Acceptance rate: 0.4670682730923695| Log-Likelihood: -10527.105714946503| Proposal [0.06363872 0.17771876 0.01978891]
# iteration: 2500| Acceptance rate: 0.4656| Log-Likelihood: -10526.562122398755| Proposal [0.05476981 0.26896185 0.02388441]
# iteration: 2510| Acceptance rate: 0.4653386454183267| Log-Likelihood: -10527.995142644953| Proposal [0.04839571 0.20265958 0.02066617]
# iteration: 2520| Acceptance rate: 0.4654761904761905| Log-Likelihood: -10528.326662901698| Proposal [0.06043427 0.13519686 0.02564665]
# iteration: 2530| Acceptance rate: 0.46561264822134385| Log-Likelihood: -10528.64000953092| Proposal [0.05651734 0.31911365 0.01487951]
# iteration: 2540| Acceptance rate: 0.46496062992125986| Log-Likelihood: -10526.941190741956| Proposal [0.05365929 0.21859781 0.02257072]
# iteration: 2550| Acceptance rate: 0.46431372549019606| Log-Likelihood: -10527.852542415561| Proposal [0.05814042 0.12986285 0.02148686]
# iteration: 2560| Acceptance rate: 0.46484375| Log-Likelihood: -10527.696993907712| Proposal [0.05062586 0.23709058 0.0210225 ]
# iteration: 2570| Acceptance rate: 0.4653696498054475| Log-Likelihood: -10526.984675727019| Proposal [0.05526635 0.26937161 0.02180531]
# iteration: 2580| Acceptance rate: 0.46434108527131784| Log-Likelihood: -10527.224557390082| Proposal [0.06156754 0.21792204 0.01881044]
# iteration: 2590| Acceptance rate: 0.4637065637065637| Log-Likelihood: -10529.715164467068| Proposal [0.04986669 0.20972576 0.02843655]
# iteration: 2600| Acceptance rate: 0.4646153846153846| Log-Likelihood: -10528.038164507685| Proposal [0.068267   0.23775987 0.01840265]
# iteration: 2610| Acceptance rate: 0.46360153256704983| Log-Likelihood: -10526.990257652098| Proposal [0.06088898 0.26661485 0.01938149]
# iteration: 2620| Acceptance rate: 0.46412213740458014| Log-Likelihood: -10527.172439044829| Proposal [0.0537033  0.20843167 0.02211902]
# iteration: 2630| Acceptance rate: 0.46387832699619774| Log-Likelihood: -10528.460165386114| Proposal [0.05100604 0.15792314 0.02243486]
# iteration: 2640| Acceptance rate: 0.4628787878787879| Log-Likelihood: -10527.115212221994| Proposal [0.05099066 0.16749065 0.02009313]
# iteration: 2650| Acceptance rate: 0.46264150943396226| Log-Likelihood: -10527.417320664954| Proposal [0.05455939 0.30727307 0.01910218]
# iteration: 2660| Acceptance rate: 0.4620300751879699| Log-Likelihood: -10529.223818117232| Proposal [0.04989625 0.14465131 0.01883517]
# iteration: 2670| Acceptance rate: 0.46292134831460674| Log-Likelihood: -10527.236965507529| Proposal [0.05264822 0.18623604 0.01833076]
# iteration: 2680| Acceptance rate: 0.4626865671641791| Log-Likelihood: -10526.746606119867| Proposal [0.05640419 0.24429363 0.02016196]
# iteration: 2690| Acceptance rate: 0.4639405204460966| Log-Likelihood: -10527.135491082425| Proposal [0.05775324 0.24301382 0.02436947]
# iteration: 2700| Acceptance rate: 0.4633333333333333| Log-Likelihood: -10526.941473405266| Proposal [0.06197889 0.24124939 0.02050012]
# iteration: 2710| Acceptance rate: 0.46346863468634686| Log-Likelihood: -10529.42252776577| Proposal [0.07321573 0.25920193 0.0188671 ]
# iteration: 2720| Acceptance rate: 0.4625| Log-Likelihood: -10526.870627143666| Proposal [0.06172154 0.26510493 0.02237684]
# iteration: 2730| Acceptance rate: 0.4622710622710623| Log-Likelihood: -10527.19226374047| Proposal [0.05988448 0.17230064 0.02116762]
# iteration: 2740| Acceptance rate: 0.46131386861313867| Log-Likelihood: -10527.732643925157| Proposal [0.05098764 0.14652221 0.01785033]
# iteration: 2750| Acceptance rate: 0.46145454545454545| Log-Likelihood: -10528.808305734454| Proposal [0.06636645 0.25310185 0.02456069]
# iteration: 2760| Acceptance rate: 0.46304347826086956| Log-Likelihood: -10528.173331813814| Proposal [0.06384024 0.10200572 0.02357178]
# iteration: 2770| Acceptance rate: 0.4631768953068592| Log-Likelihood: -10527.024303255102| Proposal [0.05712712 0.17225712 0.01867091]
# iteration: 2780| Acceptance rate: 0.46258992805755395| Log-Likelihood: -10527.637716931129| Proposal [0.0529208  0.24283929 0.0197058 ]
# iteration: 2790| Acceptance rate: 0.46164874551971324| Log-Likelihood: -10526.534647188791| Proposal [0.05897985 0.22602992 0.0211585 ]
# iteration: 2800| Acceptance rate: 0.4617857142857143| Log-Likelihood: -10527.175175330507| Proposal [0.0573759  0.19203805 0.02226879]
# iteration: 2810| Acceptance rate: 0.46120996441281137| Log-Likelihood: -10530.901868797933| Proposal [0.07566985 0.15132587 0.02885763]
# iteration: 2820| Acceptance rate: 0.46170212765957447| Log-Likelihood: -10529.984550543348| Proposal [0.07398561 0.19916196 0.02840021]
# iteration: 2830| Acceptance rate: 0.46113074204946997| Log-Likelihood: -10528.467482954049| Proposal [0.0614372  0.32147082 0.02869476]
# iteration: 2840| Acceptance rate: 0.45985915492957746| Log-Likelihood: -10525.743950565025| Proposal [0.05561929 0.24988179 0.02123137]
# iteration: 2850| Acceptance rate: 0.45824561403508773| Log-Likelihood: -10525.743950565025| Proposal [0.05561929 0.24988179 0.02123137]
# iteration: 2860| Acceptance rate: 0.4583916083916084| Log-Likelihood: -10527.03082244732| Proposal [0.05365199 0.27884915 0.01863595]
# iteration: 2870| Acceptance rate: 0.45749128919860627| Log-Likelihood: -10526.734256074407| Proposal [0.05188826 0.29311986 0.01769635]
# iteration: 2880| Acceptance rate: 0.4579861111111111| Log-Likelihood: -10528.027097775275| Proposal [0.06582804 0.17839881 0.02052875]
# iteration: 2890| Acceptance rate: 0.45709342560553634| Log-Likelihood: -10528.237634597077| Proposal [0.07684511 0.11572205 0.02020761]
# iteration: 2900| Acceptance rate: 0.45689655172413796| Log-Likelihood: -10526.701677763547| Proposal [0.05518692 0.22511937 0.02056607]
# iteration: 2910| Acceptance rate: 0.45670103092783504| Log-Likelihood: -10528.490921632583| Proposal [0.0466568  0.23215795 0.02305163]
# iteration: 2920| Acceptance rate: 0.4565068493150685| Log-Likelihood: -10527.155366673098| Proposal [0.058499   0.17013827 0.01825188]
# iteration: 2930| Acceptance rate: 0.4552901023890785| Log-Likelihood: -10528.415657830928| Proposal [0.05402569 0.18823058 0.01587347]
# iteration: 2940| Acceptance rate: 0.45476190476190476| Log-Likelihood: -10527.033104638002| Proposal [0.05438633 0.26533244 0.02144982]
# iteration: 2950| Acceptance rate: 0.45389830508474577| Log-Likelihood: -10526.9015930859| Proposal [0.06100674 0.31594216 0.02358538]
# iteration: 2960| Acceptance rate: 0.4543918918918919| Log-Likelihood: -10528.359501561423| Proposal [0.06102533 0.22225089 0.01617805]
# iteration: 2970| Acceptance rate: 0.45454545454545453| Log-Likelihood: -10527.206047054415| Proposal [0.05487689 0.3274346  0.02088757]
# iteration: 2980| Acceptance rate: 0.45503355704697984| Log-Likelihood: -10526.871119464948| Proposal [0.06116118 0.28406574 0.02312503]
# iteration: 2990| Acceptance rate: 0.4551839464882943| Log-Likelihood: -10528.07079326048| Proposal [0.05047762 0.22178313 0.02572075]
# iteration: 3000| Acceptance rate: 0.4553333333333333| Log-Likelihood: -10529.993991326382| Proposal [0.0716144  0.26426921 0.01393386]
# iteration: 3010| Acceptance rate: 0.4548172757475083| Log-Likelihood: -10529.528587054427| Proposal [0.07119086 0.27506859 0.01425462]
# iteration: 3020| Acceptance rate: 0.4543046357615894| Log-Likelihood: -10528.49797603258| Proposal [0.06638459 0.32274126 0.01542898]
# iteration: 3030| Acceptance rate: 0.4551155115511551| Log-Likelihood: -10527.80826562928| Proposal [0.06435664 0.23675855 0.01600001]
# iteration: 3040| Acceptance rate: 0.4542763157894737| Log-Likelihood: -10527.213755761624| Proposal [0.0578263  0.21134116 0.01638187]
# iteration: 3050| Acceptance rate: 0.4540983606557377| Log-Likelihood: -10527.318283797911| Proposal [0.06390925 0.22010016 0.01849071]
# iteration: 3060| Acceptance rate: 0.45359477124183006| Log-Likelihood: -10528.973547834175| Proposal [0.05623234 0.19759584 0.01344098]
# iteration: 3070| Acceptance rate: 0.4527687296416938| Log-Likelihood: -10528.017315685822| Proposal [0.05740553 0.19811801 0.0157179 ]
# iteration: 3080| Acceptance rate: 0.4525974025974026| Log-Likelihood: -10528.18344044698| Proposal [0.05781717 0.16649281 0.015443  ]
# iteration: 3090| Acceptance rate: 0.4521035598705502| Log-Likelihood: -10528.893393907862| Proposal [0.0608514  0.22300736 0.0151825 ]
# iteration: 3100| Acceptance rate: 0.45225806451612904| Log-Likelihood: -10527.898075759142| Proposal [0.05449431 0.14403346 0.01801717]
# iteration: 3110| Acceptance rate: 0.4527331189710611| Log-Likelihood: -10526.761400095551| Proposal [0.05579611 0.23377866 0.01860986]
# iteration: 3120| Acceptance rate: 0.4519230769230769| Log-Likelihood: -10527.627431804383| Proposal [0.05040542 0.23185485 0.01639964]
# iteration: 3130| Acceptance rate: 0.4523961661341853| Log-Likelihood: -10527.791791215934| Proposal [0.05880738 0.31430844 0.01750227]
# iteration: 3140| Acceptance rate: 0.45222929936305734| Log-Likelihood: -10526.863566379574| Proposal [0.05780892 0.26232631 0.02265811]
# iteration: 3150| Acceptance rate: 0.45301587301587304| Log-Likelihood: -10527.789447751407| Proposal [0.0579259  0.13688765 0.01840668]
# iteration: 3160| Acceptance rate: 0.4528481012658228| Log-Likelihood: -10528.379611125943| Proposal [0.04921193 0.24831365 0.01910342]
# iteration: 3170| Acceptance rate: 0.4529968454258675| Log-Likelihood: -10526.653872906167| Proposal [0.05756543 0.30331538 0.01787325]
# iteration: 3180| Acceptance rate: 0.45251572327044026| Log-Likelihood: -10527.515853044142| Proposal [0.0579562  0.28557657 0.0243923 ]
# iteration: 3190| Acceptance rate: 0.4526645768025078| Log-Likelihood: -10527.505371479341| Proposal [0.05244451 0.17112642 0.02071683]
# iteration: 3200| Acceptance rate: 0.4525| Log-Likelihood: -10527.126105663545| Proposal [0.05837586 0.16382015 0.01678534]
# iteration: 3210| Acceptance rate: 0.4520249221183801| Log-Likelihood: -10528.874509312125| Proposal [0.06080876 0.26594389 0.02934301]
# iteration: 3220| Acceptance rate: 0.45217391304347826| Log-Likelihood: -10528.167474800217| Proposal [0.0475877  0.28272754 0.02525079]
# iteration: 3230| Acceptance rate: 0.4520123839009288| Log-Likelihood: -10527.628013190802| Proposal [0.05630949 0.17604122 0.02070712]
# iteration: 3240| Acceptance rate: 0.45185185185185184| Log-Likelihood: -10527.731256150886| Proposal [0.06493051 0.3031433  0.02491742]
# iteration: 3250| Acceptance rate: 0.45261538461538464| Log-Likelihood: -10526.715948163468| Proposal [0.06239564 0.25061907 0.02460978]
# iteration: 3260| Acceptance rate: 0.45245398773006135| Log-Likelihood: -10526.296226920189| Proposal [0.05406098 0.28952672 0.02034289]
# iteration: 3270| Acceptance rate: 0.45168195718654436| Log-Likelihood: -10526.543493822985| Proposal [0.05799565 0.27877867 0.02122982]
# iteration: 3280| Acceptance rate: 0.45182926829268294| Log-Likelihood: -10527.07440988889| Proposal [0.064187   0.27382849 0.01975321]
# iteration: 3290| Acceptance rate: 0.4522796352583587| Log-Likelihood: -10528.25096132508| Proposal [0.06585163 0.16558622 0.01925286]
# iteration: 3300| Acceptance rate: 0.45212121212121215| Log-Likelihood: -10526.428201774646| Proposal [0.05971054 0.31174829 0.02119036]
# iteration: 3310| Acceptance rate: 0.45105740181268883| Log-Likelihood: -10527.285748842738| Proposal [0.06003472 0.26205431 0.02025401]
# iteration: 3320| Acceptance rate: 0.4515060240963855| Log-Likelihood: -10526.942145724248| Proposal [0.05519574 0.18648723 0.02305958]
# iteration: 3330| Acceptance rate: 0.45135135135135135| Log-Likelihood: -10527.963720500979| Proposal [0.06101487 0.1523943  0.0272459 ]
# iteration: 3340| Acceptance rate: 0.45119760479041915| Log-Likelihood: -10530.51761118556| Proposal [0.05272012 0.09770171 0.02726385]
# iteration: 3350| Acceptance rate: 0.45104477611940297| Log-Likelihood: -10527.349369509393| Proposal [0.06454804 0.29067507 0.02398444]
# iteration: 3360| Acceptance rate: 0.45089285714285715| Log-Likelihood: -10527.582421858813| Proposal [0.06118491 0.22811168 0.02490129]
# iteration: 3370| Acceptance rate: 0.45103857566765576| Log-Likelihood: -10527.06489894717| Proposal [0.05736883 0.26384756 0.02283705]
# iteration: 3380| Acceptance rate: 0.4511834319526627| Log-Likelihood: -10527.07718560738| Proposal [0.05717396 0.26024262 0.02088621]
# iteration: 3390| Acceptance rate: 0.4510324483775811| Log-Likelihood: -10526.558631960059| Proposal [0.05604647 0.24044875 0.02141347]
# iteration: 3400| Acceptance rate: 0.45088235294117646| Log-Likelihood: -10526.355446178428| Proposal [0.05486732 0.22899738 0.02214044]
# iteration: 3410| Acceptance rate: 0.45073313782991203| Log-Likelihood: -10526.62033283974| Proposal [0.05849866 0.29301688 0.02191322]
# iteration: 3420| Acceptance rate: 0.45| Log-Likelihood: -10526.785764436137| Proposal [0.05741181 0.26294373 0.01961875]
# iteration: 3430| Acceptance rate: 0.44985422740524783| Log-Likelihood: -10526.65665356514| Proposal [0.05957573 0.28596385 0.02030738]
# iteration: 3440| Acceptance rate: 0.4502906976744186| Log-Likelihood: -10526.765659979887| Proposal [0.05581943 0.26636924 0.01819162]
# iteration: 3450| Acceptance rate: 0.44956521739130434| Log-Likelihood: -10526.61410343146| Proposal [0.05887306 0.32189327 0.02241631]
# iteration: 3460| Acceptance rate: 0.44913294797687864| Log-Likelihood: -10526.67246587408| Proposal [0.05674034 0.33101428 0.02346631]
# iteration: 3470| Acceptance rate: 0.4489913544668588| Log-Likelihood: -10527.656756194398| Proposal [0.05217273 0.31678918 0.01564341]
# iteration: 3480| Acceptance rate: 0.4485632183908046| Log-Likelihood: -10529.696792179257| Proposal [0.04480748 0.33139968 0.02351663]
# iteration: 3490| Acceptance rate: 0.4498567335243553| Log-Likelihood: -10527.343415462152| Proposal [0.06883458 0.28394035 0.02471848]
# iteration: 3500| Acceptance rate: 0.44942857142857146| Log-Likelihood: -10529.282439247309| Proposal [0.06750587 0.20865548 0.03011865]
# iteration: 3510| Acceptance rate: 0.449002849002849| Log-Likelihood: -10528.380806801575| Proposal [0.0633809  0.2533092  0.02833121]
# iteration: 3520| Acceptance rate: 0.4491477272727273| Log-Likelihood: -10526.75763435971| Proposal [0.05466071 0.30942145 0.02188193]
# iteration: 3530| Acceptance rate: 0.4478753541076487| Log-Likelihood: -10526.75763435971| Proposal [0.05466071 0.30942145 0.02188193]
# iteration: 3540| Acceptance rate: 0.4483050847457627| Log-Likelihood: -10526.697358467496| Proposal [0.06097004 0.22836558 0.02051591]
# iteration: 3550| Acceptance rate: 0.4484507042253521| Log-Likelihood: -10526.82741948316| Proposal [0.05674038 0.19245338 0.01691121]
# iteration: 3560| Acceptance rate: 0.44747191011235954| Log-Likelihood: -10526.523209158146| Proposal [0.05782383 0.22018539 0.0169327 ]
# iteration: 3570| Acceptance rate: 0.4470588235294118| Log-Likelihood: -10529.54917838743| Proposal [0.04899673 0.25161744 0.01465072]
# iteration: 3580| Acceptance rate: 0.4460893854748603| Log-Likelihood: -10529.737656017282| Proposal [0.05442538 0.20447991 0.01182926]
# iteration: 3590| Acceptance rate: 0.4456824512534819| Log-Likelihood: -10526.916716398027| Proposal [0.05711638 0.28667141 0.01729297]
# ...
# iteration: 3820| Acceptance rate: 0.4442408376963351| Log-Likelihood: -10527.205560929526| Proposal [0.05223865 0.29957712 0.02649476]
# iteration: 3830| Acceptance rate: 0.44386422976501305| Log-Likelihood: -10527.997351306036| Proposal [0.06090555 0.27568663 0.01758574]
# iteration: 3840| Acceptance rate: 0.44375| Log-Likelihood: -10528.458677969267| Proposal [0.07269986 0.20276204 0.02076483]
# iteration: 3850| Acceptance rate: 0.4438961038961039| Log-Likelihood: -10527.369772131291| Proposal [0.0620781  0.22011333 0.02391057]
# iteration: 3860| Acceptance rate: 0.4440414507772021| Log-Likelihood: -10527.384153457235| Proposal [0.05372883 0.31261138 0.02735423]
# iteration: 3870| Acceptance rate: 0.44289405684754524| Log-Likelihood: -10527.384153457235| Proposal [0.05372883 0.31261138 0.02735423]
# iteration: 3880| Acceptance rate: 0.4422680412371134| Log-Likelihood: -10527.668043876927| Proposal [0.04996526 0.31061921 0.0217888 ]
# iteration: 3890| Acceptance rate: 0.4424164524421594| Log-Likelihood: -10529.03988275657| Proposal [0.07019391 0.1833575  0.0255567 ]
# iteration: 3900| Acceptance rate: 0.44256410256410256| Log-Likelihood: -10529.170059842543| Proposal [0.04745077 0.20565678 0.02389863]
# iteration: 3910| Acceptance rate: 0.44194373401534526| Log-Likelihood: -10528.247870291683| Proposal [0.04949662 0.15223621 0.02215967]
# iteration: 3920| Acceptance rate: 0.4418367346938776| Log-Likelihood: -10526.756433487866| Proposal [0.05618343 0.26909087 0.01821276]
# iteration: 3930| Acceptance rate: 0.44122137404580153| Log-Likelihood: -10528.959916028947| Proposal [0.06051464 0.2198679  0.01638577]
# iteration: 3940| Acceptance rate: 0.44060913705583754| Log-Likelihood: -10527.291260845399| Proposal [0.05480945 0.27027277 0.01507033]
# iteration: 3950| Acceptance rate: 0.44| Log-Likelihood: -10527.734810374268| Proposal [0.05993998 0.30057791 0.02102624]
# iteration: 3960| Acceptance rate: 0.4398989898989899| Log-Likelihood: -10527.772462380302| Proposal [0.0662276  0.25762514 0.02261819]
# iteration: 3970| Acceptance rate: 0.4397984886649874| Log-Likelihood: -10527.729054103602| Proposal [0.06055736 0.21986276 0.02237513]
# iteration: 3980| Acceptance rate: 0.43894472361809045| Log-Likelihood: -10528.766260747623| Proposal [0.05212358 0.1562487  0.02727341]
# iteration: 3990| Acceptance rate: 0.4393483709273183| Log-Likelihood: -10527.290356266123| Proposal [0.06139946 0.22098706 0.01899943]
# iteration: 4000| Acceptance rate: 0.4385| Log-Likelihood: -10527.360053274371| Proposal [0.05731763 0.3261989  0.01836518]
# iteration: 4010| Acceptance rate: 0.43840399002493763| Log-Likelihood: -10526.536580070719| Proposal [0.05139122 0.21097207 0.02131252]
# iteration: 4020| Acceptance rate: 0.4383084577114428| Log-Likelihood: -10527.943054203552| Proposal [0.06409311 0.22277391 0.02115065]
# iteration: 4030| Acceptance rate: 0.43796526054590573| Log-Likelihood: -10527.10010607917| Proposal [0.05886555 0.25100437 0.02049   ]
# iteration: 4040| Acceptance rate: 0.43787128712871287| Log-Likelihood: -10529.247001890337| Proposal [0.04721037 0.27929213 0.01804193]
# iteration: 4050| Acceptance rate: 0.4372839506172839| Log-Likelihood: -10526.783704623514| Proposal [0.06439212 0.32907721 0.01860264]
# iteration: 4060| Acceptance rate: 0.4366995073891626| Log-Likelihood: -10527.891348697596| Proposal [0.07019527 0.2677711  0.01883011]
# iteration: 4070| Acceptance rate: 0.43734643734643736| Log-Likelihood: -10527.30842614479| Proposal [0.05212703 0.13618206 0.02185339]
# iteration: 4080| Acceptance rate: 0.43676470588235294| Log-Likelihood: -10527.0767354698| Proposal [0.05372087 0.24597041 0.01957859]
# iteration: 4090| Acceptance rate: 0.4366748166259169| Log-Likelihood: -10526.878672577279| Proposal [0.06342656 0.23765595 0.01992636]
# iteration: 4100| Acceptance rate: 0.4375609756097561| Log-Likelihood: -10527.436386307674| Proposal [0.05906833 0.27174105 0.01786499]
# iteration: 4110| Acceptance rate: 0.4384428223844282| Log-Likelihood: -10526.37015890788| Proposal [0.0541153  0.24773256 0.02316646]
# iteration: 4120| Acceptance rate: 0.4383495145631068| Log-Likelihood: -10526.403880066388| Proposal [0.05380848 0.27596456 0.02202841]
# iteration: 4130| Acceptance rate: 0.438498789346247| Log-Likelihood: -10526.794354064776| Proposal [0.05456399 0.22646742 0.02216896]
# iteration: 4140| Acceptance rate: 0.43816425120772945| Log-Likelihood: -10526.922971212936| Proposal [0.05320045 0.26793469 0.02329792]
# iteration: 4150| Acceptance rate: 0.4380722891566265| Log-Likelihood: -10527.107584095482| Proposal [0.05980353 0.22250801 0.02006668]
# iteration: 4160| Acceptance rate: 0.4377403846153846| Log-Likelihood: -10527.60868896819| Proposal [0.0603503  0.27936647 0.02205922]
# iteration: 4170| Acceptance rate: 0.43764988009592326| Log-Likelihood: -10528.615050392284| Proposal [0.05103364 0.33101731 0.02762421]
# iteration: 4180| Acceptance rate: 0.43779904306220097| Log-Likelihood: -10527.16287064499| Proposal [0.06550335 0.22034925 0.02095447]
# iteration: 4190| Acceptance rate: 0.4372315035799523| Log-Likelihood: -10527.156164241851| Proposal [0.05525159 0.31148427 0.02446881]
# iteration: 4200| Acceptance rate: 0.43714285714285717| Log-Likelihood: -10527.856087542988| Proposal [0.0521354  0.18281306 0.02312675]
# iteration: 4210| Acceptance rate: 0.4368171021377672| Log-Likelihood: -10528.284341019944| Proposal [0.04929179 0.32268645 0.02005344]
# iteration: 4220| Acceptance rate: 0.4362559241706161| Log-Likelihood: -10528.489905227962| Proposal [0.05795643 0.30888373 0.02947397]
# iteration: 4230| Acceptance rate: 0.43664302600472815| Log-Likelihood: -10531.153974464733| Proposal [0.04445176 0.19684714 0.01603626]
# iteration: 4240| Acceptance rate: 0.43608490566037733| Log-Likelihood: -10528.473273054382| Proposal [0.05124611 0.14512064 0.0193582 ]
# iteration: 4250| Acceptance rate: 0.436| Log-Likelihood: -10527.618154871494| Proposal [0.05795591 0.17143753 0.02637651]
# iteration: 4260| Acceptance rate: 0.43591549295774645| Log-Likelihood: -10527.59537917017| Proposal [0.05750165 0.30886236 0.0271574 ]
# iteration: 4270| Acceptance rate: 0.43559718969555034| Log-Likelihood: -10526.770867483976| Proposal [0.05676308 0.2804591  0.02099387]
# iteration: 4280| Acceptance rate: 0.4355140186915888| Log-Likelihood: -10528.874791545| Proposal [0.07048345 0.31628244 0.02556205]
# iteration: 4290| Acceptance rate: 0.43496503496503497| Log-Likelihood: -10529.35335721583| Proposal [0.07026362 0.24835628 0.02482627]
# iteration: 4300| Acceptance rate: 0.43511627906976746| Log-Likelihood: -10527.96216459888| Proposal [0.06582125 0.25448674 0.02172933]
# iteration: 4310| Acceptance rate: 0.4345707656612529| Log-Likelihood: -10526.495296172043| Proposal [0.06436475 0.31579784 0.0206857 ]
# iteration: 4320| Acceptance rate: 0.4335648148148148| Log-Likelihood: -10526.495296172043| Proposal [0.06436475 0.31579784 0.0206857 ]
# iteration: 4330| Acceptance rate: 0.4327944572748268| Log-Likelihood: -10528.261168556217| Proposal [0.06817882 0.32545135 0.02253993]
# iteration: 4340| Acceptance rate: 0.4324884792626728| Log-Likelihood: -10527.46502192909| Proposal [0.06536311 0.28337101 0.01657672]
# iteration: 4350| Acceptance rate: 0.432183908045977| Log-Likelihood: -10528.298737595816| Proposal [0.06896647 0.23763776 0.01950382]
# iteration: 4360| Acceptance rate: 0.4323394495412844| Log-Likelihood: -10526.774623645251| Proposal [0.05226475 0.22100908 0.01920836]
# iteration: 4370| Acceptance rate: 0.43249427917620137| Log-Likelihood: -10528.0192354684| Proposal [0.05647095 0.30691789 0.01652177]
# iteration: 4380| Acceptance rate: 0.432648401826484| Log-Likelihood: -10528.958501637646| Proposal [0.06553938 0.11198022 0.01776206]
# iteration: 4390| Acceptance rate: 0.4328018223234624| Log-Likelihood: -10527.385015600634| Proposal [0.0611505  0.3227177  0.02410113]
# iteration: 4400| Acceptance rate: 0.4325| Log-Likelihood: -10528.727717261916| Proposal [0.04933635 0.28118351 0.02793434]
# iteration: 4410| Acceptance rate: 0.4326530612244898| Log-Likelihood: -10528.617810914875| Proposal [0.06770085 0.15167931 0.01729964]
# iteration: 4420| Acceptance rate: 0.4323529411764706| Log-Likelihood: -10527.67944435971| Proposal [0.0602927  0.21071869 0.02141067]
# iteration: 4430| Acceptance rate: 0.43182844243792323| Log-Likelihood: -10526.748638784877| Proposal [0.06059484 0.22892665 0.0180085 ]
# iteration: 4440| Acceptance rate: 0.43085585585585584| Log-Likelihood: -10526.748638784877| Proposal [0.06059484 0.22892665 0.0180085 ]
# iteration: 4450| Acceptance rate: 0.4312359550561798| Log-Likelihood: -10527.906285800595| Proposal [0.06756622 0.23025401 0.01823156]
# iteration: 4460| Acceptance rate: 0.4316143497757848| Log-Likelihood: -10529.136569991882| Proposal [0.06863828 0.20668963 0.01663373]
# iteration: 4470| Acceptance rate: 0.4319910514541387| Log-Likelihood: -10529.34648341595| Proposal [0.0470397  0.14312089 0.02240192]
# iteration: 4480| Acceptance rate: 0.43191964285714285| Log-Likelihood: -10527.005356103728| Proposal [0.0569787  0.23515957 0.02302544]
# iteration: 4490| Acceptance rate: 0.43207126948775054| Log-Likelihood: -10528.058029863298| Proposal [0.05087667 0.26627174 0.02167892]
# iteration: 4500| Acceptance rate: 0.4315555555555556| Log-Likelihood: -10527.989450200046| Proposal [0.06563196 0.19908167 0.01816352]
# iteration: 4510| Acceptance rate: 0.43148558758314853| Log-Likelihood: -10527.615551380311| Proposal [0.06656266 0.21896009 0.02074623]
# iteration: 4520| Acceptance rate: 0.4314159292035398| Log-Likelihood: -10527.154298629093| Proposal [0.05257375 0.27336762 0.02011722]
# iteration: 4530| Acceptance rate: 0.4313465783664459| Log-Likelihood: -10528.246270068556| Proposal [0.05107307 0.22430462 0.01468145]
# iteration: 4540| Acceptance rate: 0.43127753303964755| Log-Likelihood: -10528.016267233983| Proposal [0.05452136 0.25441735 0.02454468]
# iteration: 4550| Acceptance rate: 0.430989010989011| Log-Likelihood: -10527.774989029835| Proposal [0.05135799 0.18013584 0.02050767]
# iteration: 4560| Acceptance rate: 0.4309210526315789| Log-Likelihood: -10526.962647376551| Proposal [0.05939448 0.28363735 0.01877394]
# iteration: 4570| Acceptance rate: 0.4310722100656455| Log-Likelihood: -10526.949487103437| Proposal [0.05117407 0.28106224 0.02221792]
# iteration: 4580| Acceptance rate: 0.4310043668122271| Log-Likelihood: -10528.995387416022| Proposal [0.07361547 0.23538582 0.0199415 ]
# iteration: 4590| Acceptance rate: 0.43137254901960786| Log-Likelihood: -10527.779695825015| Proposal [0.05188772 0.25779198 0.02679293]
# iteration: 4600| Acceptance rate: 0.43130434782608695| Log-Likelihood: -10528.063561660192| Proposal [0.05674924 0.27686411 0.01601065]
# iteration: 4610| Acceptance rate: 0.4314533622559653| Log-Likelihood: -10526.495804671933| Proposal [0.05405737 0.30574398 0.0222595 ]
# iteration: 4620| Acceptance rate: 0.43073593073593075| Log-Likelihood: -10526.126893956141| Proposal [0.05786055 0.2537621  0.02293589]
# iteration: 4630| Acceptance rate: 0.4306695464362851| Log-Likelihood: -10527.12462669651| Proposal [0.06183327 0.3061989  0.02337172]
# iteration: 4640| Acceptance rate: 0.43103448275862066| Log-Likelihood: -10528.008237976002| Proposal [0.06099994 0.15984874 0.01581305]
# iteration: 4650| Acceptance rate: 0.4313978494623656| Log-Likelihood: -10527.610732771334| Proposal [0.06386322 0.24566918 0.01795853]
# iteration: 4660| Acceptance rate: 0.43068669527896997| Log-Likelihood: -10526.39278069973| Proposal [0.05900193 0.31945113 0.01952988]
# iteration: 4670| Acceptance rate: 0.430406852248394| Log-Likelihood: -10526.933898273584| Proposal [0.06352147 0.26420456 0.01924694]
# iteration: 4680| Acceptance rate: 0.4305555555555556| Log-Likelihood: -10527.92679588132| Proposal [0.07037464 0.3240106  0.01575798]
# iteration: 4690| Acceptance rate: 0.4309168443496802| Log-Likelihood: -10527.132070054198| Proposal [0.06411223 0.26524566 0.01717396]
# iteration: 4700| Acceptance rate: 0.4306382978723404| Log-Likelihood: -10527.302771603965| Proposal [0.06190774 0.32854039 0.02360036]
# iteration: 4710| Acceptance rate: 0.43014861995753717| Log-Likelihood: -10529.096487271625| Proposal [0.06436896 0.10111477 0.02043813]
# iteration: 4720| Acceptance rate: 0.43072033898305084| Log-Likelihood: -10526.53279875763| Proposal [0.05735548 0.26954718 0.02370189]
# iteration: 4730| Acceptance rate: 0.43044397463002115| Log-Likelihood: -10527.648521822948| Proposal [0.053725   0.3198577  0.01855942]
# iteration: 4740| Acceptance rate: 0.43037974683544306| Log-Likelihood: -10531.143112100386| Proposal [0.05279425 0.08907532 0.0244919 ]
# iteration: 4750| Acceptance rate: 0.4301052631578947| Log-Likelihood: -10528.049363936116| Proposal [0.06991379 0.23300508 0.01645457]
# iteration: 4760| Acceptance rate: 0.42962184873949577| Log-Likelihood: -10528.363852559005| Proposal [0.06824828 0.11865016 0.01889067]
# iteration: 4770| Acceptance rate: 0.4293501048218029| Log-Likelihood: -10531.329066736724| Proposal [0.04766175 0.11542817 0.01839015]
# iteration: 4780| Acceptance rate: 0.4297071129707113| Log-Likelihood: -10529.982925470953| Proposal [0.05084167 0.09715675 0.01658845]
# iteration: 4790| Acceptance rate: 0.4292275574112735| Log-Likelihood: -10527.948568960213| Proposal [0.05637334 0.1807936  0.01618632]
# iteration: 4800| Acceptance rate: 0.42875| Log-Likelihood: -10528.807944536613| Proposal [0.06559001 0.16557684 0.01652276]
# iteration: 4810| Acceptance rate: 0.4288981288981289| Log-Likelihood: -10529.184177418107| Proposal [0.04630876 0.27030636 0.01817071]
# iteration: 4820| Acceptance rate: 0.4284232365145228| Log-Likelihood: -10526.009868155608| Proposal [0.05841802 0.28216469 0.0178108 ]
# iteration: 4830| Acceptance rate: 0.427536231884058| Log-Likelihood: -10526.009868155608| Proposal [0.05841802 0.28216469 0.0178108 ]
# iteration: 4840| Acceptance rate: 0.42665289256198347| Log-Likelihood: -10526.009868155608| Proposal [0.05841802 0.28216469 0.0178108 ]
# iteration: 4850| Acceptance rate: 0.4268041237113402| Log-Likelihood: -10527.414379117576| Proposal [0.06011098 0.19918332 0.02054976]
# iteration: 4860| Acceptance rate: 0.42674897119341565| Log-Likelihood: -10526.680027801785| Proposal [0.05994107 0.23467986 0.0184142 ]
# iteration: 4870| Acceptance rate: 0.42669404517453796| Log-Likelihood: -10528.349912827145| Proposal [0.06407392 0.26660958 0.01985867]
# iteration: 4880| Acceptance rate: 0.426844262295082| Log-Likelihood: -10526.76588056564| Proposal [0.06290868 0.3192107  0.01888831]
# iteration: 4890| Acceptance rate: 0.4269938650306748| Log-Likelihood: -10528.148729697778| Proposal [0.06547137 0.29775963 0.02638202]
# iteration: 4900| Acceptance rate: 0.4269387755102041| Log-Likelihood: -10528.485558034921| Proposal [0.05542457 0.25507485 0.01466889]
# iteration: 4910| Acceptance rate: 0.4268839103869654| Log-Likelihood: -10527.638553333785| Proposal [0.06229753 0.21288354 0.02235999]
# iteration: 4920| Acceptance rate: 0.4268292682926829| Log-Likelihood: -10526.752067001791| Proposal [0.05248388 0.18271722 0.02173256]
# iteration: 4930| Acceptance rate: 0.4259634888438134| Log-Likelihood: -10526.752067001791| Proposal [0.05248388 0.18271722 0.02173256]
# iteration: 4940| Acceptance rate: 0.42550607287449393| Log-Likelihood: -10527.618060927882| Proposal [0.0564349  0.2509654  0.01914528]
# iteration: 4950| Acceptance rate: 0.4262626262626263| Log-Likelihood: -10526.88792162003| Proposal [0.0594328  0.28543753 0.02617513]
# iteration: 4960| Acceptance rate: 0.4266129032258065| Log-Likelihood: -10527.153323688775| Proposal [0.05824005 0.19505889 0.02080795]
# iteration: 4970| Acceptance rate: 0.42696177062374246| Log-Likelihood: -10526.40190029904| Proposal [0.05879861 0.30137068 0.02237263]
# iteration: 4980| Acceptance rate: 0.42730923694779116| Log-Likelihood: -10528.856259697382| Proposal [0.06527619 0.15859892 0.02262901]
# iteration: 4990| Acceptance rate: 0.4276553106212425| Log-Likelihood: -10527.622352801076| Proposal [0.05626893 0.31679942 0.02595207]
# 9770.895325324003

# %%
burn_in = 0

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'])
# Out:
# -10525.24840889768
# The Maximum Likelihood Estimate is [0.05638749 0.24530407 0.02143159] w/ LL of -10525.24840889768

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\eta$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[2,burn_in:])} and std: {np.std(theta[2,burn_in:])}")
# plt.hist(theta[2,burn_in:],density=True,bins = 50)
# plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[3,burn_in:])} and std: {np.std(theta[3,burn_in:])}")
# plt.hist(theta[3,burn_in:],density=True,bins = 50)
# plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 192.12870625405156
# Root Mean Squared Error for beta 0.12141442340306688

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
'''Pair plots'''

plt.title('Pairwise Plot of $\\gamma$ and $\\eta$')
plt.xlabel('$\\gamma$')
plt.ylabel('$\\eta$')
plt.scatter(pmcmc_output['accepted_params'][0,burn_in:],pmcmc_output['accepted_params'][1,burn_in:],s=0.1)

# %%
'''Pair plots'''

plt.title('Trace Plot of $\\eta$')
plt.xlabel('Iteration')
plt.ylabel('$\\eta$')
plt.plot(pmcmc_output['accepted_params'][1,burn_in:])
