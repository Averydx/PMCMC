# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
from particle_filter import particlefilter
from models import SEIR_model,SEIR_Obs
from pmcmc import particlemcmc
from math_utils import gammaln_nr

# %%
'''Simulated Data, setting up the SIR model'''

rng = np.random.default_rng(0)

gamma = 1/14
eta = 1/7
q = 0.1
mu = 0.004
rho = 0.1

T = 120
dt = 1.
t_vec = np.arange(0,T,dt)

N = 100_000
I = 5
E = 5


beta_par = {'b_0':0.4,'b_inf': 0.1, 'tau': 5,'T':20}

def beta_sim(par,t):
    if(t < par['T']):
        return 0.4
    
    return par['b_inf'] + (par['b_0'] - par['b_inf']) * np.exp(-(t - par['T'])/par['tau'])

betas = np.array([beta_sim(beta_par,t) for t in t_vec])

state = np.zeros((5,len(t_vec)))
state[:,0] = np.array([N - I - E,E, I, 0,0])

plt.title('Generative $\\beta_t$')
plt.xlabel('Time (Days)')
plt.plot(t_vec,betas)

for time_index in range(1,len(t_vec)):

    new_E = ((betas[time_index - 1] * (state[1,time_index -1] + q * state[2,time_index - 1]) * state[0,time_index - 1]/np.sum(state[:,time_index-1])) * dt)
    new_I = ((eta * state[1,time_index - 1]) * dt)
    new_ER = ((gamma * state[1,time_index -1]) * dt)
    new_IR = ((gamma * state[2,time_index - 1]) * dt)
    new_D = ((mu * state[2,time_index - 1]) * dt)


    state[0,time_index] = np.maximum(0.,state[0,time_index - 1] - new_E) #S 
    state[1,time_index] = np.maximum(0.,state[1,time_index - 1] + new_E - new_I - new_ER) #E
    state[2,time_index] = np.maximum(0.,state[2,time_index-1] + new_I - new_IR - new_D) #I
    state[3,time_index] = np.maximum(0.,state[3,time_index - 1] + new_ER + new_IR) #R
    state[4,time_index] = new_I

# %%
plt.yscale('log')
plt.title('Plot of SEIR Model')
plt.xlabel('Time (Days)')
plt.plot(t_vec,state.T)
# Out:
# [<matplotlib.lines.Line2D at 0x2041fc10590>,
#  <matplotlib.lines.Line2D at 0x2041da96c90>,
#  <matplotlib.lines.Line2D at 0x2041fc7e210>,
#  <matplotlib.lines.Line2D at 0x2041fc7e5d0>,
#  <matplotlib.lines.Line2D at 0x2041fc7e810>]

# %%
n = 100
sigma = 0.1
rho = 0.4

data = np.expand_dims(rng.poisson(state[4,::int(1/dt)]),0)
#data = np.expand_dims(state[4,::int(1/dt)],0)

plt.title('Plot of Generative Data')
plt.xlabel('Time (Days)')
plt.ylabel('Case Count')
plt.plot(data.T)

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,eta = model_params

    '''OU Process'''
    sig = 1.0
    mu = -2.0
    lam = 1/100

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((eta * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())#beta_sim(beta_par,t)#

        observations[index,0,t] = new_I

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    var = 15**2
    #return data_point*np.log(particle_observations[:,0]) - gammaln_nr(data_point + 1) - particle_observations[:,0]
    return -((((data_point - particle_observations[:,0])**2)/(2 * var)) + np.log(np.sqrt(2 * np.pi * var)))

# %%
#(0.06547914,0.28245005)
#(1/14 = 0.07,1/7 = 0.14)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(0,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,eta),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 3.010719199955929

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -451.540109976756
# Root Mean Squared Error for the Data 17.08546462099322

# %%
pmcmc_rng = np.random.default_rng(0)

num_particles = 1000

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 1/15.,max_val = 1/3)

pmcmc_params = {'iterations':5_000,
                'init_params':np.array([0.1,0.1]),
                'prior':seir_prior,
                'init_cov':0.05 * np.eye(2),
                'burn_in':100}

pf_params = {'num_particles':1_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 20| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 30| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 40| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 50| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 60| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 70| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 80| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 90| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 100| Acceptance rate: 0.0| Log-Likelihood: -447.5676820733232| Proposal [0.1 0.1]
# iteration: 110| Acceptance rate: 0.01818181818181818| Log-Likelihood: -447.74985774167334| Proposal [0.11568931 0.09186993]
# iteration: 120| Acceptance rate: 0.058333333333333334| Log-Likelihood: -447.40821507529495| Proposal [0.10931414 0.08571158]
# iteration: 130| Acceptance rate: 0.12307692307692308| Log-Likelihood: -447.9994783244805| Proposal [0.11049989 0.08973117]
# iteration: 140| Acceptance rate: 0.18571428571428572| Log-Likelihood: -448.2664512816052| Proposal [0.10292095 0.0840846 ]
# iteration: 150| Acceptance rate: 0.22666666666666666| Log-Likelihood: -447.5080490901514| Proposal [0.13382648 0.10476802]
# iteration: 160| Acceptance rate: 0.24375| Log-Likelihood: -447.38298431609564| Proposal [0.13411016 0.10346609]
# iteration: 170| Acceptance rate: 0.27647058823529413| Log-Likelihood: -447.75760224875324| Proposal [0.11124235 0.10163576]
# iteration: 180| Acceptance rate: 0.3| Log-Likelihood: -447.43752624161425| Proposal [0.13740738 0.10397624]
# iteration: 190| Acceptance rate: 0.29473684210526313| Log-Likelihood: -447.2953942645595| Proposal [0.12588188 0.10934169]
# iteration: 200| Acceptance rate: 0.31| Log-Likelihood: -447.57332298619144| Proposal [0.09595538 0.09888013]
# iteration: 210| Acceptance rate: 0.319047619047619| Log-Likelihood: -447.1732647107542| Proposal [0.13511755 0.0995683 ]
# iteration: 220| Acceptance rate: 0.32727272727272727| Log-Likelihood: -447.48459544423025| Proposal [0.13475773 0.09853173]
# iteration: 230| Acceptance rate: 0.34347826086956523| Log-Likelihood: -447.65464478343023| Proposal [0.11879659 0.0945858 ]
# iteration: 240| Acceptance rate: 0.3625| Log-Likelihood: -448.1870037872533| Proposal [0.10814822 0.07691428]
# iteration: 250| Acceptance rate: 0.376| Log-Likelihood: -447.6159013766702| Proposal [0.11236896 0.09040377]
# iteration: 260| Acceptance rate: 0.38076923076923075| Log-Likelihood: -447.1618701630756| Proposal [0.11849281 0.1074021 ]
# iteration: 270| Acceptance rate: 0.3814814814814815| Log-Likelihood: -447.4505687094203| Proposal [0.13446401 0.1379908 ]
# iteration: 280| Acceptance rate: 0.3892857142857143| Log-Likelihood: -447.6358731376869| Proposal [0.07180345 0.1807499 ]
# iteration: 290| Acceptance rate: 0.3896551724137931| Log-Likelihood: -449.8756625933544| Proposal [0.05794743 0.08760235]
# iteration: 300| Acceptance rate: 0.3933333333333333| Log-Likelihood: -447.6940670539766| Proposal [0.12771628 0.14852412]
# iteration: 310| Acceptance rate: 0.3967741935483871| Log-Likelihood: -448.02087994050794| Proposal [0.07598845 0.11069145]
# iteration: 320| Acceptance rate: 0.40625| Log-Likelihood: -448.18752412200115| Proposal [0.12173307 0.24610141]
# iteration: 330| Acceptance rate: 0.403030303030303| Log-Likelihood: -448.78764014728563| Proposal [0.06349971 0.30516008]
# iteration: 340| Acceptance rate: 0.40588235294117647| Log-Likelihood: -448.441309737884| Proposal [0.06371049 0.28721961]
# iteration: 350| Acceptance rate: 0.4114285714285714| Log-Likelihood: -448.30533285972933| Proposal [0.05239565 0.24062465]
# iteration: 360| Acceptance rate: 0.41944444444444445| Log-Likelihood: -448.3896057733257| Proposal [0.07195823 0.11375323]
# iteration: 370| Acceptance rate: 0.4243243243243243| Log-Likelihood: -448.35227492020965| Proposal [0.11850515 0.28892835]
# iteration: 380| Acceptance rate: 0.4236842105263158| Log-Likelihood: -447.1189884058304| Proposal [0.14027804 0.10045461]
# iteration: 390| Acceptance rate: 0.4128205128205128| Log-Likelihood: -447.1189884058304| Proposal [0.14027804 0.10045461]
# iteration: 400| Acceptance rate: 0.41| Log-Likelihood: -447.6353422707502| Proposal [0.06446435 0.19284569]
# iteration: 410| Acceptance rate: 0.4097560975609756| Log-Likelihood: -447.7665958961953| Proposal [0.14081127 0.15079422]
# iteration: 420| Acceptance rate: 0.4095238095238095| Log-Likelihood: -448.0270781790478| Proposal [0.13975063 0.15021061]
# iteration: 430| Acceptance rate: 0.40930232558139534| Log-Likelihood: -447.7719345097207| Proposal [0.0485292  0.24318517]
# iteration: 440| Acceptance rate: 0.4090909090909091| Log-Likelihood: -447.8965839593817| Proposal [0.083158   0.17411981]
# iteration: 450| Acceptance rate: 0.4088888888888889| Log-Likelihood: -447.5030261580975| Proposal [0.0649906  0.22321283]
# iteration: 460| Acceptance rate: 0.40869565217391307| Log-Likelihood: -447.6998913149986| Proposal [0.07945796 0.22133156]
# iteration: 470| Acceptance rate: 0.4106382978723404| Log-Likelihood: -448.81459877731163| Proposal [0.09073202 0.07736172]
# iteration: 480| Acceptance rate: 0.41041666666666665| Log-Likelihood: -447.620805063023| Proposal [0.06548986 0.20997374]
# iteration: 490| Acceptance rate: 0.41020408163265304| Log-Likelihood: -447.4733091604994| Proposal [0.0914325 0.1294245]
# iteration: 500| Acceptance rate: 0.414| Log-Likelihood: -447.7972884695919| Proposal [0.12550327 0.06714544]
# iteration: 510| Acceptance rate: 0.41568627450980394| Log-Likelihood: -447.6909012600079| Proposal [0.11307789 0.08487392]
# iteration: 520| Acceptance rate: 0.41346153846153844| Log-Likelihood: -447.90172093796764| Proposal [0.08788664 0.11405028]
# iteration: 530| Acceptance rate: 0.4169811320754717| Log-Likelihood: -448.162681389093| Proposal [0.08079508 0.22217942]
# iteration: 540| Acceptance rate: 0.4185185185185185| Log-Likelihood: -447.81460908401493| Proposal [0.13517932 0.14281196]
# iteration: 550| Acceptance rate: 0.4163636363636364| Log-Likelihood: -447.2336050545687| Proposal [0.09675319 0.13982202]
# iteration: 560| Acceptance rate: 0.4160714285714286| Log-Likelihood: -448.66369054119315| Proposal [0.07665312 0.0869135 ]
# iteration: 570| Acceptance rate: 0.41754385964912283| Log-Likelihood: -447.7781113751739| Proposal [0.12545546 0.19973955]
# iteration: 580| Acceptance rate: 0.41551724137931034| Log-Likelihood: -447.2815630257818| Proposal [0.14242607 0.12534137]
# iteration: 590| Acceptance rate: 0.4152542372881356| Log-Likelihood: -447.4186519567064| Proposal [0.0868422  0.10753201]
# iteration: 600| Acceptance rate: 0.41833333333333333| Log-Likelihood: -447.74136282617746| Proposal [0.11564422 0.15148765]
# iteration: 610| Acceptance rate: 0.42131147540983604| Log-Likelihood: -447.3448505442102| Proposal [0.10980181 0.1801073 ]
# iteration: 620| Acceptance rate: 0.4290322580645161| Log-Likelihood: -447.84913558190317| Proposal [0.12043396 0.28405536]
# iteration: 630| Acceptance rate: 0.4301587301587302| Log-Likelihood: -448.3915686719132| Proposal [0.06613012 0.11461533]
# iteration: 640| Acceptance rate: 0.43125| Log-Likelihood: -448.15136010653083| Proposal [0.07251748 0.13682672]
# iteration: 650| Acceptance rate: 0.4323076923076923| Log-Likelihood: -448.0695104436295| Proposal [0.07839603 0.14428915]
# iteration: 660| Acceptance rate: 0.43787878787878787| Log-Likelihood: -447.4697653376146| Proposal [0.1065331  0.17850347]
# iteration: 670| Acceptance rate: 0.4373134328358209| Log-Likelihood: -448.1737398297878| Proposal [0.0512748  0.18137077]
# iteration: 680| Acceptance rate: 0.4426470588235294| Log-Likelihood: -447.5959768256861| Proposal [0.12105399 0.16520338]
# iteration: 690| Acceptance rate: 0.4420289855072464| Log-Likelihood: -447.96067927887026| Proposal [0.10246184 0.18521287]
# iteration: 700| Acceptance rate: 0.4442857142857143| Log-Likelihood: -447.2485913683563| Proposal [0.12455407 0.14343276]
# iteration: 710| Acceptance rate: 0.44647887323943664| Log-Likelihood: -448.02491704107945| Proposal [0.11634892 0.22192261]
# iteration: 720| Acceptance rate: 0.44583333333333336| Log-Likelihood: -448.19526946090616| Proposal [0.1407758  0.28172633]
# iteration: 730| Acceptance rate: 0.4438356164383562| Log-Likelihood: -447.2878640131812| Proposal [0.11064475 0.14066619]
# iteration: 740| Acceptance rate: 0.4418918918918919| Log-Likelihood: -447.90329538823005| Proposal [0.06994268 0.14786177]
# iteration: 750| Acceptance rate: 0.44266666666666665| Log-Likelihood: -447.7168702519695| Proposal [0.13268466 0.21376578]
# iteration: 760| Acceptance rate: 0.4407894736842105| Log-Likelihood: -448.4540440689443| Proposal [0.13608843 0.28306555]
# iteration: 770| Acceptance rate: 0.44415584415584414| Log-Likelihood: -447.6362140887758| Proposal [0.14036937 0.1446853 ]
# iteration: 780| Acceptance rate: 0.44358974358974357| Log-Likelihood: -447.74592970106687| Proposal [0.11063652 0.10665605]
# iteration: 790| Acceptance rate: 0.4443037974683544| Log-Likelihood: -447.13522731103956| Proposal [0.1378291 0.1695534]
# iteration: 800| Acceptance rate: 0.4425| Log-Likelihood: -448.01051971427637| Proposal [0.12728915 0.19860657]
# iteration: 810| Acceptance rate: 0.4419753086419753| Log-Likelihood: -447.18002380437383| Proposal [0.1144292  0.08218749]
# iteration: 820| Acceptance rate: 0.44390243902439025| Log-Likelihood: -447.3698558415757| Proposal [0.11718144 0.13047798]
# iteration: 830| Acceptance rate: 0.44216867469879517| Log-Likelihood: -447.92456606740205| Proposal [0.1259069  0.11364642]
# iteration: 840| Acceptance rate: 0.4392857142857143| Log-Likelihood: -447.1559255079285| Proposal [0.13782417 0.13310171]
# iteration: 850| Acceptance rate: 0.4376470588235294| Log-Likelihood: -447.52688090181704| Proposal [0.12002403 0.08223686]
# iteration: 860| Acceptance rate: 0.43953488372093025| Log-Likelihood: -447.2647628663998| Proposal [0.13799527 0.09745989]
# iteration: 870| Acceptance rate: 0.43908045977011495| Log-Likelihood: -447.5405549316973| Proposal [0.12325088 0.12088166]
# iteration: 880| Acceptance rate: 0.4409090909090909| Log-Likelihood: -448.28551235585326| Proposal [0.08346263 0.09537974]
# iteration: 890| Acceptance rate: 0.44269662921348313| Log-Likelihood: -447.6111701294384| Proposal [0.09505669 0.17922096]
# iteration: 900| Acceptance rate: 0.4411111111111111| Log-Likelihood: -447.8824275189969| Proposal [0.10213308 0.18162352]
# iteration: 910| Acceptance rate: 0.43956043956043955| Log-Likelihood: -448.8046350184229| Proposal [0.09575455 0.31770353]
# iteration: 920| Acceptance rate: 0.4423913043478261| Log-Likelihood: -447.781413528839| Proposal [0.10926141 0.20826865]
# iteration: 930| Acceptance rate: 0.44086021505376344| Log-Likelihood: -447.599086503197| Proposal [0.11909264 0.18818022]
# iteration: 940| Acceptance rate: 0.44042553191489364| Log-Likelihood: -447.1376672517365| Proposal [0.12489793 0.11201719]
# iteration: 950| Acceptance rate: 0.43894736842105264| Log-Likelihood: -447.9755637083| Proposal [0.14284094 0.20498533]
# iteration: 960| Acceptance rate: 0.44166666666666665| Log-Likelihood: -448.66714803411355| Proposal [0.07428974 0.32334773]
# iteration: 970| Acceptance rate: 0.44536082474226807| Log-Likelihood: -447.5746295922893| Proposal [0.0614138 0.1979209]
# iteration: 980| Acceptance rate: 0.44387755102040816| Log-Likelihood: -447.62321989320674| Proposal [0.07372655 0.20218112]
# iteration: 990| Acceptance rate: 0.4444444444444444| Log-Likelihood: -447.7705641933744| Proposal [0.06818693 0.20156944]
# iteration: 1000| Acceptance rate: 0.446| Log-Likelihood: -447.57476882245| Proposal [0.09116032 0.23315914]
# iteration: 1010| Acceptance rate: 0.44653465346534654| Log-Likelihood: -447.92358148090966| Proposal [0.13365361 0.22300305]
# iteration: 1020| Acceptance rate: 0.45| Log-Likelihood: -447.47660944661123| Proposal [0.09866195 0.24350202]
# iteration: 1030| Acceptance rate: 0.4495145631067961| Log-Likelihood: -448.061608365511| Proposal [0.06366445 0.25398006]
# iteration: 1040| Acceptance rate: 0.44903846153846155| Log-Likelihood: -447.52372621064103| Proposal [0.09448911 0.16953715]
# iteration: 1050| Acceptance rate: 0.4504761904761905| Log-Likelihood: -448.189545123082| Proposal [0.05535517 0.14509736]
# iteration: 1060| Acceptance rate: 0.4509433962264151| Log-Likelihood: -447.57892163064525| Proposal [0.10500441 0.24074664]
# iteration: 1070| Acceptance rate: 0.44953271028037384| Log-Likelihood: -448.6148492231886| Proposal [0.05821847 0.16166048]
# iteration: 1080| Acceptance rate: 0.44907407407407407| Log-Likelihood: -447.61667114602074| Proposal [0.11902644 0.14142201]
# iteration: 1090| Acceptance rate: 0.44770642201834865| Log-Likelihood: -447.96422394062176| Proposal [0.06281391 0.1651194 ]
# iteration: 1100| Acceptance rate: 0.4490909090909091| Log-Likelihood: -448.19342061207965| Proposal [0.0571544  0.25105795]
# iteration: 1110| Acceptance rate: 0.4486486486486487| Log-Likelihood: -448.6804387124832| Proposal [0.06544599 0.32914247]
# iteration: 1120| Acceptance rate: 0.4473214285714286| Log-Likelihood: -448.79196134671366| Proposal [0.03584105 0.28184304]
# iteration: 1130| Acceptance rate: 0.4469026548672566| Log-Likelihood: -447.24630467890336| Proposal [0.11840999 0.11634033]
# iteration: 1140| Acceptance rate: 0.44649122807017544| Log-Likelihood: -447.88089288208886| Proposal [0.05966996 0.22773793]
# iteration: 1150| Acceptance rate: 0.44521739130434784| Log-Likelihood: -447.13194801927085| Proposal [0.13427004 0.0737822 ]
# iteration: 1160| Acceptance rate: 0.44482758620689655| Log-Likelihood: -448.09305879914297| Proposal [0.11754232 0.2629685 ]
# iteration: 1170| Acceptance rate: 0.44529914529914527| Log-Likelihood: -448.47032901266005| Proposal [0.03915967 0.23748933]
# iteration: 1180| Acceptance rate: 0.4440677966101695| Log-Likelihood: -447.21256806370354| Proposal [0.13920007 0.13496396]
# iteration: 1190| Acceptance rate: 0.44285714285714284| Log-Likelihood: -447.99836803221314| Proposal [0.05725566 0.14322675]
# iteration: 1200| Acceptance rate: 0.44333333333333336| Log-Likelihood: -447.7789432225659| Proposal [0.09253816 0.14099558]
# iteration: 1210| Acceptance rate: 0.44297520661157025| Log-Likelihood: -448.4198380776911| Proposal [0.08189573 0.28094686]
# iteration: 1220| Acceptance rate: 0.4418032786885246| Log-Likelihood: -448.4772011518521| Proposal [0.06830251 0.12959064]
# iteration: 1230| Acceptance rate: 0.44390243902439025| Log-Likelihood: -447.84048351121885| Proposal [0.08306049 0.2138366 ]
# iteration: 1240| Acceptance rate: 0.4435483870967742| Log-Likelihood: -448.05778580129186| Proposal [0.08981864 0.10143198]
# iteration: 1250| Acceptance rate: 0.4448| Log-Likelihood: -448.08349617327923| Proposal [0.04199441 0.16982351]
# iteration: 1260| Acceptance rate: 0.44206349206349205| Log-Likelihood: -447.8185904760045| Proposal [0.08166788 0.10580504]
# iteration: 1270| Acceptance rate: 0.44173228346456694| Log-Likelihood: -447.77190534358203| Proposal [0.09740977 0.11420492]
# iteration: 1280| Acceptance rate: 0.43984375| Log-Likelihood: -447.44407948923816| Proposal [0.11076483 0.2029557 ]
# iteration: 1290| Acceptance rate: 0.44031007751937984| Log-Likelihood: -447.96989878506065| Proposal [0.07535963 0.26169227]
# iteration: 1300| Acceptance rate: 0.44153846153846155| Log-Likelihood: -447.93512278603555| Proposal [0.10066997 0.27915883]
# iteration: 1310| Acceptance rate: 0.4404580152671756| Log-Likelihood: -447.29387958983506| Proposal [0.09063498 0.16646873]
# iteration: 1320| Acceptance rate: 0.4393939393939394| Log-Likelihood: -447.4167727541288| Proposal [0.08531625 0.17899159]
# iteration: 1330| Acceptance rate: 0.4398496240601504| Log-Likelihood: -447.47149643431385| Proposal [0.12636    0.14049912]
# iteration: 1340| Acceptance rate: 0.44029850746268656| Log-Likelihood: -447.77699292644326| Proposal [0.08881957 0.21308305]
# iteration: 1350| Acceptance rate: 0.43925925925925924| Log-Likelihood: -446.85839315199905| Proposal [0.12337861 0.14100131]
# iteration: 1360| Acceptance rate: 0.43823529411764706| Log-Likelihood: -447.60234300321235| Proposal [0.12335381 0.1419766 ]
# iteration: 1370| Acceptance rate: 0.4394160583941606| Log-Likelihood: -447.07840711370045| Proposal [0.1154788  0.08606001]
# iteration: 1380| Acceptance rate: 0.4398550724637681| Log-Likelihood: -447.4692333887129| Proposal [0.07262698 0.18253932]
# iteration: 1390| Acceptance rate: 0.44100719424460433| Log-Likelihood: -447.4688511538984| Proposal [0.10906789 0.12372807]
# iteration: 1400| Acceptance rate: 0.44142857142857145| Log-Likelihood: -447.89327089420453| Proposal [0.12097369 0.13306359]
# iteration: 1410| Acceptance rate: 0.44113475177304967| Log-Likelihood: -447.1305571186862| Proposal [0.13840978 0.10733815]
# iteration: 1420| Acceptance rate: 0.44014084507042256| Log-Likelihood: -448.3249205126086| Proposal [0.05974998 0.1448655 ]
# iteration: 1430| Acceptance rate: 0.44195804195804195| Log-Likelihood: -447.54265103075016| Proposal [0.12124915 0.17435843]
# iteration: 1440| Acceptance rate: 0.44375| Log-Likelihood: -447.29559007365924| Proposal [0.10699458 0.16382024]
# iteration: 1450| Acceptance rate: 0.44275862068965516| Log-Likelihood: -448.19707545329845| Proposal [0.06195091 0.16832115]
# iteration: 1460| Acceptance rate: 0.4452054794520548| Log-Likelihood: -447.29609690627825| Proposal [0.1320587  0.15270307]
# iteration: 1470| Acceptance rate: 0.445578231292517| Log-Likelihood: -448.1373883322584| Proposal [0.08965893 0.12081631]
# iteration: 1480| Acceptance rate: 0.4466216216216216| Log-Likelihood: -447.3425786081089| Proposal [0.13361944 0.15988689]
# iteration: 1490| Acceptance rate: 0.4469798657718121| Log-Likelihood: -447.9480631281566| Proposal [0.0872408 0.1428984]
# iteration: 1500| Acceptance rate: 0.44733333333333336| Log-Likelihood: -447.76552692909763| Proposal [0.07005189 0.2373016 ]
# iteration: 1510| Acceptance rate: 0.447682119205298| Log-Likelihood: -447.8524601298613| Proposal [0.11925164 0.09102587]
# iteration: 1520| Acceptance rate: 0.4486842105263158| Log-Likelihood: -446.9490161909256| Proposal [0.13478423 0.08181091]
# iteration: 1530| Acceptance rate: 0.44640522875816996| Log-Likelihood: -447.72231109633685| Proposal [0.08186119 0.20378548]
# iteration: 1540| Acceptance rate: 0.4474025974025974| Log-Likelihood: -447.43177616486685| Proposal [0.13754803 0.15537095]
# iteration: 1550| Acceptance rate: 0.44516129032258067| Log-Likelihood: -448.3885861243932| Proposal [0.12988342 0.27765349]
# iteration: 1560| Acceptance rate: 0.44294871794871793| Log-Likelihood: -447.41554088826524| Proposal [0.1356037  0.12271997]
# iteration: 1570| Acceptance rate: 0.44331210191082804| Log-Likelihood: -448.39072495683826| Proposal [0.05204423 0.15623411]
# iteration: 1580| Acceptance rate: 0.44367088607594934| Log-Likelihood: -447.53088643277414| Proposal [0.07184168 0.1876939 ]
# iteration: 1590| Acceptance rate: 0.4440251572327044| Log-Likelihood: -447.8208658720019| Proposal [0.06709017 0.18932222]
# iteration: 1600| Acceptance rate: 0.443125| Log-Likelihood: -447.2174171692121| Proposal [0.13784607 0.09606447]
# iteration: 1610| Acceptance rate: 0.4434782608695652| Log-Likelihood: -448.61199940485545| Proposal [0.12865797 0.32686984]
# iteration: 1620| Acceptance rate: 0.4419753086419753| Log-Likelihood: -447.86451245610414| Proposal [0.08988494 0.12358336]
# iteration: 1630| Acceptance rate: 0.4404907975460123| Log-Likelihood: -447.4583005761393| Proposal [0.12143651 0.12675765]
# iteration: 1640| Acceptance rate: 0.4396341463414634| Log-Likelihood: -448.2643436311822| Proposal [0.10615955 0.07096071]
# iteration: 1650| Acceptance rate: 0.4393939393939394| Log-Likelihood: -447.4240933220809| Proposal [0.0896818 0.231844 ]
# iteration: 1660| Acceptance rate: 0.4403614457831325| Log-Likelihood: -448.0535935257393| Proposal [0.07588523 0.23150396]
# iteration: 1670| Acceptance rate: 0.4407185628742515| Log-Likelihood: -448.9964699361664| Proposal [0.08367554 0.07965799]
# iteration: 1680| Acceptance rate: 0.44107142857142856| Log-Likelihood: -448.5710856214266| Proposal [0.13510442 0.31744661]
# iteration: 1690| Acceptance rate: 0.4408284023668639| Log-Likelihood: -447.382167432227| Proposal [0.1205382  0.14166417]
# iteration: 1700| Acceptance rate: 0.44058823529411767| Log-Likelihood: -448.36085197751174| Proposal [0.07497965 0.23870677]
# iteration: 1710| Acceptance rate: 0.4426900584795322| Log-Likelihood: -448.8051625931253| Proposal [0.07238359 0.12466503]
# iteration: 1720| Acceptance rate: 0.4424418604651163| Log-Likelihood: -447.71657102905226| Proposal [0.06599608 0.16768034]
# iteration: 1730| Acceptance rate: 0.4416184971098266| Log-Likelihood: -447.4238677310399| Proposal [0.05502635 0.1563193 ]
# iteration: 1740| Acceptance rate: 0.44022988505747124| Log-Likelihood: -447.840621939342| Proposal [0.12845257 0.16764389]
# iteration: 1750| Acceptance rate: 0.44057142857142856| Log-Likelihood: -448.17304566346223| Proposal [0.09200747 0.0741965 ]
# iteration: 1760| Acceptance rate: 0.43920454545454546| Log-Likelihood: -447.6559624506199| Proposal [0.12584484 0.1463057 ]
# iteration: 1770| Acceptance rate: 0.43898305084745765| Log-Likelihood: -447.74515466655174| Proposal [0.0925976 0.1064862]
# iteration: 1780| Acceptance rate: 0.43764044943820224| Log-Likelihood: -448.08329443677144| Proposal [0.09438437 0.21598702]
# iteration: 1790| Acceptance rate: 0.43687150837988825| Log-Likelihood: -447.5698249035232| Proposal [0.08546236 0.09812225]
# iteration: 1800| Acceptance rate: 0.43666666666666665| Log-Likelihood: -448.3035418179614| Proposal [0.05797178 0.28367018]
# iteration: 1810| Acceptance rate: 0.43922651933701656| Log-Likelihood: -448.6193899247969| Proposal [0.05297596 0.24416767]
# iteration: 1820| Acceptance rate: 0.43846153846153846| Log-Likelihood: -447.48714333024543| Proposal [0.11411967 0.10387041]
# iteration: 1830| Acceptance rate: 0.43661202185792347| Log-Likelihood: -447.492005502856| Proposal [0.08255349 0.19784915]
# iteration: 1840| Acceptance rate: 0.4358695652173913| Log-Likelihood: -447.0033119725884| Proposal [0.1334273  0.16107515]
# iteration: 1850| Acceptance rate: 0.43675675675675674| Log-Likelihood: -448.13456413186816| Proposal [0.10839114 0.09611793]
# iteration: 1860| Acceptance rate: 0.43548387096774194| Log-Likelihood: -447.40262173242104| Proposal [0.08200355 0.13886731]
# iteration: 1870| Acceptance rate: 0.43636363636363634| Log-Likelihood: -447.6827649593888| Proposal [0.13457325 0.13392019]
# iteration: 1880| Acceptance rate: 0.43670212765957445| Log-Likelihood: -448.35709420331887| Proposal [0.13951453 0.2516359 ]
# iteration: 1890| Acceptance rate: 0.43703703703703706| Log-Likelihood: -447.4523445268759| Proposal [0.09789113 0.22446785]
# iteration: 1900| Acceptance rate: 0.4368421052631579| Log-Likelihood: -447.79503023851703| Proposal [0.1167632  0.15535776]
# iteration: 1910| Acceptance rate: 0.43664921465968587| Log-Likelihood: -447.4722920112422| Proposal [0.11057344 0.11992194]
# iteration: 1920| Acceptance rate: 0.43802083333333336| Log-Likelihood: -447.3242622579925| Proposal [0.11822932 0.08753676]
# iteration: 1930| Acceptance rate: 0.4383419689119171| Log-Likelihood: -447.89795643273357| Proposal [0.08775616 0.14402128]
# iteration: 1940| Acceptance rate: 0.4381443298969072| Log-Likelihood: -447.88045651491524| Proposal [0.12110614 0.19174055]
# iteration: 1950| Acceptance rate: 0.43743589743589745| Log-Likelihood: -447.58066235656304| Proposal [0.09020553 0.14909676]
# iteration: 1960| Acceptance rate: 0.4372448979591837| Log-Likelihood: -447.80992292875425| Proposal [0.08212866 0.19353253]
# iteration: 1970| Acceptance rate: 0.4385786802030457| Log-Likelihood: -448.2361709093273| Proposal [0.0525318  0.15810517]
# iteration: 1980| Acceptance rate: 0.4388888888888889| Log-Likelihood: -447.4845733940947| Proposal [0.13496922 0.1095935 ]
# iteration: 1990| Acceptance rate: 0.4396984924623116| Log-Likelihood: -448.50424855752897| Proposal [0.06045313 0.19078604]
# iteration: 2000| Acceptance rate: 0.44| Log-Likelihood: -447.75995926881774| Proposal [0.11703031 0.07775006]
# iteration: 2010| Acceptance rate: 0.4412935323383085| Log-Likelihood: -448.2181312849218| Proposal [0.06022361 0.15137605]
# iteration: 2020| Acceptance rate: 0.4415841584158416| Log-Likelihood: -447.22318430892136| Proposal [0.10204673 0.13196522]
# iteration: 2030| Acceptance rate: 0.44236453201970444| Log-Likelihood: -448.3259260094407| Proposal [0.05078407 0.23875431]
# iteration: 2040| Acceptance rate: 0.4426470588235294| Log-Likelihood: -447.82288222341396| Proposal [0.1013442  0.20072301]
# iteration: 2050| Acceptance rate: 0.4429268292682927| Log-Likelihood: -447.4975869246742| Proposal [0.11120988 0.08940749]
# iteration: 2060| Acceptance rate: 0.4432038834951456| Log-Likelihood: -447.70869459401655| Proposal [0.0744588  0.15987415]
# iteration: 2070| Acceptance rate: 0.442512077294686| Log-Likelihood: -448.4353242057283| Proposal [0.1214422 0.2793099]
# iteration: 2080| Acceptance rate: 0.44182692307692306| Log-Likelihood: -447.75868663057327| Proposal [0.12836296 0.14991925]
# iteration: 2090| Acceptance rate: 0.4430622009569378| Log-Likelihood: -447.764998976868| Proposal [0.07878925 0.23430183]
# iteration: 2100| Acceptance rate: 0.44333333333333336| Log-Likelihood: -448.0403972779667| Proposal [0.09794179 0.19541376]
# iteration: 2110| Acceptance rate: 0.4431279620853081| Log-Likelihood: -447.631997877146| Proposal [0.0810548  0.12257459]
# iteration: 2120| Acceptance rate: 0.44245283018867926| Log-Likelihood: -447.91644647782647| Proposal [0.0897672  0.13636572]
# iteration: 2130| Acceptance rate: 0.44178403755868545| Log-Likelihood: -447.4956503214925| Proposal [0.11115059 0.14977745]
# iteration: 2140| Acceptance rate: 0.44205607476635517| Log-Likelihood: -447.36482946137363| Proposal [0.13649162 0.12290561]
# iteration: 2150| Acceptance rate: 0.4427906976744186| Log-Likelihood: -448.88334381113555| Proposal [0.05605236 0.32245641]
# iteration: 2160| Acceptance rate: 0.4425925925925926| Log-Likelihood: -447.3429172861617| Proposal [0.13405464 0.07468304]
# iteration: 2170| Acceptance rate: 0.4423963133640553| Log-Likelihood: -448.2568639472085| Proposal [0.05201657 0.24073053]
# iteration: 2180| Acceptance rate: 0.44174311926605503| Log-Likelihood: -447.74481481757755| Proposal [0.10722664 0.1141792 ]
# iteration: 2190| Acceptance rate: 0.4410958904109589| Log-Likelihood: -447.66631074116447| Proposal [0.07978053 0.27671915]
# iteration: 2200| Acceptance rate: 0.44136363636363635| Log-Likelihood: -447.90952577326584| Proposal [0.11666953 0.11170491]
# iteration: 2210| Acceptance rate: 0.4402714932126697| Log-Likelihood: -447.9828805428674| Proposal [0.05992688 0.18027602]
# iteration: 2220| Acceptance rate: 0.44144144144144143| Log-Likelihood: -447.468099698343| Proposal [0.09660457 0.13632973]
# iteration: 2230| Acceptance rate: 0.44170403587443946| Log-Likelihood: -447.4185458785181| Proposal [0.0892802  0.16334801]
# iteration: 2240| Acceptance rate: 0.44107142857142856| Log-Likelihood: -447.6998064536123| Proposal [0.08554342 0.18036017]
# iteration: 2250| Acceptance rate: 0.44133333333333336| Log-Likelihood: -448.2625740647037| Proposal [0.12440672 0.1913985 ]
# iteration: 2260| Acceptance rate: 0.44026548672566373| Log-Likelihood: -447.47462210816934| Proposal [0.14223123 0.13191465]
# iteration: 2270| Acceptance rate: 0.44052863436123346| Log-Likelihood: -448.51726834597895| Proposal [0.09748766 0.31408886]
# iteration: 2280| Acceptance rate: 0.43991228070175437| Log-Likelihood: -447.539810896091| Proposal [0.08461263 0.19583017]
# iteration: 2290| Acceptance rate: 0.4406113537117904| Log-Likelihood: -447.45377119350337| Proposal [0.13093701 0.09696451]
# iteration: 2300| Acceptance rate: 0.44130434782608696| Log-Likelihood: -447.91109438389935| Proposal [0.0926016  0.17405461]
# iteration: 2310| Acceptance rate: 0.44155844155844154| Log-Likelihood: -448.3140845368986| Proposal [0.05063773 0.28491526]
# iteration: 2320| Acceptance rate: 0.44224137931034485| Log-Likelihood: -446.92802760948666| Proposal [0.10413757 0.14734188]
# iteration: 2330| Acceptance rate: 0.44206008583690987| Log-Likelihood: -447.66395733845957| Proposal [0.10906074 0.24771389]
# iteration: 2340| Acceptance rate: 0.44188034188034186| Log-Likelihood: -447.5684786745501| Proposal [0.0917768  0.13908102]
# iteration: 2350| Acceptance rate: 0.44127659574468087| Log-Likelihood: -447.11061797914533| Proposal [0.12533933 0.15637874]
# iteration: 2360| Acceptance rate: 0.4419491525423729| Log-Likelihood: -448.2842719808526| Proposal [0.06838829 0.11044673]
# iteration: 2370| Acceptance rate: 0.4421940928270042| Log-Likelihood: -448.49642459889833| Proposal [0.06825075 0.18871162]
# iteration: 2380| Acceptance rate: 0.44159663865546217| Log-Likelihood: -448.09138823370665| Proposal [0.10552631 0.12651569]
# iteration: 2390| Acceptance rate: 0.44142259414225943| Log-Likelihood: -447.7993601627082| Proposal [0.08284104 0.31669473]
# iteration: 2400| Acceptance rate: 0.4404166666666667| Log-Likelihood: -447.72752078336856| Proposal [0.11437441 0.12497734]
# iteration: 2410| Acceptance rate: 0.44024896265560165| Log-Likelihood: -447.915597841137| Proposal [0.07085735 0.23864604]
# iteration: 2420| Acceptance rate: 0.4396694214876033| Log-Likelihood: -447.82841196925585| Proposal [0.09524206 0.23227499]
# iteration: 2430| Acceptance rate: 0.44074074074074077| Log-Likelihood: -448.3797428004933| Proposal [0.10434769 0.25556529]
# iteration: 2440| Acceptance rate: 0.44098360655737706| Log-Likelihood: -447.64091219749037| Proposal [0.13624152 0.19183356]
# iteration: 2450| Acceptance rate: 0.44081632653061226| Log-Likelihood: -448.0493590606711| Proposal [0.07312081 0.22920854]
# iteration: 2460| Acceptance rate: 0.441869918699187| Log-Likelihood: -447.868847338459| Proposal [0.11586842 0.25932801]
# iteration: 2470| Acceptance rate: 0.4408906882591093| Log-Likelihood: -448.3736425385212| Proposal [0.07329576 0.29308533]
# iteration: 2480| Acceptance rate: 0.4415322580645161| Log-Likelihood: -448.38852246303264| Proposal [0.05658341 0.2756665 ]
# iteration: 2490| Acceptance rate: 0.44176706827309237| Log-Likelihood: -448.056608987094| Proposal [0.04616841 0.18002405]
# iteration: 2500| Acceptance rate: 0.4412| Log-Likelihood: -448.3161777897719| Proposal [0.10387931 0.26461722]
# iteration: 2510| Acceptance rate: 0.44143426294820715| Log-Likelihood: -449.2647031666207| Proposal [0.04532758 0.16825354]
# iteration: 2520| Acceptance rate: 0.44087301587301586| Log-Likelihood: -447.51418924517395| Proposal [0.10901871 0.16156008]
# iteration: 2530| Acceptance rate: 0.4399209486166008| Log-Likelihood: -447.7168829477314| Proposal [0.10339629 0.2481128 ]
# iteration: 2540| Acceptance rate: 0.4405511811023622| Log-Likelihood: -448.0714207227159| Proposal [0.08690002 0.27836766]
# iteration: 2550| Acceptance rate: 0.4403921568627451| Log-Likelihood: -447.6147377036907| Proposal [0.13666766 0.1715875 ]
# iteration: 2560| Acceptance rate: 0.440234375| Log-Likelihood: -447.98257589320565| Proposal [0.09259537 0.2941339 ]
# iteration: 2570| Acceptance rate: 0.44007782101167314| Log-Likelihood: -447.8650668290915| Proposal [0.0599426  0.21930163]
# iteration: 2580| Acceptance rate: 0.44108527131782943| Log-Likelihood: -448.3658176809836| Proposal [0.0852745  0.32528742]
# iteration: 2590| Acceptance rate: 0.4416988416988417| Log-Likelihood: -448.9396901922264| Proposal [0.05267564 0.14904394]
# iteration: 2600| Acceptance rate: 0.44076923076923075| Log-Likelihood: -447.8853049345213| Proposal [0.09426683 0.22174853]
# iteration: 2610| Acceptance rate: 0.44061302681992337| Log-Likelihood: -447.33501587525643| Proposal [0.13760355 0.08110128]
# iteration: 2620| Acceptance rate: 0.43931297709923667| Log-Likelihood: -446.9426029796212| Proposal [0.13793546 0.13330525]
# iteration: 2630| Acceptance rate: 0.4376425855513308| Log-Likelihood: -446.9426029796212| Proposal [0.13793546 0.13330525]
# iteration: 2640| Acceptance rate: 0.43787878787878787| Log-Likelihood: -448.51408472488924| Proposal [0.09557053 0.07517192]
# iteration: 2650| Acceptance rate: 0.43849056603773584| Log-Likelihood: -448.52065884279756| Proposal [0.06725546 0.31699608]
# iteration: 2660| Acceptance rate: 0.43796992481203006| Log-Likelihood: -448.60581309401175| Proposal [0.06015044 0.322536  ]
# iteration: 2670| Acceptance rate: 0.4400749063670412| Log-Likelihood: -447.7846638332322| Proposal [0.10775786 0.25216897]
# iteration: 2680| Acceptance rate: 0.43917910447761194| Log-Likelihood: -447.3794034268092| Proposal [0.11377667 0.1002085 ]
# iteration: 2690| Acceptance rate: 0.43940520446096654| Log-Likelihood: -447.9598122812607| Proposal [0.11636176 0.27353449]
# iteration: 2700| Acceptance rate: 0.43851851851851853| Log-Likelihood: -447.99239860177977| Proposal [0.10379264 0.22205827]
# iteration: 2710| Acceptance rate: 0.43837638376383764| Log-Likelihood: -448.46407852406657| Proposal [0.10528484 0.31446698]
# iteration: 2720| Acceptance rate: 0.4389705882352941| Log-Likelihood: -447.82224061028273| Proposal [0.09709847 0.23233781]
# iteration: 2730| Acceptance rate: 0.4388278388278388| Log-Likelihood: -447.7197035209018| Proposal [0.12864565 0.1998389 ]
# iteration: 2740| Acceptance rate: 0.4397810218978102| Log-Likelihood: -448.4510485786092| Proposal [0.13443867 0.25038227]
# iteration: 2750| Acceptance rate: 0.4389090909090909| Log-Likelihood: -448.51527096324355| Proposal [0.12672033 0.30245196]
# iteration: 2760| Acceptance rate: 0.43876811594202897| Log-Likelihood: -448.07404876134405| Proposal [0.06055766 0.21889577]
# iteration: 2770| Acceptance rate: 0.43790613718411553| Log-Likelihood: -448.3498980467106| Proposal [0.11710969 0.28769944]
# iteration: 2780| Acceptance rate: 0.4370503597122302| Log-Likelihood: -447.8006586179401| Proposal [0.14189872 0.1786672 ]
# iteration: 2790| Acceptance rate: 0.43655913978494626| Log-Likelihood: -448.6108377884799| Proposal [0.09311119 0.08902258]
# iteration: 2800| Acceptance rate: 0.43642857142857144| Log-Likelihood: -448.10910961901106| Proposal [0.06641994 0.24476222]
# iteration: 2810| Acceptance rate: 0.4359430604982206| Log-Likelihood: -447.7215359790988| Proposal [0.14177917 0.18506099]
# iteration: 2820| Acceptance rate: 0.4347517730496454| Log-Likelihood: -447.3542410293099| Proposal [0.10872305 0.14895957]
# iteration: 2830| Acceptance rate: 0.43498233215547705| Log-Likelihood: -447.76161175575464| Proposal [0.10104039 0.25307698]
# iteration: 2840| Acceptance rate: 0.4352112676056338| Log-Likelihood: -448.55596677609776| Proposal [0.06259069 0.26521705]
# iteration: 2850| Acceptance rate: 0.43543859649122807| Log-Likelihood: -447.5557311379893| Proposal [0.08611351 0.24323657]
# iteration: 2860| Acceptance rate: 0.4342657342657343| Log-Likelihood: -447.6629904614465| Proposal [0.09302875 0.14001361]
# iteration: 2870| Acceptance rate: 0.43449477351916377| Log-Likelihood: -447.87948536298865| Proposal [0.06809144 0.20132919]
# iteration: 2880| Acceptance rate: 0.43368055555555557| Log-Likelihood: -448.6645974535759| Proposal [0.04497745 0.24582912]
# iteration: 2890| Acceptance rate: 0.43529411764705883| Log-Likelihood: -448.6594059825015| Proposal [0.08839611 0.26030422]
# iteration: 2900| Acceptance rate: 0.43551724137931036| Log-Likelihood: -447.9282219365662| Proposal [0.06619365 0.18398569]
# iteration: 2910| Acceptance rate: 0.4350515463917526| Log-Likelihood: -447.15787380478986| Proposal [0.13949446 0.13570139]
# iteration: 2920| Acceptance rate: 0.4352739726027397| Log-Likelihood: -448.11779481713813| Proposal [0.07644092 0.24300182]
# iteration: 2930| Acceptance rate: 0.4351535836177474| Log-Likelihood: -447.39563124121827| Proposal [0.13892432 0.10783604]
# iteration: 2940| Acceptance rate: 0.4346938775510204| Log-Likelihood: -447.5039747745617| Proposal [0.08982583 0.17162116]
# iteration: 2950| Acceptance rate: 0.4335593220338983| Log-Likelihood: -447.77870945077063| Proposal [0.12786681 0.17593797]
# iteration: 2960| Acceptance rate: 0.4337837837837838| Log-Likelihood: -447.7657353936833| Proposal [0.07503316 0.22369196]
# iteration: 2970| Acceptance rate: 0.43434343434343436| Log-Likelihood: -447.5187842168915| Proposal [0.0753696  0.19436882]
# iteration: 2980| Acceptance rate: 0.4348993288590604| Log-Likelihood: -447.65712357064865| Proposal [0.10940797 0.16310882]
# iteration: 2990| Acceptance rate: 0.43411371237458196| Log-Likelihood: -447.81709762476834| Proposal [0.10796745 0.22255998]
# iteration: 3000| Acceptance rate: 0.43433333333333335| Log-Likelihood: -447.51841874726335| Proposal [0.12561429 0.19767318]
# iteration: 3010| Acceptance rate: 0.43388704318936877| Log-Likelihood: -448.8148332080233| Proposal [0.11341929 0.3243556 ]
# iteration: 3020| Acceptance rate: 0.43410596026490067| Log-Likelihood: -448.57325691823803| Proposal [0.04024326 0.2831901 ]
# iteration: 3030| Acceptance rate: 0.43465346534653465| Log-Likelihood: -448.1633030611395| Proposal [0.05998027 0.11104897]
# iteration: 3040| Acceptance rate: 0.43355263157894736| Log-Likelihood: -447.7267276506692| Proposal [0.0759448 0.2317889]
# iteration: 3050| Acceptance rate: 0.43278688524590164| Log-Likelihood: -447.4526335403491| Proposal [0.10066055 0.22801303]
# iteration: 3060| Acceptance rate: 0.4326797385620915| Log-Likelihood: -448.3104526713022| Proposal [0.07651926 0.15132148]
# iteration: 3070| Acceptance rate: 0.4325732899022801| Log-Likelihood: -447.83985195803814| Proposal [0.09207804 0.12827581]
# iteration: 3080| Acceptance rate: 0.4318181818181818| Log-Likelihood: -448.7388137154291| Proposal [0.05985871 0.10800513]
# iteration: 3090| Acceptance rate: 0.4313915857605178| Log-Likelihood: -448.3281265813945| Proposal [0.08159165 0.28171789]
# iteration: 3100| Acceptance rate: 0.43129032258064515| Log-Likelihood: -447.32737168432203| Proposal [0.0935011 0.1850878]
# iteration: 3110| Acceptance rate: 0.4311897106109325| Log-Likelihood: -447.51482400676946| Proposal [0.11424574 0.11296767]
# iteration: 3120| Acceptance rate: 0.4307692307692308| Log-Likelihood: -447.89292065303124| Proposal [0.0795519  0.19171801]
# iteration: 3130| Acceptance rate: 0.4306709265175719| Log-Likelihood: -447.36313307310985| Proposal [0.12471552 0.14022977]
# iteration: 3140| Acceptance rate: 0.43089171974522295| Log-Likelihood: -447.5379138094239| Proposal [0.1380716  0.10066793]
# iteration: 3150| Acceptance rate: 0.43047619047619046| Log-Likelihood: -448.14464019890295| Proposal [0.06763395 0.131792  ]
# iteration: 3160| Acceptance rate: 0.4310126582278481| Log-Likelihood: -447.94838867358783| Proposal [0.101474   0.26610486]
# iteration: 3170| Acceptance rate: 0.4309148264984227| Log-Likelihood: -448.7349648200004| Proposal [0.05060646 0.28606198]
# iteration: 3180| Acceptance rate: 0.4308176100628931| Log-Likelihood: -448.35210717309957| Proposal [0.13702446 0.20317863]
# iteration: 3190| Acceptance rate: 0.4304075235109718| Log-Likelihood: -447.8488263577359| Proposal [0.09604958 0.11182636]
# iteration: 3200| Acceptance rate: 0.43| Log-Likelihood: -447.7042071506992| Proposal [0.08185191 0.20079371]
# iteration: 3210| Acceptance rate: 0.43021806853582556| Log-Likelihood: -447.4456551274069| Proposal [0.07136456 0.14774958]
# iteration: 3220| Acceptance rate: 0.4301242236024845| Log-Likelihood: -448.04868167102313| Proposal [0.12543434 0.20483755]
# iteration: 3230| Acceptance rate: 0.43034055727554177| Log-Likelihood: -448.2128535632627| Proposal [0.10404947 0.31749944]
# iteration: 3240| Acceptance rate: 0.42993827160493825| Log-Likelihood: -449.16843759502035| Proposal [0.05153292 0.11104791]
# iteration: 3250| Acceptance rate: 0.4298461538461538| Log-Likelihood: -447.8077597039103| Proposal [0.08109077 0.14364569]
# iteration: 3260| Acceptance rate: 0.4294478527607362| Log-Likelihood: -449.2070695348747| Proposal [0.04897496 0.31256927]
# iteration: 3270| Acceptance rate: 0.42874617737003057| Log-Likelihood: -447.5976586878537| Proposal [0.11389102 0.08593999]
# iteration: 3280| Acceptance rate: 0.42804878048780487| Log-Likelihood: -447.8704644368265| Proposal [0.10432324 0.22760496]
# iteration: 3290| Acceptance rate: 0.4279635258358663| Log-Likelihood: -447.3807290110673| Proposal [0.13950098 0.14437148]
# iteration: 3300| Acceptance rate: 0.42757575757575755| Log-Likelihood: -447.3148055281716| Proposal [0.09500408 0.18347862]
# iteration: 3310| Acceptance rate: 0.427190332326284| Log-Likelihood: -448.16806682156516| Proposal [0.12187841 0.22104453]
# iteration: 3320| Acceptance rate: 0.4274096385542169| Log-Likelihood: -447.06893247068285| Proposal [0.14180511 0.09126589]
# iteration: 3330| Acceptance rate: 0.4276276276276276| Log-Likelihood: -447.61577914801944| Proposal [0.13589275 0.11753981]
# iteration: 3340| Acceptance rate: 0.42694610778443115| Log-Likelihood: -448.33135789422846| Proposal [0.06445254 0.2707006 ]
# iteration: 3350| Acceptance rate: 0.42686567164179107| Log-Likelihood: -448.2468783285802| Proposal [0.09516493 0.07474724]
# iteration: 3360| Acceptance rate: 0.42678571428571427| Log-Likelihood: -448.66367178464134| Proposal [0.09596889 0.07451692]
# iteration: 3370| Acceptance rate: 0.4264094955489614| Log-Likelihood: -447.5688442040769| Proposal [0.09212856 0.10604613]
# iteration: 3380| Acceptance rate: 0.42633136094674556| Log-Likelihood: -448.6137508057438| Proposal [0.13552569 0.26460285]
# iteration: 3390| Acceptance rate: 0.4259587020648968| Log-Likelihood: -447.2478231277845| Proposal [0.13347039 0.10633336]
# iteration: 3400| Acceptance rate: 0.42558823529411766| Log-Likelihood: -447.77066202270964| Proposal [0.13816809 0.17058497]
# iteration: 3410| Acceptance rate: 0.42434017595307916| Log-Likelihood: -447.77066202270964| Proposal [0.13816809 0.17058497]
# iteration: 3420| Acceptance rate: 0.4245614035087719| Log-Likelihood: -448.7586772341566| Proposal [0.04973251 0.23498089]
# iteration: 3430| Acceptance rate: 0.42448979591836733| Log-Likelihood: -448.3897525998345| Proposal [0.13572569 0.28333508]
# iteration: 3440| Acceptance rate: 0.42354651162790696| Log-Likelihood: -448.0867810509855| Proposal [0.11694875 0.24881513]
# iteration: 3450| Acceptance rate: 0.42289855072463767| Log-Likelihood: -447.8407491705285| Proposal [0.11461035 0.19334835]
# iteration: 3460| Acceptance rate: 0.42283236994219653| Log-Likelihood: -447.5496504543353| Proposal [0.0871718  0.19529039]
# iteration: 3470| Acceptance rate: 0.42305475504322765| Log-Likelihood: -447.8723070852765| Proposal [0.08608675 0.22539848]
# iteration: 3480| Acceptance rate: 0.4232758620689655| Log-Likelihood: -447.85028613532506| Proposal [0.07273417 0.17542194]
# iteration: 3490| Acceptance rate: 0.42406876790830944| Log-Likelihood: -448.4019604867932| Proposal [0.10870505 0.32131049]
# iteration: 3500| Acceptance rate: 0.4237142857142857| Log-Likelihood: -447.2687043539272| Proposal [0.10467203 0.12210695]
# iteration: 3510| Acceptance rate: 0.42279202279202277| Log-Likelihood: -447.8439322938211| Proposal [0.06113664 0.15134703]
# iteration: 3520| Acceptance rate: 0.42301136363636366| Log-Likelihood: -448.2245651460029| Proposal [0.08671967 0.11703114]
# iteration: 3530| Acceptance rate: 0.4237960339943343| Log-Likelihood: -448.6660654419115| Proposal [0.05229194 0.14316612]
# iteration: 3540| Acceptance rate: 0.423728813559322| Log-Likelihood: -448.15871173553995| Proposal [0.07238063 0.18142919]
# iteration: 3550| Acceptance rate: 0.4236619718309859| Log-Likelihood: -447.75289822785646| Proposal [0.07951943 0.16244252]
# iteration: 3560| Acceptance rate: 0.423876404494382| Log-Likelihood: -447.6829315845947| Proposal [0.1222227  0.24009697]
# iteration: 3570| Acceptance rate: 0.4246498599439776| Log-Likelihood: -447.42766452787976| Proposal [0.0914009 0.1699328]
# iteration: 3580| Acceptance rate: 0.42569832402234636| Log-Likelihood: -448.4097328808815| Proposal [0.05950171 0.30147956]
# iteration: 3590| Acceptance rate: 0.4264623955431755| Log-Likelihood: -447.6450711784898| Proposal [0.09198081 0.10725782]
# iteration: 3600| Acceptance rate: 0.42694444444444446| Log-Likelihood: -448.1281490035566| Proposal [0.08593734 0.24617923]
# iteration: 3610| Acceptance rate: 0.42714681440443214| Log-Likelihood: -448.7639250517868| Proposal [0.06915105 0.31256918]
# iteration: 3620| Acceptance rate: 0.4276243093922652| Log-Likelihood: -448.13424879570437| Proposal [0.12334884 0.27257255]
# iteration: 3630| Acceptance rate: 0.4286501377410468| Log-Likelihood: -447.5871006095212| Proposal [0.07333669 0.16353466]
# iteration: 3640| Acceptance rate: 0.42857142857142855| Log-Likelihood: -448.55534828093096| Proposal [0.08448735 0.25517813]
# iteration: 3650| Acceptance rate: 0.42904109589041095| Log-Likelihood: -448.1857964394675| Proposal [0.09270378 0.27026979]
# iteration: 3660| Acceptance rate: 0.42896174863387976| Log-Likelihood: -448.2558046392801| Proposal [0.11965232 0.22559382]
# iteration: 3670| Acceptance rate: 0.42942779291553135| Log-Likelihood: -448.20259304801846| Proposal [0.06389372 0.26657284]
# iteration: 3680| Acceptance rate: 0.4296195652173913| Log-Likelihood: -448.15052196329884| Proposal [0.1404108  0.27346118]
# iteration: 3690| Acceptance rate: 0.42981029810298105| Log-Likelihood: -447.402956483042| Proposal [0.07913538 0.17117879]
# iteration: 3700| Acceptance rate: 0.42945945945945946| Log-Likelihood: -447.8643440151027| Proposal [0.11995601 0.22659387]
# iteration: 3710| Acceptance rate: 0.4293800539083558| Log-Likelihood: -447.6423109053453| Proposal [0.07389082 0.17626701]
# iteration: 3720| Acceptance rate: 0.4293010752688172| Log-Likelihood: -448.1014014779838| Proposal [0.06521895 0.15252337]
# iteration: 3730| Acceptance rate: 0.4294906166219839| Log-Likelihood: -447.6523885961768| Proposal [0.06894162 0.17312626]
# iteration: 3740| Acceptance rate: 0.4304812834224599| Log-Likelihood: -448.28847145998253| Proposal [0.1135414  0.27592129]
# iteration: 3750| Acceptance rate: 0.43093333333333333| Log-Likelihood: -447.97445847679717| Proposal [0.13668023 0.17163217]
# iteration: 3760| Acceptance rate: 0.4305851063829787| Log-Likelihood: -448.83901680431427| Proposal [0.12192926 0.33156316]
# iteration: 3770| Acceptance rate: 0.43050397877984087| Log-Likelihood: -447.20766811255805| Proposal [0.1340995  0.14016296]
# iteration: 3780| Acceptance rate: 0.43042328042328043| Log-Likelihood: -447.45636685076306| Proposal [0.06633152 0.2254996 ]
# iteration: 3790| Acceptance rate: 0.43007915567282323| Log-Likelihood: -447.8848717333765| Proposal [0.1013376  0.09293786]
# iteration: 3800| Acceptance rate: 0.43| Log-Likelihood: -448.2015108186802| Proposal [0.06301215 0.29460956]
# iteration: 3810| Acceptance rate: 0.4293963254593176| Log-Likelihood: -447.7994208131975| Proposal [0.06453436 0.20984096]
# iteration: 3820| Acceptance rate: 0.4293193717277487| Log-Likelihood: -448.5540977959109| Proposal [0.04499498 0.30490582]
# iteration: 3830| Acceptance rate: 0.4297650130548303| Log-Likelihood: -448.2209331293318| Proposal [0.13450861 0.23946421]
# iteration: 3840| Acceptance rate: 0.4296875| Log-Likelihood: -448.47946594379096| Proposal [0.04319126 0.23876536]
# iteration: 3850| Acceptance rate: 0.4296103896103896| Log-Likelihood: -448.4452168062071| Proposal [0.13651708 0.29223506]
# iteration: 3860| Acceptance rate: 0.42901554404145076| Log-Likelihood: -448.36888060390197| Proposal [0.06155464 0.2399503 ]
# iteration: 3870| Acceptance rate: 0.42868217054263563| Log-Likelihood: -448.16457948800155| Proposal [0.08721158 0.1552272 ]
# iteration: 3880| Acceptance rate: 0.4283505154639175| Log-Likelihood: -448.17524378970177| Proposal [0.05657995 0.19406865]
# iteration: 3890| Acceptance rate: 0.42776349614395887| Log-Likelihood: -447.3492122881519| Proposal [0.11970727 0.0901349 ]
# iteration: 3900| Acceptance rate: 0.4282051282051282| Log-Likelihood: -447.86827880109325| Proposal [0.13376853 0.14330415]
# iteration: 3910| Acceptance rate: 0.42762148337595907| Log-Likelihood: -448.9885835217243| Proposal [0.03987834 0.21285497]
# iteration: 3920| Acceptance rate: 0.4275510204081633| Log-Likelihood: -448.3261289635042| Proposal [0.09501412 0.32283687]
# iteration: 3930| Acceptance rate: 0.4272264631043257| Log-Likelihood: -447.522766528689| Proposal [0.11957589 0.13488876]
# iteration: 3940| Acceptance rate: 0.42690355329949237| Log-Likelihood: -447.7683753671949| Proposal [0.08396892 0.15859316]
# iteration: 3950| Acceptance rate: 0.42632911392405065| Log-Likelihood: -448.6172518389808| Proposal [0.0408681  0.23981084]
# iteration: 3960| Acceptance rate: 0.4262626262626263| Log-Likelihood: -447.8367603592759| Proposal [0.13743554 0.23574116]
# iteration: 3970| Acceptance rate: 0.42619647355163726| Log-Likelihood: -448.1976831030325| Proposal [0.08678739 0.2321086 ]
# iteration: 3980| Acceptance rate: 0.42613065326633165| Log-Likelihood: -447.3881174426722| Proposal [0.10995376 0.12187391]
# iteration: 3990| Acceptance rate: 0.4255639097744361| Log-Likelihood: -447.3743570018571| Proposal [0.11161524 0.18455372]
# iteration: 4000| Acceptance rate: 0.4255| Log-Likelihood: -447.47319875320653| Proposal [0.12463666 0.11233091]
# iteration: 4010| Acceptance rate: 0.42468827930174563| Log-Likelihood: -447.39054649010353| Proposal [0.12244607 0.14877956]
# iteration: 4020| Acceptance rate: 0.4248756218905473| Log-Likelihood: -447.80349850642307| Proposal [0.11359239 0.08441428]
# iteration: 4030| Acceptance rate: 0.4248138957816377| Log-Likelihood: -447.7052708287383| Proposal [0.13659949 0.18397861]
# iteration: 4040| Acceptance rate: 0.42475247524752474| Log-Likelihood: -447.7976137753079| Proposal [0.1356947  0.13910588]
# iteration: 4050| Acceptance rate: 0.42444444444444446| Log-Likelihood: -447.43453199091505| Proposal [0.12988522 0.08802629]
# iteration: 4060| Acceptance rate: 0.42438423645320195| Log-Likelihood: -448.0323520477712| Proposal [0.07416203 0.27788223]
# iteration: 4070| Acceptance rate: 0.4250614250614251| Log-Likelihood: -448.22928531877307| Proposal [0.07999835 0.32463102]
# iteration: 4080| Acceptance rate: 0.4247549019607843| Log-Likelihood: -447.7442804662258| Proposal [0.12246412 0.24133905]
# iteration: 4090| Acceptance rate: 0.42493887530562346| Log-Likelihood: -448.42275276417894| Proposal [0.097743  0.3188128]
# iteration: 4100| Acceptance rate: 0.424390243902439| Log-Likelihood: -448.52839284534303| Proposal [0.12364339 0.28937434]
# iteration: 4110| Acceptance rate: 0.42530413625304136| Log-Likelihood: -447.95450723683865| Proposal [0.10714086 0.12649499]
# iteration: 4120| Acceptance rate: 0.42524271844660194| Log-Likelihood: -448.0934537692211| Proposal [0.1355207  0.21354006]
# iteration: 4130| Acceptance rate: 0.42518159806295397| Log-Likelihood: -447.96875582124886| Proposal [0.07550728 0.181067  ]
# iteration: 4140| Acceptance rate: 0.4251207729468599| Log-Likelihood: -447.94509112202064| Proposal [0.08183213 0.28454193]
# iteration: 4150| Acceptance rate: 0.42481927710843376| Log-Likelihood: -448.0135421276807| Proposal [0.05972868 0.19328507]
# iteration: 4160| Acceptance rate: 0.4247596153846154| Log-Likelihood: -448.41072489343486| Proposal [0.08743803 0.09672816]
# iteration: 4170| Acceptance rate: 0.4249400479616307| Log-Likelihood: -448.3865554627007| Proposal [0.08874461 0.1058652 ]
# iteration: 4180| Acceptance rate: 0.4251196172248804| Log-Likelihood: -447.6857294638984| Proposal [0.0757755  0.17813501]
# iteration: 4190| Acceptance rate: 0.4252983293556086| Log-Likelihood: -448.7277124035485| Proposal [0.0612724  0.31082021]
# iteration: 4200| Acceptance rate: 0.42523809523809525| Log-Likelihood: -447.60277059218697| Proposal [0.10090263 0.09417171]
# iteration: 4210| Acceptance rate: 0.42494061757719714| Log-Likelihood: -447.7552437730755| Proposal [0.09152549 0.23039509]
# iteration: 4220| Acceptance rate: 0.4253554502369668| Log-Likelihood: -448.0109837327953| Proposal [0.12116323 0.22862807]
# iteration: 4230| Acceptance rate: 0.42458628841607565| Log-Likelihood: -447.5475205501616| Proposal [0.10525528 0.10358731]
# iteration: 4240| Acceptance rate: 0.4242924528301887| Log-Likelihood: -447.428766471592| Proposal [0.107214  0.0969233]
# iteration: 4250| Acceptance rate: 0.424| Log-Likelihood: -448.0960605319857| Proposal [0.08420156 0.08750463]
# iteration: 4260| Acceptance rate: 0.42417840375586857| Log-Likelihood: -448.5104632998649| Proposal [0.12236191 0.29952183]
# iteration: 4270| Acceptance rate: 0.4241217798594848| Log-Likelihood: -449.483795929221| Proposal [0.03597792 0.30600018]
# iteration: 4280| Acceptance rate: 0.42406542056074764| Log-Likelihood: -447.1222024570934| Proposal [0.13750109 0.09408899]
# iteration: 4290| Acceptance rate: 0.42377622377622376| Log-Likelihood: -446.868397844631| Proposal [0.14163438 0.13352218]
# iteration: 4300| Acceptance rate: 0.42372093023255814| Log-Likelihood: -448.1876954517185| Proposal [0.10289737 0.28203791]
# iteration: 4310| Acceptance rate: 0.4234338747099768| Log-Likelihood: -447.84323713213655| Proposal [0.1018244  0.19912634]
# iteration: 4320| Acceptance rate: 0.42407407407407405| Log-Likelihood: -447.3207704295446| Proposal [0.09074887 0.11090129]
# iteration: 4330| Acceptance rate: 0.4233256351039261| Log-Likelihood: -447.8978664484057| Proposal [0.0910891  0.11730188]
# iteration: 4340| Acceptance rate: 0.42327188940092164| Log-Likelihood: -447.45370915026785| Proposal [0.12042907 0.20539423]
# iteration: 4350| Acceptance rate: 0.4232183908045977| Log-Likelihood: -448.59247545711| Proposal [0.0459892  0.11358809]
# iteration: 4360| Acceptance rate: 0.423394495412844| Log-Likelihood: -447.18451124216773| Proposal [0.11791039 0.11057184]
# iteration: 4370| Acceptance rate: 0.42356979405034323| Log-Likelihood: -447.7301552197082| Proposal [0.14236596 0.13701087]
# iteration: 4380| Acceptance rate: 0.42397260273972603| Log-Likelihood: -447.3914206087875| Proposal [0.13188984 0.08210548]
# iteration: 4390| Acceptance rate: 0.42369020501138954| Log-Likelihood: -448.19484562288164| Proposal [0.13317392 0.21786034]
# iteration: 4400| Acceptance rate: 0.4238636363636364| Log-Likelihood: -447.3881212356707| Proposal [0.087121   0.17678969]
# iteration: 4410| Acceptance rate: 0.42448979591836733| Log-Likelihood: -448.2623403025642| Proposal [0.07472459 0.33011329]
# iteration: 4420| Acceptance rate: 0.4237556561085973| Log-Likelihood: -448.35213073453485| Proposal [0.07329071 0.3265467 ]
# iteration: 4430| Acceptance rate: 0.4239277652370203| Log-Likelihood: -448.09735687749526| Proposal [0.09743832 0.22139978]
# iteration: 4440| Acceptance rate: 0.4240990990990991| Log-Likelihood: -447.34361405269135| Proposal [0.11177543 0.09895066]
# iteration: 4450| Acceptance rate: 0.42337078651685395| Log-Likelihood: -447.77716491643724| Proposal [0.06806034 0.19797999]
# iteration: 4460| Acceptance rate: 0.42354260089686097| Log-Likelihood: -447.5369759588736| Proposal [0.11044759 0.22799002]
# iteration: 4470| Acceptance rate: 0.4230425055928412| Log-Likelihood: -447.7878774377462| Proposal [0.06895629 0.18442641]
# iteration: 4480| Acceptance rate: 0.42276785714285714| Log-Likelihood: -447.95019691300445| Proposal [0.11771148 0.06678162]
# iteration: 4490| Acceptance rate: 0.42338530066815144| Log-Likelihood: -447.53621097959297| Proposal [0.11503555 0.16838898]
# iteration: 4500| Acceptance rate: 0.4231111111111111| Log-Likelihood: -447.95010857731785| Proposal [0.07820234 0.20267611]
# iteration: 4510| Acceptance rate: 0.4228381374722838| Log-Likelihood: -447.3977231927108| Proposal [0.13817381 0.11693498]
# iteration: 4520| Acceptance rate: 0.4230088495575221| Log-Likelihood: -447.4258374232587| Proposal [0.11751536 0.14879936]
# iteration: 4530| Acceptance rate: 0.4227373068432671| Log-Likelihood: -448.07146419988067| Proposal [0.08738829 0.12756722]
# iteration: 4540| Acceptance rate: 0.42312775330396474| Log-Likelihood: -448.34534528515195| Proposal [0.1099532  0.28689418]
# iteration: 4550| Acceptance rate: 0.4235164835164835| Log-Likelihood: -448.6630213050423| Proposal [0.12749436 0.32937839]
# iteration: 4560| Acceptance rate: 0.4236842105263158| Log-Likelihood: -448.0845281287485| Proposal [0.08240385 0.16984217]
# iteration: 4570| Acceptance rate: 0.4236323851203501| Log-Likelihood: -447.92948826476396| Proposal [0.09436537 0.22973132]
# iteration: 4580| Acceptance rate: 0.42358078602620086| Log-Likelihood: -447.45091866475| Proposal [0.13111538 0.07464015]
# iteration: 4590| Acceptance rate: 0.42374727668845313| Log-Likelihood: -448.4314411507921| Proposal [0.04900668 0.23633285]
# iteration: 4600| Acceptance rate: 0.4234782608695652| Log-Likelihood: -448.5126861965283| Proposal [0.04070269 0.18773479]
# iteration: 4610| Acceptance rate: 0.4234273318872017| Log-Likelihood: -449.49810075967184| Proposal [0.0455099  0.12787826]
# iteration: 4620| Acceptance rate: 0.4235930735930736| Log-Likelihood: -448.1300907239688| Proposal [0.06774341 0.22770384]
# iteration: 4630| Acceptance rate: 0.42332613390928725| Log-Likelihood: -447.9575803671909| Proposal [0.04843862 0.230893  ]
# iteration: 4640| Acceptance rate: 0.4228448275862069| Log-Likelihood: -447.46190135403685| Proposal [0.13853553 0.16409598]
# iteration: 4650| Acceptance rate: 0.42258064516129035| Log-Likelihood: -448.3289438550864| Proposal [0.05082218 0.19640229]
# iteration: 4660| Acceptance rate: 0.4223175965665236| Log-Likelihood: -447.56225775103684| Proposal [0.11294579 0.16763   ]
# iteration: 4670| Acceptance rate: 0.42184154175588867| Log-Likelihood: -449.560893340347| Proposal [0.06329367 0.10213394]
# iteration: 4680| Acceptance rate: 0.4217948717948718| Log-Likelihood: -448.40071475186494| Proposal [0.13723438 0.2433011 ]
# iteration: 4690| Acceptance rate: 0.42174840085287846| Log-Likelihood: -447.9594820018509| Proposal [0.1266153  0.24142328]
# iteration: 4700| Acceptance rate: 0.42148936170212764| Log-Likelihood: -447.247060306643| Proposal [0.07821388 0.18904873]
# iteration: 4710| Acceptance rate: 0.4212314225053079| Log-Likelihood: -447.5658731357753| Proposal [0.13929033 0.16242508]
# iteration: 4720| Acceptance rate: 0.42139830508474574| Log-Likelihood: -447.3409093652133| Proposal [0.09277247 0.208749  ]
# iteration: 4730| Acceptance rate: 0.42093023255813955| Log-Likelihood: -446.9943625520509| Proposal [0.10231849 0.11427426]
# iteration: 4740| Acceptance rate: 0.42130801687763714| Log-Likelihood: -447.26827156610193| Proposal [0.06588028 0.18280382]
# iteration: 4750| Acceptance rate: 0.42126315789473684| Log-Likelihood: -447.30713486033966| Proposal [0.12988596 0.09936403]
# iteration: 4760| Acceptance rate: 0.421218487394958| Log-Likelihood: -447.39079591673294| Proposal [0.1003637  0.13920457]
# iteration: 4770| Acceptance rate: 0.42159329140461216| Log-Likelihood: -447.99744946585736| Proposal [0.10691967 0.20422293]
# iteration: 4780| Acceptance rate: 0.4215481171548117| Log-Likelihood: -448.62227939402175| Proposal [0.13569373 0.33163096]
# iteration: 4790| Acceptance rate: 0.42171189979123175| Log-Likelihood: -447.6382612805121| Proposal [0.11083661 0.13335326]
# iteration: 4800| Acceptance rate: 0.42125| Log-Likelihood: -447.93493935554386| Proposal [0.10459893 0.20339825]
# iteration: 4810| Acceptance rate: 0.42162162162162165| Log-Likelihood: -447.5544388101096| Proposal [0.07768361 0.13547636]
# iteration: 4820| Acceptance rate: 0.42136929460580913| Log-Likelihood: -447.44014518707445| Proposal [0.12320429 0.10606161]
# iteration: 4830| Acceptance rate: 0.4217391304347826| Log-Likelihood: -447.6423460154622| Proposal [0.11507538 0.07777555]
# iteration: 4840| Acceptance rate: 0.42210743801652895| Log-Likelihood: -448.4779151649624| Proposal [0.10484868 0.06821251]
# iteration: 4850| Acceptance rate: 0.42206185567010307| Log-Likelihood: -446.88290539485484| Proposal [0.11319342 0.20208139]
# iteration: 4860| Acceptance rate: 0.4218106995884774| Log-Likelihood: -447.79747334640876| Proposal [0.1340146 0.1838177]
# iteration: 4870| Acceptance rate: 0.4223819301848049| Log-Likelihood: -447.2944148619028| Proposal [0.13707496 0.08006327]
# iteration: 4880| Acceptance rate: 0.4223360655737705| Log-Likelihood: -448.37582437566095| Proposal [0.1312357  0.24511372]
# iteration: 4890| Acceptance rate: 0.4222903885480573| Log-Likelihood: -448.65001791226734| Proposal [0.09487475 0.0749755 ]
# iteration: 4900| Acceptance rate: 0.42244897959183675| Log-Likelihood: -448.0955065751976| Proposal [0.13389583 0.22186003]
# iteration: 4910| Acceptance rate: 0.42179226069246434| Log-Likelihood: -448.22579717361026| Proposal [0.13967234 0.17488135]
# iteration: 4920| Acceptance rate: 0.4217479674796748| Log-Likelihood: -447.1368584923723| Proposal [0.08929049 0.14223382]
# iteration: 4930| Acceptance rate: 0.42150101419878294| Log-Likelihood: -448.01668362613566| Proposal [0.05558812 0.1558344 ]
# iteration: 4940| Acceptance rate: 0.42145748987854253| Log-Likelihood: -447.4896555961107| Proposal [0.10391744 0.21870543]
# iteration: 4950| Acceptance rate: 0.4214141414141414| Log-Likelihood: -448.3398454713667| Proposal [0.05566369 0.26397303]
# iteration: 4960| Acceptance rate: 0.42116935483870965| Log-Likelihood: -448.2297070856839| Proposal [0.10613928 0.27895744]
# iteration: 4970| Acceptance rate: 0.42072434607645876| Log-Likelihood: -447.0677541341627| Proposal [0.14057777 0.15605159]
# iteration: 4980| Acceptance rate: 0.420281124497992| Log-Likelihood: -447.27532563337684| Proposal [0.13220433 0.0670425 ]
# iteration: 4990| Acceptance rate: 0.42024048096192385| Log-Likelihood: -447.64520407760796| Proposal [0.13807902 0.18478323]
# 119.22108180000214

# %%
burn_in = 0

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'])
# Out:
# -446.71638528358983
# The Maximum Likelihood Estimate is [0.13592292 0.10559785] w/ LL of -446.71638528358983

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\eta$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[2,burn_in:])} and std: {np.std(theta[2,burn_in:])}")
# plt.hist(theta[2,burn_in:],density=True,bins = 50)
# plt.show()

# plt.title(f"Distribution of OU Param $\\mu$ w/ mean: {np.mean(theta[3,burn_in:])} and std: {np.std(theta[3,burn_in:])}")
# plt.hist(theta[3,burn_in:],density=True,bins = 50)
# plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 17.1047882802919
# Root Mean Squared Error for beta 0.12458712837208234

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
'''Pair plots'''

plt.title('Pairwise Plot of $\\gamma$ and $\\eta$')
plt.xlabel('$\\eta$')
plt.ylabel('$\\gamma$')
plt.scatter(pmcmc_output['accepted_params'][0,burn_in:],pmcmc_output['accepted_params'][1,burn_in:],s=0.1)
