# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
import jsonpickle
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf,poisson_logpmf

# %%
'''Import data'''

data = pd.read_csv('../data_sets/calvetti_fixedeta_data_17_09_2024.csv').to_numpy()
state = pd.read_csv('../data_sets/calvetti_state_fixedeta_17_09_2024.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,_ = model_params

    eta = 1/7

    '''OU Process'''
    sig = 1.0
    mu = -2.0
    lam = 1/100

    state_diff = 0.01 

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = (particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt
        new_E = np.exp(np.log(new_E) + state_diff/np.sum(particles[index,:,t]) * rng.normal(0,np.sqrt(dt)))

        new_I = (eta * particles[index,1,t]) * dt
        new_I = np.exp(np.log(new_I) + state_diff * rng.normal(0,np.sqrt(dt)))

        new_ER = (gamma * particles[index,1,t]) * dt
        new_ER = np.exp(np.log(new_ER) + state_diff * rng.normal(0,np.sqrt(dt)))

        new_IR = (gamma * particles[index,2,t]) * dt
        new_IR = np.exp(np.log(new_IR) + state_diff * rng.normal(0,np.sqrt(dt)))

        new_D = (0.004 * particles[index,2,t]) * dt
        new_D = np.exp(np.log(new_D) + state_diff * rng.normal(0,np.sqrt(dt)))

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR) #R
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal()) #beta

        observations[index,0,t] += new_I

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[1]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0] + 0.005),n = np.array([r]))
    return weights

# %%
'''True parameter values, the fit to the state variables and beta if the static parameters are known. '''
rng = np.random.default_rng(0)

'''unpickle parameter sets'''
with open("../param_sets/calvetti_fixedeta_model_params.json", "r+") as f:
    model_json = f.read()
    model_params = jsonpickle.decode(model_json)

gamma = model_params['gamma']
R = model_params['R']

with open("../param_sets/calvetti_beta_params.json", "r+") as f:
    beta_json = f.read()
    beta_params = jsonpickle.decode(beta_json)

T = 120
dt = 1.
t_vec = np.arange(0,T,dt)
beta_params = {'b_0':0.4,'b_inf': 0.1, 'tau': 5,'T':20}

def beta_sim(par,t):
    if(t < par['T']):
        return 0.4
    
    return par['b_inf'] + (par['b_0'] - par['b_inf']) * np.exp(-(t - par['T'])/par['tau'])

betas = np.array([beta_sim(beta_params,t) for t in t_vec])


def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(50,200,size = (num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 10.749791307986015

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(output['particle_distribution'][:,4,:]))**2))}")

Labels = ['S','E','I','R']

for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.plot(t_vec[::int(1/dt)],state[:,i],'--',color = 'black')
    plt.show()

plt.title("Particle Distribution of $\\beta_t$")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -473.09629962904125
# Root Mean Squared Error for the Data 273.7314414144186
# Root Mean Squared Error for beta 0.1159140969228354

# %%
pmcmc_rng = np.random.default_rng(500)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1/10.)

pmcmc_params = {'iterations':10_000,
                'init_params':np.array([0.1,0.1]),
                'prior':seir_prior,
                'init_cov': 0.01 * np.diag([0.01,0.01]),
                'burn_in':1000}

pf_params = {'num_particles':1_000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.6| Log-Likelihood: -475.0981550556557| Proposal [0.0690461  0.05694162]
# iteration: 20| Acceptance rate: 0.55| Log-Likelihood: -468.9749413988706| Proposal [0.06451323 0.0165534 ]
# iteration: 30| Acceptance rate: 0.4| Log-Likelihood: -469.28743713037846| Proposal [0.0828601  0.02725897]
# iteration: 40| Acceptance rate: 0.375| Log-Likelihood: -468.46610983660116| Proposal [0.05781761 0.02170905]
# iteration: 50| Acceptance rate: 0.3| Log-Likelihood: -468.46610983660116| Proposal [0.05781761 0.02170905]
# iteration: 60| Acceptance rate: 0.35| Log-Likelihood: -468.5968026942307| Proposal [0.06872746 0.02331686]
# iteration: 70| Acceptance rate: 0.35714285714285715| Log-Likelihood: -468.496518946717| Proposal [0.08324818 0.0225692 ]
# iteration: 80| Acceptance rate: 0.375| Log-Likelihood: -468.50653216690114| Proposal [0.08152818 0.01687987]
# iteration: 90| Acceptance rate: 0.35555555555555557| Log-Likelihood: -468.69603076124037| Proposal [0.05234012 0.01918253]
# iteration: 100| Acceptance rate: 0.36| Log-Likelihood: -468.7363635882654| Proposal [0.0996565  0.01844782]
# iteration: 110| Acceptance rate: 0.35454545454545455| Log-Likelihood: -470.60153276588346| Proposal [0.11861345 0.02427038]
# iteration: 120| Acceptance rate: 0.3416666666666667| Log-Likelihood: -469.4656817003555| Proposal [0.09929589 0.02288854]
# iteration: 130| Acceptance rate: 0.3384615384615385| Log-Likelihood: -468.6965002365999| Proposal [0.0811929  0.02211005]
# iteration: 140| Acceptance rate: 0.32142857142857145| Log-Likelihood: -470.3106081416089| Proposal [0.12563442 0.02528938]
# iteration: 150| Acceptance rate: 0.32| Log-Likelihood: -468.83054467676294| Proposal [0.09655073 0.02171064]
# iteration: 160| Acceptance rate: 0.31875| Log-Likelihood: -469.6409252714062| Proposal [0.09221663 0.02941209]
# iteration: 170| Acceptance rate: 0.32941176470588235| Log-Likelihood: -470.1675683654796| Proposal [0.11668691 0.01731722]
# iteration: 180| Acceptance rate: 0.32222222222222224| Log-Likelihood: -469.36164861797425| Proposal [0.09255594 0.01668463]
# iteration: 190| Acceptance rate: 0.3105263157894737| Log-Likelihood: -469.3693533475559| Proposal [0.09287288 0.01897445]
# iteration: 200| Acceptance rate: 0.305| Log-Likelihood: -468.838963961185| Proposal [0.07625425 0.0187911 ]
# iteration: 210| Acceptance rate: 0.3| Log-Likelihood: -468.89229596302937| Proposal [0.09673048 0.01868275]
# iteration: 220| Acceptance rate: 0.30454545454545456| Log-Likelihood: -469.7949138785259| Proposal [0.11134026 0.01957644]
# iteration: 230| Acceptance rate: 0.3| Log-Likelihood: -468.6216408436895| Proposal [0.07510871 0.02160402]
# iteration: 240| Acceptance rate: 0.29583333333333334| Log-Likelihood: -468.53283176671727| Proposal [0.06507009 0.02624541]
# iteration: 250| Acceptance rate: 0.296| Log-Likelihood: -468.8455811912672| Proposal [0.0725712 0.0236336]
# iteration: 260| Acceptance rate: 0.3| Log-Likelihood: -469.67713149736585| Proposal [0.04540009 0.02410293]
# iteration: 270| Acceptance rate: 0.2962962962962963| Log-Likelihood: -469.4056420460942| Proposal [0.05335397 0.01499987]
# iteration: 280| Acceptance rate: 0.30714285714285716| Log-Likelihood: -469.53369798568514| Proposal [0.04910054 0.01750175]
# iteration: 290| Acceptance rate: 0.30344827586206896| Log-Likelihood: -469.3144374117059| Proposal [0.0711827  0.02883285]
# iteration: 300| Acceptance rate: 0.30333333333333334| Log-Likelihood: -471.0789026309773| Proposal [0.05929654 0.03820588]
# iteration: 310| Acceptance rate: 0.3| Log-Likelihood: -470.8639779848094| Proposal [0.05550854 0.03664504]
# iteration: 320| Acceptance rate: 0.3| Log-Likelihood: -468.65223784869545| Proposal [0.07993761 0.02500082]
# iteration: 330| Acceptance rate: 0.3| Log-Likelihood: -470.12905658972903| Proposal [0.05235884 0.03315341]
# iteration: 340| Acceptance rate: 0.29411764705882354| Log-Likelihood: -468.246727237024| Proposal [0.07956872 0.02327913]
# iteration: 350| Acceptance rate: 0.29714285714285715| Log-Likelihood: -471.74986800308255| Proposal [0.11778345 0.03219123]
# iteration: 360| Acceptance rate: 0.3055555555555556| Log-Likelihood: -474.09176699195325| Proposal [0.10537933 0.0460446 ]
# iteration: 370| Acceptance rate: 0.3108108108108108| Log-Likelihood: -468.74511649041614| Proposal [0.07209282 0.01812706]
# iteration: 380| Acceptance rate: 0.30526315789473685| Log-Likelihood: -469.1422027029077| Proposal [0.10065556 0.02262962]
# iteration: 390| Acceptance rate: 0.30512820512820515| Log-Likelihood: -469.6580624211928| Proposal [0.10131405 0.02305087]
# iteration: 400| Acceptance rate: 0.3075| Log-Likelihood: -468.746989075169| Proposal [0.05537741 0.02215199]
# iteration: 410| Acceptance rate: 0.3048780487804878| Log-Likelihood: -469.1437026883404| Proposal [0.05276254 0.01930412]
# iteration: 420| Acceptance rate: 0.3| Log-Likelihood: -468.92343591829217| Proposal [0.04846749 0.01897314]
# iteration: 430| Acceptance rate: 0.2930232558139535| Log-Likelihood: -468.92343591829217| Proposal [0.04846749 0.01897314]
# iteration: 440| Acceptance rate: 0.28863636363636364| Log-Likelihood: -468.5140974599518| Proposal [0.062903   0.02299958]
# iteration: 450| Acceptance rate: 0.2866666666666667| Log-Likelihood: -468.5258687323721| Proposal [0.06598309 0.02019961]
# iteration: 460| Acceptance rate: 0.28043478260869564| Log-Likelihood: -468.5258687323721| Proposal [0.06598309 0.02019961]
# iteration: 470| Acceptance rate: 0.28085106382978725| Log-Likelihood: -469.3670313829213| Proposal [0.09329809 0.02054866]
# iteration: 480| Acceptance rate: 0.28541666666666665| Log-Likelihood: -468.8598675891096| Proposal [0.07575746 0.01616207]
# iteration: 490| Acceptance rate: 0.2857142857142857| Log-Likelihood: -469.6642959585398| Proposal [0.08651309 0.03284771]
# iteration: 500| Acceptance rate: 0.288| Log-Likelihood: -471.81047578439774| Proposal [0.1238764  0.03100552]
# iteration: 510| Acceptance rate: 0.28823529411764703| Log-Likelihood: -470.80722728851157| Proposal [0.11132665 0.02736559]
# iteration: 520| Acceptance rate: 0.2923076923076923| Log-Likelihood: -470.6752757658917| Proposal [0.08688645 0.03421684]
# iteration: 530| Acceptance rate: 0.29245283018867924| Log-Likelihood: -468.8837022306879| Proposal [0.05810822 0.02223702]
# iteration: 540| Acceptance rate: 0.29259259259259257| Log-Likelihood: -469.24846290507224| Proposal [0.07063216 0.01852724]
# iteration: 550| Acceptance rate: 0.2872727272727273| Log-Likelihood: -469.24846290507224| Proposal [0.07063216 0.01852724]
# iteration: 560| Acceptance rate: 0.2839285714285714| Log-Likelihood: -468.78397483691873| Proposal [0.06704504 0.02516316]
# iteration: 570| Acceptance rate: 0.28596491228070176| Log-Likelihood: -470.4791713752381| Proposal [0.10692905 0.02321831]
# iteration: 580| Acceptance rate: 0.28448275862068967| Log-Likelihood: -470.8758062327758| Proposal [0.09922416 0.03252386]
# iteration: 590| Acceptance rate: 0.29322033898305083| Log-Likelihood: -468.8994442999414| Proposal [0.0664815  0.02239959]
# iteration: 600| Acceptance rate: 0.28833333333333333| Log-Likelihood: -468.8994442999414| Proposal [0.0664815  0.02239959]
# iteration: 610| Acceptance rate: 0.2901639344262295| Log-Likelihood: -468.6085759001284| Proposal [0.08207879 0.02043664]
# iteration: 620| Acceptance rate: 0.2870967741935484| Log-Likelihood: -468.4639600959983| Proposal [0.07662088 0.02434247]
# iteration: 630| Acceptance rate: 0.2857142857142857| Log-Likelihood: -469.0897432539055| Proposal [0.08508176 0.01746526]
# iteration: 640| Acceptance rate: 0.2890625| Log-Likelihood: -469.12967326666586| Proposal [0.06690994 0.01472877]
# iteration: 650| Acceptance rate: 0.2876923076923077| Log-Likelihood: -469.20619078718534| Proposal [0.06125052 0.02984017]
# iteration: 660| Acceptance rate: 0.2863636363636364| Log-Likelihood: -468.61967710759916| Proposal [0.07648633 0.02207057]
# iteration: 670| Acceptance rate: 0.2880597014925373| Log-Likelihood: -470.3513347446905| Proposal [0.08675758 0.03221677]
# iteration: 680| Acceptance rate: 0.28823529411764703| Log-Likelihood: -469.36778459461954| Proposal [0.0917733  0.01779562]
# iteration: 690| Acceptance rate: 0.28695652173913044| Log-Likelihood: -471.61101902467834| Proposal [0.08421114 0.01157048]
# iteration: 700| Acceptance rate: 0.29285714285714287| Log-Likelihood: -471.06083954684556| Proposal [0.05873825 0.03804799]
# iteration: 710| Acceptance rate: 0.2915492957746479| Log-Likelihood: -470.7496984682504| Proposal [0.03892689 0.02908688]
# iteration: 720| Acceptance rate: 0.28888888888888886| Log-Likelihood: -471.8476712065539| Proposal [0.04173429 0.0333421 ]
# iteration: 730| Acceptance rate: 0.29041095890410956| Log-Likelihood: -468.5037229088545| Proposal [0.07320132 0.02521917]
# iteration: 740| Acceptance rate: 0.2891891891891892| Log-Likelihood: -469.0843132891187| Proposal [0.07512994 0.02632019]
# iteration: 750| Acceptance rate: 0.28933333333333333| Log-Likelihood: -468.51281850884544| Proposal [0.08451919 0.01697346]
# iteration: 760| Acceptance rate: 0.2868421052631579| Log-Likelihood: -468.3328261899613| Proposal [0.0834434  0.01815716]
# iteration: 770| Acceptance rate: 0.2857142857142857| Log-Likelihood: -469.37000011191395| Proposal [0.08202599 0.02797815]
# iteration: 780| Acceptance rate: 0.2846153846153846| Log-Likelihood: -469.4649116596366| Proposal [0.0703347  0.03063934]
# iteration: 790| Acceptance rate: 0.28607594936708863| Log-Likelihood: -468.62328127824634| Proposal [0.05513468 0.02189921]
# iteration: 800| Acceptance rate: 0.28625| Log-Likelihood: -469.11696532405733| Proposal [0.07410947 0.02499963]
# iteration: 810| Acceptance rate: 0.2839506172839506| Log-Likelihood: -467.9626675927046| Proposal [0.07087114 0.02010378]
# iteration: 820| Acceptance rate: 0.28292682926829266| Log-Likelihood: -468.68017121822226| Proposal [0.07480493 0.02329992]
# iteration: 830| Acceptance rate: 0.2819277108433735| Log-Likelihood: -469.64892799628933| Proposal [0.09762079 0.01843456]
# iteration: 840| Acceptance rate: 0.28214285714285714| Log-Likelihood: -468.9825299628613| Proposal [0.06625039 0.015382  ]
# iteration: 850| Acceptance rate: 0.2823529411764706| Log-Likelihood: -468.31816487639475| Proposal [0.06310757 0.02394637]
# iteration: 860| Acceptance rate: 0.2837209302325581| Log-Likelihood: -468.508845803126| Proposal [0.05324364 0.02059754]
# iteration: 870| Acceptance rate: 0.28390804597701147| Log-Likelihood: -470.48974250245595| Proposal [0.08729547 0.03610601]
# iteration: 880| Acceptance rate: 0.2840909090909091| Log-Likelihood: -468.4442178010923| Proposal [0.05745812 0.02782608]
# iteration: 890| Acceptance rate: 0.2842696629213483| Log-Likelihood: -472.8303419054006| Proposal [0.08213762 0.04286742]
# iteration: 900| Acceptance rate: 0.28555555555555556| Log-Likelihood: -471.45130406487664| Proposal [0.13296435 0.01495725]
# iteration: 910| Acceptance rate: 0.2868131868131868| Log-Likelihood: -471.2772114388396| Proposal [0.13330579 0.01908616]
# iteration: 920| Acceptance rate: 0.2858695652173913| Log-Likelihood: -469.04965894348373| Proposal [0.09612487 0.02143832]
# iteration: 930| Acceptance rate: 0.2860215053763441| Log-Likelihood: -470.0361502794106| Proposal [0.09837211 0.01471079]
# iteration: 940| Acceptance rate: 0.28617021276595744| Log-Likelihood: -469.22867473582113| Proposal [0.10202729 0.0249118 ]
# iteration: 950| Acceptance rate: 0.2863157894736842| Log-Likelihood: -469.3348795872845| Proposal [0.07949116 0.02519398]
# iteration: 960| Acceptance rate: 0.28854166666666664| Log-Likelihood: -468.6723094156462| Proposal [0.07028249 0.0189649 ]
# iteration: 970| Acceptance rate: 0.2865979381443299| Log-Likelihood: -467.6622830356245| Proposal [0.05527049 0.02520114]
# iteration: 980| Acceptance rate: 0.28469387755102044| Log-Likelihood: -468.53481502731876| Proposal [0.06288735 0.02466224]
# iteration: 990| Acceptance rate: 0.28383838383838383| Log-Likelihood: -468.43989518139296| Proposal [0.06967885 0.02121384]
# iteration: 1000| Acceptance rate: 0.286| Log-Likelihood: -469.06146520753117| Proposal [0.08470985 0.0203542 ]
# iteration: 1010| Acceptance rate: 0.2881188118811881| Log-Likelihood: -467.6209882721983| Proposal [0.07095664 0.01864421]
# iteration: 1020| Acceptance rate: 0.29215686274509806| Log-Likelihood: -468.5334586495496| Proposal [0.06037857 0.01847354]
# iteration: 1030| Acceptance rate: 0.29902912621359223| Log-Likelihood: -469.6149408738396| Proposal [0.05181139 0.02328802]
# iteration: 1040| Acceptance rate: 0.3038461538461538| Log-Likelihood: -468.96469256723617| Proposal [0.05361517 0.02262453]
# iteration: 1050| Acceptance rate: 0.3076190476190476| Log-Likelihood: -469.30149982651136| Proposal [0.04825321 0.02647355]
# iteration: 1060| Acceptance rate: 0.30849056603773584| Log-Likelihood: -469.22604960109703| Proposal [0.04840753 0.02470329]
# iteration: 1070| Acceptance rate: 0.3102803738317757| Log-Likelihood: -468.9336121190562| Proposal [0.04942459 0.02324803]
# iteration: 1080| Acceptance rate: 0.3148148148148148| Log-Likelihood: -470.7838293586036| Proposal [0.04483596 0.01505351]
# iteration: 1090| Acceptance rate: 0.3174311926605505| Log-Likelihood: -468.89233992215304| Proposal [0.05487494 0.01924788]
# iteration: 1100| Acceptance rate: 0.3181818181818182| Log-Likelihood: -468.8834552586267| Proposal [0.05704825 0.01645433]
# iteration: 1110| Acceptance rate: 0.3225225225225225| Log-Likelihood: -468.6663415813459| Proposal [0.04982446 0.02369133]
# iteration: 1120| Acceptance rate: 0.3223214285714286| Log-Likelihood: -469.0545459553762| Proposal [0.0685687  0.01595373]
# iteration: 1130| Acceptance rate: 0.3256637168141593| Log-Likelihood: -469.93511226536333| Proposal [0.07491585 0.01425001]
# iteration: 1140| Acceptance rate: 0.3307017543859649| Log-Likelihood: -470.7963415581639| Proposal [0.08531214 0.01284919]
# iteration: 1150| Acceptance rate: 0.3339130434782609| Log-Likelihood: -470.1681772566758| Proposal [0.09444716 0.03140198]
# iteration: 1160| Acceptance rate: 0.3353448275862069| Log-Likelihood: -468.1120218726391| Proposal [0.06363556 0.02637339]
# iteration: 1170| Acceptance rate: 0.33760683760683763| Log-Likelihood: -468.5456031711093| Proposal [0.07120524 0.02872354]
# iteration: 1180| Acceptance rate: 0.34067796610169493| Log-Likelihood: -469.6469934361615| Proposal [0.09773567 0.02261456]
# iteration: 1190| Acceptance rate: 0.34369747899159664| Log-Likelihood: -468.73351031120563| Proposal [0.06035168 0.02568489]
# iteration: 1200| Acceptance rate: 0.345| Log-Likelihood: -469.3988762330933| Proposal [0.04663068 0.02443845]
# iteration: 1210| Acceptance rate: 0.343801652892562| Log-Likelihood: -468.5925145227396| Proposal [0.05542305 0.02190002]
# iteration: 1220| Acceptance rate: 0.3442622950819672| Log-Likelihood: -468.005560106465| Proposal [0.05977533 0.01878662]
# iteration: 1230| Acceptance rate: 0.34552845528455284| Log-Likelihood: -469.0897233378636| Proposal [0.07758676 0.02463474]
# iteration: 1240| Acceptance rate: 0.3467741935483871| Log-Likelihood: -470.4880327821343| Proposal [0.09869616 0.02999426]
# iteration: 1250| Acceptance rate: 0.3464| Log-Likelihood: -468.32910516439034| Proposal [0.06022672 0.02111285]
# iteration: 1260| Acceptance rate: 0.34444444444444444| Log-Likelihood: -468.5216571384314| Proposal [0.06501859 0.02342294]
# iteration: 1270| Acceptance rate: 0.34409448818897637| Log-Likelihood: -469.3165251775969| Proposal [0.05452975 0.02447459]
# iteration: 1280| Acceptance rate: 0.3453125| Log-Likelihood: -468.1637002202329| Proposal [0.06632787 0.02222846]
# iteration: 1290| Acceptance rate: 0.34728682170542635| Log-Likelihood: -469.73826419105995| Proposal [0.10604289 0.01765036]
# iteration: 1300| Acceptance rate: 0.34615384615384615| Log-Likelihood: -470.3561012613572| Proposal [0.12087266 0.01578714]
# iteration: 1310| Acceptance rate: 0.3473282442748092| Log-Likelihood: -470.2092852048431| Proposal [0.09520466 0.01430933]
# iteration: 1320| Acceptance rate: 0.346969696969697| Log-Likelihood: -470.3600836292096| Proposal [0.10051636 0.01754855]
# iteration: 1330| Acceptance rate: 0.3473684210526316| Log-Likelihood: -469.87144327046326| Proposal [0.0585158  0.03025989]
# iteration: 1340| Acceptance rate: 0.34701492537313433| Log-Likelihood: -468.73690917871846| Proposal [0.08474185 0.01820475]
# iteration: 1350| Acceptance rate: 0.3488888888888889| Log-Likelihood: -469.92093278580336| Proposal [0.09416897 0.01985332]
# iteration: 1360| Acceptance rate: 0.35294117647058826| Log-Likelihood: -470.78001442592534| Proposal [0.1223388  0.01644134]
# iteration: 1370| Acceptance rate: 0.35255474452554747| Log-Likelihood: -469.07617359641137| Proposal [0.08123019 0.02165794]
# iteration: 1380| Acceptance rate: 0.35434782608695653| Log-Likelihood: -468.41827470530603| Proposal [0.05334974 0.02262162]
# iteration: 1390| Acceptance rate: 0.35251798561151076| Log-Likelihood: -467.8457468123928| Proposal [0.05868238 0.0192651 ]
# iteration: 1400| Acceptance rate: 0.355| Log-Likelihood: -468.0154965227969| Proposal [0.06349373 0.01918061]
# iteration: 1410| Acceptance rate: 0.35602836879432626| Log-Likelihood: -468.97072080124826| Proposal [0.09391382 0.01920776]
# iteration: 1420| Acceptance rate: 0.35774647887323946| Log-Likelihood: -468.6992516307917| Proposal [0.0881463  0.02203617]
# iteration: 1430| Acceptance rate: 0.35874125874125873| Log-Likelihood: -468.506299714946| Proposal [0.06954562 0.01710638]
# iteration: 1440| Acceptance rate: 0.35833333333333334| Log-Likelihood: -468.0752983074666| Proposal [0.06831299 0.01855582]
# iteration: 1450| Acceptance rate: 0.35724137931034483| Log-Likelihood: -468.6022553793171| Proposal [0.05882235 0.01871262]
# iteration: 1460| Acceptance rate: 0.3595890410958904| Log-Likelihood: -468.10908249547225| Proposal [0.07416673 0.02056841]
# iteration: 1470| Acceptance rate: 0.3578231292517007| Log-Likelihood: -468.60798044010886| Proposal [0.07408326 0.01725201]
# iteration: 1480| Acceptance rate: 0.3601351351351351| Log-Likelihood: -468.8096672411357| Proposal [0.0553864  0.02129686]
# iteration: 1490| Acceptance rate: 0.35838926174496644| Log-Likelihood: -468.01196675289145| Proposal [0.08082919 0.01920519]
# iteration: 1500| Acceptance rate: 0.36133333333333334| Log-Likelihood: -470.6648152776385| Proposal [0.10937741 0.01541697]
# iteration: 1510| Acceptance rate: 0.3629139072847682| Log-Likelihood: -468.38035925764115| Proposal [0.05452    0.02016363]
# iteration: 1520| Acceptance rate: 0.3638157894736842| Log-Likelihood: -468.7510985439989| Proposal [0.09589421 0.02260389]
# iteration: 1530| Acceptance rate: 0.36405228758169933| Log-Likelihood: -467.71454908420804| Proposal [0.06350072 0.01797166]
# iteration: 1540| Acceptance rate: 0.36168831168831167| Log-Likelihood: -467.71454908420804| Proposal [0.06350072 0.01797166]
# iteration: 1550| Acceptance rate: 0.36258064516129035| Log-Likelihood: -468.6777572377829| Proposal [0.06740419 0.01983139]
# iteration: 1560| Acceptance rate: 0.36538461538461536| Log-Likelihood: -468.9714417231201| Proposal [0.07905665 0.01762147]
# iteration: 1570| Acceptance rate: 0.3668789808917197| Log-Likelihood: -469.74717276920876| Proposal [0.0982495  0.01815091]
# iteration: 1580| Acceptance rate: 0.3677215189873418| Log-Likelihood: -468.5913767489729| Proposal [0.05510436 0.01983698]
# iteration: 1590| Acceptance rate: 0.370440251572327| Log-Likelihood: -469.87026216178026| Proposal [0.10474509 0.02620247]
# iteration: 1600| Acceptance rate: 0.37125| Log-Likelihood: -468.34783913660465| Proposal [0.06031433 0.01623735]
# iteration: 1610| Acceptance rate: 0.37267080745341613| Log-Likelihood: -468.61542203556957| Proposal [0.05366418 0.0215715 ]
# iteration: 1620| Acceptance rate: 0.37160493827160496| Log-Likelihood: -468.3275003752099| Proposal [0.09502929 0.021686  ]
# iteration: 1630| Acceptance rate: 0.3736196319018405| Log-Likelihood: -470.5122288911228| Proposal [0.10584318 0.01651059]
# iteration: 1640| Acceptance rate: 0.37317073170731707| Log-Likelihood: -469.238498175905| Proposal [0.0647878  0.02814077]
# iteration: 1650| Acceptance rate: 0.37272727272727274| Log-Likelihood: -468.56700705057443| Proposal [0.08929101 0.01952531]
# iteration: 1660| Acceptance rate: 0.3740963855421687| Log-Likelihood: -468.5780226152995| Proposal [0.079718   0.02338801]
# iteration: 1670| Acceptance rate: 0.37604790419161677| Log-Likelihood: -469.37534717902554| Proposal [0.09225815 0.01899751]
# iteration: 1680| Acceptance rate: 0.3767857142857143| Log-Likelihood: -469.13703283567094| Proposal [0.10826902 0.02206606]
# iteration: 1690| Acceptance rate: 0.3763313609467456| Log-Likelihood: -468.4484825074092| Proposal [0.06105941 0.02060157]
# iteration: 1700| Acceptance rate: 0.3770588235294118| Log-Likelihood: -470.28310943954364| Proposal [0.09326269 0.01616627]
# iteration: 1710| Acceptance rate: 0.37894736842105264| Log-Likelihood: -470.2839257286875| Proposal [0.12080697 0.02620416]
# iteration: 1720| Acceptance rate: 0.37965116279069766| Log-Likelihood: -470.0565029434876| Proposal [0.08432595 0.0312608 ]
# iteration: 1730| Acceptance rate: 0.37976878612716763| Log-Likelihood: -469.52544183803747| Proposal [0.11181703 0.01769844]
# iteration: 1740| Acceptance rate: 0.3810344827586207| Log-Likelihood: -468.5936373975123| Proposal [0.09103775 0.02339901]
# iteration: 1750| Acceptance rate: 0.37942857142857145| Log-Likelihood: -468.84147726086974| Proposal [0.07771803 0.02636537]
# iteration: 1760| Acceptance rate: 0.3801136363636364| Log-Likelihood: -468.82137390688695| Proposal [0.079231   0.02889169]
# iteration: 1770| Acceptance rate: 0.3807909604519774| Log-Likelihood: -468.3140262791505| Proposal [0.06259138 0.0218814 ]
# iteration: 1780| Acceptance rate: 0.38033707865168537| Log-Likelihood: -467.73746925788925| Proposal [0.05872785 0.02425459]
# iteration: 1790| Acceptance rate: 0.3787709497206704| Log-Likelihood: -468.8624532311467| Proposal [0.05458656 0.016126  ]
# iteration: 1800| Acceptance rate: 0.38| Log-Likelihood: -469.1641970030111| Proposal [0.06535349 0.01592076]
# iteration: 1810| Acceptance rate: 0.3806629834254144| Log-Likelihood: -470.33850655233516| Proposal [0.0982374  0.02354219]
# iteration: 1820| Acceptance rate: 0.3802197802197802| Log-Likelihood: -469.558919115019| Proposal [0.08463649 0.01495707]
# iteration: 1830| Acceptance rate: 0.380327868852459| Log-Likelihood: -467.96030234412996| Proposal [0.08096473 0.02235664]
# iteration: 1840| Acceptance rate: 0.3804347826086957| Log-Likelihood: -468.26796099575586| Proposal [0.08904818 0.02494182]
# iteration: 1850| Acceptance rate: 0.3810810810810811| Log-Likelihood: -470.07931302630294| Proposal [0.0847372  0.02312867]
# iteration: 1860| Acceptance rate: 0.38225806451612904| Log-Likelihood: -470.0094663500599| Proposal [0.10533612 0.02397704]
# iteration: 1870| Acceptance rate: 0.38235294117647056| Log-Likelihood: -468.9036713242328| Proposal [0.07048312 0.01464529]
# iteration: 1880| Acceptance rate: 0.3819148936170213| Log-Likelihood: -470.2475451018071| Proposal [0.10973927 0.01877845]
# iteration: 1890| Acceptance rate: 0.3835978835978836| Log-Likelihood: -470.5060603907964| Proposal [0.06452644 0.01244603]
# iteration: 1900| Acceptance rate: 0.3836842105263158| Log-Likelihood: -470.03730323597375| Proposal [0.05943103 0.0153778 ]
# iteration: 1910| Acceptance rate: 0.38272251308900523| Log-Likelihood: -470.16153774474935| Proposal [0.05812794 0.03106473]
# iteration: 1920| Acceptance rate: 0.38385416666666666| Log-Likelihood: -471.0750880460651| Proposal [0.06871228 0.03814281]
# iteration: 1930| Acceptance rate: 0.3839378238341969| Log-Likelihood: -468.4844241499623| Proposal [0.07203159 0.02397645]
# iteration: 1940| Acceptance rate: 0.3835051546391753| Log-Likelihood: -469.11392332829524| Proposal [0.08448511 0.02455045]
# iteration: 1950| Acceptance rate: 0.38461538461538464| Log-Likelihood: -470.10590156760395| Proposal [0.08167248 0.01369871]
# iteration: 1960| Acceptance rate: 0.3846938775510204| Log-Likelihood: -471.30751014628726| Proposal [0.1090883  0.03329725]
# iteration: 1970| Acceptance rate: 0.3847715736040609| Log-Likelihood: -468.9653785159881| Proposal [0.05986549 0.02516592]
# iteration: 1980| Acceptance rate: 0.38484848484848483| Log-Likelihood: -469.34405461854533| Proposal [0.04945208 0.02504309]
# iteration: 1990| Acceptance rate: 0.385929648241206| Log-Likelihood: -468.929664570147| Proposal [0.06658805 0.02445521]
# iteration: 2000| Acceptance rate: 0.387| Log-Likelihood: -469.55779324041384| Proposal [0.04541234 0.02718731]
# iteration: 2010| Acceptance rate: 0.38656716417910447| Log-Likelihood: -468.5424918721289| Proposal [0.0484846  0.02158151]
# iteration: 2020| Acceptance rate: 0.38514851485148516| Log-Likelihood: -469.4372705851402| Proposal [0.0787173  0.02908259]
# iteration: 2030| Acceptance rate: 0.38571428571428573| Log-Likelihood: -469.2069562864546| Proposal [0.07718616 0.01757148]
# iteration: 2040| Acceptance rate: 0.38529411764705884| Log-Likelihood: -468.80378002412306| Proposal [0.04260465 0.02105203]
# iteration: 2050| Acceptance rate: 0.3848780487804878| Log-Likelihood: -468.76561518830505| Proposal [0.09265891 0.01733167]
# iteration: 2060| Acceptance rate: 0.3859223300970874| Log-Likelihood: -470.5288202747729| Proposal [0.12472809 0.01670518]
# iteration: 2070| Acceptance rate: 0.3869565217391304| Log-Likelihood: -471.4712637684682| Proposal [0.13148856 0.01473956]
# iteration: 2080| Acceptance rate: 0.38798076923076924| Log-Likelihood: -468.4408213739751| Proposal [0.06402907 0.02046057]
# iteration: 2090| Acceptance rate: 0.38708133971291864| Log-Likelihood: -469.3795155335086| Proposal [0.05132745 0.01911092]
# iteration: 2100| Acceptance rate: 0.3861904761904762| Log-Likelihood: -467.52411642604454| Proposal [0.06396028 0.01977971]
# iteration: 2110| Acceptance rate: 0.385781990521327| Log-Likelihood: -468.7959992121392| Proposal [0.08267688 0.01745979]
# iteration: 2120| Acceptance rate: 0.38537735849056604| Log-Likelihood: -468.44776821083536| Proposal [0.06219757 0.01779418]
# iteration: 2130| Acceptance rate: 0.3863849765258216| Log-Likelihood: -471.5818306421948| Proposal [0.11573511 0.01262644]
# iteration: 2140| Acceptance rate: 0.38738317757009344| Log-Likelihood: -469.75647311996005| Proposal [0.11596774 0.02162341]
# iteration: 2150| Acceptance rate: 0.386046511627907| Log-Likelihood: -471.15691785372627| Proposal [0.09277876 0.01381472]
# iteration: 2160| Acceptance rate: 0.3851851851851852| Log-Likelihood: -471.750017155139| Proposal [0.10539085 0.01246942]
# iteration: 2170| Acceptance rate: 0.38387096774193546| Log-Likelihood: -471.17573124449024| Proposal [0.09044274 0.01294357]
# iteration: 2180| Acceptance rate: 0.3839449541284404| Log-Likelihood: -470.033087246457| Proposal [0.11620506 0.02076515]
# iteration: 2190| Acceptance rate: 0.38401826484018264| Log-Likelihood: -468.1202239962035| Proposal [0.08548468 0.01955119]
# iteration: 2200| Acceptance rate: 0.3840909090909091| Log-Likelihood: -468.90643100293| Proposal [0.07828742 0.01684614]
# iteration: 2210| Acceptance rate: 0.38416289592760183| Log-Likelihood: -467.5651452773718| Proposal [0.06787502 0.02190698]
# iteration: 2220| Acceptance rate: 0.38333333333333336| Log-Likelihood: -469.2526250911944| Proposal [0.06468846 0.02045839]
# iteration: 2230| Acceptance rate: 0.3829596412556054| Log-Likelihood: -468.9353166473408| Proposal [0.0559801  0.02581907]
# iteration: 2240| Acceptance rate: 0.384375| Log-Likelihood: -469.71212066516057| Proposal [0.06871256 0.02939417]
# iteration: 2250| Acceptance rate: 0.38533333333333336| Log-Likelihood: -468.85857739819954| Proposal [0.07171258 0.01965269]
# iteration: 2260| Acceptance rate: 0.3858407079646018| Log-Likelihood: -468.97922543593876| Proposal [0.06423262 0.02295997]
# iteration: 2270| Acceptance rate: 0.3854625550660793| Log-Likelihood: -469.0382280050422| Proposal [0.08234984 0.02124505]
# iteration: 2280| Acceptance rate: 0.3864035087719298| Log-Likelihood: -468.4188041347234| Proposal [0.05954138 0.02245392]
# iteration: 2290| Acceptance rate: 0.385589519650655| Log-Likelihood: -469.3266171396719| Proposal [0.09666008 0.02239084]
# iteration: 2300| Acceptance rate: 0.38608695652173913| Log-Likelihood: -468.753182503876| Proposal [0.09858515 0.01834911]
# iteration: 2310| Acceptance rate: 0.38614718614718613| Log-Likelihood: -469.11141542527776| Proposal [0.09138661 0.02092615]
# iteration: 2320| Acceptance rate: 0.38663793103448274| Log-Likelihood: -468.8502046314066| Proposal [0.0915631  0.01906125]
# iteration: 2330| Acceptance rate: 0.3866952789699571| Log-Likelihood: -468.25385318876675| Proposal [0.07004628 0.02097764]
# iteration: 2340| Acceptance rate: 0.38675213675213677| Log-Likelihood: -468.681331495228| Proposal [0.0690298  0.02145923]
# iteration: 2350| Acceptance rate: 0.38595744680851063| Log-Likelihood: -468.43857719933817| Proposal [0.08062289 0.01878939]
# iteration: 2360| Acceptance rate: 0.3864406779661017| Log-Likelihood: -469.24920147526774| Proposal [0.0958983  0.02231578]
# iteration: 2370| Acceptance rate: 0.38776371308016877| Log-Likelihood: -469.8902776866577| Proposal [0.05204027 0.01754314]
# iteration: 2380| Acceptance rate: 0.38823529411764707| Log-Likelihood: -468.6558918512639| Proposal [0.05835749 0.01671274]
# iteration: 2390| Acceptance rate: 0.3891213389121339| Log-Likelihood: -468.6654515850037| Proposal [0.07349174 0.01754783]
# iteration: 2400| Acceptance rate: 0.39| Log-Likelihood: -469.24523468721117| Proposal [0.07006595 0.02927626]
# iteration: 2410| Acceptance rate: 0.3900414937759336| Log-Likelihood: -471.21881925952306| Proposal [0.12247031 0.01967342]
# iteration: 2420| Acceptance rate: 0.3896694214876033| Log-Likelihood: -468.6803909898766| Proposal [0.05668281 0.01698331]
# iteration: 2430| Acceptance rate: 0.388477366255144| Log-Likelihood: -468.711503637864| Proposal [0.05928882 0.02248337]
# iteration: 2440| Acceptance rate: 0.38729508196721313| Log-Likelihood: -468.1332780880064| Proposal [0.05494129 0.02020578]
# iteration: 2450| Acceptance rate: 0.38571428571428573| Log-Likelihood: -468.1332780880064| Proposal [0.05494129 0.02020578]
# iteration: 2460| Acceptance rate: 0.3857723577235772| Log-Likelihood: -468.7181537948737| Proposal [0.07278515 0.0202146 ]
# iteration: 2470| Acceptance rate: 0.3866396761133603| Log-Likelihood: -470.523824585301| Proposal [0.04514429 0.0149597 ]
# iteration: 2480| Acceptance rate: 0.3866935483870968| Log-Likelihood: -467.6665107747737| Proposal [0.06238025 0.02067442]
# iteration: 2490| Acceptance rate: 0.3859437751004016| Log-Likelihood: -468.2112659907668| Proposal [0.06051662 0.0207804 ]
# iteration: 2500| Acceptance rate: 0.3868| Log-Likelihood: -468.7632213236655| Proposal [0.04454709 0.02217735]
# iteration: 2510| Acceptance rate: 0.38645418326693226| Log-Likelihood: -469.0491721501815| Proposal [0.08042617 0.02712777]
# iteration: 2520| Acceptance rate: 0.3865079365079365| Log-Likelihood: -469.2634440459472| Proposal [0.05637125 0.01784885]
# iteration: 2530| Acceptance rate: 0.38616600790513833| Log-Likelihood: -467.8013075042762| Proposal [0.06695195 0.02082583]
# iteration: 2540| Acceptance rate: 0.3858267716535433| Log-Likelihood: -468.3298535262447| Proposal [0.0869211  0.01624562]
# iteration: 2550| Acceptance rate: 0.3862745098039216| Log-Likelihood: -470.28162836495795| Proposal [0.03987823 0.02055003]
# iteration: 2560| Acceptance rate: 0.386328125| Log-Likelihood: -469.7843319641202| Proposal [0.0452652  0.02268132]
# iteration: 2570| Acceptance rate: 0.38638132295719846| Log-Likelihood: -468.6497120811309| Proposal [0.07303505 0.02180879]
# iteration: 2580| Acceptance rate: 0.3875968992248062| Log-Likelihood: -468.5619167669901| Proposal [0.07097738 0.0142927 ]
# iteration: 2590| Acceptance rate: 0.3884169884169884| Log-Likelihood: -467.81714772738286| Proposal [0.08113028 0.02144451]
# iteration: 2600| Acceptance rate: 0.38769230769230767| Log-Likelihood: -468.6834327776664| Proposal [0.07973393 0.02712916]
# iteration: 2610| Acceptance rate: 0.3888888888888889| Log-Likelihood: -469.7315909844547| Proposal [0.06175114 0.0323497 ]
# iteration: 2620| Acceptance rate: 0.3893129770992366| Log-Likelihood: -469.47319483392516| Proposal [0.08911297 0.01699867]
# iteration: 2630| Acceptance rate: 0.38935361216730036| Log-Likelihood: -468.3697296958207| Proposal [0.0598002  0.02586762]
# iteration: 2640| Acceptance rate: 0.38825757575757575| Log-Likelihood: -468.10094952839603| Proposal [0.06540913 0.02555317]
# iteration: 2650| Acceptance rate: 0.38943396226415095| Log-Likelihood: -469.64161681134107| Proposal [0.07432075 0.03038762]
# iteration: 2660| Acceptance rate: 0.3894736842105263| Log-Likelihood: -468.5197511387981| Proposal [0.05890024 0.02329482]
# iteration: 2670| Acceptance rate: 0.3880149812734082| Log-Likelihood: -468.5197511387981| Proposal [0.05890024 0.02329482]
# iteration: 2680| Acceptance rate: 0.38731343283582087| Log-Likelihood: -468.6281700714691| Proposal [0.06750364 0.0228772 ]
# iteration: 2690| Acceptance rate: 0.38773234200743495| Log-Likelihood: -469.1640746932756| Proposal [0.05812284 0.01945013]
# iteration: 2700| Acceptance rate: 0.3874074074074074| Log-Likelihood: -470.1670824203896| Proposal [0.07122181 0.03602553]
# iteration: 2710| Acceptance rate: 0.3874538745387454| Log-Likelihood: -468.43338655248385| Proposal [0.05120093 0.0240653 ]
# iteration: 2720| Acceptance rate: 0.38676470588235295| Log-Likelihood: -468.9701270119988| Proposal [0.0759156  0.02600474]
# iteration: 2730| Acceptance rate: 0.3871794871794872| Log-Likelihood: -468.34114902366645| Proposal [0.06412362 0.02657049]
# iteration: 2740| Acceptance rate: 0.3875912408759124| Log-Likelihood: -468.11122424286265| Proposal [0.06304124 0.02243021]
# iteration: 2750| Acceptance rate: 0.38836363636363636| Log-Likelihood: -468.6239502768116| Proposal [0.08412714 0.02570486]
# iteration: 2760| Acceptance rate: 0.388768115942029| Log-Likelihood: -468.7829156414853| Proposal [0.08250482 0.02520871]
# iteration: 2770| Acceptance rate: 0.38880866425992777| Log-Likelihood: -469.3833998126941| Proposal [0.04999151 0.01855854]
# iteration: 2780| Acceptance rate: 0.3881294964028777| Log-Likelihood: -469.5794480800876| Proposal [0.09675036 0.02297265]
# iteration: 2790| Acceptance rate: 0.3881720430107527| Log-Likelihood: -468.56811735876676| Proposal [0.09449658 0.02003026]
# iteration: 2800| Acceptance rate: 0.38821428571428573| Log-Likelihood: -468.59885824769617| Proposal [0.06776436 0.02058924]
# iteration: 2810| Acceptance rate: 0.3879003558718861| Log-Likelihood: -468.54960749850943| Proposal [0.07552969 0.01821676]
# iteration: 2820| Acceptance rate: 0.3893617021276596| Log-Likelihood: -468.7819435435487| Proposal [0.0651202  0.01740151]
# iteration: 2830| Acceptance rate: 0.3893992932862191| Log-Likelihood: -468.89826765948965| Proposal [0.08532949 0.02625813]
# iteration: 2840| Acceptance rate: 0.3897887323943662| Log-Likelihood: -468.6924265167312| Proposal [0.0742245 0.0259011]
# iteration: 2850| Acceptance rate: 0.39052631578947367| Log-Likelihood: -469.26570841298127| Proposal [0.05310744 0.0277717 ]
# iteration: 2860| Acceptance rate: 0.39090909090909093| Log-Likelihood: -468.0817928236882| Proposal [0.07120142 0.01786968]
# iteration: 2870| Acceptance rate: 0.3909407665505226| Log-Likelihood: -469.1965880007895| Proposal [0.08848435 0.0175132 ]
# iteration: 2880| Acceptance rate: 0.39166666666666666| Log-Likelihood: -471.0808978048441| Proposal [0.07278521 0.03699807]
# iteration: 2890| Acceptance rate: 0.3916955017301038| Log-Likelihood: -470.5458535667163| Proposal [0.09627399 0.0319597 ]
# iteration: 2900| Acceptance rate: 0.3917241379310345| Log-Likelihood: -471.2492453035065| Proposal [0.10040905 0.03179886]
# iteration: 2910| Acceptance rate: 0.3920962199312715| Log-Likelihood: -468.4850957321659| Proposal [0.07245843 0.01953473]
# iteration: 2920| Acceptance rate: 0.3921232876712329| Log-Likelihood: -469.03629157492634| Proposal [0.09913013 0.0247231 ]
# iteration: 2930| Acceptance rate: 0.39283276450511945| Log-Likelihood: -468.56555441800884| Proposal [0.06568628 0.01974925]
# iteration: 2940| Acceptance rate: 0.3921768707482993| Log-Likelihood: -468.89578487108025| Proposal [0.08806453 0.01674199]
# iteration: 2950| Acceptance rate: 0.391864406779661| Log-Likelihood: -468.7818904888009| Proposal [0.06716781 0.02692029]
# iteration: 2960| Acceptance rate: 0.3912162162162162| Log-Likelihood: -469.9215842780415| Proposal [0.0508956  0.01817988]
# iteration: 2970| Acceptance rate: 0.39191919191919194| Log-Likelihood: -469.865058170553| Proposal [0.10347432 0.0178903 ]
# iteration: 2980| Acceptance rate: 0.3919463087248322| Log-Likelihood: -468.8469189827055| Proposal [0.05323366 0.02609717]
# iteration: 2990| Acceptance rate: 0.39264214046822743| Log-Likelihood: -468.4773439517807| Proposal [0.06294037 0.01587315]
# iteration: 3000| Acceptance rate: 0.3923333333333333| Log-Likelihood: -468.7589734975998| Proposal [0.05665316 0.0270518 ]
# iteration: 3010| Acceptance rate: 0.39368770764119604| Log-Likelihood: -470.5607435800842| Proposal [0.06303657 0.03562399]
# iteration: 3020| Acceptance rate: 0.3937086092715232| Log-Likelihood: -469.60977970178203| Proposal [0.06529682 0.0148096 ]
# iteration: 3030| Acceptance rate: 0.3933993399339934| Log-Likelihood: -469.9973209773411| Proposal [0.06084637 0.0344394 ]
# iteration: 3040| Acceptance rate: 0.3930921052631579| Log-Likelihood: -468.6388446823299| Proposal [0.04445874 0.01975674]
# iteration: 3050| Acceptance rate: 0.3921311475409836| Log-Likelihood: -467.87130351744685| Proposal [0.07317827 0.01802661]
# iteration: 3060| Acceptance rate: 0.39215686274509803| Log-Likelihood: -467.55043050833507| Proposal [0.05972714 0.01726995]
# iteration: 3070| Acceptance rate: 0.39120521172638434| Log-Likelihood: -468.24822628634166| Proposal [0.07738361 0.02127235]
# iteration: 3080| Acceptance rate: 0.3912337662337662| Log-Likelihood: -469.5357719662893| Proposal [0.0493643  0.02294194]
# iteration: 3090| Acceptance rate: 0.39093851132686086| Log-Likelihood: -470.48316389589974| Proposal [0.04060151 0.02412996]
# iteration: 3100| Acceptance rate: 0.3903225806451613| Log-Likelihood: -467.95888884258414| Proposal [0.05339716 0.02073836]
# iteration: 3110| Acceptance rate: 0.3897106109324759| Log-Likelihood: -469.53106491659753| Proposal [0.09274018 0.0238437 ]
# iteration: 3120| Acceptance rate: 0.3903846153846154| Log-Likelihood: -468.5939750878443| Proposal [0.05439077 0.02229345]
# iteration: 3130| Acceptance rate: 0.3904153354632588| Log-Likelihood: -468.09592400288824| Proposal [0.06271872 0.02393025]
# iteration: 3140| Acceptance rate: 0.3910828025477707| Log-Likelihood: -467.7340884452387| Proposal [0.06339219 0.01629255]
# iteration: 3150| Acceptance rate: 0.3907936507936508| Log-Likelihood: -469.85373679490584| Proposal [0.04135047 0.01975272]
# iteration: 3160| Acceptance rate: 0.3911392405063291| Log-Likelihood: -468.60767032241887| Proposal [0.08138841 0.02341286]
# iteration: 3170| Acceptance rate: 0.39148264984227127| Log-Likelihood: -470.1244831323783| Proposal [0.0547238  0.01347499]
# iteration: 3180| Acceptance rate: 0.3915094339622642| Log-Likelihood: -468.3118140486976| Proposal [0.07276967 0.01664292]
# iteration: 3190| Acceptance rate: 0.39122257053291537| Log-Likelihood: -468.65199268819686| Proposal [0.05891678 0.02804056]
# iteration: 3200| Acceptance rate: 0.3909375| Log-Likelihood: -469.98291675646004| Proposal [0.043199   0.01701047]
# iteration: 3210| Acceptance rate: 0.3909657320872274| Log-Likelihood: -470.16277757955237| Proposal [0.04749461 0.03403978]
# iteration: 3220| Acceptance rate: 0.3903726708074534| Log-Likelihood: -467.77716286060166| Proposal [0.06939836 0.01894651]
# iteration: 3230| Acceptance rate: 0.39009287925696595| Log-Likelihood: -468.45014509583757| Proposal [0.06029817 0.02297202]
# iteration: 3240| Acceptance rate: 0.3904320987654321| Log-Likelihood: -468.3270733903062| Proposal [0.07817047 0.02382335]
# iteration: 3250| Acceptance rate: 0.3913846153846154| Log-Likelihood: -469.04414928074976| Proposal [0.08941712 0.02248357]
# iteration: 3260| Acceptance rate: 0.3923312883435583| Log-Likelihood: -468.1296320656251| Proposal [0.07057468 0.01750895]
# iteration: 3270| Acceptance rate: 0.391131498470948| Log-Likelihood: -468.1296320656251| Proposal [0.07057468 0.01750895]
# iteration: 3280| Acceptance rate: 0.39115853658536587| Log-Likelihood: -468.38547831226293| Proposal [0.07501493 0.02091123]
# iteration: 3290| Acceptance rate: 0.39179331306990883| Log-Likelihood: -468.889636523565| Proposal [0.09068798 0.02181418]
# iteration: 3300| Acceptance rate: 0.39181818181818184| Log-Likelihood: -469.2501407149709| Proposal [0.09759365 0.02482213]
# iteration: 3310| Acceptance rate: 0.3918429003021148| Log-Likelihood: -469.0495051643957| Proposal [0.04725508 0.02022764]
# iteration: 3320| Acceptance rate: 0.39126506024096386| Log-Likelihood: -469.09158720077875| Proposal [0.08820626 0.01955096]
# iteration: 3330| Acceptance rate: 0.3918918918918919| Log-Likelihood: -468.90831112982494| Proposal [0.06569562 0.02692711]
# iteration: 3340| Acceptance rate: 0.39191616766467063| Log-Likelihood: -468.74790590484105| Proposal [0.06717888 0.02364851]
# iteration: 3350| Acceptance rate: 0.39134328358208953| Log-Likelihood: -470.0237683540368| Proposal [0.05146864 0.03155379]
# iteration: 3360| Acceptance rate: 0.3907738095238095| Log-Likelihood: -468.88526414402753| Proposal [0.07748789 0.01731397]
# iteration: 3370| Acceptance rate: 0.3910979228486647| Log-Likelihood: -468.20734778563383| Proposal [0.07646034 0.01983261]
# iteration: 3380| Acceptance rate: 0.39023668639053255| Log-Likelihood: -468.285348899455| Proposal [0.05959467 0.01924102]
# iteration: 3390| Acceptance rate: 0.3893805309734513| Log-Likelihood: -469.15074534325464| Proposal [0.04245563 0.0229582 ]
# iteration: 3400| Acceptance rate: 0.3891176470588235| Log-Likelihood: -468.9710203169493| Proposal [0.08127672 0.02873238]
# iteration: 3410| Acceptance rate: 0.3885630498533724| Log-Likelihood: -469.72245151390734| Proposal [0.09666007 0.02659811]
# iteration: 3420| Acceptance rate: 0.38859649122807016| Log-Likelihood: -471.67430873187783| Proposal [0.10984517 0.01416884]
# iteration: 3430| Acceptance rate: 0.3880466472303207| Log-Likelihood: -471.00735840823455| Proposal [0.11799564 0.01739268]
# iteration: 3440| Acceptance rate: 0.3877906976744186| Log-Likelihood: -468.93014254980255| Proposal [0.08447662 0.01789639]
# iteration: 3450| Acceptance rate: 0.3881159420289855| Log-Likelihood: -468.71318347521446| Proposal [0.08136553 0.02222434]
# iteration: 3460| Acceptance rate: 0.3875722543352601| Log-Likelihood: -468.75397285375976| Proposal [0.0597764  0.02466918]
# iteration: 3470| Acceptance rate: 0.3881844380403458| Log-Likelihood: -469.08115186731766| Proposal [0.07188269 0.02799525]
# iteration: 3480| Acceptance rate: 0.3882183908045977| Log-Likelihood: -468.1894752033105| Proposal [0.06986157 0.01679904]
# iteration: 3490| Acceptance rate: 0.38853868194842406| Log-Likelihood: -469.65931498733727| Proposal [0.07025645 0.01371542]
# iteration: 3500| Acceptance rate: 0.38857142857142857| Log-Likelihood: -468.4984113380952| Proposal [0.0871823  0.02158372]
# iteration: 3510| Acceptance rate: 0.3891737891737892| Log-Likelihood: -470.0081401481089| Proposal [0.11660138 0.02145875]
# iteration: 3520| Acceptance rate: 0.38892045454545454| Log-Likelihood: -469.7879874173223| Proposal [0.11375311 0.02471969]
# iteration: 3530| Acceptance rate: 0.3895184135977337| Log-Likelihood: -470.2795425665803| Proposal [0.09088667 0.02910205]
# iteration: 3540| Acceptance rate: 0.3889830508474576| Log-Likelihood: -467.88920924404954| Proposal [0.06431284 0.01955995]
# iteration: 3550| Acceptance rate: 0.38873239436619716| Log-Likelihood: -470.4443644856539| Proposal [0.09107066 0.03240409]
# iteration: 3560| Acceptance rate: 0.3890449438202247| Log-Likelihood: -469.2366039377487| Proposal [0.08209917 0.01583058]
# iteration: 3570| Acceptance rate: 0.38823529411764707| Log-Likelihood: -468.637831331458| Proposal [0.06289823 0.01898492]
# iteration: 3580| Acceptance rate: 0.3877094972067039| Log-Likelihood: -468.19872101004324| Proposal [0.07373421 0.02424668]
# iteration: 3590| Acceptance rate: 0.38690807799442894| Log-Likelihood: -468.8838159039954| Proposal [0.05393262 0.02436507]
# iteration: 3600| Acceptance rate: 0.3883333333333333| Log-Likelihood: -467.9697616452308| Proposal [0.07593621 0.02132159]
# iteration: 3610| Acceptance rate: 0.38753462603878114| Log-Likelihood: -469.4557189625572| Proposal [0.06239828 0.02879391]
# iteration: 3620| Acceptance rate: 0.38812154696132595| Log-Likelihood: -468.58644712561414| Proposal [0.06872712 0.02229158]
# iteration: 3630| Acceptance rate: 0.3881542699724518| Log-Likelihood: -469.1631584514917| Proposal [0.06158913 0.03023121]
# iteration: 3640| Acceptance rate: 0.3879120879120879| Log-Likelihood: -468.53390984272795| Proposal [0.0758613  0.02642821]
# iteration: 3650| Acceptance rate: 0.38794520547945205| Log-Likelihood: -470.13553850964195| Proposal [0.04566146 0.01732866]
# iteration: 3660| Acceptance rate: 0.3879781420765027| Log-Likelihood: -468.2910471346561| Proposal [0.06163316 0.01998006]
# iteration: 3670| Acceptance rate: 0.3874659400544959| Log-Likelihood: -469.2564965514437| Proposal [0.07511682 0.0209828 ]
# iteration: 3680| Acceptance rate: 0.3877717391304348| Log-Likelihood: -469.0392353787858| Proposal [0.08552471 0.024248  ]
# iteration: 3690| Acceptance rate: 0.389159891598916| Log-Likelihood: -468.97931520587434| Proposal [0.07547264 0.0278267 ]
# iteration: 3700| Acceptance rate: 0.38891891891891894| Log-Likelihood: -469.99015202358254| Proposal [0.12289704 0.02186536]
# iteration: 3710| Acceptance rate: 0.38840970350404314| Log-Likelihood: -469.8360184274282| Proposal [0.05661789 0.03038404]
# iteration: 3720| Acceptance rate: 0.38844086021505375| Log-Likelihood: -469.4067396802612| Proposal [0.09471905 0.02077823]
# iteration: 3730| Acceptance rate: 0.3890080428954424| Log-Likelihood: -469.9017849803533| Proposal [0.10251555 0.02140356]
# iteration: 3740| Acceptance rate: 0.38850267379679143| Log-Likelihood: -469.7827471161271| Proposal [0.09810935 0.01824221]
# iteration: 3750| Acceptance rate: 0.38853333333333334| Log-Likelihood: -471.0212794139606| Proposal [0.14161632 0.01887041]
# iteration: 3760| Acceptance rate: 0.3882978723404255| Log-Likelihood: -468.3665896570796| Proposal [0.07883185 0.02269828]
# iteration: 3770| Acceptance rate: 0.3885941644562334| Log-Likelihood: -469.23423034628996| Proposal [0.0769294  0.03140744]
# iteration: 3780| Acceptance rate: 0.38835978835978835| Log-Likelihood: -468.98237356420196| Proposal [0.09145958 0.02254653]
# iteration: 3790| Acceptance rate: 0.38786279683377306| Log-Likelihood: -468.68722611636707| Proposal [0.07191911 0.02275699]
# iteration: 3800| Acceptance rate: 0.38789473684210524| Log-Likelihood: -470.93112239680136| Proposal [0.04152513 0.0155396 ]
# iteration: 3810| Acceptance rate: 0.38871391076115486| Log-Likelihood: -470.45498940730175| Proposal [0.09955537 0.01413159]
# iteration: 3820| Acceptance rate: 0.38848167539267014| Log-Likelihood: -469.31062808944165| Proposal [0.08022107 0.03045331]
# iteration: 3830| Acceptance rate: 0.3882506527415144| Log-Likelihood: -468.96280925727973| Proposal [0.07178626 0.02661536]
# iteration: 3840| Acceptance rate: 0.38828125| Log-Likelihood: -469.1477016298938| Proposal [0.04572751 0.0244374 ]
# iteration: 3850| Acceptance rate: 0.3888311688311688| Log-Likelihood: -470.72333856517014| Proposal [0.11483478 0.01719209]
# iteration: 3860| Acceptance rate: 0.388860103626943| Log-Likelihood: -471.5849294555575| Proposal [0.11842368 0.0333696 ]
# iteration: 3870| Acceptance rate: 0.3886304909560723| Log-Likelihood: -468.5167088786198| Proposal [0.05606531 0.02510103]
# iteration: 3880| Acceptance rate: 0.388659793814433| Log-Likelihood: -468.9360670713928| Proposal [0.06198382 0.02595728]
# iteration: 3890| Acceptance rate: 0.38868894601542414| Log-Likelihood: -469.772364483947| Proposal [0.08755728 0.02978228]
# iteration: 3900| Acceptance rate: 0.3892307692307692| Log-Likelihood: -468.6279121679043| Proposal [0.08367375 0.02172922]
# iteration: 3910| Acceptance rate: 0.389769820971867| Log-Likelihood: -469.3733893783675| Proposal [0.08996412 0.02792733]
# iteration: 3920| Acceptance rate: 0.3895408163265306| Log-Likelihood: -468.3891854337176| Proposal [0.07138831 0.02367949]
# ...
# iteration: 8710| Acceptance rate: 0.3756601607347876| Log-Likelihood: -470.4065425932154| Proposal [0.1081979  0.02780884]
# iteration: 8720| Acceptance rate: 0.3756880733944954| Log-Likelihood: -468.9028198396161| Proposal [0.0764558  0.02683298]
# iteration: 8730| Acceptance rate: 0.3754868270332188| Log-Likelihood: -468.48270153392895| Proposal [0.09309319 0.02165452]
# iteration: 8740| Acceptance rate: 0.3750572082379863| Log-Likelihood: -468.48270153392895| Proposal [0.09309319 0.02165452]
# iteration: 8750| Acceptance rate: 0.3750857142857143| Log-Likelihood: -472.0054843788375| Proposal [0.10392016 0.01240723]
# iteration: 8760| Acceptance rate: 0.37511415525114156| Log-Likelihood: -470.8179645058626| Proposal [0.1147889  0.02759292]
# iteration: 8770| Acceptance rate: 0.37525655644241734| Log-Likelihood: -471.33102911425254| Proposal [0.05972773 0.01093689]
# iteration: 8780| Acceptance rate: 0.3751708428246014| Log-Likelihood: -469.9564224576871| Proposal [0.11005114 0.02415327]
# iteration: 8790| Acceptance rate: 0.3750853242320819| Log-Likelihood: -468.9346860352353| Proposal [0.09601534 0.01698579]
# iteration: 8800| Acceptance rate: 0.37488636363636363| Log-Likelihood: -468.18431017585755| Proposal [0.06234684 0.02208288]
# iteration: 8810| Acceptance rate: 0.3750283768444949| Log-Likelihood: -469.30477136247583| Proposal [0.05146066 0.01749627]
# iteration: 8820| Acceptance rate: 0.3750566893424036| Log-Likelihood: -469.9306209816627| Proposal [0.11457713 0.02135861]
# iteration: 8830| Acceptance rate: 0.3750849377123443| Log-Likelihood: -469.4421388952536| Proposal [0.06274928 0.02926976]
# iteration: 8840| Acceptance rate: 0.3752262443438914| Log-Likelihood: -469.28501715564886| Proposal [0.06795297 0.0298551 ]
# iteration: 8850| Acceptance rate: 0.3752542372881356| Log-Likelihood: -469.76617378511605| Proposal [0.10602966 0.02214087]
# iteration: 8860| Acceptance rate: 0.37539503386004514| Log-Likelihood: -468.5538183136793| Proposal [0.06517739 0.02060385]
# iteration: 8870| Acceptance rate: 0.3753100338218715| Log-Likelihood: -469.1136274879213| Proposal [0.06582156 0.02103115]
# iteration: 8880| Acceptance rate: 0.37545045045045045| Log-Likelihood: -469.82689308157006| Proposal [0.05829414 0.01324408]
# iteration: 8890| Acceptance rate: 0.3750281214848144| Log-Likelihood: -469.82689308157006| Proposal [0.05829414 0.01324408]
# iteration: 8900| Acceptance rate: 0.3748314606741573| Log-Likelihood: -468.4019352223216| Proposal [0.05085614 0.02171421]
# iteration: 8910| Acceptance rate: 0.37463524130190795| Log-Likelihood: -468.99690465740645| Proposal [0.10217287 0.02215723]
# iteration: 8920| Acceptance rate: 0.3744394618834081| Log-Likelihood: -469.3539759128632| Proposal [0.0570447  0.03014722]
# iteration: 8930| Acceptance rate: 0.37458006718924974| Log-Likelihood: -469.09091982789715| Proposal [0.08306637 0.02592883]
# iteration: 8940| Acceptance rate: 0.374496644295302| Log-Likelihood: -469.20066457309116| Proposal [0.09280201 0.02143385]
# iteration: 8950| Acceptance rate: 0.3745251396648045| Log-Likelihood: -470.19708982207607| Proposal [0.10401435 0.0159872 ]
# iteration: 8960| Acceptance rate: 0.37455357142857143| Log-Likelihood: -468.83629340349273| Proposal [0.07868313 0.01971892]
# iteration: 8970| Acceptance rate: 0.3744704570791527| Log-Likelihood: -468.5386336225425| Proposal [0.07115127 0.01704122]
# iteration: 8980| Acceptance rate: 0.3744988864142539| Log-Likelihood: -472.2621055797451| Proposal [0.03859165 0.03312256]
# iteration: 8990| Acceptance rate: 0.37486095661846497| Log-Likelihood: -470.9085445354719| Proposal [0.11517268 0.01876539]
# iteration: 9000| Acceptance rate: 0.37477777777777777| Log-Likelihood: -468.2301442076298| Proposal [0.07050959 0.02148816]
# iteration: 9010| Acceptance rate: 0.3748057713651498| Log-Likelihood: -469.0862561386113| Proposal [0.08794488 0.02007579]
# iteration: 9020| Acceptance rate: 0.3746119733924612| Log-Likelihood: -469.09966741072986| Proposal [0.09055877 0.02226057]
# iteration: 9030| Acceptance rate: 0.37452934662236986| Log-Likelihood: -468.5166754108714| Proposal [0.06586836 0.01624705]
# iteration: 9040| Acceptance rate: 0.37411504424778763| Log-Likelihood: -468.5166754108714| Proposal [0.06586836 0.01624705]
# iteration: 9050| Acceptance rate: 0.37392265193370167| Log-Likelihood: -467.784883005415| Proposal [0.06351355 0.01940462]
# iteration: 9060| Acceptance rate: 0.37362030905077265| Log-Likelihood: -468.30761447593096| Proposal [0.054987   0.01869136]
# iteration: 9070| Acceptance rate: 0.3733186328555678| Log-Likelihood: -468.7964816065213| Proposal [0.05568399 0.0180194 ]
# iteration: 9080| Acceptance rate: 0.373568281938326| Log-Likelihood: -469.0183991641408| Proposal [0.08958078 0.02487891]
# iteration: 9090| Acceptance rate: 0.3734873487348735| Log-Likelihood: -468.73239612214235| Proposal [0.05584498 0.02639456]
# iteration: 9100| Acceptance rate: 0.3732967032967033| Log-Likelihood: -468.47411244162123| Proposal [0.0801591  0.02068276]
# iteration: 9110| Acceptance rate: 0.37365532381997807| Log-Likelihood: -467.96811916486496| Proposal [0.05673305 0.0200822 ]
# iteration: 9120| Acceptance rate: 0.3732456140350877| Log-Likelihood: -467.96811916486496| Proposal [0.05673305 0.0200822 ]
# iteration: 9130| Acceptance rate: 0.3736035049288061| Log-Likelihood: -471.06863168292153| Proposal [0.10602007 0.0256971 ]
# iteration: 9140| Acceptance rate: 0.3740700218818381| Log-Likelihood: -469.8619095914148| Proposal [0.10058404 0.02032339]
# iteration: 9150| Acceptance rate: 0.37398907103825135| Log-Likelihood: -467.73663927150454| Proposal [0.07108297 0.02191839]
# iteration: 9160| Acceptance rate: 0.3740174672489083| Log-Likelihood: -469.43135427180226| Proposal [0.09463776 0.01734535]
# iteration: 9170| Acceptance rate: 0.3739367502726281| Log-Likelihood: -468.85653799391264| Proposal [0.06356899 0.02714283]
# iteration: 9180| Acceptance rate: 0.37429193899782137| Log-Likelihood: -469.38281363164555| Proposal [0.0880659  0.02498964]
# iteration: 9190| Acceptance rate: 0.37431991294885747| Log-Likelihood: -470.40565737180685| Proposal [0.10800563 0.03131499]
# iteration: 9200| Acceptance rate: 0.37423913043478263| Log-Likelihood: -468.0527826663241| Proposal [0.06064138 0.01852886]
# iteration: 9210| Acceptance rate: 0.3740499457111835| Log-Likelihood: -469.37051346236746| Proposal [0.053966   0.02624697]
# iteration: 9220| Acceptance rate: 0.3739696312364425| Log-Likelihood: -469.13841952248185| Proposal [0.09895901 0.02028524]
# iteration: 9230| Acceptance rate: 0.37378114842903576| Log-Likelihood: -470.75181340150414| Proposal [0.12730442 0.02136034]
# iteration: 9240| Acceptance rate: 0.3737012987012987| Log-Likelihood: -469.3802852772229| Proposal [0.06014227 0.01428299]
# iteration: 9250| Acceptance rate: 0.37351351351351353| Log-Likelihood: -469.03010008489855| Proposal [0.06134894 0.02481684]
# iteration: 9260| Acceptance rate: 0.37375809935205184| Log-Likelihood: -468.54012943154777| Proposal [0.05998588 0.02369576]
# iteration: 9270| Acceptance rate: 0.37357065803667744| Log-Likelihood: -468.75127540489297| Proposal [0.06723774 0.02502938]
# iteration: 9280| Acceptance rate: 0.3734913793103448| Log-Likelihood: -468.3317018286852| Proposal [0.05598757 0.02250229]
# iteration: 9290| Acceptance rate: 0.37384284176533905| Log-Likelihood: -468.73789605074575| Proposal [0.07561417 0.02562301]
# iteration: 9300| Acceptance rate: 0.3738709677419355| Log-Likelihood: -468.83942404177145| Proposal [0.06472329 0.01916462]
# iteration: 9310| Acceptance rate: 0.37400644468313643| Log-Likelihood: -470.04889014472707| Proposal [0.05531238 0.03101591]
# iteration: 9320| Acceptance rate: 0.3742489270386266| Log-Likelihood: -470.87739672334686| Proposal [0.04725898 0.0366103 ]
# iteration: 9330| Acceptance rate: 0.3745980707395498| Log-Likelihood: -468.3478654724149| Proposal [0.06714897 0.02114673]
# iteration: 9340| Acceptance rate: 0.37430406852248393| Log-Likelihood: -469.2441537253745| Proposal [0.0600817  0.02823994]
# iteration: 9350| Acceptance rate: 0.37411764705882355| Log-Likelihood: -469.53435046609394| Proposal [0.08183473 0.02046302]
# iteration: 9360| Acceptance rate: 0.37393162393162394| Log-Likelihood: -471.45416811871246| Proposal [0.05150822 0.01225069]
# iteration: 9370| Acceptance rate: 0.37406616862326575| Log-Likelihood: -470.2600508336106| Proposal [0.07955185 0.03486839]
# iteration: 9380| Acceptance rate: 0.3742004264392324| Log-Likelihood: -469.6977126737995| Proposal [0.09708759 0.02236649]
# iteration: 9390| Acceptance rate: 0.37454739084132055| Log-Likelihood: -470.27328322749054| Proposal [0.07985393 0.03456015]
# iteration: 9400| Acceptance rate: 0.37436170212765957| Log-Likelihood: -469.87395327453686| Proposal [0.1021805  0.01929806]
# iteration: 9410| Acceptance rate: 0.37417640807651437| Log-Likelihood: -468.8562444693084| Proposal [0.07285774 0.02512216]
# iteration: 9420| Acceptance rate: 0.37452229299363055| Log-Likelihood: -468.17911154851095| Proposal [0.06863222 0.01630093]
# iteration: 9430| Acceptance rate: 0.3745493107104984| Log-Likelihood: -469.1151050649014| Proposal [0.07352893 0.03078014]
# iteration: 9440| Acceptance rate: 0.3746822033898305| Log-Likelihood: -471.694804289832| Proposal [0.08076757 0.04166692]
# iteration: 9450| Acceptance rate: 0.3747089947089947| Log-Likelihood: -468.4286158463129| Proposal [0.07861935 0.01658516]
# iteration: 9460| Acceptance rate: 0.37463002114164906| Log-Likelihood: -470.07219755907937| Proposal [0.08255468 0.01296856]
# iteration: 9470| Acceptance rate: 0.37444561774023233| Log-Likelihood: -469.0588480336789| Proposal [0.06846871 0.03022931]
# iteration: 9480| Acceptance rate: 0.3744725738396624| Log-Likelihood: -469.2770452644724| Proposal [0.07800188 0.02505647]
# iteration: 9490| Acceptance rate: 0.3742887249736565| Log-Likelihood: -468.4075998943376| Proposal [0.06929223 0.02008839]
# iteration: 9500| Acceptance rate: 0.3743157894736842| Log-Likelihood: -468.3954088297207| Proposal [0.07285382 0.02100863]
# iteration: 9510| Acceptance rate: 0.3744479495268139| Log-Likelihood: -468.74601227138214| Proposal [0.05709759 0.0184318 ]
# iteration: 9520| Acceptance rate: 0.3744747899159664| Log-Likelihood: -469.1708635523584| Proposal [0.08198284 0.0148235 ]
# iteration: 9530| Acceptance rate: 0.37429171038824766| Log-Likelihood: -468.6880815866479| Proposal [0.07307255 0.02041567]
# iteration: 9540| Acceptance rate: 0.3743186582809224| Log-Likelihood: -469.6735948624608| Proposal [0.04738168 0.02929903]
# iteration: 9550| Acceptance rate: 0.3743455497382199| Log-Likelihood: -468.9858258352985| Proposal [0.07483404 0.02208996]
# iteration: 9560| Acceptance rate: 0.37447698744769875| Log-Likelihood: -468.8944077993909| Proposal [0.05385271 0.02562937]
# iteration: 9570| Acceptance rate: 0.37450365726227797| Log-Likelihood: -469.06793834890067| Proposal [0.07649094 0.02867203]
# iteration: 9580| Acceptance rate: 0.3747390396659708| Log-Likelihood: -470.65133433425535| Proposal [0.13168658 0.01943523]
# iteration: 9590| Acceptance rate: 0.3748696558915537| Log-Likelihood: -469.8094692063441| Proposal [0.04839282 0.02132428]
# iteration: 9600| Acceptance rate: 0.3746875| Log-Likelihood: -468.7355228003964| Proposal [0.080536   0.02322527]
# iteration: 9610| Acceptance rate: 0.37460978147762747| Log-Likelihood: -468.60665709972074| Proposal [0.09646393 0.02191733]
# iteration: 9620| Acceptance rate: 0.37422037422037424| Log-Likelihood: -468.60665709972074| Proposal [0.09646393 0.02191733]
# iteration: 9630| Acceptance rate: 0.37414330218068537| Log-Likelihood: -468.76905637615897| Proposal [0.07714603 0.0204612 ]
# iteration: 9640| Acceptance rate: 0.37437759336099585| Log-Likelihood: -469.6384198340758| Proposal [0.11367319 0.01955774]
# iteration: 9650| Acceptance rate: 0.3745077720207254| Log-Likelihood: -471.58949091013045| Proposal [0.06015539 0.01116957]
# iteration: 9660| Acceptance rate: 0.3746376811594203| Log-Likelihood: -469.11492921988446| Proposal [0.0964551  0.02068517]
# iteration: 9670| Acceptance rate: 0.37435367114788004| Log-Likelihood: -469.3916386950713| Proposal [0.09287949 0.02038704]
# iteration: 9680| Acceptance rate: 0.3743801652892562| Log-Likelihood: -470.6759585685898| Proposal [0.08387195 0.01211151]
# iteration: 9690| Acceptance rate: 0.37450980392156863| Log-Likelihood: -469.29722483625795| Proposal [0.10420617 0.01880182]
# iteration: 9700| Acceptance rate: 0.3745360824742268| Log-Likelihood: -471.92503737098906| Proposal [0.11804754 0.01229604]
# iteration: 9710| Acceptance rate: 0.37476828012358393| Log-Likelihood: -469.5058404792013| Proposal [0.09264703 0.02401374]
# iteration: 9720| Acceptance rate: 0.37469135802469133| Log-Likelihood: -468.17703142149486| Proposal [0.07607496 0.02248529]
# iteration: 9730| Acceptance rate: 0.3745118191161357| Log-Likelihood: -471.1075777038202| Proposal [0.08473857 0.01185318]
# iteration: 9740| Acceptance rate: 0.374435318275154| Log-Likelihood: -469.10049832078766| Proposal [0.07563621 0.02897587]
# iteration: 9750| Acceptance rate: 0.37456410256410255| Log-Likelihood: -470.9127547653645| Proposal [0.12153743 0.02196362]
# iteration: 9760| Acceptance rate: 0.3744877049180328| Log-Likelihood: -468.4728185089909| Proposal [0.08066495 0.01869544]
# iteration: 9770| Acceptance rate: 0.3742067553735926| Log-Likelihood: -469.51454161108967| Proposal [0.04582619 0.02009728]
# iteration: 9780| Acceptance rate: 0.37423312883435583| Log-Likelihood: -468.32216797091536| Proposal [0.07245139 0.01571627]
# iteration: 9790| Acceptance rate: 0.373953013278856| Log-Likelihood: -468.21017518945285| Proposal [0.07354745 0.01907827]
# iteration: 9800| Acceptance rate: 0.37387755102040815| Log-Likelihood: -468.77477831481525| Proposal [0.06229404 0.02099295]
# iteration: 9810| Acceptance rate: 0.37380224260958206| Log-Likelihood: -469.38219387013925| Proposal [0.07537141 0.02966517]
# iteration: 9820| Acceptance rate: 0.3738289205702648| Log-Likelihood: -468.64055487921763| Proposal [0.07212124 0.01902512]
# iteration: 9830| Acceptance rate: 0.37375381485249237| Log-Likelihood: -468.0772632268409| Proposal [0.07165587 0.01940599]
# iteration: 9840| Acceptance rate: 0.37378048780487805| Log-Likelihood: -468.7331940308449| Proposal [0.07293621 0.02757923]
# iteration: 9850| Acceptance rate: 0.3741116751269036| Log-Likelihood: -469.83681027833694| Proposal [0.08253622 0.01661811]
# iteration: 9860| Acceptance rate: 0.3744421906693712| Log-Likelihood: -468.9081903369957| Proposal [0.09936095 0.01546635]
# iteration: 9870| Acceptance rate: 0.3746707193515704| Log-Likelihood: -469.5395535005179| Proposal [0.1052726  0.01836601]
# iteration: 9880| Acceptance rate: 0.3748987854251012| Log-Likelihood: -469.08004327529505| Proposal [0.08945759 0.02047269]
# iteration: 9890| Acceptance rate: 0.37492416582406474| Log-Likelihood: -467.8830846404057| Proposal [0.07988624 0.01876875]
# iteration: 9900| Acceptance rate: 0.3748484848484849| Log-Likelihood: -468.76122474414376| Proposal [0.06594917 0.02724715]
# iteration: 9910| Acceptance rate: 0.3751765893037336| Log-Likelihood: -469.0192510581036| Proposal [0.06667955 0.02597485]
# iteration: 9920| Acceptance rate: 0.3753024193548387| Log-Likelihood: -469.03118136006304| Proposal [0.0631964  0.02742588]
# iteration: 9930| Acceptance rate: 0.3754279959718026| Log-Likelihood: -468.3995496879559| Proposal [0.06295016 0.02539068]
# iteration: 9940| Acceptance rate: 0.3755533199195171| Log-Likelihood: -469.09669263559374| Proposal [0.08415105 0.01601065]
# iteration: 9950| Acceptance rate: 0.37537688442211053| Log-Likelihood: -468.7084657751727| Proposal [0.08975561 0.01879793]
# iteration: 9960| Acceptance rate: 0.37560240963855424| Log-Likelihood: -468.6040958149808| Proposal [0.06391815 0.02386852]
# iteration: 9970| Acceptance rate: 0.37582748244734204| Log-Likelihood: -468.79882663574733| Proposal [0.06849164 0.01954862]
# iteration: 9980| Acceptance rate: 0.3758517034068136| Log-Likelihood: -469.69422685016974| Proposal [0.0638056  0.02928164]
# iteration: 9990| Acceptance rate: 0.37577577577577576| Log-Likelihood: -468.7650869762053| Proposal [0.07735354 0.02672034]
# 434.69029527698876

# %%
burn_in = 1000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'],lw=0.1)
# Out:
# -467.2998555490236
# The Maximum Likelihood Estimate is [0.05640412 0.01669696] w/ LL of -467.2998555490236

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {round(np.mean(pmcmc_output['accepted_params'][0,burn_in:]),2)} and std: {round(np.std(pmcmc_output['accepted_params'][0,burn_in:]),2)}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {round(np.mean((pmcmc_output['accepted_params'][1,burn_in:])),2)} and std: {round(np.std((pmcmc_output['accepted_params'][1,burn_in:])),2)}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

# %%
'''Maximum likelihood plots from the pmcmc run'''
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec[::int(1/dt)],state[:,i],'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 273.7350869712205
# Root Mean Squared Error for beta 0.11570220008887461

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
plt.show()

# %%
'''Pair plots'''

plt.title('Pairwise Plot of $\\gamma$ and $\\eta$')
plt.xlabel('$\\gamma$')
plt.ylabel('1/R')
plt.scatter(pmcmc_output['accepted_params'][0,burn_in:],pmcmc_output['accepted_params'][1,burn_in:],s=0.1)

# %%
'''Pair plots'''

plt.title('Trace Plot of $\\eta$')
plt.xlabel('Iteration')
plt.ylabel('$1/R$')
plt.plot(pmcmc_output['accepted_params'][1,burn_in:],lw = 0.1)
plt.show()

plt.title('Trace Plot of $\\gamma$')
plt.xlabel('Iteration')
plt.ylabel('$\\gamma$')
plt.plot(pmcmc_output['accepted_params'][0,burn_in:],lw=0.1)

# %%
'''Optimal fit using expectation of parameter distribution'''

pf_params = {'num_particles':10_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (np.mean((pmcmc_output['accepted_params'][0,burn_in:])),np.mean((pmcmc_output['accepted_params'][1,burn_in:]))),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 6.367824432003545

# %%
'''Plots using the Expectation of the parameters and running the filter. '''
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(output['particle_distribution'][:,4,:]))**2))}")

for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.plot(t_vec[::int(1/dt)],state[:,i],'--',color = 'black')
    plt.show()

plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -473.15506219686597
# Root Mean Squared Error for the Data 273.7348998690485
# Root Mean Squared Error for beta 0.1172499572318271

# %%
np.savez('../pmcmc_output/calvetti_fixedeta_pmcmc_output.npz',
accepted_params = pmcmc_output['accepted_params'],
log_likelihood=pmcmc_output['Log Likelihood'],
MLE_particle_dist = pmcmc_output['MLE_particle_dist'],
MLE_particle_observations = pmcmc_output['MLE_particle_observations'])
