# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
import jsonpickle

from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('../data_sets/ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('../data_sets/ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('../data_sets/ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0] + 0.005),n = np.array([r]))
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

'''unpickle parameter sets'''
with open("../param_sets/SEIR_OU_model_params.json", "r+") as f:
    SEIR_model_json = f.read()
    SEIR_model_params = jsonpickle.decode(SEIR_model_json)

gamma = SEIR_model_params['gamma']
R = SEIR_model_params['R']

with open("../param_sets/SEIR_OU_process_params.json", "r+") as f:
    OU_process_json = f.read()
    SEIR_OU_process_params = jsonpickle.decode(OU_process_json)

lam = SEIR_OU_process_params['lambda']
mean_ou = SEIR_OU_process_params['mean_ou']
sig = SEIR_OU_process_params['sig']

T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 12.484472827985883

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0),color = 'orange')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    plt.show()

plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0),color = 'orange')
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10863.645024501251
# Root Mean Squared Error for the Data 5027.266064172513

# %%
pmcmc_rng = np.random.default_rng(100)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':50_000,
                'init_params':np.array([0.1,0.1,-0.7,0.01,0.01]),
                'prior':seir_prior,
                'init_cov':  np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1_000}

pf_params = {'num_particles':1000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -18059.275405943165| Proposal [ 0.1   0.1  -0.7   0.01  0.01]
# iteration: 20| Acceptance rate: 0.15| Log-Likelihood: -10916.948853084312| Proposal [ 0.0894231   0.45157858 -0.65305428  0.13946264  0.08719816]
# iteration: 30| Acceptance rate: 0.13333333333333333| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 40| Acceptance rate: 0.1| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 50| Acceptance rate: 0.08| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 60| Acceptance rate: 0.06666666666666667| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 70| Acceptance rate: 0.05714285714285714| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 80| Acceptance rate: 0.05| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 90| Acceptance rate: 0.044444444444444446| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 100| Acceptance rate: 0.04| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 110| Acceptance rate: 0.03636363636363636| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 120| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 130| Acceptance rate: 0.03076923076923077| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 140| Acceptance rate: 0.02857142857142857| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 150| Acceptance rate: 0.02666666666666667| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 160| Acceptance rate: 0.025| Log-Likelihood: -10878.607400203537| Proposal [ 0.07306861  0.32992722 -0.71638765  0.14185447  0.03573403]
# iteration: 170| Acceptance rate: 0.029411764705882353| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 180| Acceptance rate: 0.027777777777777776| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 190| Acceptance rate: 0.02631578947368421| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 200| Acceptance rate: 0.025| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 210| Acceptance rate: 0.023809523809523808| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 220| Acceptance rate: 0.022727272727272728| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 230| Acceptance rate: 0.021739130434782608| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 240| Acceptance rate: 0.020833333333333332| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 250| Acceptance rate: 0.02| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 260| Acceptance rate: 0.019230769230769232| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 270| Acceptance rate: 0.018518518518518517| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 280| Acceptance rate: 0.017857142857142856| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 290| Acceptance rate: 0.017241379310344827| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 300| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 310| Acceptance rate: 0.016129032258064516| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 320| Acceptance rate: 0.015625| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 330| Acceptance rate: 0.015151515151515152| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 340| Acceptance rate: 0.014705882352941176| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 350| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 360| Acceptance rate: 0.013888888888888888| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 370| Acceptance rate: 0.013513513513513514| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 380| Acceptance rate: 0.013157894736842105| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 390| Acceptance rate: 0.01282051282051282| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 400| Acceptance rate: 0.0125| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 410| Acceptance rate: 0.012195121951219513| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 420| Acceptance rate: 0.011904761904761904| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 430| Acceptance rate: 0.011627906976744186| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 440| Acceptance rate: 0.011363636363636364| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 450| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 460| Acceptance rate: 0.010869565217391304| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 470| Acceptance rate: 0.010638297872340425| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 480| Acceptance rate: 0.010416666666666666| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 490| Acceptance rate: 0.01020408163265306| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 500| Acceptance rate: 0.01| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 510| Acceptance rate: 0.00980392156862745| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 520| Acceptance rate: 0.009615384615384616| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 530| Acceptance rate: 0.009433962264150943| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 540| Acceptance rate: 0.009259259259259259| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 550| Acceptance rate: 0.00909090909090909| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 560| Acceptance rate: 0.008928571428571428| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 570| Acceptance rate: 0.008771929824561403| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 580| Acceptance rate: 0.008620689655172414| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 590| Acceptance rate: 0.00847457627118644| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 600| Acceptance rate: 0.008333333333333333| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 610| Acceptance rate: 0.00819672131147541| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 620| Acceptance rate: 0.008064516129032258| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 630| Acceptance rate: 0.007936507936507936| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 640| Acceptance rate: 0.0078125| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 650| Acceptance rate: 0.007692307692307693| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 660| Acceptance rate: 0.007575757575757576| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 670| Acceptance rate: 0.007462686567164179| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 680| Acceptance rate: 0.007352941176470588| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 690| Acceptance rate: 0.007246376811594203| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 700| Acceptance rate: 0.007142857142857143| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 710| Acceptance rate: 0.007042253521126761| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 720| Acceptance rate: 0.006944444444444444| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 730| Acceptance rate: 0.00684931506849315| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 740| Acceptance rate: 0.006756756756756757| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 750| Acceptance rate: 0.006666666666666667| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 760| Acceptance rate: 0.006578947368421052| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 770| Acceptance rate: 0.006493506493506494| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 780| Acceptance rate: 0.00641025641025641| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 790| Acceptance rate: 0.006329113924050633| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 800| Acceptance rate: 0.00625| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 810| Acceptance rate: 0.006172839506172839| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 820| Acceptance rate: 0.006097560975609756| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 830| Acceptance rate: 0.006024096385542169| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 840| Acceptance rate: 0.005952380952380952| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 850| Acceptance rate: 0.0058823529411764705| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 860| Acceptance rate: 0.005813953488372093| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 870| Acceptance rate: 0.005747126436781609| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 880| Acceptance rate: 0.005681818181818182| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 890| Acceptance rate: 0.0056179775280898875| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 900| Acceptance rate: 0.005555555555555556| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 910| Acceptance rate: 0.005494505494505495| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 920| Acceptance rate: 0.005434782608695652| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 930| Acceptance rate: 0.005376344086021506| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 940| Acceptance rate: 0.005319148936170213| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 950| Acceptance rate: 0.005263157894736842| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 960| Acceptance rate: 0.005208333333333333| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 970| Acceptance rate: 0.005154639175257732| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 980| Acceptance rate: 0.00510204081632653| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 990| Acceptance rate: 0.005050505050505051| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 1000| Acceptance rate: 0.005| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 1010| Acceptance rate: 0.0049504950495049506| Log-Likelihood: -10862.55451019193| Proposal [ 0.07531455  0.28070781 -0.82738073  0.05255753  0.01804078]
# iteration: 1020| Acceptance rate: 0.013725490196078431| Log-Likelihood: -10864.043727703638| Proposal [ 0.0762244   0.28994105 -0.85362621  0.05197762  0.01378646]
# iteration: 1030| Acceptance rate: 0.018446601941747572| Log-Likelihood: -10861.854310700919| Proposal [ 0.07534953  0.28763909 -0.84885108  0.05166511  0.01549344]
# iteration: 1040| Acceptance rate: 0.026923076923076925| Log-Likelihood: -10862.2453588165| Proposal [ 0.07556874  0.28832939 -0.85044813  0.05196788  0.01512432]
# iteration: 1050| Acceptance rate: 0.03238095238095238| Log-Likelihood: -10861.91589066826| Proposal [ 0.07579866  0.28767588 -0.84829129  0.05187603  0.01534153]
# iteration: 1060| Acceptance rate: 0.038679245283018866| Log-Likelihood: -10862.464111803363| Proposal [ 0.0758303   0.28761854 -0.84805237  0.0518495   0.01531032]
# iteration: 1070| Acceptance rate: 0.04579439252336449| Log-Likelihood: -10862.343198581748| Proposal [ 0.07569035  0.28809298 -0.84972153  0.05191943  0.01511748]
# iteration: 1080| Acceptance rate: 0.053703703703703705| Log-Likelihood: -10862.158436146945| Proposal [ 0.07565859  0.28827247 -0.85054405  0.05191667  0.01502188]
# iteration: 1090| Acceptance rate: 0.060550458715596334| Log-Likelihood: -10862.656979760599| Proposal [ 0.07569407  0.28840758 -0.8508097   0.05198102  0.01495581]
# iteration: 1100| Acceptance rate: 0.06727272727272728| Log-Likelihood: -10863.526603837367| Proposal [ 0.07545297  0.28965893 -0.85542059  0.05213983  0.01437659]
# iteration: 1110| Acceptance rate: 0.07207207207207207| Log-Likelihood: -10862.10958533447| Proposal [ 0.07551432  0.28921793 -0.85361717  0.05211429  0.01459843]
# iteration: 1120| Acceptance rate: 0.07767857142857143| Log-Likelihood: -10862.400314750435| Proposal [ 0.07551634  0.28909024 -0.85123769  0.05244599  0.01477587]
# iteration: 1130| Acceptance rate: 0.08141592920353982| Log-Likelihood: -10862.80424523634| Proposal [ 0.07550665  0.2891985  -0.85260099  0.05228372  0.01466602]
# iteration: 1140| Acceptance rate: 0.08596491228070176| Log-Likelihood: -10862.21822176182| Proposal [ 0.07556042  0.28865199 -0.84809546  0.0526667   0.01507855]
# iteration: 1150| Acceptance rate: 0.09217391304347826| Log-Likelihood: -10862.774509699613| Proposal [ 0.07544563  0.28970194 -0.85548624  0.05216194  0.01436346]
# iteration: 1160| Acceptance rate: 0.09827586206896552| Log-Likelihood: -10862.530315067303| Proposal [ 0.07545671  0.28959509 -0.85448815  0.05225831  0.01445114]
# iteration: 1170| Acceptance rate: 0.10598290598290598| Log-Likelihood: -10862.749855092728| Proposal [ 0.07533378  0.29069373 -0.86090429  0.05197151  0.01378179]
# iteration: 1180| Acceptance rate: 0.11016949152542373| Log-Likelihood: -10862.71791407313| Proposal [ 0.07538537  0.29015115 -0.8579089   0.05208059  0.01410387]
# iteration: 1190| Acceptance rate: 0.1134453781512605| Log-Likelihood: -10862.848174766686| Proposal [ 0.07541281  0.2897318  -0.85536453  0.05220574  0.01436901]
# iteration: 1200| Acceptance rate: 0.11916666666666667| Log-Likelihood: -10862.216668579767| Proposal [ 0.07550671  0.28894538 -0.85068942  0.05242649  0.0148519 ]
# iteration: 1210| Acceptance rate: 0.12396694214876033| Log-Likelihood: -10862.674675992164| Proposal [ 0.07538611  0.29020584 -0.85809999  0.05209051  0.0140768 ]
# iteration: 1220| Acceptance rate: 0.130327868852459| Log-Likelihood: -10863.215046660758| Proposal [ 0.07542562  0.28973545 -0.85534674  0.05221309  0.01436645]
# iteration: 1230| Acceptance rate: 0.13414634146341464| Log-Likelihood: -10862.359609624858| Proposal [ 0.07578843  0.28663388 -0.83667886  0.05312523  0.01628632]
# iteration: 1240| Acceptance rate: 0.13709677419354838| Log-Likelihood: -10862.65460777119| Proposal [ 0.07638465  0.28151905 -0.80584707  0.05463774  0.01945559]
# iteration: 1250| Acceptance rate: 0.1432| Log-Likelihood: -10861.889382029798| Proposal [ 0.07578775  0.28666519 -0.83682827  0.0531235   0.01626865]
# iteration: 1260| Acceptance rate: 0.14603174603174604| Log-Likelihood: -10862.401306558419| Proposal [ 0.07616727  0.28329462 -0.8165553   0.05411075  0.01835721]
# iteration: 1270| Acceptance rate: 0.15196850393700786| Log-Likelihood: -10862.383636675888| Proposal [ 0.07590839  0.28556878 -0.83024558  0.05344218  0.0169479 ]
# iteration: 1280| Acceptance rate: 0.15703125| Log-Likelihood: -10862.283553771691| Proposal [ 0.07551692  0.28904828 -0.85122864  0.0524127   0.01478861]
# iteration: 1290| Acceptance rate: 0.162015503875969| Log-Likelihood: -10862.826682831297| Proposal [ 0.07627481  0.28241824 -0.81128753  0.05436754  0.0188983 ]
# iteration: 1300| Acceptance rate: 0.16692307692307692| Log-Likelihood: -10862.884165499636| Proposal [ 0.07612676  0.28376191 -0.81939055  0.05397023  0.01806383]
# iteration: 1310| Acceptance rate: 0.1717557251908397| Log-Likelihood: -10862.986266198974| Proposal [ 0.07625392  0.28248341 -0.81170226  0.05434311  0.01885926]
# iteration: 1320| Acceptance rate: 0.17727272727272728| Log-Likelihood: -10862.85801495379| Proposal [ 0.07646089  0.28064869 -0.80064554  0.05488455  0.01999731]
# iteration: 1330| Acceptance rate: 0.18195488721804512| Log-Likelihood: -10863.463603185508| Proposal [ 0.07672757  0.27839117 -0.78701234  0.05555708  0.02139689]
# iteration: 1340| Acceptance rate: 0.18582089552238806| Log-Likelihood: -10863.571215208885| Proposal [ 0.07675001  0.27787693 -0.78397516  0.05569448  0.02171925]
# iteration: 1350| Acceptance rate: 0.18962962962962962| Log-Likelihood: -10863.472577850564| Proposal [ 0.07667628  0.27840829 -0.78719012  0.0555342   0.02139162]
# iteration: 1360| Acceptance rate: 0.19411764705882353| Log-Likelihood: -10862.464251989024| Proposal [ 0.0763937   0.28085781 -0.80196631  0.05480811  0.01987262]
# iteration: 1370| Acceptance rate: 0.19854014598540146| Log-Likelihood: -10863.892585472542| Proposal [ 0.07669939  0.27798029 -0.78465978  0.0556494   0.02165918]
# iteration: 1380| Acceptance rate: 0.2036231884057971| Log-Likelihood: -10865.198974911003| Proposal [ 0.07709667  0.27484463 -0.76567155  0.05659535  0.02360094]
# iteration: 1390| Acceptance rate: 0.20647482014388488| Log-Likelihood: -10863.362056922122| Proposal [ 0.07650106  0.27952762 -0.79402831  0.0551827   0.02070153]
# iteration: 1400| Acceptance rate: 0.21| Log-Likelihood: -10862.368891823467| Proposal [ 0.07595398  0.28552508 -0.82993576  0.05346695  0.01696973]
# iteration: 1410| Acceptance rate: 0.21205673758865248| Log-Likelihood: -10862.796562793486| Proposal [ 0.07653816  0.2828302  -0.81313066  0.05438996  0.01861917]
# iteration: 1420| Acceptance rate: 0.2147887323943662| Log-Likelihood: -10862.05046946242| Proposal [ 0.07571735  0.28867765 -0.84870303  0.0525892   0.01500436]
# iteration: 1430| Acceptance rate: 0.21678321678321677| Log-Likelihood: -10862.395450472779| Proposal [ 0.07587279  0.2890205  -0.85038959  0.05257428  0.01477569]
# iteration: 1440| Acceptance rate: 0.21944444444444444| Log-Likelihood: -10861.986023041562| Proposal [ 0.07638546  0.28425918 -0.8217302   0.05397115  0.01773184]
# iteration: 1450| Acceptance rate: 0.22275862068965518| Log-Likelihood: -10862.143640446451| Proposal [ 0.07595293  0.28831162 -0.84612322  0.05278244  0.01521504]
# iteration: 1460| Acceptance rate: 0.2273972602739726| Log-Likelihood: -10862.708683683391| Proposal [ 0.07663448  0.28028237 -0.79813581  0.05505965  0.02021613]
# iteration: 1470| Acceptance rate: 0.23129251700680273| Log-Likelihood: -10862.186676204095| Proposal [ 0.07650293  0.28322293 -0.8154769   0.05427861  0.01837498]
# iteration: 1480| Acceptance rate: 0.23378378378378378| Log-Likelihood: -10861.436352860772| Proposal [ 0.07624653  0.28675484 -0.83650341  0.0532957   0.01617137]
# iteration: 1490| Acceptance rate: 0.2348993288590604| Log-Likelihood: -10863.191301271234| Proposal [ 0.07672956  0.29007942 -0.85486122  0.0526958   0.0140384 ]
# iteration: 1500| Acceptance rate: 0.236| Log-Likelihood: -10861.845107299308| Proposal [ 0.07570882  0.28624661 -0.83461134  0.05317988  0.01653528]
# iteration: 1510| Acceptance rate: 0.2390728476821192| Log-Likelihood: -10861.992470660403| Proposal [ 0.0760609   0.28681235 -0.83720527  0.05319817  0.01615018]
# iteration: 1520| Acceptance rate: 0.24210526315789474| Log-Likelihood: -10862.266139982241| Proposal [ 0.07476944  0.28682438 -0.83982515  0.05261662  0.0162477 ]
# iteration: 1530| Acceptance rate: 0.24705882352941178| Log-Likelihood: -10861.990012240076| Proposal [ 0.07493676  0.28751769 -0.8435185   0.05252201  0.01579767]
# iteration: 1540| Acceptance rate: 0.2506493506493506| Log-Likelihood: -10863.520575240616| Proposal [ 0.07942825  0.28909999 -0.84383559  0.05414682  0.01443604]
# iteration: 1550| Acceptance rate: 0.2541935483870968| Log-Likelihood: -10862.967990647328| Proposal [ 0.07495924  0.28658363 -0.83804733  0.05276163  0.01638413]
# iteration: 1560| Acceptance rate: 0.25576923076923075| Log-Likelihood: -10863.42114865916| Proposal [ 0.07194528  0.28576574 -0.83925128  0.05161143  0.01714425]
# iteration: 1570| Acceptance rate: 0.25796178343949044| Log-Likelihood: -10868.24449064839| Proposal [ 0.06775989  0.29230954 -0.88552073  0.04813063  0.0133642 ]
# iteration: 1580| Acceptance rate: 0.2588607594936709| Log-Likelihood: -10865.308616539683| Proposal [ 0.0691166   0.28754565 -0.85517193  0.04990777  0.01625374]
# iteration: 1590| Acceptance rate: 0.26037735849056604| Log-Likelihood: -10863.074043624634| Proposal [ 0.07751081  0.28154408 -0.80374345  0.05514076  0.01934973]
# iteration: 1600| Acceptance rate: 0.2625| Log-Likelihood: -10862.855379214272| Proposal [ 0.07476085  0.28952831 -0.85554809  0.05194893  0.01454562]
# iteration: 1610| Acceptance rate: 0.26335403726708073| Log-Likelihood: -10862.779893345154| Proposal [ 0.07875042  0.28437413 -0.81773679  0.05500087  0.01746651]
# iteration: 1620| Acceptance rate: 0.2660493827160494| Log-Likelihood: -10863.435652085562| Proposal [ 0.07803883  0.27880947 -0.78681832  0.05604839  0.02102877]
# iteration: 1630| Acceptance rate: 0.26932515337423313| Log-Likelihood: -10861.911657722745| Proposal [ 0.07504444  0.28737249 -0.84246655  0.05260513  0.01588012]
# iteration: 1640| Acceptance rate: 0.2701219512195122| Log-Likelihood: -10862.015200275197| Proposal [ 0.0785184   0.28466601 -0.81988901  0.05482551  0.01730166]
# iteration: 1650| Acceptance rate: 0.27151515151515154| Log-Likelihood: -10862.266812725515| Proposal [ 0.07495985  0.28792839 -0.84586227  0.05243081  0.01553694]
# iteration: 1660| Acceptance rate: 0.2740963855421687| Log-Likelihood: -10862.261157521565| Proposal [ 0.07739844  0.28470936 -0.82235304  0.05431294  0.01736544]
# iteration: 1670| Acceptance rate: 0.2748502994011976| Log-Likelihood: -10863.434777939026| Proposal [ 0.07726346  0.27791947 -0.78318072  0.0559193   0.02165228]
# iteration: 1680| Acceptance rate: 0.2773809523809524| Log-Likelihood: -10862.01588140494| Proposal [ 0.07714571  0.28449965 -0.82163352  0.05425128  0.0175181 ]
# iteration: 1690| Acceptance rate: 0.27928994082840236| Log-Likelihood: -10861.979045880846| Proposal [ 0.07673852  0.28578424 -0.82989856  0.05375358  0.01674231]
# iteration: 1700| Acceptance rate: 0.2817647058823529| Log-Likelihood: -10862.868953838333| Proposal [ 0.07646148  0.28896998 -0.84894915  0.05284752  0.01475871]
# iteration: 1710| Acceptance rate: 0.28362573099415206| Log-Likelihood: -10863.58264745321| Proposal [ 0.07617234  0.2916513  -0.86509515  0.05205961  0.01309367]
# iteration: 1720| Acceptance rate: 0.28430232558139534| Log-Likelihood: -10862.993678014893| Proposal [ 0.0796737   0.2813079  -0.79810583  0.05616684  0.01932217]
# iteration: 1730| Acceptance rate: 0.28670520231213875| Log-Likelihood: -10862.455776913139| Proposal [ 0.07835391  0.28503725 -0.82237146  0.05466043  0.01708118]
# iteration: 1740| Acceptance rate: 0.28908045977011493| Log-Likelihood: -10862.027387387894| Proposal [ 0.0775558   0.28674286 -0.83385395  0.05388422  0.01607206]
# iteration: 1750| Acceptance rate: 0.292| Log-Likelihood: -10862.988745699542| Proposal [ 0.07809607  0.28762411 -0.83790577  0.05390996  0.01547315]
# iteration: 1760| Acceptance rate: 0.2948863636363636| Log-Likelihood: -10863.107397618947| Proposal [ 0.07687836  0.28867526 -0.84641625  0.05310625  0.01491026]
# iteration: 1770| Acceptance rate: 0.29774011299435027| Log-Likelihood: -10862.141541093566| Proposal [ 0.07865301  0.28489205 -0.82093764  0.05483005  0.01714827]
# iteration: 1780| Acceptance rate: 0.29943820224719103| Log-Likelihood: -10862.959181043543| Proposal [ 0.07894215  0.28465353 -0.81898242  0.05501793  0.01727488]
# iteration: 1790| Acceptance rate: 0.30223463687150837| Log-Likelihood: -10862.269838461836| Proposal [ 0.078658    0.28537802 -0.82374953  0.05471317  0.01684189]
# iteration: 1800| Acceptance rate: 0.30444444444444446| Log-Likelihood: -10862.984167579| Proposal [ 0.07748278  0.28874167 -0.84561008  0.05336045  0.01481917]
# iteration: 1810| Acceptance rate: 0.305524861878453| Log-Likelihood: -10862.103264491014| Proposal [ 0.07695547  0.28921523 -0.84940429  0.05300751  0.01456373]
# iteration: 1820| Acceptance rate: 0.30714285714285716| Log-Likelihood: -10862.64889268229| Proposal [ 0.0777072   0.28800353 -0.84087959  0.05364219  0.01526574]
# iteration: 1830| Acceptance rate: 0.3092896174863388| Log-Likelihood: -10862.78573006472| Proposal [ 0.07762181  0.28246988 -0.80890403  0.05496278  0.01875755]
# iteration: 1840| Acceptance rate: 0.3125| Log-Likelihood: -10862.165111627022| Proposal [ 0.07619031  0.28750053 -0.84095132  0.05308639  0.01570603]
# iteration: 1850| Acceptance rate: 0.31513513513513514| Log-Likelihood: -10863.55271667339| Proposal [ 0.07688528  0.29057819 -0.85745765  0.05264183  0.01371124]
# iteration: 1860| Acceptance rate: 0.317741935483871| Log-Likelihood: -10862.168915941229| Proposal [ 0.07646122  0.28849796 -0.84621155  0.05296261  0.01505578]
# iteration: 1870| Acceptance rate: 0.31871657754010696| Log-Likelihood: -10862.72040906619| Proposal [ 0.07647621  0.28849537 -0.84616857  0.05296965  0.01505609]
# iteration: 1880| Acceptance rate: 0.32127659574468087| Log-Likelihood: -10863.284033961327| Proposal [ 0.07508397  0.29055272 -0.86086926  0.05184052  0.0138737 ]
# iteration: 1890| Acceptance rate: 0.32222222222222224| Log-Likelihood: -10863.434578685023| Proposal [ 0.07528616  0.2918885  -0.86822853  0.05160325  0.01301608]
# iteration: 1900| Acceptance rate: 0.3231578947368421| Log-Likelihood: -10861.92746696529| Proposal [ 0.07642871  0.28740822 -0.83994645  0.05321548  0.01574465]
# iteration: 1910| Acceptance rate: 0.325130890052356| Log-Likelihood: -10862.95202031808| Proposal [ 0.0778223   0.2852549  -0.8246847   0.05436895  0.01698742]
# iteration: 1920| Acceptance rate: 0.32760416666666664| Log-Likelihood: -10863.382088203794| Proposal [ 0.07901903  0.28119837 -0.79876764  0.0558994   0.01944411]
# iteration: 1930| Acceptance rate: 0.32694300518134717| Log-Likelihood: -10863.100073621537| Proposal [ 0.07913844  0.28373374 -0.81325747  0.05533069  0.01783784]
# iteration: 1940| Acceptance rate: 0.3283505154639175| Log-Likelihood: -10862.400254173534| Proposal [ 0.07794222  0.28507291 -0.82339622  0.05446633  0.01709196]
# iteration: 1950| Acceptance rate: 0.3302564102564103| Log-Likelihood: -10862.294293448313| Proposal [ 0.07761718  0.28484694 -0.82272625  0.05437603  0.01726067]
# iteration: 1960| Acceptance rate: 0.33163265306122447| Log-Likelihood: -10862.596032253206| Proposal [ 0.07482328  0.28938517 -0.85459316  0.05201208  0.01463069]
# iteration: 1970| Acceptance rate: 0.33401015228426395| Log-Likelihood: -10862.737361058245| Proposal [ 0.07814515  0.28300506 -0.81099385  0.05506311  0.01837711]
# iteration: 1980| Acceptance rate: 0.33636363636363636| Log-Likelihood: -10862.821403411022| Proposal [ 0.07849019  0.28531302 -0.82371936  0.05465092  0.01689556]
# iteration: 1990| Acceptance rate: 0.33768844221105526| Log-Likelihood: -10861.836296300931| Proposal [ 0.07570644  0.28822832 -0.84614612  0.05268867  0.0152864 ]
# iteration: 2000| Acceptance rate: 0.3405| Log-Likelihood: -10863.11905935183| Proposal [ 0.07603756  0.28651462 -0.83553708  0.05325795  0.01633871]
# iteration: 2010| Acceptance rate: 0.34129353233830845| Log-Likelihood: -10862.720210963755| Proposal [ 0.07791067  0.28472123 -0.82141601  0.05453849  0.01731598]
# iteration: 2020| Acceptance rate: 0.3420792079207921| Log-Likelihood: -10862.709594461798| Proposal [ 0.07904033  0.28414824 -0.81584947  0.05518674  0.01758533]
# iteration: 2030| Acceptance rate: 0.3443349753694581| Log-Likelihood: -10862.090803006247| Proposal [ 0.0765845   0.28769913 -0.84133865  0.05321196  0.01554819]
# iteration: 2040| Acceptance rate: 0.346078431372549| Log-Likelihood: -10862.909916692886| Proposal [ 0.07879642  0.28818501 -0.83980417  0.05408163  0.01506161]
# iteration: 2050| Acceptance rate: 0.3473170731707317| Log-Likelihood: -10862.466212091427| Proposal [ 0.07849788  0.2849794  -0.82177793  0.05473407  0.01710437]
# iteration: 2060| Acceptance rate: 0.34951456310679613| Log-Likelihood: -10862.37688614078| Proposal [ 0.07775568  0.28728583 -0.83665966  0.05383168  0.01571121]
# iteration: 2070| Acceptance rate: 0.3507246376811594| Log-Likelihood: -10864.096546717827| Proposal [ 0.07900859  0.2904532  -0.8525873   0.05361471  0.01361441]
# iteration: 2080| Acceptance rate: 0.35144230769230766| Log-Likelihood: -10862.983564450173| Proposal [ 0.07832121  0.2869782  -0.8337425   0.05416315  0.01585969]
# iteration: 2090| Acceptance rate: 0.35167464114832536| Log-Likelihood: -10862.324790107928| Proposal [ 0.07513528  0.28760824 -0.84364213  0.05259067  0.01572509]
# iteration: 2100| Acceptance rate: 0.3547619047619048| Log-Likelihood: -10862.31096745548| Proposal [ 0.07422984  0.28789776 -0.84711549  0.05211321  0.01561622]
# iteration: 2110| Acceptance rate: 0.35592417061611376| Log-Likelihood: -10862.886603062892| Proposal [ 0.07812735  0.28938844 -0.84814239  0.05348134  0.01435666]
# iteration: 2120| Acceptance rate: 0.35754716981132073| Log-Likelihood: -10864.35725219015| Proposal [ 0.08083245  0.28659887 -0.82658331  0.05538087  0.01589407]
# iteration: 2130| Acceptance rate: 0.35821596244131454| Log-Likelihood: -10863.355970695382| Proposal [ 0.07779179  0.28832366 -0.84259652  0.05359687  0.01505585]
# iteration: 2140| Acceptance rate: 0.3598130841121495| Log-Likelihood: -10862.354144203562| Proposal [ 0.07642942  0.28777532 -0.84208345  0.05312452  0.01551306]
# iteration: 2150| Acceptance rate: 0.3623255813953488| Log-Likelihood: -10863.173429181195| Proposal [ 0.07877461  0.28814892 -0.83966243  0.05407603  0.01508469]
# iteration: 2160| Acceptance rate: 0.3648148148148148| Log-Likelihood: -10864.340849764369| Proposal [ 0.08063868  0.28736645 -0.83142953  0.05510465  0.01542617]
# iteration: 2170| Acceptance rate: 0.36682027649769583| Log-Likelihood: -10863.91654992406| Proposal [ 0.07868298  0.29016802 -0.85158224  0.05353723  0.01382001]
# iteration: 2180| Acceptance rate: 0.368348623853211| Log-Likelihood: -10862.435583048358| Proposal [ 0.07754598  0.28702477 -0.83555598  0.05380208  0.01589275]
# iteration: 2190| Acceptance rate: 0.37031963470319634| Log-Likelihood: -10862.006195209902| Proposal [ 0.07727006  0.28901328 -0.84765499  0.05318954  0.01466274]
# iteration: 2200| Acceptance rate: 0.3709090909090909| Log-Likelihood: -10862.116086287888| Proposal [ 0.07355566  0.2886943  -0.85322529  0.05158692  0.01516078]
# iteration: 2210| Acceptance rate: 0.37104072398190047| Log-Likelihood: -10861.925452299882| Proposal [ 0.07648488  0.28614248 -0.83262333  0.05352496  0.01652916]
# iteration: 2220| Acceptance rate: 0.37117117117117115| Log-Likelihood: -10863.120105741964| Proposal [ 0.07265753  0.286454   -0.84197593  0.0517364   0.01664524]
# iteration: 2230| Acceptance rate: 0.3726457399103139| Log-Likelihood: -10862.2947585748| Proposal [ 0.07491347  0.28809971 -0.84711145  0.05233727  0.01542353]
# iteration: 2240| Acceptance rate: 0.3732142857142857| Log-Likelihood: -10862.174526812329| Proposal [ 0.07737272  0.28706926 -0.83629536  0.0536873   0.01587089]
# iteration: 2250| Acceptance rate: 0.37466666666666665| Log-Likelihood: -10862.78555718256| Proposal [ 0.07548231  0.28550889 -0.83100986  0.05321487  0.01700476]
# iteration: 2260| Acceptance rate: 0.3756637168141593| Log-Likelihood: -10862.137360471324| Proposal [ 0.07369467  0.28500974 -0.83171943  0.05252155  0.01746004]
# iteration: 2270| Acceptance rate: 0.3762114537444934| Log-Likelihood: -10861.97926770982| Proposal [ 0.07552839  0.28577591 -0.83250586  0.05316316  0.0168308 ]
# iteration: 2280| Acceptance rate: 0.37719298245614036| Log-Likelihood: -10865.046631066034| Proposal [ 0.07945495  0.27701567 -0.77431661  0.05698837  0.02200234]
# iteration: 2290| Acceptance rate: 0.37685589519650653| Log-Likelihood: -10864.540196341264| Proposal [ 0.07570814  0.27873235 -0.79161808  0.05490113  0.02123007]
# iteration: 2300| Acceptance rate: 0.37782608695652176| Log-Likelihood: -10864.91353202897| Proposal [ 0.070686    0.28763925 -0.85280913  0.05055159  0.01605608]
# iteration: 2310| Acceptance rate: 0.37835497835497833| Log-Likelihood: -10862.449309383193| Proposal [ 0.07567078  0.28459912 -0.8254872   0.05349736  0.01755469]
# iteration: 2320| Acceptance rate: 0.3793103448275862| Log-Likelihood: -10862.577530948247| Proposal [ 0.07729531  0.28646632 -0.83301861  0.05378692  0.01625273]
# iteration: 2330| Acceptance rate: 0.3798283261802575| Log-Likelihood: -10863.313318782342| Proposal [ 0.07902737  0.28715212 -0.83357052  0.05439675  0.01568057]
# iteration: 2340| Acceptance rate: 0.3799145299145299| Log-Likelihood: -10861.693031164168| Proposal [ 0.07595887  0.28544037 -0.82976057  0.05342825  0.017004  ]
# iteration: 2350| Acceptance rate: 0.38085106382978723| Log-Likelihood: -10862.614477324514| Proposal [ 0.07811225  0.28810249 -0.8408696   0.05375875  0.01515816]
# iteration: 2360| Acceptance rate: 0.38177966101694916| Log-Likelihood: -10865.160122051471| Proposal [ 0.07532088  0.29355613 -0.87752984  0.05126921  0.01198118]
# iteration: 2370| Acceptance rate: 0.3831223628691983| Log-Likelihood: -10863.058985202746| Proposal [ 0.07751504  0.28809807 -0.84192558  0.0535107   0.01521512]
# iteration: 2380| Acceptance rate: 0.38445378151260506| Log-Likelihood: -10862.57954961094| Proposal [ 0.07695618  0.28558214 -0.82840258  0.05388036  0.0168457 ]
# iteration: 2390| Acceptance rate: 0.38535564853556487| Log-Likelihood: -10861.71830901577| Proposal [ 0.07566255  0.28454953 -0.82447327  0.05364604  0.01762903]
# iteration: 2400| Acceptance rate: 0.38666666666666666| Log-Likelihood: -10862.156976656162| Proposal [ 0.07765574  0.2858817  -0.82810306  0.05424459  0.01663777]
# iteration: 2410| Acceptance rate: 0.3871369294605809| Log-Likelihood: -10862.406131754251| Proposal [ 0.07736336  0.28876623 -0.84569755  0.05335589  0.01483006]
# iteration: 2420| Acceptance rate: 0.3888429752066116| Log-Likelihood: -10863.262110231255| Proposal [ 0.07466176  0.28331296 -0.82055362  0.05325813  0.01841559]
# iteration: 2430| Acceptance rate: 0.3893004115226337| Log-Likelihood: -10863.052712507806| Proposal [ 0.0757591   0.28135456 -0.80729694  0.05417662  0.01954325]
# iteration: 2440| Acceptance rate: 0.3901639344262295| Log-Likelihood: -10862.848412595325| Proposal [ 0.07472458  0.28313824 -0.81890675  0.05342513  0.01854955]
# iteration: 2450| Acceptance rate: 0.3906122448979592| Log-Likelihood: -10862.352924763984| Proposal [ 0.07536471  0.28566513 -0.83209864  0.05313345  0.01691885]
# iteration: 2460| Acceptance rate: 0.39146341463414636| Log-Likelihood: -10862.001504735365| Proposal [ 0.07705048  0.28358043 -0.81739313  0.05426219  0.01805263]
# iteration: 2470| Acceptance rate: 0.39190283400809717| Log-Likelihood: -10861.993442312838| Proposal [ 0.07411316  0.28487812 -0.82966303  0.0528293   0.01753549]
# iteration: 2480| Acceptance rate: 0.392741935483871| Log-Likelihood: -10863.792731950745| Proposal [ 0.07395236  0.2887351  -0.8515453   0.0519688   0.01516764]
# iteration: 2490| Acceptance rate: 0.39357429718875503| Log-Likelihood: -10862.967242772123| Proposal [ 0.07875801  0.28509355 -0.82257412  0.05470041  0.01697432]
# iteration: 2500| Acceptance rate: 0.3952| Log-Likelihood: -10864.272636918167| Proposal [ 0.08006259  0.28271581 -0.80748252  0.05562389  0.01829144]
# iteration: 2510| Acceptance rate: 0.3960159362549801| Log-Likelihood: -10861.53054075079| Proposal [ 0.0765935   0.28838794 -0.84512712  0.05308367  0.01512483]
# iteration: 2520| Acceptance rate: 0.3948412698412698| Log-Likelihood: -10862.0800735317| Proposal [ 0.07713052  0.28918913 -0.84885791  0.05310162  0.01456873]
# iteration: 2530| Acceptance rate: 0.3960474308300395| Log-Likelihood: -10862.54500400102| Proposal [ 0.07852072  0.28753335 -0.83791903  0.05386199  0.01541689]
# iteration: 2540| Acceptance rate: 0.3968503937007874| Log-Likelihood: -10862.632362341828| Proposal [ 0.07831923  0.28569768 -0.82623793  0.05448995  0.01667028]
# iteration: 2550| Acceptance rate: 0.3988235294117647| Log-Likelihood: -10862.444153100723| Proposal [ 0.07379865  0.28799606 -0.84454921  0.0526494   0.0158175 ]
# iteration: 2560| Acceptance rate: 0.399609375| Log-Likelihood: -10863.317616754464| Proposal [ 0.076225    0.28024903 -0.80085341  0.05448715  0.02015018]
# iteration: 2570| Acceptance rate: 0.4003891050583658| Log-Likelihood: -10863.175658814554| Proposal [ 0.07285584  0.28637585 -0.83805294  0.0524258   0.01685431]
# iteration: 2580| Acceptance rate: 0.40232558139534885| Log-Likelihood: -10863.244076098825| Proposal [ 0.07533832  0.28072537 -0.80734292  0.05360043  0.0198096 ]
# iteration: 2590| Acceptance rate: 0.40115830115830114| Log-Likelihood: -10862.081616892707| Proposal [ 0.0762631   0.28309391 -0.81805662  0.05366337  0.01831244]
# iteration: 2600| Acceptance rate: 0.4026923076923077| Log-Likelihood: -10862.480220231851| Proposal [ 0.07781494  0.28561311 -0.8259059   0.05444282  0.01681241]
# iteration: 2610| Acceptance rate: 0.40383141762452107| Log-Likelihood: -10863.201363823882| Proposal [ 0.0740763   0.29041602 -0.85714517  0.05235202  0.01432312]
# iteration: 2620| Acceptance rate: 0.40534351145038167| Log-Likelihood: -10862.864232605514| Proposal [ 0.07474547  0.28653294 -0.84086548  0.05217003  0.01627958]
# iteration: 2630| Acceptance rate: 0.40570342205323195| Log-Likelihood: -10862.331463551054| Proposal [ 0.07512129  0.28574825 -0.83700923  0.05225832  0.01666059]
# iteration: 2640| Acceptance rate: 0.4056818181818182| Log-Likelihood: -10862.085579369455| Proposal [ 0.07429141  0.28531163 -0.83594743  0.05202474  0.01701248]
# iteration: 2650| Acceptance rate: 0.4075471698113208| Log-Likelihood: -10863.274431123158| Proposal [ 0.07685451  0.28214522 -0.81987556  0.05255602  0.01837581]
# iteration: 2660| Acceptance rate: 0.40827067669172934| Log-Likelihood: -10862.160707447645| Proposal [ 0.07617233  0.28075479 -0.82355067  0.05062621  0.01871193]
# iteration: 2670| Acceptance rate: 0.40973782771535583| Log-Likelihood: -10861.962323182843| Proposal [ 0.07463278  0.28490586 -0.84212624  0.05053745  0.01671354]
# iteration: 2680| Acceptance rate: 0.41082089552238804| Log-Likelihood: -10862.215859428114| Proposal [ 0.07391297  0.28607264 -0.8476757   0.05042897  0.01618884]
# iteration: 2690| Acceptance rate: 0.41152416356877325| Log-Likelihood: -10862.371851258911| Proposal [ 0.07323746  0.28564531 -0.85238424  0.0491248   0.01617798]
# iteration: 2700| Acceptance rate: 0.41333333333333333| Log-Likelihood: -10863.075934063301| Proposal [ 0.07695166  0.27869819 -0.81927246  0.04974108  0.01941716]
# iteration: 2710| Acceptance rate: 0.4140221402214022| Log-Likelihood: -10862.620674190295| Proposal [ 0.0731721   0.2887641  -0.80936899  0.0599026   0.01772256]
# iteration: 2720| Acceptance rate: 0.41544117647058826| Log-Likelihood: -10863.23442742961| Proposal [ 0.07639954  0.27785516 -0.8345045   0.04610405  0.01890421]
# iteration: 2730| Acceptance rate: 0.41611721611721614| Log-Likelihood: -10863.84957212182| Proposal [ 0.07363177  0.28114459 -0.78514455  0.05802308  0.0212859 ]
# iteration: 2740| Acceptance rate: 0.4167883211678832| Log-Likelihood: -10862.38004686628| Proposal [ 0.07632514  0.28323409 -0.83716481  0.05017767  0.01716593]
# iteration: 2750| Acceptance rate: 0.4178181818181818| Log-Likelihood: -10864.765252918818| Proposal [ 0.06953298  0.28438137 -0.88189904  0.04219458  0.01558596]
# iteration: 2760| Acceptance rate: 0.41739130434782606| Log-Likelihood: -10863.526176209978| Proposal [ 0.07226344  0.29125176 -0.87428176  0.04969059  0.01344665]
# iteration: 2770| Acceptance rate: 0.4184115523465704| Log-Likelihood: -10862.655192630915| Proposal [ 0.07352323  0.27441393 -0.85961152  0.038214    0.01905122]
# iteration: 2780| Acceptance rate: 0.41942446043165466| Log-Likelihood: -10863.503685748121| Proposal [ 0.0725435   0.27897222 -0.84214724  0.04532248  0.01888392]
# iteration: 2790| Acceptance rate: 0.41935483870967744| Log-Likelihood: -10863.50875185119| Proposal [ 0.07252436  0.26897863 -0.87815695  0.03000582  0.0198021 ]
# iteration: 2800| Acceptance rate: 0.41892857142857143| Log-Likelihood: -10863.300002094522| Proposal [ 0.07333042  0.27558612 -0.85484663  0.04009816  0.01901238]
# iteration: 2810| Acceptance rate: 0.4195729537366548| Log-Likelihood: -10864.36983607975| Proposal [ 0.08029889  0.27031686 -0.84659096  0.0376921   0.01969853]
# iteration: 2820| Acceptance rate: 0.42021276595744683| Log-Likelihood: -10864.177373100236| Proposal [ 0.07971299  0.27525116 -0.80813303  0.04911638  0.02054337]
# iteration: 2830| Acceptance rate: 0.4204946996466431| Log-Likelihood: -10862.805151535676| Proposal [ 0.07406767  0.28031065 -0.84530193  0.04598093  0.01800911]
# iteration: 2840| Acceptance rate: 0.42007042253521126| Log-Likelihood: -10863.163718981443| Proposal [ 0.07371524  0.2897034  -0.80067961  0.06238496  0.01783444]
# iteration: 2850| Acceptance rate: 0.4203508771929825| Log-Likelihood: -10863.309259151947| Proposal [ 0.07727152  0.29572877 -0.73606888  0.07998989  0.01904543]
# iteration: 2860| Acceptance rate: 0.4206293706293706| Log-Likelihood: -10863.744103181285| Proposal [ 0.07966467  0.29688613 -0.72975209  0.08234857  0.01859732]
# iteration: 2870| Acceptance rate: 0.42090592334494775| Log-Likelihood: -10865.25322372328| Proposal [ 0.08127132  0.30975176 -0.67244709  0.10425366  0.01773389]
# iteration: 2880| Acceptance rate: 0.4215277777777778| Log-Likelihood: -10865.866164957004| Proposal [ 0.08055316  0.33578904 -0.55182034  0.14916622  0.01702387]
# iteration: 2890| Acceptance rate: 0.42249134948096884| Log-Likelihood: -10863.14853090302| Proposal [ 0.07696311  0.29156953 -0.77061595  0.06989754  0.01836735]
# iteration: 2900| Acceptance rate: 0.42310344827586205| Log-Likelihood: -10862.635148634341| Proposal [ 0.07859996  0.29286463 -0.75471583  0.07412724  0.01857325]
# iteration: 2910| Acceptance rate: 0.42302405498281787| Log-Likelihood: -10862.940006491786| Proposal [ 0.07741516  0.29843806 -0.75149414  0.07939443  0.01732921]
# iteration: 2920| Acceptance rate: 0.4226027397260274| Log-Likelihood: -10862.155345693696| Proposal [ 0.07586946  0.27379295 -0.86241576  0.03733131  0.01861981]
# iteration: 2930| Acceptance rate: 0.4235494880546075| Log-Likelihood: -10863.691308308391| Proposal [ 0.0793459   0.30764624 -0.70505136  0.0961564   0.01686996]
# iteration: 2940| Acceptance rate: 0.4238095238095238| Log-Likelihood: -10864.17123063787| Proposal [ 0.07820213  0.32012035 -0.65193348  0.11673066  0.01641796]
# iteration: 2950| Acceptance rate: 0.42406779661016947| Log-Likelihood: -10864.577431179829| Proposal [ 0.08034541  0.32148301 -0.6165628   0.12473411  0.01761881]
# iteration: 2960| Acceptance rate: 0.4239864864864865| Log-Likelihood: -10863.115360991762| Proposal [ 0.07568633  0.27112835 -0.85698752  0.03607334  0.01975874]
# iteration: 2970| Acceptance rate: 0.4239057239057239| Log-Likelihood: -10864.089592465174| Proposal [ 0.07657873  0.29307782 -0.7292167   0.0789743   0.02036073]
# iteration: 2980| Acceptance rate: 0.4238255033557047| Log-Likelihood: -10862.238276231757| Proposal [ 0.07774937  0.28707968 -0.80686781  0.05928367  0.01747751]
# ...
# iteration: 49030| Acceptance rate: 0.3614725678156231| Log-Likelihood: -10863.876349429887| Proposal [ 0.06622255  0.24783881 -1.31011029  0.07827238  0.01489847]
# iteration: 49040| Acceptance rate: 0.3614804241435563| Log-Likelihood: -10859.94006894434| Proposal [ 0.07059494  0.17544428 -1.22583914  0.07540211  0.01714381]
# iteration: 49050| Acceptance rate: 0.3614678899082569| Log-Likelihood: -10860.381161786701| Proposal [ 0.07392405  0.16842521 -1.17079072  0.04038156  0.01536513]
# iteration: 49060| Acceptance rate: 0.36151651039543414| Log-Likelihood: -10860.385086493594| Proposal [ 0.0720898   0.09721671 -1.13072359  0.08930958  0.01589416]
# iteration: 49070| Acceptance rate: 0.36146321581414304| Log-Likelihood: -10861.65839113305| Proposal [ 0.0728555   0.21598741 -1.04530237  0.09703061  0.01851433]
# iteration: 49080| Acceptance rate: 0.3614710676446618| Log-Likelihood: -10862.19063650724| Proposal [ 0.06409479  0.40304354 -1.89667297  0.05291597  0.01719092]
# iteration: 49090| Acceptance rate: 0.36147891627622736| Log-Likelihood: -10863.701109991827| Proposal [ 0.06414234  0.32456954 -1.85888254  0.05588064  0.01701278]
# iteration: 49100| Acceptance rate: 0.3614663951120163| Log-Likelihood: -10861.797275032723| Proposal [ 0.0632276   0.21247787 -1.99075701  0.02429148  0.0220414 ]
# iteration: 49110| Acceptance rate: 0.3614335165953981| Log-Likelihood: -10864.589295709751| Proposal [ 0.07114158  0.07607163 -1.335795    0.0494414   0.01419159]
# iteration: 49120| Acceptance rate: 0.3613599348534202| Log-Likelihood: -10864.589295709751| Proposal [ 0.07114158  0.07607163 -1.335795    0.0494414   0.01419159]
# iteration: 49130| Acceptance rate: 0.3613474455526155| Log-Likelihood: -10859.954941478509| Proposal [ 0.06557344  0.17771719 -1.71631717  0.03490984  0.01538463]
# iteration: 49140| Acceptance rate: 0.3612739112739113| Log-Likelihood: -10859.954941478509| Proposal [ 0.06557344  0.17771719 -1.71631717  0.03490984  0.01538463]
# iteration: 49150| Acceptance rate: 0.3612207527975585| Log-Likelihood: -10859.88738754438| Proposal [ 0.06558196  0.13835964 -1.72838605  0.03614984  0.01668825]
# iteration: 49160| Acceptance rate: 0.3611472742066721| Log-Likelihood: -10859.88738754438| Proposal [ 0.06558196  0.13835964 -1.72838605  0.03614984  0.01668825]
# iteration: 49170| Acceptance rate: 0.36113483831604637| Log-Likelihood: -10861.29138815056| Proposal [ 0.0677769   0.28929058 -1.45445317  0.05718058  0.0166394 ]
# iteration: 49180| Acceptance rate: 0.36112240748271657| Log-Likelihood: -10861.055040577283| Proposal [ 0.06381855  0.18665944 -1.82909981  0.03394893  0.01994727]
# iteration: 49190| Acceptance rate: 0.36115064037405975| Log-Likelihood: -10860.686698272742| Proposal [ 0.06730313  0.16364253 -1.59198937  0.03171776  0.01498584]
# iteration: 49200| Acceptance rate: 0.3611382113821138| Log-Likelihood: -10860.655240517677| Proposal [ 0.07571384  0.2061987  -0.9581383   0.07090512  0.015178  ]
# iteration: 49210| Acceptance rate: 0.36106482422271896| Log-Likelihood: -10860.655240517677| Proposal [ 0.07571384  0.2061987  -0.9581383   0.07090512  0.015178  ]
# iteration: 49220| Acceptance rate: 0.3610524177163755| Log-Likelihood: -10861.028900133684| Proposal [ 0.07095263  0.26666972 -1.64413517  0.02168133  0.01859823]
# iteration: 49230| Acceptance rate: 0.36101970343286616| Log-Likelihood: -10861.885521650762| Proposal [ 0.07728925  0.24491852 -1.08599008  0.06053342  0.01774069]
# iteration: 49240| Acceptance rate: 0.36098700243704307| Log-Likelihood: -10861.79617283724| Proposal [ 0.07554323  0.27431388 -0.99729788  0.05822223  0.01914037]
# iteration: 49250| Acceptance rate: 0.360994923857868| Log-Likelihood: -10860.52729828344| Proposal [ 0.06883448  0.335195   -1.75926746  0.02356769  0.01827056]
# iteration: 49260| Acceptance rate: 0.36098254161591553| Log-Likelihood: -10863.084233467225| Proposal [ 0.06671723  0.46780226 -1.55782851  0.05716582  0.01664115]
# iteration: 49270| Acceptance rate: 0.3609904607266085| Log-Likelihood: -10862.519421241805| Proposal [ 0.0687855   0.34700401 -1.35396781  0.07712324  0.0167468 ]
# iteration: 49280| Acceptance rate: 0.36101866883116884| Log-Likelihood: -10861.548470086074| Proposal [ 0.07280883  0.22464744 -0.99647859  0.06166919  0.01927602]
# iteration: 49290| Acceptance rate: 0.3610062893081761| Log-Likelihood: -10861.258965297637| Proposal [ 0.06603563  0.20560455 -1.67933863  0.02715092  0.01799156]
# iteration: 49300| Acceptance rate: 0.3610141987829615| Log-Likelihood: -10861.82993845364| Proposal [ 0.06704821  0.35119391 -1.39525203  0.03494762  0.01705718]
# iteration: 49310| Acceptance rate: 0.36108294463597645| Log-Likelihood: -10862.185644254158| Proposal [ 0.0726684   0.32454327 -1.0597431   0.07482741  0.01667086]
# iteration: 49320| Acceptance rate: 0.3611111111111111| Log-Likelihood: -10861.194889615641| Proposal [ 0.07128402  0.28415437 -1.63018573  0.03782258  0.01817786]
# iteration: 49330| Acceptance rate: 0.3610581796067302| Log-Likelihood: -10861.249568932326| Proposal [ 0.06919046  0.17773974 -1.4873304   0.04901894  0.02031531]
# iteration: 49340| Acceptance rate: 0.3610255370895825| Log-Likelihood: -10862.14853452184| Proposal [ 0.0783464   0.16731289 -0.88510969  0.08711805  0.01869209]
# iteration: 49350| Acceptance rate: 0.36103343465045595| Log-Likelihood: -10860.899701682634| Proposal [ 0.06899866  0.19853918 -1.37467691  0.06672044  0.01900013]
# iteration: 49360| Acceptance rate: 0.3610210696920583| Log-Likelihood: -10860.326979889735| Proposal [ 0.06878296  0.17555947 -1.25447844  0.07788984  0.01604019]
# iteration: 49370| Acceptance rate: 0.3610694753899129| Log-Likelihood: -10860.572954943776| Proposal [ 0.06930824  0.21079438 -1.35558116  0.03797906  0.01870644]
# iteration: 49380| Acceptance rate: 0.3610368570271365| Log-Likelihood: -10860.338563179475| Proposal [ 0.069852    0.13611367 -1.23976299  0.05257048  0.01879541]
# iteration: 49390| Acceptance rate: 0.36096375784571777| Log-Likelihood: -10860.338563179475| Proposal [ 0.069852    0.13611367 -1.23976299  0.05257048  0.01879541]
# iteration: 49400| Acceptance rate: 0.36091093117408907| Log-Likelihood: -10860.225558016758| Proposal [ 0.07063598  0.17121208 -1.32812342  0.06197881  0.019252  ]
# iteration: 49410| Acceptance rate: 0.3609593199757134| Log-Likelihood: -10862.337958636452| Proposal [ 0.06506222  0.32868701 -1.45504819  0.04599811  0.01402594]
# iteration: 49420| Acceptance rate: 0.36092675030352084| Log-Likelihood: -10861.957594200974| Proposal [ 0.06798315  0.1973467  -1.32833889  0.05633156  0.01384285]
# iteration: 49430| Acceptance rate: 0.3609346550677726| Log-Likelihood: -10862.52778455442| Proposal [ 0.07339032  0.34685189 -1.17580785  0.072918    0.01878204]
# iteration: 49440| Acceptance rate: 0.36092233009708735| Log-Likelihood: -10862.481394918617| Proposal [ 0.07761818  0.15638216 -0.83501403  0.12810631  0.0174206 ]
# iteration: 49450| Acceptance rate: 0.36086956521739133| Log-Likelihood: -10860.982777097051| Proposal [ 0.07601866  0.18590968 -0.90488905  0.11761726  0.01779768]
# iteration: 49460| Acceptance rate: 0.3609179134654266| Log-Likelihood: -10860.30651489506| Proposal [ 0.07145883  0.11233361 -1.2314621   0.06612258  0.01519447]
# iteration: 49470| Acceptance rate: 0.3608853850818678| Log-Likelihood: -10859.915088595002| Proposal [ 0.06923294  0.14374982 -1.30751341  0.05277748  0.01658702]
# iteration: 49480| Acceptance rate: 0.3608730800323363| Log-Likelihood: -10859.882179500548| Proposal [ 0.06529769  0.18883224 -1.70811777  0.0365264   0.01635835]
# iteration: 49490| Acceptance rate: 0.36080016164881795| Log-Likelihood: -10859.882179500548| Proposal [ 0.06529769  0.18883224 -1.70811777  0.0365264   0.01635835]
# iteration: 49500| Acceptance rate: 0.36078787878787877| Log-Likelihood: -10864.277767966154| Proposal [ 0.06886224  0.4148093  -1.61522319  0.07897774  0.01481001]
# iteration: 49510| Acceptance rate: 0.3607957988285195| Log-Likelihood: -10864.327539719383| Proposal [ 0.07804122  0.23166272 -1.16773562  0.07956142  0.01767432]
# iteration: 49520| Acceptance rate: 0.36074313408723746| Log-Likelihood: -10864.54051301638| Proposal [ 0.0737494   0.13180565 -1.32693874  0.03232043  0.0199667 ]
# iteration: 49530| Acceptance rate: 0.36069049061175046| Log-Likelihood: -10862.249021543957| Proposal [ 0.0731056   0.13128456 -1.27294532  0.04045835  0.02081546]
# iteration: 49540| Acceptance rate: 0.36065805409769885| Log-Likelihood: -10860.887157355672| Proposal [ 0.07104444  0.14311572 -1.35620845  0.04491409  0.01606803]
# iteration: 49550| Acceptance rate: 0.3606659939455096| Log-Likelihood: -10860.967913639519| Proposal [ 0.07050786  0.26454909 -1.35844149  0.06374873  0.01624814]
# iteration: 49560| Acceptance rate: 0.3606537530266344| Log-Likelihood: -10861.544270727176| Proposal [ 0.0726826   0.28849259 -1.23289561  0.08673006  0.01607042]
# iteration: 49570| Acceptance rate: 0.36064151704660075| Log-Likelihood: -10860.97415862217| Proposal [ 0.06941212  0.28572414 -1.33625837  0.05940441  0.01832761]
# iteration: 49580| Acceptance rate: 0.3607099636950383| Log-Likelihood: -10862.36810877704| Proposal [ 0.06589601  0.3365086  -1.46855089  0.03835373  0.019014  ]
# iteration: 49590| Acceptance rate: 0.3607380520266183| Log-Likelihood: -10864.631609944428| Proposal [ 0.06697717  0.08689343 -1.36419272  0.04226684  0.02120175]
# iteration: 49600| Acceptance rate: 0.3607661290322581| Log-Likelihood: -10863.649157169828| Proposal [ 0.06597947  0.33364408 -1.48949679  0.04805475  0.02226364]
# iteration: 49610| Acceptance rate: 0.3607538802660754| Log-Likelihood: -10859.452534543112| Proposal [ 0.07047079  0.15993181 -1.30389462  0.0679502   0.01631079]
# iteration: 49620| Acceptance rate: 0.36076178960096733| Log-Likelihood: -10862.851586852332| Proposal [ 0.06817182  0.47608665 -1.87257231  0.03015077  0.01743405]
# iteration: 49630| Acceptance rate: 0.3607092484384445| Log-Likelihood: -10862.85256639286| Proposal [ 0.06844931  0.48555042 -1.9796087   0.03212459  0.01542932]
# iteration: 49640| Acceptance rate: 0.36069701853344077| Log-Likelihood: -10862.215325903375| Proposal [ 0.06560633  0.1846424  -1.45349067  0.03898541  0.02130772]
# iteration: 49650| Acceptance rate: 0.3606847935548842| Log-Likelihood: -10861.426762367633| Proposal [ 0.06355046  0.2270629  -1.742629    0.02443497  0.01679481]
# iteration: 49660| Acceptance rate: 0.3606524365686669| Log-Likelihood: -10861.501165662517| Proposal [ 0.065304    0.23053806 -1.69529793  0.03121965  0.01897071]
# iteration: 49670| Acceptance rate: 0.36070062411918663| Log-Likelihood: -10860.420482374799| Proposal [ 0.06737876  0.19909132 -1.5743834   0.04658281  0.01611573]
# iteration: 49680| Acceptance rate: 0.3606682769726248| Log-Likelihood: -10861.557289640035| Proposal [ 0.06438821  0.17010275 -1.704409    0.03788193  0.0144012 ]
# iteration: 49690| Acceptance rate: 0.3606560676192393| Log-Likelihood: -10864.117060551114| Proposal [ 0.06439052  0.19016415 -1.56613971  0.06430558  0.01783344]
# iteration: 49700| Acceptance rate: 0.36064386317907443| Log-Likelihood: -10863.510855205524| Proposal [ 0.06928142  0.06738795 -1.26461935  0.06449679  0.0136749 ]
# iteration: 49710| Acceptance rate: 0.36063166364916516| Log-Likelihood: -10861.44786420171| Proposal [ 0.06629252  0.24728652 -1.42670469  0.06804745  0.0163513 ]
# iteration: 49720| Acceptance rate: 0.36063958165728077| Log-Likelihood: -10864.32171886537| Proposal [ 0.06684099  0.28575499 -1.69922446  0.04148631  0.01206253]
# iteration: 49730| Acceptance rate: 0.3606676050673638| Log-Likelihood: -10861.34016133252| Proposal [ 0.06673237  0.30057968 -1.41549858  0.03484191  0.01695304]
# iteration: 49740| Acceptance rate: 0.3606554081222356| Log-Likelihood: -10860.716470536492| Proposal [ 0.06433205  0.22122159 -1.88086335  0.02150467  0.01775437]
# iteration: 49750| Acceptance rate: 0.36062311557788945| Log-Likelihood: -10861.02008563517| Proposal [ 0.0692517   0.27266676 -1.73118485  0.02159616  0.01638189]
# iteration: 49760| Acceptance rate: 0.36059083601286174| Log-Likelihood: -10861.083916031272| Proposal [ 0.07006041  0.32390151 -1.70579839  0.02315353  0.01847711]
# iteration: 49770| Acceptance rate: 0.3605384769941732| Log-Likelihood: -10861.421318931474| Proposal [ 0.06824494  0.42856165 -1.89648876  0.0174769   0.01870377]
# iteration: 49780| Acceptance rate: 0.3605263157894737| Log-Likelihood: -10860.34637568844| Proposal [ 0.06845416  0.20659864 -1.54257931  0.05405905  0.01631835]
# iteration: 49790| Acceptance rate: 0.36051415946977305| Log-Likelihood: -10862.620981941| Proposal [ 0.07279324  0.12441807 -1.07041018  0.12192752  0.01365021]
# iteration: 49800| Acceptance rate: 0.36052208835341365| Log-Likelihood: -10866.285137504714| Proposal [ 0.06440895  0.38842218 -1.25312058  0.11307388  0.01737988]
# iteration: 49810| Acceptance rate: 0.3604898614735997| Log-Likelihood: -10865.566733003394| Proposal [ 0.06607397  0.43388387 -1.39800629  0.12496144  0.01852326]
# iteration: 49820| Acceptance rate: 0.36053793657165795| Log-Likelihood: -10861.744252902377| Proposal [ 0.06653321  0.42171477 -1.99699516  0.01339746  0.01690939]
# iteration: 49830| Acceptance rate: 0.360485651214128| Log-Likelihood: -10861.979103127447| Proposal [ 0.06557307  0.35401801 -1.92380839  0.01436268  0.01798744]
# iteration: 49840| Acceptance rate: 0.36041332263242376| Log-Likelihood: -10861.979103127447| Proposal [ 0.06557307  0.35401801 -1.92380839  0.01436268  0.01798744]
# iteration: 49850| Acceptance rate: 0.36036108324974925| Log-Likelihood: -10861.50744135958| Proposal [ 0.06448581  0.34163432 -1.8595682   0.0196149   0.01590161]
# iteration: 49860| Acceptance rate: 0.36034897713598074| Log-Likelihood: -10861.370308691212| Proposal [ 0.06876264  0.35833831 -1.76911823  0.0273763   0.01482006]
# iteration: 49870| Acceptance rate: 0.3603368758772809| Log-Likelihood: -10861.036428326513| Proposal [ 0.06673778  0.33401039 -1.68530365  0.04031455  0.01550217]
# iteration: 49880| Acceptance rate: 0.3603448275862069| Log-Likelihood: -10862.068591053941| Proposal [ 0.06510964  0.28060922 -1.54673167  0.04272159  0.01695208]
# iteration: 49890| Acceptance rate: 0.3603728202044498| Log-Likelihood: -10862.178046661029| Proposal [ 0.07388232  0.24955908 -1.40161887  0.04654421  0.01751585]
# iteration: 49900| Acceptance rate: 0.36034068136272546| Log-Likelihood: -10860.371108224259| Proposal [ 0.07328524  0.20421468 -1.12163907  0.0684797   0.01588359]
# iteration: 49910| Acceptance rate: 0.3603486275295532| Log-Likelihood: -10859.257837013734| Proposal [ 0.07129976  0.17019597 -1.31458662  0.05102514  0.01549412]
# iteration: 49920| Acceptance rate: 0.3602764423076923| Log-Likelihood: -10859.257837013734| Proposal [ 0.07129976  0.17019597 -1.31458662  0.05102514  0.01549412]
# iteration: 49930| Acceptance rate: 0.3602443420789105| Log-Likelihood: -10859.757925673885| Proposal [ 0.07369094  0.1557015  -1.26465165  0.05229802  0.01648936]
# iteration: 49940| Acceptance rate: 0.360252302763316| Log-Likelihood: -10864.196181321473| Proposal [ 0.0696714   0.22537892 -1.06294395  0.12772965  0.01434998]
# iteration: 49950| Acceptance rate: 0.3602202202202202| Log-Likelihood: -10861.01413455916| Proposal [ 0.0737412   0.21785748 -1.27618601  0.06794985  0.0160032 ]
# iteration: 49960| Acceptance rate: 0.36020816653322657| Log-Likelihood: -10860.791233389205| Proposal [ 0.06960934  0.24767613 -1.25531536  0.07200426  0.01742435]
# iteration: 49970| Acceptance rate: 0.3602161296778067| Log-Likelihood: -10861.414179124464| Proposal [ 0.07247227  0.25543827 -1.17593478  0.09704788  0.01743591]
# iteration: 49980| Acceptance rate: 0.36018407362945176| Log-Likelihood: -10861.735549735979| Proposal [ 0.07559706  0.2633629  -0.88353535  0.14261155  0.01731955]
# iteration: 49990| Acceptance rate: 0.36019203840768155| Log-Likelihood: -10864.43222058454| Proposal [ 0.08007031  0.29164471 -0.72458605  0.19442987  0.01651821]
# 4473.962112081004

# %%
burn_in = 20000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10858.209650383065
# The Maximum Likelihood Estimate is [ 0.07065636  0.12282305 -1.36621425  0.04905314  0.01573077] w/ LL of -10858.209650383065

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5026.464827204742
# Root Mean Squared Error for beta 0.09577335030119437

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
'''Optimal fit using expectation of parameter distribution'''

pf_params = {'num_particles':10_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (np.mean((pmcmc_output['accepted_params'][0,burn_in:])),np.mean((pmcmc_output['accepted_params'][1,burn_in:])),np.mean((pmcmc_output['accepted_params'][2,burn_in:])),np.mean((pmcmc_output['accepted_params'][3,burn_in:])),np.mean((pmcmc_output['accepted_params'][4,burn_in:]))),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[19], line 16
#      11 from time import perf_counter
#      15 t = perf_counter()
# ---> 16 output = particlefilter(data = data,
#      17         model_params= (),
#      18         pf_params = pf_params,
#      19         rng = rng,
#      20         req_jit=True
#      21         )
#      23 print(perf_counter() - t)
#
# File ~/PMCMC/examples/../particle_filter.py:12, in particlefilter(data, model_params, pf_params, rng, req_jit)
#       9 def particlefilter(data:NDArray[np.float64],model_params:NDArray[np.float64],pf_params:Dict,rng:Generator,req_jit = False):
#      10     p_filter = pf_validator(data,model_params,pf_params,rng,req_jit) #mild shape enforcement and checking of parameters.
# ---> 12     particles,particle_observations,weights,likelihood = p_filter(
#      13     data,
#      14     model_params,
#      15     rng = rng,
#      16     )
#      18     return {'particle_distribution':particles,'particle_observations':particle_observations,'log_weights':weights,'Log_likelihood':likelihood}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numba/core/dispatcher.py:423, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     419         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     420                f"by the following argument(s):\n{args_str}\n")
#     421         e.patch_message(msg)
# --> 423     error_rewrite(e, 'typing')
#     424 except errors.UnsupportedError as e:
#     425     # Something unsupported is present in the user code, add help info
#     426     error_rewrite(e, 'unsupported_error')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numba/core/dispatcher.py:364, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     362     raise e
#     363 else:
# --> 364     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# ('wrong tuple length for model_params: ', 'expected 5, got 0')
# During: typing of exhaust iter at /var/folders/3q/t1wxfpx9531dbcdd2380p6dm0000gp/T/ipykernel_5015/25001288.py (4)
#
# File "../../../../var/folders/3q/t1wxfpx9531dbcdd2380p6dm0000gp/T/ipykernel_5015/25001288.py", line 4:
# <source missing, REPL/exec in use?>
#
# During: resolving callee type: type(CPUDispatcher(<function SEIR_model at 0x12d89dda0>))
# During: typing of call at /Users/averydrennan/PMCMC/examples/../particle_filter.py (98)
#
# During: resolving callee type: type(CPUDispatcher(<function SEIR_model at 0x12d89dda0>))
# During: typing of call at /Users/averydrennan/PMCMC/examples/../particle_filter.py (98)
#
#
# File "../particle_filter.py", line 98:
# def filter_internal(data:NDArray[np.float64],model_params:NDArray[np.float64],
#     <source elided>
#             for _ in range(int(1/dt)):
#                 particles,particle_observations = model(particles, particle_observations, t, dt, model_params, rng)
#                 ^

# %%
'''Plots using the Expectation of the parameters and running the filter. '''
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

dt = pf_params['dt']

for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    plt.show()

plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,25,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue')
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10862.47096038752
# Root Mean Squared Error for the Data 5026.485295584059

# %%
np.savez(f'../pmcmc_output/SEIR_OU_PMCMC.npz',distribution = pmcmc_output['MLE_particle_dist'], 
         observations = pmcmc_output['MLE_particle_observations'], 
         params = pmcmc_output['accepted_params'], 
         likelihood = pmcmc_output['Log Likelihood']
)
