# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('..\\data_sets\\ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('..\\data_sets\\ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('..\\data_sets\\ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0]),n = np.array([r]))
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

gamma = 1/14
R = 50
lam = 1/20
mean_ou = -0.7
sig = 0.1


T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':100_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 38.38900690001901

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10833.677057638935
# Root Mean Squared Error for the Data 10061.499689585722

# %%
pmcmc_rng = np.random.default_rng(20)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

(gamma,sig,mean_ou,lam,1/R)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':100_000,
                'init_params':np.array([0.1,0.1,-0.5,0.05,0.01]),
                'prior':seir_prior,
                'init_cov': 0.1 * np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1000}

pf_params = {'num_particles':1000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.1| Log-Likelihood: -10858.21950751658| Proposal [ 0.07313643  0.07874499 -0.48977693  0.06810986  0.02259759]
# iteration: 20| Acceptance rate: 0.1| Log-Likelihood: -10859.905873740181| Proposal [ 0.06503394  0.09548474 -0.478637    0.12155244  0.03405587]
# iteration: 30| Acceptance rate: 0.1| Log-Likelihood: -10856.453502688339| Proposal [ 0.07419279  0.13817844 -0.47843976  0.09621596  0.06066567]
# iteration: 40| Acceptance rate: 0.1| Log-Likelihood: -10855.19691022134| Proposal [ 0.07096042  0.14848443 -0.49789167  0.08467028  0.06669577]
# iteration: 50| Acceptance rate: 0.08| Log-Likelihood: -10855.19691022134| Proposal [ 0.07096042  0.14848443 -0.49789167  0.08467028  0.06669577]
# iteration: 60| Acceptance rate: 0.06666666666666667| Log-Likelihood: -10855.19691022134| Proposal [ 0.07096042  0.14848443 -0.49789167  0.08467028  0.06669577]
# iteration: 70| Acceptance rate: 0.07142857142857142| Log-Likelihood: -10847.711289677265| Proposal [ 0.06755628  0.17845285 -0.51270435  0.15946421  0.0385489 ]
# iteration: 80| Acceptance rate: 0.0625| Log-Likelihood: -10847.711289677265| Proposal [ 0.06755628  0.17845285 -0.51270435  0.15946421  0.0385489 ]
# iteration: 90| Acceptance rate: 0.06666666666666667| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 100| Acceptance rate: 0.06| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 110| Acceptance rate: 0.05454545454545454| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 120| Acceptance rate: 0.05| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 130| Acceptance rate: 0.046153846153846156| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 140| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 150| Acceptance rate: 0.04| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 160| Acceptance rate: 0.0375| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 170| Acceptance rate: 0.03529411764705882| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 180| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 190| Acceptance rate: 0.031578947368421054| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 200| Acceptance rate: 0.03| Log-Likelihood: -10835.499877855409| Proposal [ 0.06952172  0.19710238 -0.52366508  0.12950204  0.02687778]
# iteration: 210| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 220| Acceptance rate: 0.031818181818181815| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 230| Acceptance rate: 0.030434782608695653| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 240| Acceptance rate: 0.029166666666666667| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 250| Acceptance rate: 0.028| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 260| Acceptance rate: 0.026923076923076925| Log-Likelihood: -10834.448915418325| Proposal [ 0.07009835  0.17381351 -0.59285313  0.10976741  0.02190267]
# iteration: 270| Acceptance rate: 0.02962962962962963| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 280| Acceptance rate: 0.02857142857142857| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 290| Acceptance rate: 0.027586206896551724| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 300| Acceptance rate: 0.02666666666666667| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 310| Acceptance rate: 0.025806451612903226| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 320| Acceptance rate: 0.025| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 330| Acceptance rate: 0.024242424242424242| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 340| Acceptance rate: 0.023529411764705882| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 350| Acceptance rate: 0.022857142857142857| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 360| Acceptance rate: 0.022222222222222223| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 370| Acceptance rate: 0.021621621621621623| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 380| Acceptance rate: 0.021052631578947368| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 390| Acceptance rate: 0.020512820512820513| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 400| Acceptance rate: 0.02| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 410| Acceptance rate: 0.01951219512195122| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 420| Acceptance rate: 0.01904761904761905| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 430| Acceptance rate: 0.018604651162790697| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 440| Acceptance rate: 0.01818181818181818| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 450| Acceptance rate: 0.017777777777777778| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 460| Acceptance rate: 0.017391304347826087| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 470| Acceptance rate: 0.01702127659574468| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 480| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 490| Acceptance rate: 0.0163265306122449| Log-Likelihood: -10835.655697328026| Proposal [ 0.06998936  0.17125964 -0.57917083  0.13124929  0.02345679]
# iteration: 500| Acceptance rate: 0.018| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 510| Acceptance rate: 0.01764705882352941| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 520| Acceptance rate: 0.01730769230769231| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 530| Acceptance rate: 0.016981132075471698| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 540| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 550| Acceptance rate: 0.016363636363636365| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 560| Acceptance rate: 0.01607142857142857| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 570| Acceptance rate: 0.015789473684210527| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 580| Acceptance rate: 0.015517241379310345| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 590| Acceptance rate: 0.015254237288135594| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 600| Acceptance rate: 0.015| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 610| Acceptance rate: 0.014754098360655738| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 620| Acceptance rate: 0.014516129032258065| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 630| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 640| Acceptance rate: 0.0140625| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 650| Acceptance rate: 0.013846153846153847| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 660| Acceptance rate: 0.013636363636363636| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 670| Acceptance rate: 0.013432835820895522| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 680| Acceptance rate: 0.013235294117647059| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 690| Acceptance rate: 0.013043478260869565| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 700| Acceptance rate: 0.012857142857142857| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 710| Acceptance rate: 0.01267605633802817| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 720| Acceptance rate: 0.0125| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 730| Acceptance rate: 0.012328767123287671| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 740| Acceptance rate: 0.012162162162162163| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# iteration: 750| Acceptance rate: 0.012| Log-Likelihood: -10833.36628104129| Proposal [ 0.06961739  0.12575918 -0.56691077  0.12334156  0.02324347]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 32
#      23 pf_params = {'num_particles':1000,
#      24                       'dt':1.,
#      25                       'model':SEIR_model,
#    (...)
#      28                       'particle_initializer':SEIR_init
#      29                       }
#      31 t = perf_counter()
# ---> 32 pmcmc_output = particlemcmc(
#      33                   data = data,
#      34                   pmcmc_params=pmcmc_params,
#      35                   pf_params=pf_params,
#      36                   adaptive=True,
#      37                   rng = rng,
#      38                   req_jit=True
#      39                   )
#      40 print(perf_counter() - t)
#
# File c:\Users\avery\PMCMC\examples\..\pmcmc.py:22, in particlemcmc(data, pmcmc_params, pf_params, rng, req_jit, adaptive)
#      20 def particlemcmc(data,pmcmc_params,pf_params,rng,req_jit = False,adaptive = False):
#      21     p_filter = pmcmc_validator(data,pmcmc_params,pf_params,rng,req_jit)
# ---> 22     param_set,LL,MLE_Particles,MLE_Observations = particlemcmc_internal(data,
#      23                           num_particles = pf_params['num_particles'],
#      24                           model_dim = pf_params['model_dim'],
#      25                           init_params = pmcmc_params['init_params'],
#      26                           prior = pmcmc_params['prior'],
#      27                           iterations = pmcmc_params['iterations'],
#      28                           rng = rng,
#      29                           p_filter=p_filter,
#      30                           adaptive=adaptive,
#      31                           init_cov= pmcmc_params['init_cov'],
#      32                           burn_in = pmcmc_params['burn_in']
#      33                           )
#      35     return {'accepted_params':param_set,'Log Likelihood':LL,'MLE_particle_dist':MLE_Particles,'MLE_particle_observations':MLE_Observations}
#
# File c:\Users\avery\PMCMC\examples\..\pmcmc.py:97, in particlemcmc_internal(data, num_particles, model_dim, init_params, init_cov, prior, iterations, rng, p_filter, adaptive, burn_in)
#      90 '''Generating the next proposal using the cholesky decompostion'''
#      93 # z = rng.standard_normal((len(theta[:,iter-1])))
#      94 # L = cholesky((2.38**2/len(theta[:,iter - 1])) * cov)
#      95 #theta_prop = theta[:,iter - 1] + L @ z
# ---> 97 theta_prop = rng.multivariate_normal(theta[:,iter - 1],(2.38**2/len(theta[:,iter - 1])) * cov)
#      99 LL_new = prior(theta_prop)
#     101 if(np.isfinite(LL_new)):
#
# File _generator.pyx:3718, in numpy.random._generator.Generator.multivariate_normal()
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File c:\Users\avery\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
burn_in = 15000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10796.162110411546
# The Maximum Likelihood Estimate is [ 0.07091561  0.07485034 -1.0844954   0.4523181   0.01603679] w/ LL of -10796.162110411546

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5811.363266208734
# Root Mean Squared Error for beta 0.031590589252167296

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
