# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('..\\data_sets\\ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('..\\data_sets\\ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('..\\data_sets\\ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0]),n = np.array([r]))
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

gamma = 1/14
R = 50
lam = 1/10
mean_ou = -1.
sig = 0.2


T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':0.1,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 12.004798499983735

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10804.889904743704
# Root Mean Squared Error for the Data 5811.587473838714

# %%
pmcmc_rng = np.random.default_rng(20)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

(gamma,sig,mean_ou,lam,1/R)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':100_000,
                'init_params':np.array([0.1,0.1,-0.5,0.05,0.01]),
                'prior':seir_prior,
                'init_cov': 0.1 * np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1000}

pf_params = {'num_particles':1000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.2| Log-Likelihood: -10835.124550083188| Proposal [ 0.07328268  0.14626174 -0.52101357  0.03686223  0.05828452]
# iteration: 20| Acceptance rate: 0.15| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 30| Acceptance rate: 0.1| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 40| Acceptance rate: 0.075| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 50| Acceptance rate: 0.06| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 60| Acceptance rate: 0.05| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 70| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 80| Acceptance rate: 0.0375| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 90| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 100| Acceptance rate: 0.03| Log-Likelihood: -10823.45318019897| Proposal [ 0.06949341  0.08978875 -0.55401676  0.02936761  0.02571187]
# iteration: 110| Acceptance rate: 0.03636363636363636| Log-Likelihood: -10813.947212366418| Proposal [ 0.07545283  0.16068019 -0.50157416  0.04159155  0.01380211]
# iteration: 120| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10813.947212366418| Proposal [ 0.07545283  0.16068019 -0.50157416  0.04159155  0.01380211]
# iteration: 130| Acceptance rate: 0.038461538461538464| Log-Likelihood: -10810.491079909169| Proposal [ 0.07912131  0.15358474 -0.58028951  0.03349173  0.02239567]
# iteration: 140| Acceptance rate: 0.03571428571428571| Log-Likelihood: -10810.491079909169| Proposal [ 0.07912131  0.15358474 -0.58028951  0.03349173  0.02239567]
# iteration: 150| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10810.491079909169| Proposal [ 0.07912131  0.15358474 -0.58028951  0.03349173  0.02239567]
# iteration: 160| Acceptance rate: 0.0375| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 170| Acceptance rate: 0.03529411764705882| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 180| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 190| Acceptance rate: 0.031578947368421054| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 200| Acceptance rate: 0.03| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 210| Acceptance rate: 0.02857142857142857| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 220| Acceptance rate: 0.02727272727272727| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 230| Acceptance rate: 0.02608695652173913| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 240| Acceptance rate: 0.025| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 250| Acceptance rate: 0.024| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 260| Acceptance rate: 0.023076923076923078| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 270| Acceptance rate: 0.022222222222222223| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 280| Acceptance rate: 0.02142857142857143| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 290| Acceptance rate: 0.020689655172413793| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 300| Acceptance rate: 0.02| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 310| Acceptance rate: 0.01935483870967742| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 320| Acceptance rate: 0.01875| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 330| Acceptance rate: 0.01818181818181818| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 340| Acceptance rate: 0.01764705882352941| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 350| Acceptance rate: 0.017142857142857144| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 360| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 370| Acceptance rate: 0.016216216216216217| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 380| Acceptance rate: 0.015789473684210527| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 390| Acceptance rate: 0.015384615384615385| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 400| Acceptance rate: 0.015| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 410| Acceptance rate: 0.014634146341463415| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 420| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 430| Acceptance rate: 0.013953488372093023| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 440| Acceptance rate: 0.013636363636363636| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 450| Acceptance rate: 0.013333333333333334| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 460| Acceptance rate: 0.013043478260869565| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 470| Acceptance rate: 0.01276595744680851| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 480| Acceptance rate: 0.0125| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 490| Acceptance rate: 0.012244897959183673| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 500| Acceptance rate: 0.012| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 510| Acceptance rate: 0.011764705882352941| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 520| Acceptance rate: 0.011538461538461539| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 530| Acceptance rate: 0.011320754716981131| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 540| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 550| Acceptance rate: 0.01090909090909091| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 560| Acceptance rate: 0.010714285714285714| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 570| Acceptance rate: 0.010526315789473684| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 580| Acceptance rate: 0.010344827586206896| Log-Likelihood: -10806.767491523864| Proposal [ 0.075656    0.16627267 -0.52534044  0.02836402  0.01812515]
# iteration: 590| Acceptance rate: 0.011864406779661017| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 600| Acceptance rate: 0.011666666666666667| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 610| Acceptance rate: 0.011475409836065573| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 620| Acceptance rate: 0.01129032258064516| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 630| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 640| Acceptance rate: 0.0109375| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 650| Acceptance rate: 0.010769230769230769| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 660| Acceptance rate: 0.010606060606060607| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 670| Acceptance rate: 0.010447761194029851| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 680| Acceptance rate: 0.010294117647058823| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 690| Acceptance rate: 0.010144927536231883| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 700| Acceptance rate: 0.01| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 710| Acceptance rate: 0.009859154929577466| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 720| Acceptance rate: 0.009722222222222222| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 730| Acceptance rate: 0.009589041095890411| Log-Likelihood: -10806.674519386144| Proposal [ 0.07417336  0.15537471 -0.51948059  0.00735181  0.02455205]
# iteration: 740| Acceptance rate: 0.010810810810810811| Log-Likelihood: -10805.252036598797| Proposal [ 0.0725723   0.15547803 -0.50257105  0.02538643  0.01501731]
# iteration: 750| Acceptance rate: 0.010666666666666666| Log-Likelihood: -10805.252036598797| Proposal [ 0.0725723   0.15547803 -0.50257105  0.02538643  0.01501731]
# iteration: 760| Acceptance rate: 0.010526315789473684| Log-Likelihood: -10805.252036598797| Proposal [ 0.0725723   0.15547803 -0.50257105  0.02538643  0.01501731]
# iteration: 770| Acceptance rate: 0.011688311688311689| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 780| Acceptance rate: 0.011538461538461539| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 790| Acceptance rate: 0.01139240506329114| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 800| Acceptance rate: 0.01125| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 810| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 820| Acceptance rate: 0.01097560975609756| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 830| Acceptance rate: 0.010843373493975903| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 840| Acceptance rate: 0.010714285714285714| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 850| Acceptance rate: 0.010588235294117647| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 860| Acceptance rate: 0.010465116279069767| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 870| Acceptance rate: 0.010344827586206896| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 880| Acceptance rate: 0.010227272727272727| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 890| Acceptance rate: 0.010112359550561797| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 900| Acceptance rate: 0.01| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 910| Acceptance rate: 0.00989010989010989| Log-Likelihood: -10804.478223485059| Proposal [ 0.06987403  0.17997056 -0.50203476  0.00579505  0.0146571 ]
# iteration: 920| Acceptance rate: 0.010869565217391304| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 930| Acceptance rate: 0.010752688172043012| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 940| Acceptance rate: 0.010638297872340425| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 950| Acceptance rate: 0.010526315789473684| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 960| Acceptance rate: 0.010416666666666666| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 970| Acceptance rate: 0.010309278350515464| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 980| Acceptance rate: 0.01020408163265306| Log-Likelihood: -10805.092337886925| Proposal [ 0.07544303  0.21270973 -0.48115726  0.0045543   0.01342925]
# iteration: 990| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10804.44046674571| Proposal [ 0.07364726  0.17503953 -0.49112054  0.01609918  0.01937003]
# iteration: 1000| Acceptance rate: 0.011| Log-Likelihood: -10804.44046674571| Proposal [ 0.07364726  0.17503953 -0.49112054  0.01609918  0.01937003]
# iteration: 1010| Acceptance rate: 0.01287128712871287| Log-Likelihood: -10803.883782663072| Proposal [ 0.07513353  0.17529948 -0.48671393  0.01499718  0.01744468]
# iteration: 1020| Acceptance rate: 0.0196078431372549| Log-Likelihood: -10802.930647881683| Proposal [ 0.07550853  0.17335527 -0.47629076  0.01116119  0.01416861]
# iteration: 1030| Acceptance rate: 0.02233009708737864| Log-Likelihood: -10802.632043061074| Proposal [ 0.07580578  0.17359224 -0.47794224  0.01101758  0.01498751]
# iteration: 1040| Acceptance rate: 0.028846153846153848| Log-Likelihood: -10804.093790570598| Proposal [ 0.07578355  0.17417518 -0.47849137  0.01157703  0.0148086 ]
# iteration: 1050| Acceptance rate: 0.0380952380952381| Log-Likelihood: -10804.390926554393| Proposal [ 0.07559144  0.17500519 -0.48030155  0.01260921  0.01492041]
# iteration: 1060| Acceptance rate: 0.04150943396226415| Log-Likelihood: -10803.551194113103| Proposal [ 0.0755335   0.17498833 -0.48024864  0.01261861  0.01487747]
# iteration: 1070| Acceptance rate: 0.04392523364485981| Log-Likelihood: -10802.71619705544| Proposal [ 0.07547344  0.17525758 -0.48074657  0.01291275  0.01488078]
# iteration: 1080| Acceptance rate: 0.04722222222222222| Log-Likelihood: -10804.039732893092| Proposal [ 0.0754153   0.17543547 -0.48110801  0.01313248  0.01488613]
# iteration: 1090| Acceptance rate: 0.05504587155963303| Log-Likelihood: -10804.280547240365| Proposal [ 0.0753861   0.17544301 -0.4811513   0.01316151  0.01488831]
# iteration: 1100| Acceptance rate: 0.06181818181818182| Log-Likelihood: -10803.222005283515| Proposal [ 0.07545835  0.17517831 -0.48065432  0.01285575  0.01489086]
# iteration: 1110| Acceptance rate: 0.062162162162162166| Log-Likelihood: -10803.073263036378| Proposal [ 0.07546161  0.17513623 -0.48059022  0.01281296  0.01489478]
# iteration: 1120| Acceptance rate: 0.06785714285714285| Log-Likelihood: -10803.210620170252| Proposal [ 0.07544966  0.17514134 -0.48061511  0.01282773  0.01489765]
# iteration: 1130| Acceptance rate: 0.07256637168141593| Log-Likelihood: -10804.172158354746| Proposal [ 0.07548562  0.17501221 -0.48036894  0.0126763   0.01489782]
# iteration: 1140| Acceptance rate: 0.07719298245614035| Log-Likelihood: -10803.583805380633| Proposal [ 0.07546459  0.17503912 -0.48044068  0.012719    0.01490184]
# iteration: 1150| Acceptance rate: 0.08347826086956522| Log-Likelihood: -10803.183171026194| Proposal [ 0.07547929  0.17499387 -0.48034955  0.01266446  0.01490046]
# iteration: 1160| Acceptance rate: 0.08706896551724137| Log-Likelihood: -10803.50575946055| Proposal [ 0.0754804   0.17500423 -0.4803633   0.01267328  0.01489931]
# iteration: 1170| Acceptance rate: 0.08974358974358974| Log-Likelihood: -10803.308902542472| Proposal [ 0.07553984  0.17475581 -0.47990757  0.01239008  0.01490357]
# iteration: 1180| Acceptance rate: 0.0923728813559322| Log-Likelihood: -10802.68423937407| Proposal [ 0.07556331  0.17467634 -0.47975412  0.01229586  0.01490324]
# iteration: 1190| Acceptance rate: 0.09831932773109243| Log-Likelihood: -10803.526023290297| Proposal [ 0.07564947  0.1743332  -0.47911778  0.01190142  0.01490765]
# iteration: 1200| Acceptance rate: 0.105| Log-Likelihood: -10804.57069384417| Proposal [ 0.07550824  0.17489783 -0.48016364  0.01255005  0.01490012]
# iteration: 1210| Acceptance rate: 0.10909090909090909| Log-Likelihood: -10802.689599493218| Proposal [ 0.07561604  0.17447399 -0.47937527  0.01206176  0.01490502]
# iteration: 1220| Acceptance rate: 0.11147540983606558| Log-Likelihood: -10804.24363470076| Proposal [ 0.07561391  0.17447852 -0.47938553  0.0120677   0.01490538]
# iteration: 1230| Acceptance rate: 0.11463414634146342| Log-Likelihood: -10802.805622904216| Proposal [ 0.0755996   0.17453362 -0.4794886   0.01213144  0.01490488]
# iteration: 1240| Acceptance rate: 0.11854838709677419| Log-Likelihood: -10803.27965704761| Proposal [ 0.07556624  0.17466937 -0.47973898  0.01228692  0.01490283]
# iteration: 1250| Acceptance rate: 0.1208| Log-Likelihood: -10803.250866624752| Proposal [ 0.07553859  0.17477654 -0.47993908  0.0124107   0.01490178]
# iteration: 1260| Acceptance rate: 0.1253968253968254| Log-Likelihood: -10803.612811754308| Proposal [ 0.07557861  0.17462064 -0.47964837  0.01223079  0.0149034 ]
# iteration: 1270| Acceptance rate: 0.12755905511811025| Log-Likelihood: -10803.571182451382| Proposal [ 0.07569805  0.17415187 -0.47877575  0.01169052  0.0149086 ]
# iteration: 1280| Acceptance rate: 0.13203125| Log-Likelihood: -10803.04715113427| Proposal [ 0.07577918  0.17383363 -0.4781833   0.01132371  0.01491212]
# iteration: 1290| Acceptance rate: 0.13333333333333333| Log-Likelihood: -10802.934921514285| Proposal [ 0.07574556  0.17396566 -0.478429    0.01147586  0.01491063]
# iteration: 1300| Acceptance rate: 0.1376923076923077| Log-Likelihood: -10803.846876078904| Proposal [ 0.07554891  0.17473805 -0.47986656  0.01236593  0.01490202]
# iteration: 1310| Acceptance rate: 0.14045801526717558| Log-Likelihood: -10801.935080548345| Proposal [ 0.07503478  0.17675694 -0.48362433  0.01469252  0.01487955]
# iteration: 1320| Acceptance rate: 0.1409090909090909| Log-Likelihood: -10802.759099719715| Proposal [ 0.07492672  0.17718176 -0.48441485  0.01518198  0.01487478]
# iteration: 1330| Acceptance rate: 0.1443609022556391| Log-Likelihood: -10803.804961057136| Proposal [ 0.07562262  0.17444828 -0.47932737  0.01203206  0.01490528]
# iteration: 1340| Acceptance rate: 0.14626865671641792| Log-Likelihood: -10804.342732970581| Proposal [ 0.07353079  0.18266423 -0.49461897  0.02149982  0.01481368]
# iteration: 1350| Acceptance rate: 0.1474074074074074| Log-Likelihood: -10803.453549741304| Proposal [ 0.07404767  0.18063397 -0.49084029  0.01916025  0.01483632]
# iteration: 1360| Acceptance rate: 0.15| Log-Likelihood: -10805.354588175616| Proposal [ 0.07310707  0.18432843 -0.49771639  0.02341757  0.01479512]
# iteration: 1370| Acceptance rate: 0.15255474452554746| Log-Likelihood: -10804.162228759313| Proposal [ 0.07389837  0.18122049 -0.49193188  0.0198361   0.01482978]
# iteration: 1380| Acceptance rate: 0.15579710144927536| Log-Likelihood: -10804.136605176695| Proposal [ 0.07449881  0.17886206 -0.4875424   0.01711836  0.01485608]
# iteration: 1390| Acceptance rate: 0.15755395683453238| Log-Likelihood: -10803.037033642737| Proposal [ 0.07431246  0.17959402 -0.4889047   0.01796183  0.01484792]
# iteration: 1400| Acceptance rate: 0.16071428571428573| Log-Likelihood: -10804.349359418795| Proposal [ 0.07531059  0.17567336 -0.48160771  0.01344389  0.01489167]
# iteration: 1410| Acceptance rate: 0.1624113475177305| Log-Likelihood: -10803.755031721194| Proposal [ 0.07466982  0.17819008 -0.48629183  0.01634406  0.0148636 ]
# iteration: 1420| Acceptance rate: 0.16267605633802817| Log-Likelihood: -10802.395724172346| Proposal [ 0.07418021  0.18011344 -0.48987147  0.0185604   0.01484213]
# iteration: 1430| Acceptance rate: 0.16433566433566432| Log-Likelihood: -10802.786160115984| Proposal [ 0.07444371  0.17907842 -0.48794513  0.01736771  0.01485368]
# iteration: 1440| Acceptance rate: 0.16458333333333333| Log-Likelihood: -10802.737598146114| Proposal [ 0.07452088  0.17877529 -0.48738094  0.0170184   0.01485706]
# iteration: 1450| Acceptance rate: 0.16413793103448276| Log-Likelihood: -10801.643611141111| Proposal [ 0.07442642  0.17914633 -0.48807152  0.01744596  0.01485292]
# iteration: 1460| Acceptance rate: 0.16575342465753426| Log-Likelihood: -10803.021510064045| Proposal [ 0.07476886  0.17780115 -0.48556794  0.01589586  0.01486793]
# iteration: 1470| Acceptance rate: 0.16938775510204082| Log-Likelihood: -10804.520712954061| Proposal [ 0.07558449  0.17459733 -0.47960512  0.01220397  0.01490369]
# iteration: 1480| Acceptance rate: 0.17297297297297298| Log-Likelihood: -10803.830571810502| Proposal [ 0.07617438  0.17228013 -0.47529247  0.00953378  0.01492956]
# iteration: 1490| Acceptance rate: 0.1738255033557047| Log-Likelihood: -10802.853585883624| Proposal [ 0.07484829  0.17748922 -0.48498735  0.0155364   0.01487141]
# iteration: 1500| Acceptance rate: 0.17533333333333334| Log-Likelihood: -10802.811410227365| Proposal [ 0.07375412  0.18178726 -0.49298665  0.02048919  0.01482343]
# iteration: 1510| Acceptance rate: 0.17682119205298014| Log-Likelihood: -10803.41145257767| Proposal [ 0.07470846  0.17803849 -0.48600963  0.01616934  0.01486528]
# iteration: 1520| Acceptance rate: 0.17828947368421053| Log-Likelihood: -10805.519053946318| Proposal [ 0.07217527  0.18798917 -0.50452933  0.02763588  0.0147542 ]
# iteration: 1530| Acceptance rate: 0.18104575163398692| Log-Likelihood: -10803.27696578933| Proposal [ 0.07479004  0.17771804 -0.48541323  0.01580008  0.01486886]
# iteration: 1540| Acceptance rate: 0.18376623376623377| Log-Likelihood: -10803.627293924348| Proposal [ 0.07471975  0.17799414 -0.4859271   0.01611824  0.01486577]
# iteration: 1550| Acceptance rate: 0.18451612903225806| Log-Likelihood: -10802.069810400371| Proposal [ 0.07442993  0.17913258 -0.48804589  0.0174301   0.01485307]
# iteration: 1560| Acceptance rate: 0.1858974358974359| Log-Likelihood: -10803.997246948862| Proposal [ 0.07395671  0.18099147 -0.49150556  0.01957217  0.01483231]
# iteration: 1570| Acceptance rate: 0.18726114649681527| Log-Likelihood: -10804.553945138592| Proposal [ 0.07297759  0.18483762 -0.49866381  0.02400422  0.01478938]
# iteration: 1580| Acceptance rate: 0.18924050632911393| Log-Likelihood: -10804.244563024035| Proposal [ 0.07309459  0.18437804 -0.49780846  0.02347463  0.01479451]
# iteration: 1590| Acceptance rate: 0.189937106918239| Log-Likelihood: -10804.42295379417| Proposal [ 0.07336741  0.18330634 -0.49581387  0.02223967  0.01480647]
# iteration: 1600| Acceptance rate: 0.193125| Log-Likelihood: -10805.095014391301| Proposal [ 0.07484766  0.17749163 -0.48499186  0.01553919  0.01487139]
# iteration: 1610| Acceptance rate: 0.1968944099378882| Log-Likelihood: -10803.046586972147| Proposal [ 0.07539464  0.17534304 -0.48099301  0.01306328  0.01489537]
# iteration: 1620| Acceptance rate: 0.2006172839506173| Log-Likelihood: -10803.312378071616| Proposal [ 0.07578228  0.17382032 -0.478159    0.01130859  0.01491237]
# iteration: 1630| Acceptance rate: 0.2| Log-Likelihood: -10803.313143023797| Proposal [ 0.07554388  0.17475679 -0.47990191  0.01238772  0.01490191]
# iteration: 1640| Acceptance rate: 0.20182926829268294| Log-Likelihood: -10802.772397949448| Proposal [ 0.0746329   0.17833528 -0.486562    0.01651134  0.01486197]
# iteration: 1650| Acceptance rate: 0.20242424242424242| Log-Likelihood: -10804.753238312536| Proposal [ 0.07193649  0.18892725 -0.5062752   0.02871685  0.01474372]
# iteration: 1660| Acceptance rate: 0.20481927710843373| Log-Likelihood: -10802.92614587661| Proposal [ 0.07444888  0.17905815 -0.48790737  0.01734433  0.0148539 ]
# iteration: 1670| Acceptance rate: 0.20838323353293414| Log-Likelihood: -10803.804225435646| Proposal [ 0.07576075  0.17390487 -0.47831639  0.01140604  0.01491143]
# iteration: 1680| Acceptance rate: 0.20952380952380953| Log-Likelihood: -10803.708365991466| Proposal [ 0.07506273  0.17664683 -0.48341956  0.01456569  0.01488082]
# iteration: 1690| Acceptance rate: 0.21124260355029587| Log-Likelihood: -10802.877386330956| Proposal [ 0.07557946  0.17461704 -0.47964182  0.01222668  0.01490348]
# iteration: 1700| Acceptance rate: 0.2111764705882353| Log-Likelihood: -10802.838661962247| Proposal [ 0.07464045  0.17830562 -0.48650681  0.01647717  0.0148623 ]
# iteration: 1710| Acceptance rate: 0.21052631578947367| Log-Likelihood: -10803.046920482422| Proposal [ 0.07424606  0.17985486 -0.48939016  0.01826241  0.014845  ]
# iteration: 1720| Acceptance rate: 0.21104651162790697| Log-Likelihood: -10804.487985746626| Proposal [ 0.07580871  0.17371649 -0.47796578  0.01118895  0.01491353]
# iteration: 1730| Acceptance rate: 0.21329479768786128| Log-Likelihood: -10803.74924477929| Proposal [ 0.07630285  0.17177544 -0.4743532   0.00895221  0.0149352 ]
# iteration: 1740| Acceptance rate: 0.2132183908045977| Log-Likelihood: -10802.611212208878| Proposal [ 0.07449995  0.17885753 -0.48753398  0.01711315  0.01485614]
# iteration: 1750| Acceptance rate: 0.21371428571428572| Log-Likelihood: -10803.403861405472| Proposal [ 0.07419396  0.18005953 -0.48977107  0.01849825  0.01484272]
# iteration: 1760| Acceptance rate: 0.21420454545454545| Log-Likelihood: -10804.446863183555| Proposal [ 0.0736138   0.18233851 -0.49401259  0.0211244   0.01481728]
# iteration: 1770| Acceptance rate: 0.21525423728813559| Log-Likelihood: -10802.544196597293| Proposal [ 0.07512589  0.17639875 -0.48295784  0.01427981  0.01488358]
# iteration: 1780| Acceptance rate: 0.2140449438202247| Log-Likelihood: -10802.544196597293| Proposal [ 0.07512589  0.17639875 -0.48295784  0.01427981  0.01488358]
# iteration: 1790| Acceptance rate: 0.21620111731843575| Log-Likelihood: -10803.620096592498| Proposal [ 0.07430563  0.17962088 -0.48895468  0.01799278  0.01484761]
# iteration: 1800| Acceptance rate: 0.21722222222222223| Log-Likelihood: -10803.96457618583| Proposal [ 0.07412045  0.18034828 -0.49030848  0.01883099  0.01483949]
# iteration: 1810| Acceptance rate: 0.21823204419889503| Log-Likelihood: -10804.979198499106| Proposal [ 0.07380682  0.18158031 -0.49260146  0.0202507   0.01482574]
# iteration: 1820| Acceptance rate: 0.22142857142857142| Log-Likelihood: -10804.125203188933| Proposal [ 0.0759385   0.17320666 -0.47701691  0.01060146  0.01491922]
# iteration: 1830| Acceptance rate: 0.22349726775956283| Log-Likelihood: -10802.900301945943| Proposal [ 0.07451883  0.17878337 -0.48739597  0.0170277   0.01485696]
# iteration: 1840| Acceptance rate: 0.22282608695652173| Log-Likelihood: -10804.354566698583| Proposal [ 0.07416386  0.18017775 -0.48999111  0.01863449  0.0148414 ]
# iteration: 1850| Acceptance rate: 0.22486486486486487| Log-Likelihood: -10803.66430711327| Proposal [ 0.0746101   0.17842484 -0.48672868  0.01661455  0.01486097]
# iteration: 1860| Acceptance rate: 0.2252688172043011| Log-Likelihood: -10803.495574256329| Proposal [ 0.07575109  0.17394283 -0.47838702  0.01144977  0.014911  ]
# iteration: 1870| Acceptance rate: 0.22780748663101605| Log-Likelihood: -10804.12731535426| Proposal [ 0.07481763  0.17760965 -0.4852115   0.01567518  0.01487007]
# iteration: 1880| Acceptance rate: 0.22872340425531915| Log-Likelihood: -10803.51428600624| Proposal [ 0.07619821  0.17218645 -0.47511815  0.00942584  0.01493061]
# iteration: 1890| Acceptance rate: 0.23227513227513227| Log-Likelihood: -10803.031028694655| Proposal [ 0.075984    0.17302791 -0.47668423  0.01039548  0.01492122]
# iteration: 1900| Acceptance rate: 0.23473684210526316| Log-Likelihood: -10803.66889512471| Proposal [ 0.07454911  0.17866445 -0.48717463  0.01689065  0.01485829]
# iteration: 1910| Acceptance rate: 0.2356020942408377| Log-Likelihood: -10802.54902619764| Proposal [ 0.07446354  0.17900056 -0.48780018  0.01727797  0.01485454]
# iteration: 1920| Acceptance rate: 0.2375| Log-Likelihood: -10802.329956549976| Proposal [ 0.07549429  0.17495159 -0.48026446  0.0126122   0.01489974]
# iteration: 1930| Acceptance rate: 0.23989637305699482| Log-Likelihood: -10804.709407109616| Proposal [ 0.07480176  0.17767201 -0.48532755  0.01574703  0.01486937]
# iteration: 1940| Acceptance rate: 0.2422680412371134| Log-Likelihood: -10803.993377096722| Proposal [ 0.07573798  0.17399435 -0.4784829   0.01150913  0.01491043]
# iteration: 1950| Acceptance rate: 0.2441025641025641| Log-Likelihood: -10804.364583610184| Proposal [ 0.07591249  0.17330883 -0.47720705  0.01071919  0.01491808]
# iteration: 1960| Acceptance rate: 0.24693877551020407| Log-Likelihood: -10803.378987911821| Proposal [ 0.07546569  0.17506396 -0.48047357  0.01274165  0.01489848]
# iteration: 1970| Acceptance rate: 0.24619289340101522| Log-Likelihood: -10802.313599834295| Proposal [ 0.07570816  0.17411151 -0.47870092  0.01164411  0.01490911]
# iteration: 1980| Acceptance rate: 0.2474747474747475| Log-Likelihood: -10804.179460675818| Proposal [ 0.07528654  0.1757677  -0.48178336  0.01355262  0.01489063]
# iteration: 1990| Acceptance rate: 0.25025125628140704| Log-Likelihood: -10802.191946406254| Proposal [ 0.07442272  0.17916094 -0.48809865  0.01746276  0.01485275]
# iteration: 2000| Acceptance rate: 0.251| Log-Likelihood: -10803.079033035085| Proposal [ 0.07526061  0.17586955 -0.4819729   0.01366997  0.01488949]
# iteration: 2010| Acceptance rate: 0.25422885572139303| Log-Likelihood: -10802.202788425213| Proposal [ 0.07518198  0.17617844 -0.48254779  0.01402592  0.01488604]
# iteration: 2020| Acceptance rate: 0.25445544554455446| Log-Likelihood: -10802.865883398974| Proposal [ 0.07501712  0.17682601 -0.48375305  0.01477217  0.01487882]
# iteration: 2030| Acceptance rate: 0.2541871921182266| Log-Likelihood: -10802.298992723378| Proposal [ 0.07505414  0.17668059 -0.48348238  0.01460458  0.01488044]
# iteration: 2040| Acceptance rate: 0.25588235294117645| Log-Likelihood: -10803.561072321249| Proposal [ 0.07471     0.17803244 -0.48599836  0.01616235  0.01486534]
# iteration: 2050| Acceptance rate: 0.2570731707317073| Log-Likelihood: -10803.9125294046| Proposal [ 0.07502116  0.17681021 -0.48372354  0.01475387  0.01487898]
# iteration: 2060| Acceptance rate: 0.25776699029126215| Log-Likelihood: -10802.420987994374| Proposal [ 0.07457308  0.17857029 -0.48699937  0.01678213  0.01485934]
# iteration: 2070| Acceptance rate: 0.2613526570048309| Log-Likelihood: -10804.542578468241| Proposal [ 0.07364502  0.18221586 -0.49378431  0.02098307  0.01481864]
# iteration: 2080| Acceptance rate: 0.2620192307692308| Log-Likelihood: -10804.170586206124| Proposal [ 0.0745147   0.17879962 -0.4874262   0.01704641  0.01485678]
# iteration: 2090| Acceptance rate: 0.2641148325358852| Log-Likelihood: -10804.14664055874| Proposal [ 0.07435017  0.1794459  -0.48862902  0.01779115  0.01484957]
# iteration: 2100| Acceptance rate: 0.2661904761904762| Log-Likelihood: -10804.100900086441| Proposal [ 0.07423328  0.17990505 -0.48948359  0.01832026  0.01484444]
# iteration: 2110| Acceptance rate: 0.2672985781990521| Log-Likelihood: -10803.737395065635| Proposal [ 0.07412782  0.18031939 -0.49025468  0.01879767  0.01483981]
# iteration: 2120| Acceptance rate: 0.26933962264150946| Log-Likelihood: -10804.100463087312| Proposal [ 0.07421759  0.17996672 -0.48959831  0.01839128  0.01484375]
# iteration: 2130| Acceptance rate: 0.2708920187793427| Log-Likelihood: -10803.142335348468| Proposal [ 0.07554432  0.17475515 -0.47989877  0.01238574  0.01490192]
# iteration: 2140| Acceptance rate: 0.2714953271028037| Log-Likelihood: -10802.635574695632| Proposal [ 0.07445556  0.17903193 -0.48785853  0.01731408  0.01485418]
# iteration: 2150| Acceptance rate: 0.2725581395348837| Log-Likelihood: -10802.671096006743| Proposal [ 0.07447401  0.17895949 -0.48772371  0.01723061  0.01485499]
# iteration: 2160| Acceptance rate: 0.2712962962962963| Log-Likelihood: -10802.671096006743| Proposal [ 0.07447401  0.17895949 -0.48772371  0.01723061  0.01485499]
# iteration: 2170| Acceptance rate: 0.2732718894009217| Log-Likelihood: -10804.78528672546| Proposal [ 0.07432413  0.1795482  -0.48881942  0.01790902  0.01484842]
# iteration: 2180| Acceptance rate: 0.27522935779816515| Log-Likelihood: -10801.876514311758| Proposal [ 0.07432855  0.17953088 -0.48878714  0.01788902  0.01484861]
# iteration: 2190| Acceptance rate: 0.27579908675799086| Log-Likelihood: -10803.06499997242| Proposal [ 0.07448123  0.17893107 -0.48767085  0.01719788  0.01485531]
# iteration: 2200| Acceptance rate: 0.2768181818181818| Log-Likelihood: -10804.496003749533| Proposal [ 0.07326247  0.18371852 -0.49658105  0.0227147   0.01480188]
# iteration: 2210| Acceptance rate: 0.27692307692307694| Log-Likelihood: -10803.94023907036| Proposal [ 0.07343989  0.18302147 -0.49528382  0.02191152  0.01480966]
# iteration: 2220| Acceptance rate: 0.2756756756756757| Log-Likelihood: -10803.94023907036| Proposal [ 0.07343989  0.18302147 -0.49528382  0.02191152  0.01480966]
# iteration: 2230| Acceptance rate: 0.27757847533632285| Log-Likelihood: -10804.551260440636| Proposal [ 0.07374682  0.18181597 -0.49304007  0.02052225  0.01482311]
# iteration: 2240| Acceptance rate: 0.2794642857142857| Log-Likelihood: -10803.97252346422| Proposal [ 0.07361519  0.18233304 -0.49400237  0.02111804  0.01481733]
# iteration: 2250| Acceptance rate: 0.28044444444444444| Log-Likelihood: -10805.817478165942| Proposal [ 0.07290147  0.18513658 -0.49922024  0.02434874  0.01478604]
# iteration: 2260| Acceptance rate: 0.2809734513274336| Log-Likelihood: -10804.395105864103| Proposal [ 0.07304816  0.18456036 -0.49814781  0.02368474  0.01479247]
# iteration: 2270| Acceptance rate: 0.28105726872246695| Log-Likelihood: -10803.19491849032| Proposal [ 0.07446254  0.17900459 -0.48780758  0.0172825   0.01485448]
# iteration: 2280| Acceptance rate: 0.28157894736842104| Log-Likelihood: -10804.616578141504| Proposal [ 0.07346012  0.18294214 -0.49513604  0.02181999  0.01481054]
# iteration: 2290| Acceptance rate: 0.28296943231441046| Log-Likelihood: -10804.097957513342| Proposal [ 0.0733915   0.18321161 -0.49563764  0.02213058  0.01480754]
# iteration: 2300| Acceptance rate: 0.2847826086956522| Log-Likelihood: -10802.854029687893| Proposal [ 0.07438747  0.17929947 -0.48835638  0.01762227  0.01485119]
# iteration: 2310| Acceptance rate: 0.28484848484848485| Log-Likelihood: -10802.961616340985| Proposal [ 0.0760242   0.17287024 -0.47639055  0.01021356  0.01492295]
# iteration: 2320| Acceptance rate: 0.28448275862068967| Log-Likelihood: -10803.325229239386| Proposal [ 0.07580567  0.17372863 -0.47798815  0.01120273  0.01491337]
# iteration: 2330| Acceptance rate: 0.2849785407725322| Log-Likelihood: -10802.558090182813| Proposal [ 0.0744164   0.17918581 -0.48814488  0.01749135  0.01485246]
# iteration: 2340| Acceptance rate: 0.28376068376068375| Log-Likelihood: -10802.558090182813| Proposal [ 0.0744164   0.17918581 -0.48814488  0.01749135  0.01485246]
# iteration: 2350| Acceptance rate: 0.2846808510638298| Log-Likelihood: -10802.824257166547| Proposal [ 0.07406453  0.180568   -0.49071738  0.01908414  0.01483704]
# iteration: 2360| Acceptance rate: 0.2847457627118644| Log-Likelihood: -10804.051680825814| Proposal [ 0.07414931  0.18023497 -0.49009754  0.01870037  0.01484075]
# iteration: 2370| Acceptance rate: 0.28607594936708863| Log-Likelihood: -10802.715797368332| Proposal [ 0.07474285  0.1779035  -0.48575826  0.01601365  0.01486677]
# iteration: 2380| Acceptance rate: 0.2857142857142857| Log-Likelihood: -10803.164933326552| Proposal [ 0.07318899  0.18400714 -0.49711821  0.02304728  0.01479865]
# iteration: 2390| Acceptance rate: 0.28577405857740584| Log-Likelihood: -10804.656633289414| Proposal [ 0.0737278   0.18189065 -0.49317908  0.02060833  0.01482228]
# iteration: 2400| Acceptance rate: 0.28625| Log-Likelihood: -10804.218600883883| Proposal [ 0.07402179  0.18073589 -0.49102984  0.01927761  0.01483516]
# iteration: 2410| Acceptance rate: 0.287551867219917| Log-Likelihood: -10803.834516109193| Proposal [ 0.07540502  0.17530243 -0.48091726  0.01301632  0.0148958 ]
# iteration: 2420| Acceptance rate: 0.2884297520661157| Log-Likelihood: -10802.865510147081| Proposal [ 0.07391634  0.18115009 -0.49180072  0.0197549   0.01483054]
# iteration: 2430| Acceptance rate: 0.28847736625514403| Log-Likelihood: -10802.951895497194| Proposal [ 0.07423844  0.17988488 -0.48944597  0.01829694  0.01484466]
# iteration: 2440| Acceptance rate: 0.2889344262295082| Log-Likelihood: -10802.284535988074| Proposal [ 0.07491648  0.17722147 -0.48448892  0.01522775  0.01487439]
# iteration: 2450| Acceptance rate: 0.2897959183673469| Log-Likelihood: -10803.862645147567| Proposal [ 0.07351162  0.18273986 -0.49475957  0.02158689  0.01481279]
# iteration: 2460| Acceptance rate: 0.2910569105691057| Log-Likelihood: -10802.962677997299| Proposal [ 0.07552068  0.17484814 -0.48007174  0.01249282  0.01490087]
# iteration: 2470| Acceptance rate: 0.291497975708502| Log-Likelihood: -10803.559743243806| Proposal [ 0.07536069  0.17547658 -0.48124138  0.01321701  0.01489386]
# iteration: 2480| Acceptance rate: 0.2923387096774194| Log-Likelihood: -10802.95334753577| Proposal [ 0.07427883  0.17972619 -0.48915064  0.01811409  0.01484643]
# iteration: 2490| Acceptance rate: 0.2927710843373494| Log-Likelihood: -10803.100618160986| Proposal [ 0.0746066   0.17843873 -0.48675442  0.01663044  0.0148608 ]
# iteration: 2500| Acceptance rate: 0.2936| Log-Likelihood: -10803.686515127976| Proposal [ 0.07563132  0.17441352 -0.47926284  0.01199197  0.01490572]
# iteration: 2510| Acceptance rate: 0.2948207171314741| Log-Likelihood: -10803.843462003279| Proposal [ 0.07553221  0.17480282 -0.47998737  0.01244056  0.01490138]
# iteration: 2520| Acceptance rate: 0.29484126984126985| Log-Likelihood: -10802.234881808687| Proposal [ 0.07540714  0.17529409 -0.48090174  0.0130067   0.01489589]
# iteration: 2530| Acceptance rate: 0.29604743083003954| Log-Likelihood: -10804.300556498403| Proposal [ 0.07598773  0.17301345 -0.47665709  0.01037859  0.01492135]
# iteration: 2540| Acceptance rate: 0.2980314960629921| Log-Likelihood: -10802.792944845358| Proposal [ 0.07435882  0.17941203 -0.48856586  0.01775198  0.01484993]
# iteration: 2550| Acceptance rate: 0.29764705882352943| Log-Likelihood: -10803.212530687095| Proposal [ 0.07543504  0.17518455 -0.48069786  0.01288049  0.01489712]
# iteration: 2560| Acceptance rate: 0.2984375| Log-Likelihood: -10803.471948391129| Proposal [ 0.07576029  0.17390709 -0.47832006  0.01140813  0.01491135]
# iteration: 2570| Acceptance rate: 0.29961089494163423| Log-Likelihood: -10805.897076027444| Proposal [ 0.07632076  0.17170565 -0.47422271  0.0088712   0.01493591]
# iteration: 2580| Acceptance rate: 0.30077519379844964| Log-Likelihood: -10804.085796429303| Proposal [ 0.07483891  0.17752633 -0.48505617  0.01557893  0.01487097]
# iteration: 2590| Acceptance rate: 0.3007722007722008| Log-Likelihood: -10804.431835167494| Proposal [ 0.07646982  0.17112008 -0.47313294  0.00819651  0.01494245]
# iteration: 2600| Acceptance rate: 0.30115384615384616| Log-Likelihood: -10803.60458955936| Proposal [ 0.07598668  0.17301788 -0.47666513  0.01038355  0.01492128]
# iteration: 2610| Acceptance rate: 0.30114942528735633| Log-Likelihood: -10804.118466507207| Proposal [ 0.07522406  0.17601356 -0.48224056  0.01383561  0.01488784]
# iteration: 2620| Acceptance rate: 0.300763358778626| Log-Likelihood: -10802.66933483717| Proposal [ 0.07553394  0.1747964  -0.47997513  0.01243293  0.01490142]
# iteration: 2630| Acceptance rate: 0.30076045627376424| Log-Likelihood: -10803.23913967508| Proposal [ 0.07529481  0.17573561 -0.48172329  0.01351535  0.01489095]
# iteration: 2640| Acceptance rate: 0.30037878787878786| Log-Likelihood: -10803.48638616524| Proposal [ 0.0755714   0.17464914 -0.47970118  0.01226333  0.01490307]
# iteration: 2650| Acceptance rate: 0.3011320754716981| Log-Likelihood: -10803.794293148218| Proposal [ 0.07590955  0.17332102 -0.47722916  0.01073271  0.01491788]
# iteration: 2660| Acceptance rate: 0.3022556390977444| Log-Likelihood: -10806.209479437262| Proposal [ 0.07612175  0.17248795 -0.47567824  0.0097723   0.01492713]
# iteration: 2670| Acceptance rate: 0.30337078651685395| Log-Likelihood: -10803.386440838834| Proposal [ 0.07598578  0.17302243 -0.47667264  0.01038788  0.01492112]
# iteration: 2680| Acceptance rate: 0.3041044776119403| Log-Likelihood: -10805.659956732172| Proposal [ 0.0760833   0.17263932 -0.47595963  0.00994641  0.0149254 ]
# iteration: 2690| Acceptance rate: 0.30520446096654275| Log-Likelihood: -10802.61536397608| Proposal [ 0.07537806  0.1754088  -0.48111485  0.01313858  0.01489458]
# iteration: 2700| Acceptance rate: 0.3062962962962963| Log-Likelihood: -10803.939032962815| Proposal [ 0.07496009  0.17705068 -0.48417061  0.01503056  0.01487624]
# iteration: 2710| Acceptance rate: 0.3081180811808118| Log-Likelihood: -10803.75618547551| Proposal [ 0.0750161   0.17683342 -0.48376369  0.0147778   0.01487838]
# iteration: 2720| Acceptance rate: 0.30919117647058825| Log-Likelihood: -10804.132391440678| Proposal [ 0.07441246  0.17920166 -0.48817414  0.01750946  0.01485226]
# iteration: 2730| Acceptance rate: 0.31025641025641026| Log-Likelihood: -10802.532083532418| Proposal [ 0.07486257  0.17743056 -0.48488064  0.01547117  0.01487235]
# iteration: 2740| Acceptance rate: 0.3094890510948905| Log-Likelihood: -10802.00537257466| Proposal [ 0.07466426  0.17821039 -0.48633125  0.01636908  0.01486356]
# iteration: 2750| Acceptance rate: 0.31018181818181817| Log-Likelihood: -10803.020035049933| Proposal [ 0.07593424  0.17322012 -0.47704503  0.01061988  0.01491942]
# iteration: 2760| Acceptance rate: 0.3090579710144927| Log-Likelihood: -10803.020035049933| Proposal [ 0.07593424  0.17322012 -0.47704503  0.01061988  0.01491942]
# iteration: 2770| Acceptance rate: 0.30938628158844766| Log-Likelihood: -10802.342464659296| Proposal [ 0.07525756  0.17588706 -0.48200035  0.01368534  0.01488871]
# iteration: 2780| Acceptance rate: 0.30899280575539567| Log-Likelihood: -10802.418994191561| Proposal [ 0.07451738  0.17879336 -0.48741059  0.01703552  0.0148564 ]
# iteration: 2790| Acceptance rate: 0.3100358422939068| Log-Likelihood: -10803.90076755463| Proposal [ 0.07588923  0.17340861 -0.47738488  0.01082675  0.01491606]
# iteration: 2800| Acceptance rate: 0.3107142857142857| Log-Likelihood: -10803.975751701118| Proposal [ 0.07454472  0.17867693 -0.48720238  0.01690936  0.01485868]
# iteration: 2810| Acceptance rate: 0.31209964412811386| Log-Likelihood: -10804.294506999164| Proposal [ 0.07582892  0.17363916 -0.47781995  0.01109808  0.01491418]
# iteration: 2820| Acceptance rate: 0.31382978723404253| Log-Likelihood: -10803.368411818376| Proposal [ 0.07544301  0.17515232 -0.48063875  0.01284419  0.01489758]
# iteration: 2830| Acceptance rate: 0.3137809187279152| Log-Likelihood: -10802.045175181049| Proposal [ 0.07482368  0.17759295 -0.48517384  0.01564978  0.0148695 ]
# iteration: 2840| Acceptance rate: 0.3144366197183099| Log-Likelihood: -10804.147600354223| Proposal [ 0.07369159  0.18203655 -0.49344732  0.02077344  0.01482028]
# iteration: 2850| Acceptance rate: 0.3154385964912281| Log-Likelihood: -10804.387932800806| Proposal [ 0.0754059   0.1752996  -0.48091145  0.01301258  0.01489577]
# iteration: 2860| Acceptance rate: 0.3153846153846154| Log-Likelihood: -10804.353069672652| Proposal [ 0.0749149   0.17723443 -0.48450673  0.01523679  0.01487352]
# iteration: 2870| Acceptance rate: 0.31637630662020905| Log-Likelihood: -10803.3962522292| Proposal [ 0.07438361  0.17932254 -0.488392    0.01764206  0.0148501 ]
# iteration: 2880| Acceptance rate: 0.3170138888888889| Log-Likelihood: -10803.513826875265| Proposal [ 0.07559897  0.17453543 -0.47949462  0.01213708  0.01490493]
# iteration: 2890| Acceptance rate: 0.3166089965397924| Log-Likelihood: -10803.673182845532| Proposal [ 0.07569901  0.1741411  -0.47876197  0.01168386  0.01490947]
# iteration: 2900| Acceptance rate: 0.31689655172413794| Log-Likelihood: -10803.387695276206| Proposal [ 0.0740561   0.18061702 -0.49079377  0.01912672  0.01483479]
# iteration: 2910| Acceptance rate: 0.31752577319587627| Log-Likelihood: -10803.777992479385| Proposal [ 0.07502546  0.17679523 -0.48369394  0.01473503  0.01487896]
# iteration: 2920| Acceptance rate: 0.3178082191780822| Log-Likelihood: -10803.848906207471| Proposal [ 0.07537649  0.17541043 -0.48112215  0.01314447  0.01489505]
# iteration: 2930| Acceptance rate: 0.3194539249146758| Log-Likelihood: -10803.116052361924| Proposal [ 0.07440731  0.17921354 -0.48820408  0.01753054  0.01485303]
# iteration: 2940| Acceptance rate: 0.319047619047619| Log-Likelihood: -10802.670779664499| Proposal [ 0.07501483  0.17682989 -0.4837651   0.01478124  0.01487933]
# iteration: 2950| Acceptance rate: 0.32033898305084746| Log-Likelihood: -10803.478494923922| Proposal [ 0.07534234  0.17547318 -0.48130602  0.01328001  0.01490204]
# iteration: 2960| Acceptance rate: 0.3199324324324324| Log-Likelihood: -10804.599153101219| Proposal [ 0.07600641  0.17286337 -0.47644992  0.01027368  0.0149313 ]
# iteration: 2970| Acceptance rate: 0.32087542087542087| Log-Likelihood: -10802.679576433151| Proposal [ 0.07506789  0.1765051  -0.48327     0.01451008  0.0148955 ]
# iteration: 2980| Acceptance rate: 0.3208053691275168| Log-Likelihood: -10802.500732379018| Proposal [ 0.07525962  0.17579877 -0.4819114   0.01365465  0.01489834]
# ...
# iteration: 99030| Acceptance rate: 0.3376552559830354| Log-Likelihood: -10799.64968736021| Proposal [ 0.07174153  0.1293039  -1.07481972  0.29474609  0.01223011]
# iteration: 99040| Acceptance rate: 0.3376514539579968| Log-Likelihood: -10798.065295838578| Proposal [ 0.06869133  0.13747496 -1.12875195  0.40202761  0.01432044]
# iteration: 99050| Acceptance rate: 0.3376476527006562| Log-Likelihood: -10798.444029030543| Proposal [ 0.06927387  0.13391153 -1.14199001  0.37280607  0.01832113]
# iteration: 99060| Acceptance rate: 0.33761356753482735| Log-Likelihood: -10798.444029030543| Proposal [ 0.06927387  0.13391153 -1.14199001  0.37280607  0.01832113]
# iteration: 99070| Acceptance rate: 0.33760977086908245| Log-Likelihood: -10797.124246236157| Proposal [ 0.07104752  0.09825965 -1.07982887  0.26911219  0.01479354]
# iteration: 99080| Acceptance rate: 0.3375857892612031| Log-Likelihood: -10798.980871571861| Proposal [ 0.06881189  0.16786    -1.13783154  0.24941921  0.01666764]
# iteration: 99090| Acceptance rate: 0.3375819961651024| Log-Likelihood: -10798.564561223227| Proposal [ 0.06993758  0.15154585 -1.07906781  0.4732192   0.01878911]
# iteration: 99100| Acceptance rate: 0.3375782038345106| Log-Likelihood: -10799.297802221148| Proposal [ 0.07134234  0.08845998 -1.01730304  0.4293819   0.01494138]
# iteration: 99110| Acceptance rate: 0.33758450206840884| Log-Likelihood: -10799.144031243435| Proposal [ 0.0676904   0.16538238 -1.14597133  0.3609385   0.01456994]
# iteration: 99120| Acceptance rate: 0.3376008878127522| Log-Likelihood: -10799.979410714515| Proposal [ 0.06795486  0.11571241 -1.18809773  0.23742737  0.01363383]
# iteration: 99130| Acceptance rate: 0.3376071824876425| Log-Likelihood: -10798.41696954799| Proposal [ 0.06949047  0.13384905 -1.11525803  0.2056364   0.013815  ]
# iteration: 99140| Acceptance rate: 0.3375731289086141| Log-Likelihood: -10798.41696954799| Proposal [ 0.06949047  0.13384905 -1.11525803  0.2056364   0.013815  ]
# iteration: 99150| Acceptance rate: 0.33757942511346445| Log-Likelihood: -10796.708169610096| Proposal [ 0.07003914  0.07355615 -1.09296576  0.27880293  0.01822687]
# iteration: 99160| Acceptance rate: 0.3375857200484066| Log-Likelihood: -10798.607778008392| Proposal [ 0.07138149  0.14512195 -1.08993724  0.41424268  0.01790481]
# iteration: 99170| Acceptance rate: 0.3375718463244933| Log-Likelihood: -10798.439269556762| Proposal [ 0.06919992  0.07773495 -1.14207412  0.38531557  0.01580393]
# iteration: 99180| Acceptance rate: 0.33756805807622503| Log-Likelihood: -10797.061450816042| Proposal [ 0.07135539  0.05468952 -1.06873564  0.47460597  0.0162771 ]
# iteration: 99190| Acceptance rate: 0.33755418893033573| Log-Likelihood: -10799.498949114335| Proposal [ 0.07051328  0.05107249 -1.10280864  0.47674327  0.01664279]
# iteration: 99200| Acceptance rate: 0.33754032258064515| Log-Likelihood: -10796.892625967219| Proposal [ 0.07067812  0.09209642 -1.09978848  0.33863045  0.01785839]
# iteration: 99210| Acceptance rate: 0.33751637939723816| Log-Likelihood: -10796.875000592667| Proposal [ 0.07121267  0.0778855  -1.05738293  0.42454712  0.01848424]
# iteration: 99220| Acceptance rate: 0.33752267687966137| Log-Likelihood: -10801.013191538792| Proposal [ 0.07092321  0.144442   -0.98414642  0.40647991  0.01525711]
# iteration: 99230| Acceptance rate: 0.33752897309281465| Log-Likelihood: -10797.493246753247| Proposal [ 0.07179784  0.05791359 -1.03946858  0.26489023  0.01663412]
# iteration: 99240| Acceptance rate: 0.3375151148730351| Log-Likelihood: -10797.160202049929| Proposal [ 0.07127753  0.06954229 -1.04868531  0.26797172  0.01633052]
# iteration: 99250| Acceptance rate: 0.33748110831234257| Log-Likelihood: -10797.160202049929| Proposal [ 0.07127753  0.06954229 -1.04868531  0.26797172  0.01633052]
# iteration: 99260| Acceptance rate: 0.3374974813620794| Log-Likelihood: -10798.374067329354| Proposal [ 0.06959479  0.09347369 -1.12363899  0.41404413  0.01976064]
# iteration: 99270| Acceptance rate: 0.33749370403948825| Log-Likelihood: -10800.598102455688| Proposal [ 0.07196757  0.05479079 -1.01748306  0.4746416   0.02250449]
# iteration: 99280| Acceptance rate: 0.33751007252215953| Log-Likelihood: -10798.501984556235| Proposal [ 0.07003896  0.04708614 -1.07834963  0.40483411  0.02078259]
# iteration: 99290| Acceptance rate: 0.33753650921542955| Log-Likelihood: -10799.003453115234| Proposal [ 0.06993772  0.11298377 -1.05415633  0.21721302  0.01844418]
# iteration: 99300| Acceptance rate: 0.33756294058408864| Log-Likelihood: -10799.05048022484| Proposal [ 0.07053864  0.09106813 -1.10879638  0.32049928  0.02163559]
# iteration: 99310| Acceptance rate: 0.3375591581915215| Log-Likelihood: -10801.90129705718| Proposal [ 0.07038513  0.07383576 -1.00468562  0.38536961  0.01988965]
# iteration: 99320| Acceptance rate: 0.337565445026178| Log-Likelihood: -10797.70188813025| Proposal [ 0.07071276  0.09538441 -1.05301015  0.47601424  0.01458171]
# iteration: 99330| Acceptance rate: 0.33754152823920264| Log-Likelihood: -10797.063504296702| Proposal [ 0.06984909  0.11126334 -1.10534352  0.43165989  0.01683245]
# iteration: 99340| Acceptance rate: 0.3375176162673646| Log-Likelihood: -10797.967315686888| Proposal [ 0.06993946  0.14104999 -1.12148241  0.46627308  0.01961048]
# iteration: 99350| Acceptance rate: 0.3375138399597383| Log-Likelihood: -10801.703308964721| Proposal [ 0.06963988  0.10394764 -1.15637328  0.43728039  0.02454322]
# iteration: 99360| Acceptance rate: 0.3375100644122383| Log-Likelihood: -10798.870151361798| Proposal [ 0.06863327  0.08726168 -1.12806962  0.09412844  0.01739593]
# iteration: 99370| Acceptance rate: 0.3375062896246352| Log-Likelihood: -10799.083670829246| Proposal [ 0.07000125  0.09299151 -1.06449945  0.22305221  0.01341591]
# iteration: 99380| Acceptance rate: 0.3375125779834977| Log-Likelihood: -10798.966003781117| Proposal [ 0.07266903  0.10526512 -1.03635052  0.29091819  0.01438162]
# iteration: 99390| Acceptance rate: 0.33749874232820204| Log-Likelihood: -10798.58831396925| Proposal [ 0.07130501  0.08591695 -1.05496299  0.16819237  0.01821367]
# iteration: 99400| Acceptance rate: 0.3374849094567404| Log-Likelihood: -10801.195879749346| Proposal [ 0.07208428  0.04086719 -1.01804186  0.07907409  0.01323322]
# iteration: 99410| Acceptance rate: 0.33748113871843877| Log-Likelihood: -10800.436077729575| Proposal [ 0.07091658  0.07074394 -1.00758213  0.27772477  0.01528165]
# iteration: 99420| Acceptance rate: 0.3374773687386844| Log-Likelihood: -10799.392536835168| Proposal [ 0.06919501  0.15857721 -1.05909212  0.48140227  0.01734445]
# iteration: 99430| Acceptance rate: 0.33746354219048574| Log-Likelihood: -10799.305326247586| Proposal [ 0.06896621  0.20507932 -1.09821631  0.36440777  0.01504481]
# iteration: 99440| Acceptance rate: 0.3374597747385358| Log-Likelihood: -10797.555821605605| Proposal [ 0.06941075  0.10546061 -1.11853263  0.22461271  0.01741779]
# iteration: 99450| Acceptance rate: 0.33748617395676217| Log-Likelihood: -10801.507849826427| Proposal [ 0.06985748  0.09673567 -1.05062     0.02198595  0.01920384]
# iteration: 99460| Acceptance rate: 0.3374924592801126| Log-Likelihood: -10798.16864502938| Proposal [ 0.07061     0.12969809 -1.08408849  0.39836502  0.01659857]
# iteration: 99470| Acceptance rate: 0.337478636774907| Log-Likelihood: -10798.539416062358| Proposal [ 0.06940668  0.0931337  -1.14110862  0.20897424  0.01596817]
# iteration: 99480| Acceptance rate: 0.337464817048653| Log-Likelihood: -10797.469119144615| Proposal [ 0.06914769  0.0927995  -1.09694662  0.42510654  0.01791585]
# iteration: 99490| Acceptance rate: 0.33747110262337926| Log-Likelihood: -10798.184149638177| Proposal [ 0.06989643  0.10915243 -1.09823143  0.37678684  0.01334127]
# iteration: 99500| Acceptance rate: 0.3374773869346734| Log-Likelihood: -10799.143103704404| Proposal [ 0.07084169  0.0778608  -1.0945939   0.4383049   0.02302506]
# iteration: 99510| Acceptance rate: 0.3374836699829163| Log-Likelihood: -10798.771216785412| Proposal [ 0.06971341  0.13308094 -1.04767599  0.44505871  0.01871775]
# iteration: 99520| Acceptance rate: 0.3374899517684887| Log-Likelihood: -10798.68223686552| Proposal [ 0.07189432  0.0833519  -1.04929427  0.25621428  0.01362793]
# iteration: 99530| Acceptance rate: 0.33751632673565757| Log-Likelihood: -10798.99209256686| Proposal [ 0.06840298  0.17089129 -1.11415337  0.34242877  0.01679522]
# iteration: 99540| Acceptance rate: 0.3375025115531445| Log-Likelihood: -10801.32199462801| Proposal [ 0.06858758  0.09121786 -1.07642411  0.09050301  0.01373454]
# iteration: 99550| Acceptance rate: 0.3374886991461577| Log-Likelihood: -10799.019964738378| Proposal [ 0.06830842  0.11567385 -1.09814165  0.1789471   0.0160814 ]
# iteration: 99560| Acceptance rate: 0.3374949779027722| Log-Likelihood: -10798.064566723617| Proposal [ 0.06921757  0.16139417 -1.09325683  0.44977923  0.01658737]
# iteration: 99570| Acceptance rate: 0.3374912122125138| Log-Likelihood: -10798.88266394275| Proposal [ 0.06940067  0.1563079  -1.11972619  0.35196976  0.01976006]
# iteration: 99580| Acceptance rate: 0.337507531632858| Log-Likelihood: -10798.62510900307| Proposal [ 0.07159191  0.10969967 -1.05891785  0.31856468  0.01269765]
# iteration: 99590| Acceptance rate: 0.3375138066070891| Log-Likelihood: -10797.176592702419| Proposal [ 0.07036538  0.08572586 -1.06830213  0.34373864  0.01533292]
# iteration: 99600| Acceptance rate: 0.33752008032128517| Log-Likelihood: -10797.821381645414| Proposal [ 0.07113319  0.1280171  -1.08851673  0.46210074  0.01497183]
# iteration: 99610| Acceptance rate: 0.3375062744704347| Log-Likelihood: -10800.21534568523| Proposal [ 0.0695362   0.0832812  -1.11557786  0.04247918  0.0177338 ]
# iteration: 99620| Acceptance rate: 0.3375125476811885| Log-Likelihood: -10798.635513415446| Proposal [ 0.06927571  0.11090227 -1.14422645  0.24763259  0.01975866]
# iteration: 99630| Acceptance rate: 0.3375288567700492| Log-Likelihood: -10801.23114302458| Proposal [ 0.06564766  0.16924446 -1.19910553  0.12562961  0.01537108]
# iteration: 99640| Acceptance rate: 0.33751505419510236| Log-Likelihood: -10802.9527918344| Proposal [ 0.06531823  0.22149754 -1.16883621  0.3406474   0.01957334]
# iteration: 99650| Acceptance rate: 0.33753135975915705| Log-Likelihood: -10799.563158645744| Proposal [ 0.07209565  0.14362566 -1.03812909  0.3413255   0.01478848]
# iteration: 99660| Acceptance rate: 0.3375175597029902| Log-Likelihood: -10799.48266994896| Proposal [ 0.06828372  0.16376131 -1.15461836  0.20393221  0.01697878]
# iteration: 99670| Acceptance rate: 0.3375338617437544| Log-Likelihood: -10798.123977949394| Proposal [ 0.06938405  0.12738669 -1.14198677  0.18004763  0.01639368]
# iteration: 99680| Acceptance rate: 0.33752006420545744| Log-Likelihood: -10799.342976396028| Proposal [ 0.06816736  0.1201537  -1.13089278  0.19887616  0.0190962 ]
# iteration: 99690| Acceptance rate: 0.33752633162804696| Log-Likelihood: -10798.111607595323| Proposal [ 0.07024365  0.10750197 -1.12230743  0.34536038  0.01901885]
# iteration: 99700| Acceptance rate: 0.33752256770310934| Log-Likelihood: -10797.454214556774| Proposal [ 0.06975416  0.09622465 -1.08970485  0.33785907  0.01451878]
# iteration: 99710| Acceptance rate: 0.33750877544880153| Log-Likelihood: -10798.188438320421| Proposal [ 0.07070476  0.085293   -1.06913865  0.40152907  0.01408758]
# iteration: 99720| Acceptance rate: 0.33750501403931005| Log-Likelihood: -10797.939906251342| Proposal [ 0.06977061  0.11196522 -1.0993468   0.42325938  0.01559347]
# iteration: 99730| Acceptance rate: 0.3374912263110398| Log-Likelihood: -10798.370156112089| Proposal [ 0.06982645  0.15625853 -1.08411837  0.49989499  0.01351589]
# iteration: 99740| Acceptance rate: 0.33748746741527974| Log-Likelihood: -10798.26625377515| Proposal [ 0.06965281  0.10936777 -1.1307492   0.49272184  0.01900115]
# iteration: 99750| Acceptance rate: 0.33748370927318294| Log-Likelihood: -10798.663378730756| Proposal [ 0.07138574  0.04980642 -1.02199153  0.29614715  0.01880941]
# iteration: 99760| Acceptance rate: 0.33748997594226143| Log-Likelihood: -10798.014761939141| Proposal [ 0.07112965  0.07183176 -1.04468599  0.28478771  0.01477309]
# iteration: 99770| Acceptance rate: 0.3374661721960509| Log-Likelihood: -10797.345381840263| Proposal [ 0.07122194  0.05298667 -1.04257037  0.29503237  0.01505118]
# iteration: 99780| Acceptance rate: 0.33749248346362| Log-Likelihood: -10798.340214473104| Proposal [ 0.07052589  0.11689793 -1.04280349  0.39689418  0.0154712 ]
# iteration: 99790| Acceptance rate: 0.3374987473694759| Log-Likelihood: -10798.578921883405| Proposal [ 0.06920175  0.13595647 -1.07765269  0.42069888  0.01438561]
# iteration: 99800| Acceptance rate: 0.3375050100200401| Log-Likelihood: -10797.4243545328| Proposal [ 0.07102939  0.05169314 -1.05923783  0.24115182  0.01837347]
# iteration: 99810| Acceptance rate: 0.3375212904518585| Log-Likelihood: -10799.92389325037| Proposal [ 0.07241236  0.00185017 -1.06252475  0.26859201  0.01925299]
# iteration: 99820| Acceptance rate: 0.33751753155680225| Log-Likelihood: -10798.02419719704| Proposal [ 0.07137053  0.06007385 -1.07852503  0.49446386  0.01381657]
# iteration: 99830| Acceptance rate: 0.33751377341480515| Log-Likelihood: -10799.936420712853| Proposal [ 0.07045225  0.07768173 -1.12972131  0.28027536  0.02232233]
# iteration: 99840| Acceptance rate: 0.33752003205128206| Log-Likelihood: -10802.581986315572| Proposal [ 0.0676405   0.10645123 -1.12835124  0.0320473   0.0205288 ]
# iteration: 99850| Acceptance rate: 0.33752628943415125| Log-Likelihood: -10798.957321720978| Proposal [ 0.06922394  0.08524072 -1.13675363  0.31274281  0.02002694]
# iteration: 99860| Acceptance rate: 0.33752253154416184| Log-Likelihood: -10799.08440928493| Proposal [ 0.07120957  0.02180412 -1.04219874  0.41114716  0.02142605]
# iteration: 99870| Acceptance rate: 0.3375187744067287| Log-Likelihood: -10798.574640618544| Proposal [ 0.07211752  0.04001376 -1.05014693  0.460259    0.02118829]
# iteration: 99880| Acceptance rate: 0.337515018021626| Log-Likelihood: -10797.533208624636| Proposal [ 0.07133013  0.04969342 -1.04274855  0.47452993  0.01416825]
# iteration: 99890| Acceptance rate: 0.3375112623886275| Log-Likelihood: -10797.917738651633| Proposal [ 0.06970184  0.10098189 -1.10846331  0.4394774   0.01358719]
# iteration: 99900| Acceptance rate: 0.3375075075075075| Log-Likelihood: -10797.161918553542| Proposal [ 0.07072009  0.03541286 -1.05215798  0.29870458  0.01573983]
# iteration: 99910| Acceptance rate: 0.33749374436993296| Log-Likelihood: -10797.885515160984| Proposal [ 0.06866403  0.11223566 -1.10793525  0.37509707  0.01499088]
# iteration: 99920| Acceptance rate: 0.33746997598078465| Log-Likelihood: -10799.627185993151| Proposal [ 0.07007057  0.05980867 -1.03736582  0.42620535  0.01550752]
# iteration: 99930| Acceptance rate: 0.33747623336335436| Log-Likelihood: -10800.392065443797| Proposal [ 0.07089403  0.06235931 -1.04580802  0.41574005  0.02512102]
# iteration: 99940| Acceptance rate: 0.3374924954972984| Log-Likelihood: -10799.411463273707| Proposal [ 0.0695432   0.08084941 -1.10209343  0.39605666  0.02298306]
# iteration: 99950| Acceptance rate: 0.3374987493746873| Log-Likelihood: -10801.58596341328| Proposal [ 0.06788408  0.12738652 -1.17923097  0.26637788  0.02418995]
# iteration: 99960| Acceptance rate: 0.3375050020008003| Log-Likelihood: -10800.680819550966| Proposal [ 0.0669748   0.09846906 -1.16018116  0.16544123  0.01917094]
# iteration: 99970| Acceptance rate: 0.3375512653796139| Log-Likelihood: -10800.295264765227| Proposal [ 0.07011287  0.07411552 -1.1339147   0.15020538  0.02058767]
# iteration: 99980| Acceptance rate: 0.3375275055011002| Log-Likelihood: -10797.75112443893| Proposal [ 0.07104908  0.09590375 -1.1005115   0.47117747  0.01426046]
# iteration: 99990| Acceptance rate: 0.3375137513751375| Log-Likelihood: -10798.124176858646| Proposal [ 0.06999823  0.13377861 -1.1007962   0.38800167  0.01833016]
# 5123.111219500017

# %%
burn_in = 15000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10796.162110411546
# The Maximum Likelihood Estimate is [ 0.07091561  0.07485034 -1.0844954   0.4523181   0.01603679] w/ LL of -10796.162110411546

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5811.363266208734
# Root Mean Squared Error for beta 0.031590589252167296

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
