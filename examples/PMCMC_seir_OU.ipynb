# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('..\\data_sets\\ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('..\\data_sets\\ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('..\\data_sets\\ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0]),n = np.array([r]))
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

gamma = 1/14
R = 50
lam = 1/20
mean_ou = -1.1
sig = 0.2


T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':1_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 8.728154300013557

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10863.944277535322
# Root Mean Squared Error for the Data 5027.303251465589

# %%
pmcmc_rng = np.random.default_rng(20)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

(gamma,sig,mean_ou,lam,1/R)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':50_000,
                'init_params':np.array([0.1,0.1,-0.7,0.01,0.01]),
                'prior':seir_prior,
                'init_cov':  np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1_000}

pf_params = {'num_particles':1000, 
                      'dt':1.,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -17517.104888899925| Proposal [ 0.1   0.1  -0.7   0.01  0.01]
# iteration: 20| Acceptance rate: 0.0| Log-Likelihood: -17517.104888899925| Proposal [ 0.1   0.1  -0.7   0.01  0.01]
# iteration: 30| Acceptance rate: 0.0| Log-Likelihood: -17517.104888899925| Proposal [ 0.1   0.1  -0.7   0.01  0.01]
# iteration: 40| Acceptance rate: 0.025| Log-Likelihood: -11001.734652712614| Proposal [ 0.05807523  0.27313927 -0.64168283  0.11314245  0.12095217]
# iteration: 50| Acceptance rate: 0.02| Log-Likelihood: -11001.734652712614| Proposal [ 0.05807523  0.27313927 -0.64168283  0.11314245  0.12095217]
# iteration: 60| Acceptance rate: 0.05| Log-Likelihood: -10965.758395803972| Proposal [ 0.08593425  0.25515618 -0.54900118  0.01853082  0.2575784 ]
# iteration: 70| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10965.758395803972| Proposal [ 0.08593425  0.25515618 -0.54900118  0.01853082  0.2575784 ]
# iteration: 80| Acceptance rate: 0.0375| Log-Likelihood: -10965.758395803972| Proposal [ 0.08593425  0.25515618 -0.54900118  0.01853082  0.2575784 ]
# iteration: 90| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10965.758395803972| Proposal [ 0.08593425  0.25515618 -0.54900118  0.01853082  0.2575784 ]
# iteration: 100| Acceptance rate: 0.03| Log-Likelihood: -10965.758395803972| Proposal [ 0.08593425  0.25515618 -0.54900118  0.01853082  0.2575784 ]
# iteration: 110| Acceptance rate: 0.03636363636363636| Log-Likelihood: -10964.268268843593| Proposal [ 0.08647234  0.32226207 -0.44762704  0.22629282  0.24329715]
# iteration: 120| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10964.268268843593| Proposal [ 0.08647234  0.32226207 -0.44762704  0.22629282  0.24329715]
# iteration: 130| Acceptance rate: 0.03076923076923077| Log-Likelihood: -10964.268268843593| Proposal [ 0.08647234  0.32226207 -0.44762704  0.22629282  0.24329715]
# iteration: 140| Acceptance rate: 0.02857142857142857| Log-Likelihood: -10964.268268843593| Proposal [ 0.08647234  0.32226207 -0.44762704  0.22629282  0.24329715]
# iteration: 150| Acceptance rate: 0.04| Log-Likelihood: -10948.888385206945| Proposal [ 0.07168528  0.43800705 -0.34348653  0.23391985  0.17252344]
# iteration: 160| Acceptance rate: 0.0375| Log-Likelihood: -10948.888385206945| Proposal [ 0.07168528  0.43800705 -0.34348653  0.23391985  0.17252344]
# iteration: 170| Acceptance rate: 0.041176470588235294| Log-Likelihood: -10940.008830237855| Proposal [ 0.08588396  0.57816764 -0.46409752  0.22848394  0.15935564]
# iteration: 180| Acceptance rate: 0.044444444444444446| Log-Likelihood: -10908.412293742977| Proposal [ 0.07585263  0.65823696 -0.36941485  0.35683346  0.07044374]
# iteration: 190| Acceptance rate: 0.042105263157894736| Log-Likelihood: -10908.412293742977| Proposal [ 0.07585263  0.65823696 -0.36941485  0.35683346  0.07044374]
# iteration: 200| Acceptance rate: 0.04| Log-Likelihood: -10908.412293742977| Proposal [ 0.07585263  0.65823696 -0.36941485  0.35683346  0.07044374]
# iteration: 210| Acceptance rate: 0.0380952380952381| Log-Likelihood: -10908.412293742977| Proposal [ 0.07585263  0.65823696 -0.36941485  0.35683346  0.07044374]
# iteration: 220| Acceptance rate: 0.03636363636363636| Log-Likelihood: -10908.412293742977| Proposal [ 0.07585263  0.65823696 -0.36941485  0.35683346  0.07044374]
# iteration: 230| Acceptance rate: 0.0391304347826087| Log-Likelihood: -10908.889016399366| Proposal [ 0.06970559  0.69894256 -0.30697429  0.40985352  0.05234619]
# iteration: 240| Acceptance rate: 0.0375| Log-Likelihood: -10908.889016399366| Proposal [ 0.06970559  0.69894256 -0.30697429  0.40985352  0.05234619]
# iteration: 250| Acceptance rate: 0.04| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 260| Acceptance rate: 0.038461538461538464| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 270| Acceptance rate: 0.037037037037037035| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 280| Acceptance rate: 0.03571428571428571| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 290| Acceptance rate: 0.034482758620689655| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 300| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10907.896928683605| Proposal [ 0.0877243   0.74488566 -0.30525657  0.44005609  0.06761501]
# iteration: 310| Acceptance rate: 0.035483870967741936| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 320| Acceptance rate: 0.034375| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 330| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 340| Acceptance rate: 0.03235294117647059| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 350| Acceptance rate: 0.03142857142857143| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 360| Acceptance rate: 0.030555555555555555| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 370| Acceptance rate: 0.02972972972972973| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 380| Acceptance rate: 0.02894736842105263| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 390| Acceptance rate: 0.028205128205128206| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 400| Acceptance rate: 0.0275| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 410| Acceptance rate: 0.026829268292682926| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 420| Acceptance rate: 0.02619047619047619| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 430| Acceptance rate: 0.02558139534883721| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 440| Acceptance rate: 0.025| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 450| Acceptance rate: 0.024444444444444446| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 460| Acceptance rate: 0.02391304347826087| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 470| Acceptance rate: 0.023404255319148935| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 480| Acceptance rate: 0.022916666666666665| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 490| Acceptance rate: 0.022448979591836733| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 500| Acceptance rate: 0.022| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 510| Acceptance rate: 0.021568627450980392| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 520| Acceptance rate: 0.021153846153846155| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 530| Acceptance rate: 0.020754716981132074| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 540| Acceptance rate: 0.020370370370370372| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 550| Acceptance rate: 0.02| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 560| Acceptance rate: 0.019642857142857142| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 570| Acceptance rate: 0.01929824561403509| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 580| Acceptance rate: 0.01896551724137931| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 590| Acceptance rate: 0.01864406779661017| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 600| Acceptance rate: 0.018333333333333333| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 610| Acceptance rate: 0.018032786885245903| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 620| Acceptance rate: 0.017741935483870968| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 630| Acceptance rate: 0.01746031746031746| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 640| Acceptance rate: 0.0171875| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 650| Acceptance rate: 0.016923076923076923| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 660| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 670| Acceptance rate: 0.016417910447761194| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 680| Acceptance rate: 0.016176470588235296| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 690| Acceptance rate: 0.015942028985507246| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 700| Acceptance rate: 0.015714285714285715| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 710| Acceptance rate: 0.015492957746478873| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 720| Acceptance rate: 0.015277777777777777| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 730| Acceptance rate: 0.015068493150684932| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 740| Acceptance rate: 0.014864864864864866| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 750| Acceptance rate: 0.014666666666666666| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 760| Acceptance rate: 0.014473684210526316| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 770| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 780| Acceptance rate: 0.014102564102564103| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 790| Acceptance rate: 0.013924050632911392| Log-Likelihood: -10874.65611910059| Proposal [ 0.07977529  0.79368742 -0.32320749  0.31134629  0.01450524]
# iteration: 800| Acceptance rate: 0.015| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 810| Acceptance rate: 0.014814814814814815| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 820| Acceptance rate: 0.014634146341463415| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 830| Acceptance rate: 0.014457831325301205| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 840| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 850| Acceptance rate: 0.01411764705882353| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 860| Acceptance rate: 0.013953488372093023| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 870| Acceptance rate: 0.013793103448275862| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 880| Acceptance rate: 0.013636363636363636| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 890| Acceptance rate: 0.01348314606741573| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 900| Acceptance rate: 0.013333333333333334| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 910| Acceptance rate: 0.013186813186813187| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 920| Acceptance rate: 0.013043478260869565| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 930| Acceptance rate: 0.012903225806451613| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 940| Acceptance rate: 0.01276595744680851| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 950| Acceptance rate: 0.01263157894736842| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 960| Acceptance rate: 0.0125| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 970| Acceptance rate: 0.012371134020618556| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 980| Acceptance rate: 0.012244897959183673| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 990| Acceptance rate: 0.012121212121212121| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 1000| Acceptance rate: 0.012| Log-Likelihood: -10874.665618895406| Proposal [ 0.08129795  0.92424538 -0.40578317  0.18791535  0.0160241 ]
# iteration: 1010| Acceptance rate: 0.01485148514851485| Log-Likelihood: -10870.672670642123| Proposal [ 0.0811954   0.62922437 -0.31103455  0.12506532  0.01755858]
# iteration: 1020| Acceptance rate: 0.021568627450980392| Log-Likelihood: -10871.136324388546| Proposal [ 0.07667823  0.63406287 -0.31426545  0.12408874  0.01614778]
# iteration: 1030| Acceptance rate: 0.027184466019417475| Log-Likelihood: -10871.106971172032| Proposal [ 0.07758048  0.63000939 -0.31278951  0.12327948  0.01686419]
# iteration: 1040| Acceptance rate: 0.03461538461538462| Log-Likelihood: -10871.91660192447| Proposal [ 0.07730652  0.6242808  -0.3122859   0.11375322  0.02051439]
# iteration: 1050| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10872.135252692382| Proposal [ 0.07714887  0.62080058 -0.3116122   0.11033103  0.02165099]
# iteration: 1060| Acceptance rate: 0.04716981132075472| Log-Likelihood: -10870.925654647248| Proposal [ 0.07745589  0.62062592 -0.31139668  0.11377131  0.02007688]
# iteration: 1070| Acceptance rate: 0.0514018691588785| Log-Likelihood: -10871.90278722889| Proposal [ 0.07729788  0.62015267 -0.3114216   0.11148882  0.0210566 ]
# iteration: 1080| Acceptance rate: 0.05740740740740741| Log-Likelihood: -10871.06896016181| Proposal [ 0.07751488  0.62180107 -0.31163158  0.11497672  0.01965863]
# iteration: 1090| Acceptance rate: 0.06513761467889909| Log-Likelihood: -10870.868434392114| Proposal [ 0.0775418   0.6214947  -0.31158681  0.11499989  0.01961946]
# iteration: 1100| Acceptance rate: 0.06909090909090909| Log-Likelihood: -10871.055360146336| Proposal [ 0.07763172  0.62250966 -0.31169418  0.11674837  0.01893145]
# iteration: 1110| Acceptance rate: 0.07567567567567568| Log-Likelihood: -10871.018649212145| Proposal [ 0.07812855  0.62766886 -0.31217717  0.12635902  0.01510697]
# iteration: 1120| Acceptance rate: 0.08035714285714286| Log-Likelihood: -10870.977241703178| Proposal [ 0.07791605  0.62538485 -0.31197441  0.12211538  0.01679771]
# iteration: 1130| Acceptance rate: 0.08672566371681416| Log-Likelihood: -10870.813483377624| Proposal [ 0.07796787  0.62578835 -0.31200179  0.12303707  0.01642065]
# iteration: 1140| Acceptance rate: 0.09385964912280702| Log-Likelihood: -10869.672975457148| Proposal [ 0.0778549   0.62466437 -0.31188214  0.12097212  0.01723862]
# iteration: 1150| Acceptance rate: 0.09391304347826086| Log-Likelihood: -10870.363138355948| Proposal [ 0.07779352  0.62405906 -0.31181367  0.1198755   0.01767167]
# iteration: 1160| Acceptance rate: 0.09913793103448276| Log-Likelihood: -10871.106763001193| Proposal [ 0.07785775  0.62465481 -0.31186816  0.12105401  0.01719894]
# iteration: 1170| Acceptance rate: 0.10512820512820513| Log-Likelihood: -10871.197986417941| Proposal [ 0.07771447  0.62319485 -0.31172222  0.11835222  0.01827191]
# iteration: 1180| Acceptance rate: 0.11101694915254237| Log-Likelihood: -10871.085865645688| Proposal [ 0.07746728  0.62079846 -0.31147217  0.11386858  0.02005331]
# iteration: 1190| Acceptance rate: 0.11680672268907563| Log-Likelihood: -10872.107380137637| Proposal [ 0.07733529  0.61950451 -0.31133325  0.11148454  0.02099804]
# iteration: 1200| Acceptance rate: 0.1225| Log-Likelihood: -10871.016707986173| Proposal [ 0.07789982  0.62506052 -0.31191204  0.12180858  0.01689957]
# iteration: 1210| Acceptance rate: 0.1256198347107438| Log-Likelihood: -10870.497252609646| Proposal [ 0.07769244  0.62298693 -0.31170003  0.11796469  0.01842565]
# iteration: 1220| Acceptance rate: 0.13114754098360656| Log-Likelihood: -10873.182863211361| Proposal [ 0.07689587  0.61508526 -0.3108936   0.10324773  0.02427233]
# iteration: 1230| Acceptance rate: 0.13495934959349593| Log-Likelihood: -10872.04807497316| Proposal [ 0.07714335  0.61756069 -0.31114607  0.10783966  0.02244901]
# iteration: 1240| Acceptance rate: 0.13870967741935483| Log-Likelihood: -10873.600316660544| Proposal [ 0.07687824  0.61493704 -0.31087353  0.10297369  0.02438036]
# iteration: 1250| Acceptance rate: 0.1416| Log-Likelihood: -10873.682046770518| Proposal [ 0.07688038  0.61494781 -0.31087434  0.10300574  0.02436696]
# iteration: 1260| Acceptance rate: 0.14761904761904762| Log-Likelihood: -10871.666237305762| Proposal [ 0.07742082  0.62030024 -0.31142219  0.11297225  0.0204079 ]
# iteration: 1270| Acceptance rate: 0.15196850393700786| Log-Likelihood: -10871.818338501447| Proposal [ 0.07803443  0.62636063 -0.31204357  0.12426893  0.01591997]
# iteration: 1280| Acceptance rate: 0.15703125| Log-Likelihood: -10872.084635546777| Proposal [ 0.07724291  0.61856685 -0.3112463   0.10970658  0.02170737]
# iteration: 1290| Acceptance rate: 0.162015503875969| Log-Likelihood: -10871.95526650328| Proposal [ 0.07719455  0.61809074 -0.31119761  0.10881692  0.02206094]
# iteration: 1300| Acceptance rate: 0.16615384615384615| Log-Likelihood: -10870.756464918362| Proposal [ 0.07763532  0.62241776 -0.31164121  0.11691077  0.01884393]
# iteration: 1310| Acceptance rate: 0.17099236641221374| Log-Likelihood: -10871.234395992828| Proposal [ 0.07753684  0.62143232 -0.31154011  0.1150877   0.01956746]
# iteration: 1320| Acceptance rate: 0.175| Log-Likelihood: -10870.681210592718| Proposal [ 0.07757932  0.62189435 -0.31158715  0.11590544  0.01924484]
# iteration: 1330| Acceptance rate: 0.17894736842105263| Log-Likelihood: -10870.880012121983| Proposal [ 0.07754463  0.62151125 -0.31154749  0.11523649  0.01950816]
# iteration: 1340| Acceptance rate: 0.1798507462686567| Log-Likelihood: -10870.120039635627| Proposal [ 0.07748919  0.620932   -0.31148827  0.11418953  0.01992239]
# iteration: 1350| Acceptance rate: 0.18444444444444444| Log-Likelihood: -10871.976380652206| Proposal [ 0.07761956  0.62215259 -0.31161373  0.11653489  0.01898696]
# iteration: 1360| Acceptance rate: 0.18970588235294117| Log-Likelihood: -10871.11065082659| Proposal [ 0.07750393  0.62100296 -0.31149653  0.1143964   0.0198364 ]
# iteration: 1370| Acceptance rate: 0.1927007299270073| Log-Likelihood: -10871.185215424715| Proposal [ 0.07761082  0.62210162 -0.31160799  0.11640495  0.01904036]
# iteration: 1380| Acceptance rate: 0.19710144927536233| Log-Likelihood: -10870.57418226973| Proposal [ 0.07763833  0.6223416  -0.31163372  0.11688022  0.01885022]
# iteration: 1390| Acceptance rate: 0.19928057553956835| Log-Likelihood: -10872.237179131545| Proposal [ 0.0776623   0.622473   -0.3116483   0.11723134  0.01870527]
# iteration: 1400| Acceptance rate: 0.20357142857142857| Log-Likelihood: -10870.862248395179| Proposal [ 0.07800782  0.62554189 -0.31196679  0.12329815  0.01627728]
# iteration: 1410| Acceptance rate: 0.20921985815602837| Log-Likelihood: -10871.337569970554| Proposal [ 0.07782838  0.62406149 -0.31181145  0.12024638  0.01750464]
# iteration: 1420| Acceptance rate: 0.2119718309859155| Log-Likelihood: -10870.321069201758| Proposal [ 0.07799771  0.62572949 -0.31198246  0.12336069  0.01626712]
# iteration: 1430| Acceptance rate: 0.21468531468531468| Log-Likelihood: -10871.472322289808| Proposal [ 0.0777954   0.62410308 -0.31181108  0.11995769  0.01763804]
# iteration: 1440| Acceptance rate: 0.22013888888888888| Log-Likelihood: -10871.983980818948| Proposal [ 0.07832547  0.62830417 -0.31225446  0.12882307  0.01406311]
# iteration: 1450| Acceptance rate: 0.22275862068965518| Log-Likelihood: -10870.7302574065| Proposal [ 0.07818132  0.62711155 -0.31212945  0.12636825  0.01505022]
# iteration: 1460| Acceptance rate: 0.22465753424657534| Log-Likelihood: -10870.579259425995| Proposal [ 0.07796865  0.62544848 -0.31195331  0.12283231  0.01647722]
# iteration: 1470| Acceptance rate: 0.2272108843537415| Log-Likelihood: -10871.075609426314| Proposal [ 0.07815423  0.62708667 -0.3121233   0.12608289  0.01517571]
# iteration: 1480| Acceptance rate: 0.22905405405405405| Log-Likelihood: -10871.448057200067| Proposal [ 0.0781484   0.62665983 -0.31208469  0.12565261  0.01532807]
# iteration: 1490| Acceptance rate: 0.23221476510067113| Log-Likelihood: -10870.152795236514| Proposal [ 0.07809223  0.62565279 -0.31198854  0.12421848  0.01587541]
# iteration: 1500| Acceptance rate: 0.23533333333333334| Log-Likelihood: -10870.59443946342| Proposal [ 0.07822621  0.62424879 -0.31188362  0.12429516  0.01570807]
# iteration: 1510| Acceptance rate: 0.23841059602649006| Log-Likelihood: -10870.587753387284| Proposal [ 0.07822399  0.62494086 -0.31194503  0.12487632  0.01551331]
# iteration: 1520| Acceptance rate: 0.2394736842105263| Log-Likelihood: -10871.068139159748| Proposal [ 0.07814576  0.62469395 -0.31191225  0.12389636  0.01592905]
# iteration: 1530| Acceptance rate: 0.24248366013071895| Log-Likelihood: -10870.813344588405| Proposal [ 0.07815364  0.62436447 -0.31188349  0.12368897  0.01599065]
# iteration: 1540| Acceptance rate: 0.24415584415584415| Log-Likelihood: -10870.696194988768| Proposal [ 0.07810309  0.62400953 -0.31184707  0.12287333  0.01632282]
# iteration: 1550| Acceptance rate: 0.24774193548387097| Log-Likelihood: -10870.158263219997| Proposal [ 0.07830329  0.62394536 -0.31186847  0.12477726  0.01546343]
# iteration: 1560| Acceptance rate: 0.24743589743589745| Log-Likelihood: -10871.764500606587| Proposal [ 0.07861578  0.62233441 -0.31177003  0.12641684  0.0145761 ]
# iteration: 1570| Acceptance rate: 0.25095541401273885| Log-Likelihood: -10871.174449147824| Proposal [ 0.07853809  0.62509069 -0.31199829  0.12809637  0.01408396]
# iteration: 1580| Acceptance rate: 0.25443037974683547| Log-Likelihood: -10872.524356591914| Proposal [ 0.0789748   0.62372869 -0.31194169  0.13115308  0.01258557]
# iteration: 1590| Acceptance rate: 0.2578616352201258| Log-Likelihood: -10871.54649947473| Proposal [ 0.07826982  0.62369104 -0.31183995  0.12423539  0.01568193]
# iteration: 1600| Acceptance rate: 0.26125| Log-Likelihood: -10871.283032956739| Proposal [ 0.07773636  0.62412456 -0.31179827  0.11943608  0.01787281]
# iteration: 1610| Acceptance rate: 0.2639751552795031| Log-Likelihood: -10870.862694557556| Proposal [ 0.07784812  0.62227518 -0.31165394  0.11888869  0.01794341]
# iteration: 1620| Acceptance rate: 0.2654320987654321| Log-Likelihood: -10870.492378373103| Proposal [ 0.07818326  0.62486349 -0.31192594  0.12444752  0.01569712]
# iteration: 1630| Acceptance rate: 0.26809815950920246| Log-Likelihood: -10872.29529572632| Proposal [ 0.07836573  0.62742766 -0.31216412  0.12855235  0.0140985 ]
# iteration: 1640| Acceptance rate: 0.2682926829268293| Log-Likelihood: -10870.593899434007| Proposal [ 0.07792788  0.62575569 -0.31195957  0.12278819  0.01652375]
# iteration: 1650| Acceptance rate: 0.2696969696969697| Log-Likelihood: -10871.882322058853| Proposal [ 0.07816462  0.6269959  -0.31209664  0.12621725  0.01510379]
# iteration: 1660| Acceptance rate: 0.2728915662650602| Log-Likelihood: -10871.667652887612| Proposal [ 0.07805483  0.62554483 -0.31195758  0.12384942  0.01602805]
# iteration: 1670| Acceptance rate: 0.274251497005988| Log-Likelihood: -10870.018676883541| Proposal [ 0.07787321  0.62595057 -0.31196346  0.12245678  0.01668985]
# iteration: 1680| Acceptance rate: 0.2779761904761905| Log-Likelihood: -10872.062631309635| Proposal [ 0.07822404  0.62691689 -0.31209837  0.126726    0.01486839]
# iteration: 1690| Acceptance rate: 0.2804733727810651| Log-Likelihood: -10871.840196856332| Proposal [ 0.07796464  0.62803192 -0.31215347  0.12520942  0.01565254]
# iteration: 1700| Acceptance rate: 0.28294117647058825| Log-Likelihood: -10871.862041422422| Proposal [ 0.07856895  0.62721295 -0.31217542  0.13033828  0.01327815]
# iteration: 1710| Acceptance rate: 0.2847953216374269| Log-Likelihood: -10871.838356355252| Proposal [ 0.07852425  0.62770232 -0.31220984  0.13034465  0.01332126]
# iteration: 1720| Acceptance rate: 0.28604651162790695| Log-Likelihood: -10870.622954745331| Proposal [ 0.0780356   0.62845076 -0.3121971   0.12628749  0.01520861]
# iteration: 1730| Acceptance rate: 0.2884393063583815| Log-Likelihood: -10870.82886216513| Proposal [ 0.07800074  0.62901489 -0.31223924  0.12645696  0.01518569]
# iteration: 1740| Acceptance rate: 0.28908045977011493| Log-Likelihood: -10874.95571535832| Proposal [ 0.07527161  0.63090938 -0.31198333  0.10170023  0.02645256]
# iteration: 1750| Acceptance rate: 0.29028571428571426| Log-Likelihood: -10871.703229678482| Proposal [ 0.07679761  0.62861744 -0.31202343  0.11443051  0.02053531]
# iteration: 1760| Acceptance rate: 0.29147727272727275| Log-Likelihood: -10871.41249724384| Proposal [ 0.0788042   0.62368237 -0.31191726  0.12942702  0.0133552 ]
# iteration: 1770| Acceptance rate: 0.29265536723163843| Log-Likelihood: -10870.67639444168| Proposal [ 0.07779945  0.62874591 -0.31218659  0.12426001  0.01614457]
# iteration: 1780| Acceptance rate: 0.2949438202247191| Log-Likelihood: -10871.94981854441| Proposal [ 0.07839829  0.62655908 -0.31209584  0.12808781  0.01422497]
# iteration: 1790| Acceptance rate: 0.29608938547486036| Log-Likelihood: -10871.451984040461| Proposal [ 0.07734361  0.62947941 -0.312179    0.12049966  0.01789779]
# iteration: 1800| Acceptance rate: 0.29833333333333334| Log-Likelihood: -10870.494748338979| Proposal [ 0.07814869  0.62069847 -0.3115712   0.12036161  0.01713622]
# iteration: 1810| Acceptance rate: 0.30165745856353593| Log-Likelihood: -10869.457887057535| Proposal [ 0.07886238  0.61608438 -0.3112964   0.12310518  0.01547471]
# iteration: 1820| Acceptance rate: 0.30164835164835163| Log-Likelihood: -10870.140652205895| Proposal [ 0.07956118  0.60668998 -0.31062229  0.12137678  0.0153681 ]
# iteration: 1830| Acceptance rate: 0.30327868852459017| Log-Likelihood: -10869.544988723319| Proposal [ 0.08139334  0.56815446 -0.30770046  0.10425488  0.0194244 ]
# iteration: 1840| Acceptance rate: 0.30543478260869567| Log-Likelihood: -10870.737082091124| Proposal [ 0.07975522  0.5896958  -0.30923981  0.10787651  0.01982173]
# iteration: 1850| Acceptance rate: 0.30594594594594593| Log-Likelihood: -10870.999504442649| Proposal [ 0.07928749  0.59660167 -0.30974528  0.10957619  0.01970835]
# iteration: 1860| Acceptance rate: 0.3086021505376344| Log-Likelihood: -10869.86381882441| Proposal [ 0.0826172   0.55906585 -0.30715139  0.10778368  0.01699474]
# iteration: 1870| Acceptance rate: 0.30962566844919787| Log-Likelihood: -10870.239654827226| Proposal [ 0.08104649  0.57341633 -0.30810108  0.105564    0.0193339 ]
# iteration: 1880| Acceptance rate: 0.3101063829787234| Log-Likelihood: -10869.112555586109| Proposal [ 0.08340965  0.5445604  -0.30606468  0.10234947  0.01806847]
# iteration: 1890| Acceptance rate: 0.31216931216931215| Log-Likelihood: -10869.98802993717| Proposal [ 0.0819288   0.57355998 -0.3082564   0.11419747  0.01548171]
# iteration: 1900| Acceptance rate: 0.3136842105263158| Log-Likelihood: -10869.515076842052| Proposal [ 0.08034941  0.58995817 -0.30936829  0.11378404  0.01720278]
# iteration: 1910| Acceptance rate: 0.3157068062827225| Log-Likelihood: -10870.870824114698| Proposal [ 0.08529864  0.51285236 -0.30375123  0.09177669  0.01983651]
# iteration: 1920| Acceptance rate: 0.31666666666666665| Log-Likelihood: -10869.279382030361| Proposal [ 0.08228596  0.56238334 -0.30737134  0.10760436  0.01738529]
# iteration: 1930| Acceptance rate: 0.31865284974093266| Log-Likelihood: -10873.11976655281| Proposal [ 0.08787554  0.48718301 -0.30201962  0.09347686  0.01666965]
# iteration: 1940| Acceptance rate: 0.31958762886597936| Log-Likelihood: -10870.866617617236| Proposal [ 0.0853832   0.52445246 -0.30472126  0.10313325  0.01583631]
# iteration: 1950| Acceptance rate: 0.32051282051282054| Log-Likelihood: -10869.521685958456| Proposal [ 0.08175905  0.57140301 -0.30801753  0.11078841  0.01680119]
# iteration: 1960| Acceptance rate: 0.3198979591836735| Log-Likelihood: -10869.098107414033| Proposal [ 0.08323851  0.55271722 -0.3067033   0.10814604  0.01623484]
# iteration: 1970| Acceptance rate: 0.3223350253807107| Log-Likelihood: -10869.24507194042| Proposal [ 0.08342263  0.55076292 -0.30659458  0.10801896  0.01611252]
# iteration: 1980| Acceptance rate: 0.32474747474747473| Log-Likelihood: -10868.7904795613| Proposal [ 0.08359946  0.55140947 -0.30664471  0.11048918  0.01506194]
# iteration: 1990| Acceptance rate: 0.3256281407035176| Log-Likelihood: -10869.596702820181| Proposal [ 0.08048502  0.59121402 -0.30937523  0.11689558  0.01590845]
# iteration: 2000| Acceptance rate: 0.3275| Log-Likelihood: -10869.875023111506| Proposal [ 0.08275853  0.5565638  -0.3069244   0.10711635  0.01705274]
# iteration: 2010| Acceptance rate: 0.32935323383084575| Log-Likelihood: -10870.200463717343| Proposal [ 0.08384896  0.53871252 -0.30563035  0.10140133  0.01794249]
# iteration: 2020| Acceptance rate: 0.3316831683168317| Log-Likelihood: -10869.523755047518| Proposal [ 0.08260019  0.56454407 -0.30749644  0.11317848  0.01507523]
# iteration: 2030| Acceptance rate: 0.3334975369458128| Log-Likelihood: -10869.587252850335| Proposal [ 0.08300379  0.55693165 -0.30693966  0.11012155  0.01573296]
# iteration: 2040| Acceptance rate: 0.3352941176470588| Log-Likelihood: -10869.460595594628| Proposal [ 0.08326545  0.55017543 -0.30656843  0.10570289  0.01710209]
# iteration: 2050| Acceptance rate: 0.33707317073170734| Log-Likelihood: -10869.688568278814| Proposal [ 0.07966796  0.60086995 -0.31013996  0.1172282   0.0166783 ]
# iteration: 2060| Acceptance rate: 0.3383495145631068| Log-Likelihood: -10870.356411917002| Proposal [ 0.08453316  0.52994023 -0.30516533  0.09920198  0.01812999]
# iteration: 2070| Acceptance rate: 0.3386473429951691| Log-Likelihood: -10871.38134331101| Proposal [ 0.08713601  0.49581796 -0.3026662   0.09388941  0.01730096]
# iteration: 2080| Acceptance rate: 0.3389423076923077| Log-Likelihood: -10871.243452317849| Proposal [ 0.08621778  0.50699499 -0.30343775  0.09520039  0.01775898]
# iteration: 2090| Acceptance rate: 0.3406698564593301| Log-Likelihood: -10870.263266002274| Proposal [ 0.08455565  0.52771357 -0.30481263  0.09836143  0.01827109]
# iteration: 2100| Acceptance rate: 0.3423809523809524| Log-Likelihood: -10871.235669200612| Proposal [ 0.0864707   0.49650138 -0.30262354  0.08804732  0.01998208]
# iteration: 2110| Acceptance rate: 0.34360189573459715| Log-Likelihood: -10870.798486770698| Proposal [ 0.08643773  0.50313078 -0.30287603  0.09536826  0.01727883]
# iteration: 2120| Acceptance rate: 0.3452830188679245| Log-Likelihood: -10870.960444127268| Proposal [ 0.0845723   0.51703675 -0.30388567  0.08909611  0.02141353]
# iteration: 2130| Acceptance rate: 0.3460093896713615| Log-Likelihood: -10870.77476979339| Proposal [ 0.07795486  0.60635272 -0.30934583  0.11111158  0.01977817]
# iteration: 2140| Acceptance rate: 0.347196261682243| Log-Likelihood: -10869.773808599612| Proposal [ 0.08494471  0.52231898 -0.30449768  0.0968367   0.01845977]
# iteration: 2150| Acceptance rate: 0.34744186046511627| Log-Likelihood: -10870.92294213445| Proposal [ 0.08303009  0.54331909 -0.3062275   0.09573571  0.02096488]
# iteration: 2160| Acceptance rate: 0.3490740740740741| Log-Likelihood: -10869.835807870337| Proposal [ 0.08103724  0.57479477 -0.30829422  0.1062745   0.01915735]
# iteration: 2170| Acceptance rate: 0.35023041474654376| Log-Likelihood: -10870.466898405248| Proposal [ 0.08453894  0.51835605 -0.30414807  0.0890841   0.02156717]
# iteration: 2180| Acceptance rate: 0.35091743119266056| Log-Likelihood: -10871.51076509818| Proposal [ 0.0766743   0.63612046 -0.31321374  0.11675106  0.02029052]
# iteration: 2190| Acceptance rate: 0.35205479452054794| Log-Likelihood: -10869.615402557789| Proposal [ 0.08316032  0.54889903 -0.306626    0.10252379  0.01843434]
# iteration: 2200| Acceptance rate: 0.3513636363636364| Log-Likelihood: -10868.97170405627| Proposal [ 0.08294638  0.54741191 -0.3059554   0.10198048  0.0184582 ]
# iteration: 2210| Acceptance rate: 0.3506787330316742| Log-Likelihood: -10869.426504619492| Proposal [ 0.08279466  0.54250242 -0.30551401  0.09612387  0.02061954]
# iteration: 2220| Acceptance rate: 0.35225225225225226| Log-Likelihood: -10868.87586991019| Proposal [ 0.0816057   0.56743112 -0.30746859  0.10680032  0.01818468]
# iteration: 2230| Acceptance rate: 0.3538116591928251| Log-Likelihood: -10869.47743021044| Proposal [ 0.08202668  0.57743807 -0.30907853  0.11594441  0.01513832]
# iteration: 2240| Acceptance rate: 0.35535714285714287| Log-Likelihood: -10869.406035522295| Proposal [ 0.08209753  0.56192753 -0.30759063  0.10376659  0.01910604]
# iteration: 2250| Acceptance rate: 0.35644444444444445| Log-Likelihood: -10869.156886457109| Proposal [ 0.08292431  0.55137267 -0.30618162  0.10590783  0.01705494]
# iteration: 2260| Acceptance rate: 0.3579646017699115| Log-Likelihood: -10869.6582618491| Proposal [ 0.08050458  0.57718662 -0.30778364  0.1067881   0.01905378]
# iteration: 2270| Acceptance rate: 0.3585903083700441| Log-Likelihood: -10869.690965170188| Proposal [ 0.08254349  0.54474051 -0.30437176  0.10292786  0.017581  ]
# iteration: 2280| Acceptance rate: 0.35789473684210527| Log-Likelihood: -10868.502423229138| Proposal [ 0.08376602  0.5445535  -0.30619726  0.10535712  0.01673294]
# iteration: 2290| Acceptance rate: 0.3589519650655022| Log-Likelihood: -10869.327735424558| Proposal [ 0.08474312  0.52801713 -0.30456765  0.10212424  0.01656763]
# iteration: 2300| Acceptance rate: 0.36| Log-Likelihood: -10870.605630351816| Proposal [ 0.08099377  0.58110839 -0.30865129  0.11246731  0.0169504 ]
# iteration: 2310| Acceptance rate: 0.3619047619047619| Log-Likelihood: -10870.465167416818| Proposal [ 0.08291082  0.57474329 -0.30981639  0.11745187  0.01433919]
# iteration: 2320| Acceptance rate: 0.36336206896551726| Log-Likelihood: -10869.767595844667| Proposal [ 0.08375048  0.55785648 -0.30818765  0.1122847   0.01501535]
# iteration: 2330| Acceptance rate: 0.36523605150214594| Log-Likelihood: -10870.089208474521| Proposal [ 0.08533597  0.5311038  -0.30596587  0.10478599  0.01582845]
# iteration: 2340| Acceptance rate: 0.36752136752136755| Log-Likelihood: -10869.530539259898| Proposal [ 0.08260451  0.52873361 -0.30213983  0.09412695  0.01988045]
# iteration: 2350| Acceptance rate: 0.36851063829787234| Log-Likelihood: -10869.562945849353| Proposal [ 0.0843677   0.53757406 -0.30536913  0.10677357  0.01539122]
# iteration: 2360| Acceptance rate: 0.3690677966101695| Log-Likelihood: -10869.20519505502| Proposal [ 0.08307786  0.53262846 -0.30332143  0.09784661  0.01870186]
# iteration: 2370| Acceptance rate: 0.37088607594936707| Log-Likelihood: -10870.256954583201| Proposal [ 0.08413648  0.54182203 -0.30623966  0.10528571  0.01654197]
# iteration: 2380| Acceptance rate: 0.3726890756302521| Log-Likelihood: -10870.930176391128| Proposal [ 0.08179949  0.62352158 -0.31817977  0.12577736  0.01588066]
# iteration: 2390| Acceptance rate: 0.37364016736401673| Log-Likelihood: -10869.735101482474| Proposal [ 0.08225638  0.57942937 -0.31116225  0.10944263  0.01853039]
# iteration: 2400| Acceptance rate: 0.37416666666666665| Log-Likelihood: -10868.712870361758| Proposal [ 0.08300047  0.50275001 -0.29675484  0.09282454  0.01751616]
# iteration: 2410| Acceptance rate: 0.37344398340248963| Log-Likelihood: -10868.497675547113| Proposal [ 0.08388858  0.48741526 -0.29593386  0.08577741  0.0192844 ]
# iteration: 2420| Acceptance rate: 0.3743801652892562| Log-Likelihood: -10869.334884586833| Proposal [ 0.08373612  0.55199377 -0.30823145  0.10385795  0.01832312]
# iteration: 2430| Acceptance rate: 0.37613168724279833| Log-Likelihood: -10870.580074907892| Proposal [ 0.08460083  0.52037778 -0.3040144   0.09325353  0.01984076]
# iteration: 2440| Acceptance rate: 0.37745901639344265| Log-Likelihood: -10870.471006668404| Proposal [ 0.08440249  0.54440092 -0.30750432  0.10455171  0.01726971]
# iteration: 2450| Acceptance rate: 0.37918367346938775| Log-Likelihood: -10870.265453444465| Proposal [ 0.08333466  0.54742732 -0.30696393  0.10045701  0.0192896 ]
# iteration: 2460| Acceptance rate: 0.3804878048780488| Log-Likelihood: -10866.862456967876| Proposal [ 0.08402737  0.35741839 -0.27028199  0.05262263  0.019632  ]
# iteration: 2470| Acceptance rate: 0.3809716599190283| Log-Likelihood: -10868.210936036976| Proposal [ 0.08431494  0.36156278 -0.27055899  0.05978311  0.01679598]
# iteration: 2480| Acceptance rate: 0.38064516129032255| Log-Likelihood: -10867.319408426974| Proposal [ 0.08283512  0.43138304 -0.28182399  0.07681862  0.01659719]
# iteration: 2490| Acceptance rate: 0.37991967871485943| Log-Likelihood: -10867.984093460525| Proposal [ 0.08115993  0.42610057 -0.27696995  0.07905891  0.01445097]
# iteration: 2500| Acceptance rate: 0.3808| Log-Likelihood: -10868.427222374934| Proposal [ 0.08140449  0.42587719 -0.27720356  0.08002581  0.0140304 ]
# iteration: 2510| Acceptance rate: 0.3812749003984064| Log-Likelihood: -10869.285711927507| Proposal [ 0.08384856  0.28966217 -0.25395902  0.04920485  0.0131501 ]
# iteration: 2520| Acceptance rate: 0.3825396825396825| Log-Likelihood: -10867.99325266459| Proposal [ 0.08285194  0.37975096 -0.27057178  0.06919496  0.01408701]
# iteration: 2530| Acceptance rate: 0.38300395256916997| Log-Likelihood: -10867.552678975526| Proposal [ 0.07987761  0.46369061 -0.28309898  0.08275059  0.01681999]
# iteration: 2540| Acceptance rate: 0.3826771653543307| Log-Likelihood: -10866.594935827876| Proposal [ 0.08077345  0.35431899 -0.26222279  0.05912593  0.01529132]
# iteration: 2550| Acceptance rate: 0.3819607843137255| Log-Likelihood: -10867.351271109266| Proposal [ 0.08289255  0.44289064 -0.28417107  0.08006201  0.01643849]
# iteration: 2560| Acceptance rate: 0.3828125| Log-Likelihood: -10868.269788563352| Proposal [ 0.08067426  0.48341035 -0.28811741  0.09010067  0.01588385]
# iteration: 2570| Acceptance rate: 0.3832684824902724| Log-Likelihood: -10865.907764978856| Proposal [ 0.0825541   0.31395361 -0.25811972  0.04555968  0.01742446]
# iteration: 2580| Acceptance rate: 0.3825581395348837| Log-Likelihood: -10867.035636943792| Proposal [ 0.08095516  0.3561033  -0.26229281  0.06309472  0.01366444]
# iteration: 2590| Acceptance rate: 0.3818532818532819| Log-Likelihood: -10867.402068982448| Proposal [ 0.08218532  0.43871518 -0.28227617  0.07748013  0.01697929]
# iteration: 2600| Acceptance rate: 0.38269230769230766| Log-Likelihood: -10866.392672015418| Proposal [ 0.08029244  0.33935555 -0.25860747  0.05377352  0.01592801]
# iteration: 2610| Acceptance rate: 0.3839080459770115| Log-Likelihood: -10867.680147767056| Proposal [ 0.0815319   0.47687685 -0.28978565  0.08086821  0.01973046]
# iteration: 2620| Acceptance rate: 0.3843511450381679| Log-Likelihood: -10867.361704210904| Proposal [ 0.08201868  0.40109626 -0.27381664  0.07149947  0.01530482]
# iteration: 2630| Acceptance rate: 0.38479087452471483| Log-Likelihood: -10868.016077787046| Proposal [ 0.07910355  0.29617089 -0.24731149  0.04524931  0.01452573]
# iteration: 2640| Acceptance rate: 0.38484848484848483| Log-Likelihood: -10866.263882719199| Proposal [ 0.08182141  0.36241782 -0.2665946   0.05682484  0.01763221]
# iteration: 2650| Acceptance rate: 0.3860377358490566| Log-Likelihood: -10867.009916663046| Proposal [ 0.0804547   0.24926287 -0.24026646  0.03464266  0.0143567 ]
# iteration: 2660| Acceptance rate: 0.38571428571428573| Log-Likelihood: -10867.091063127233| Proposal [ 0.08221866  0.40251817 -0.27524074  0.06759285  0.0173865 ]
# iteration: 2670| Acceptance rate: 0.38689138576779025| Log-Likelihood: -10865.461852547853| Proposal [ 0.08237421  0.35965168 -0.26674799  0.05800827  0.01688933]
# iteration: 2680| Acceptance rate: 0.3880597014925373| Log-Likelihood: -10867.382047162082| Proposal [ 0.08065153  0.42145501 -0.27626721  0.07126374  0.01746974]
# iteration: 2690| Acceptance rate: 0.38773234200743495| Log-Likelihood: -10866.945860676868| Proposal [ 0.08183241  0.4271799  -0.27903679  0.07607213  0.01618179]
# iteration: 2700| Acceptance rate: 0.3874074074074074| Log-Likelihood: -10866.360328241617| Proposal [ 0.08198459  0.33792369 -0.26212194  0.05000592  0.01800674]
# iteration: 2710| Acceptance rate: 0.388929889298893| Log-Likelihood: -10867.55714128397| Proposal [ 0.08231644  0.41953042 -0.27979313  0.06646994  0.01997072]
# iteration: 2720| Acceptance rate: 0.38933823529411765| Log-Likelihood: -10869.318485766762| Proposal [ 0.08239247  0.45996082 -0.2858747   0.08864301  0.01425165]
# iteration: 2730| Acceptance rate: 0.39084249084249084| Log-Likelihood: -10868.132001079553| Proposal [ 0.08202971  0.41193405 -0.27828073  0.0614983   0.02135502]
# iteration: 2740| Acceptance rate: 0.39197080291970804| Log-Likelihood: -10868.118783950187| Proposal [ 0.08372497  0.33396874 -0.26308711  0.05754621  0.01441865]
# iteration: 2750| Acceptance rate: 0.39236363636363636| Log-Likelihood: -10868.04408644431| Proposal [ 0.08371203  0.41373619 -0.27947529  0.07502904  0.01558611]
# iteration: 2760| Acceptance rate: 0.3927536231884058| Log-Likelihood: -10868.14331346263| Proposal [ 0.08383198  0.29656465 -0.25567137  0.04890922  0.01410732]
# iteration: 2770| Acceptance rate: 0.3935018050541516| Log-Likelihood: -10868.03498038584| Proposal [ 0.08271075  0.38877267 -0.27224536  0.07070464  0.01440382]
# iteration: 2780| Acceptance rate: 0.39388489208633093| Log-Likelihood: -10866.400838878137| Proposal [ 0.08388268  0.33410832 -0.26452359  0.05136827  0.01741696]
# iteration: 2790| Acceptance rate: 0.3935483870967742| Log-Likelihood: -10866.029613292187| Proposal [ 0.08175112  0.36569925 -0.26612892  0.06318206  0.01497912]
# iteration: 2800| Acceptance rate: 0.39357142857142857| Log-Likelihood: -10866.701782889966| Proposal [ 0.08295848  0.40382223 -0.27649728  0.07015504  0.0165223 ]
# iteration: 2810| Acceptance rate: 0.39466192170818504| Log-Likelihood: -10867.311173433209| Proposal [ 0.08213891  0.35928274 -0.26693764  0.05396088  0.01870749]
# iteration: 2820| Acceptance rate: 0.39609929078014183| Log-Likelihood: -10867.027638019383| Proposal [ 0.0838447   0.33174868 -0.26455116  0.04758157  0.01892755]
# iteration: 2830| Acceptance rate: 0.396113074204947| Log-Likelihood: -10866.977586795365| Proposal [ 0.08273678  0.3535465  -0.26526467  0.06176395  0.01447419]
# iteration: 2840| Acceptance rate: 0.3957746478873239| Log-Likelihood: -10865.988806993599| Proposal [ 0.08289735  0.36066821 -0.26833194  0.05606069  0.01807798]
# iteration: 2850| Acceptance rate: 0.39614035087719296| Log-Likelihood: -10867.219168085447| Proposal [ 0.08175914  0.25335923 -0.24395178  0.03340301  0.01578572]
# iteration: 2860| Acceptance rate: 0.3972027972027972| Log-Likelihood: -10866.202811653155| Proposal [ 0.08330407  0.2890498  -0.25374263  0.04383362  0.01548568]
# iteration: 2870| Acceptance rate: 0.3979094076655052| Log-Likelihood: -10866.757136369915| Proposal [ 0.08356322  0.38705505 -0.27383346  0.0684621   0.01549643]
# iteration: 2880| Acceptance rate: 0.39826388888888886| Log-Likelihood: -10867.126429990383| Proposal [ 0.08293173  0.31021061 -0.25690938  0.05118335  0.01440568]
# iteration: 2890| Acceptance rate: 0.39965397923875434| Log-Likelihood: -10868.137027793879| Proposal [ 0.08263196  0.49699186 -0.29384734  0.09730926  0.01459818]
# iteration: 2900| Acceptance rate: 0.4003448275862069| Log-Likelihood: -10866.761124795157| Proposal [ 0.08412103  0.37906532 -0.27311881  0.06739745  0.01520308]
# iteration: 2910| Acceptance rate: 0.40103092783505156| Log-Likelihood: -10867.186213808458| Proposal [ 0.08470844  0.30939849 -0.2605071   0.04869095  0.01597427]
# iteration: 2920| Acceptance rate: 0.40034246575342464| Log-Likelihood: -10867.355580035579| Proposal [ 0.08463336  0.34145255 -0.26656792  0.05791306  0.01537945]
# iteration: 2930| Acceptance rate: 0.40034129692832765| Log-Likelihood: -10866.413838090251| Proposal [ 0.08206097  0.32434828 -0.2588249   0.05065344  0.01610449]
# iteration: 2940| Acceptance rate: 0.40034013605442176| Log-Likelihood: -10867.597459143071| Proposal [ 0.0840846   0.35779859 -0.27020072  0.05420139  0.01894157]
# iteration: 2950| Acceptance rate: 0.4010169491525424| Log-Likelihood: -10867.031200704116| Proposal [ 0.08219818  0.46630392 -0.28713445  0.08823789  0.01514647]
# iteration: 2960| Acceptance rate: 0.4| Log-Likelihood: -10867.756424360055| Proposal [ 0.08169846  0.45294286 -0.28347206  0.08514617  0.0148932 ]
# iteration: 2970| Acceptance rate: 0.4003367003367003| Log-Likelihood: -10867.532819414777| Proposal [ 0.08451881  0.37464686 -0.27352075  0.06329296  0.01673754]
# iteration: 2980| Acceptance rate: 0.401006711409396| Log-Likelihood: -10867.832154484147| Proposal [ 0.08407812  0.2606561  -0.24980106  0.03514623  0.01645013]
# iteration: 2990| Acceptance rate: 0.40100334448160535| Log-Likelihood: -10865.958946317853| Proposal [ 0.08323116  0.33737692 -0.26392309  0.05233212  0.0171714 ]
# ...
# iteration: 49030| Acceptance rate: 0.3585763818070569| Log-Likelihood: -10860.068321781835| Proposal [ 0.07477913  0.13977106 -1.03563915  0.08315191  0.01720318]
# iteration: 49040| Acceptance rate: 0.35856443719412723| Log-Likelihood: -10860.556513904983| Proposal [ 0.06699483  0.21184271 -1.6318733   0.04007834  0.01934873]
# iteration: 49050| Acceptance rate: 0.35855249745158| Log-Likelihood: -10862.135981491576| Proposal [ 0.0620028   0.18938787 -1.74418518  0.04223732  0.01958408]
# iteration: 49060| Acceptance rate: 0.35849979616795763| Log-Likelihood: -10861.790839884672| Proposal [ 0.07015655  0.15827505 -1.17336918  0.0685115   0.02193264]
# iteration: 49070| Acceptance rate: 0.3585082535153862| Log-Likelihood: -10860.943437018319| Proposal [ 0.06713874  0.24477511 -1.66562259  0.04964389  0.01527207]
# iteration: 49080| Acceptance rate: 0.3584759576202119| Log-Likelihood: -10861.009433125075| Proposal [ 0.07242395  0.17248739 -1.24672694  0.07857012  0.01474553]
# iteration: 49090| Acceptance rate: 0.3584436748828682| Log-Likelihood: -10860.377638232736| Proposal [ 0.07130282  0.17163524 -1.20016985  0.07482106  0.017268  ]
# iteration: 49100| Acceptance rate: 0.35845213849287166| Log-Likelihood: -10860.756166404219| Proposal [ 0.07143643  0.19193572 -1.33659654  0.07428781  0.01840058]
# iteration: 49110| Acceptance rate: 0.35839951130116066| Log-Likelihood: -10861.557597042247| Proposal [ 0.06718476  0.2403863  -1.58398397  0.03780526  0.02143687]
# iteration: 49120| Acceptance rate: 0.35838762214983716| Log-Likelihood: -10860.72711191195| Proposal [ 0.0685003   0.29538305 -1.7538247   0.03410299  0.01686687]
# iteration: 49130| Acceptance rate: 0.3583960920008142| Log-Likelihood: -10860.711494799925| Proposal [ 0.06843864  0.28916964 -1.50131061  0.04517232  0.01652892]
# iteration: 49140| Acceptance rate: 0.35838420838420837| Log-Likelihood: -10862.982637018682| Proposal [ 0.06031883  0.28681481 -1.95027201  0.0294853   0.0183883 ]
# iteration: 49150| Acceptance rate: 0.35843336724313324| Log-Likelihood: -10860.01910779183| Proposal [ 0.0693168   0.16654037 -1.38716633  0.03929724  0.0172615 ]
# iteration: 49160| Acceptance rate: 0.3583807973962571| Log-Likelihood: -10859.15648250715| Proposal [ 0.07046136  0.15595676 -1.29709778  0.06245387  0.01760895]
# iteration: 49170| Acceptance rate: 0.358348586536506| Log-Likelihood: -10863.091960992204| Proposal [ 0.06112201  0.07993517 -1.88159427  0.03583301  0.0191357 ]
# iteration: 49180| Acceptance rate: 0.3582960553070354| Log-Likelihood: -10861.429622402851| Proposal [ 0.06625298  0.15157141 -1.72115033  0.02291207  0.01482029]
# iteration: 49190| Acceptance rate: 0.35826387477129495| Log-Likelihood: -10860.301670014183| Proposal [ 0.0679088   0.20316215 -1.58930585  0.03829393  0.01713611]
# iteration: 49200| Acceptance rate: 0.3582520325203252| Log-Likelihood: -10860.507483034744| Proposal [ 0.06472146  0.13249002 -1.75108278  0.03854161  0.01686429]
# iteration: 49210| Acceptance rate: 0.3583011583011583| Log-Likelihood: -10861.31059209865| Proposal [ 0.07225158  0.27421024 -1.27593081  0.08155951  0.01481899]
# iteration: 49220| Acceptance rate: 0.35830963023161316| Log-Likelihood: -10861.076563244094| Proposal [ 0.07345438  0.16504533 -1.06980377  0.07055461  0.01318742]
# iteration: 49230| Acceptance rate: 0.35829778590290473| Log-Likelihood: -10860.678464255145| Proposal [ 0.0766556   0.20825335 -0.90479896  0.11288513  0.01597605]
# iteration: 49240| Acceptance rate: 0.35824532900081235| Log-Likelihood: -10860.198115233145| Proposal [ 0.07298643  0.19164799 -1.2388354   0.08085486  0.01639537]
# iteration: 49250| Acceptance rate: 0.35823350253807107| Log-Likelihood: -10861.04940008742| Proposal [ 0.07105706  0.12241132 -1.39617683  0.0596894   0.01482979]
# iteration: 49260| Acceptance rate: 0.3582013804303695| Log-Likelihood: -10860.538770101315| Proposal [ 0.06693227  0.11818938 -1.58101449  0.05086278  0.01639426]
# iteration: 49270| Acceptance rate: 0.35823016034097827| Log-Likelihood: -10862.327078595623| Proposal [ 0.06801174  0.26948416 -1.51143394  0.08170385  0.01677648]
# iteration: 49280| Acceptance rate: 0.35825892857142855| Log-Likelihood: -10860.42275465982| Proposal [ 0.07285703  0.17387382 -1.18800287  0.09213621  0.01892127]
# iteration: 49290| Acceptance rate: 0.35826739703793875| Log-Likelihood: -10860.188332301117| Proposal [ 0.07359585  0.14637199 -0.98707476  0.09433221  0.01591046]
# iteration: 49300| Acceptance rate: 0.3582758620689655| Log-Likelihood: -10860.316556282862| Proposal [ 0.07009193  0.22153555 -1.22553373  0.06006411  0.01656795]
# iteration: 49310| Acceptance rate: 0.35828432366659907| Log-Likelihood: -10861.013930353887| Proposal [ 0.06890844  0.26396919 -1.50914912  0.03167935  0.01596952]
# iteration: 49320| Acceptance rate: 0.3583130575831306| Log-Likelihood: -10860.262882265377| Proposal [ 0.07063664  0.22553879 -1.26414936  0.05174283  0.01642117]
# iteration: 49330| Acceptance rate: 0.3583620514899655| Log-Likelihood: -10863.441948658976| Proposal [ 0.06711034  0.2512736  -1.31172879  0.10344261  0.01463733]
# iteration: 49340| Acceptance rate: 0.35837049047426023| Log-Likelihood: -10863.881367970107| Proposal [ 0.06996421  0.25265635 -0.97357207  0.1065269   0.01883495]
# iteration: 49350| Acceptance rate: 0.35839918946301924| Log-Likelihood: -10859.651858305999| Proposal [ 0.07266695  0.18268586 -1.06867045  0.0937796   0.01721961]
# iteration: 49360| Acceptance rate: 0.3583265802269044| Log-Likelihood: -10859.651858305999| Proposal [ 0.07266695  0.18268586 -1.06867045  0.0937796   0.01721961]
# iteration: 49370| Acceptance rate: 0.3582540004051043| Log-Likelihood: -10859.651858305999| Proposal [ 0.07266695  0.18268586 -1.06867045  0.0937796   0.01721961]
# iteration: 49380| Acceptance rate: 0.3582827055488052| Log-Likelihood: -10860.35993098794| Proposal [ 0.07367139  0.15391863 -1.03188754  0.05664763  0.01499154]
# iteration: 49390| Acceptance rate: 0.35825065802794087| Log-Likelihood: -10860.18395980617| Proposal [ 0.0717835   0.14998162 -1.20209967  0.09057496  0.01587026]
# iteration: 49400| Acceptance rate: 0.35827935222672064| Log-Likelihood: -10860.205981448922| Proposal [ 0.07386445  0.20412859 -1.12468212  0.08893689  0.01697623]
# iteration: 49410| Acceptance rate: 0.35830803481076706| Log-Likelihood: -10860.645992927499| Proposal [ 0.07310942  0.18425442 -1.13422504  0.09713173  0.01674851]
# iteration: 49420| Acceptance rate: 0.3582962363415621| Log-Likelihood: -10862.757794780187| Proposal [ 0.0683119   0.17867254 -1.36401255  0.08974606  0.02160446]
# iteration: 49430| Acceptance rate: 0.3583046732753389| Log-Likelihood: -10861.669815882076| Proposal [ 0.06482972  0.16577348 -1.7567718   0.02383705  0.01856142]
# iteration: 49440| Acceptance rate: 0.3583535598705502| Log-Likelihood: -10860.402162759514| Proposal [ 0.07219363  0.19554302 -1.02291106  0.09226255  0.01482547]
# iteration: 49450| Acceptance rate: 0.35832153690596563| Log-Likelihood: -10863.144668664598| Proposal [ 0.07179347  0.14667293 -0.99741551  0.11004627  0.01557916]
# iteration: 49460| Acceptance rate: 0.35826930853214717| Log-Likelihood: -10858.565535666565| Proposal [ 0.07026028  0.15565634 -1.30340572  0.05208826  0.01715839]
# iteration: 49470| Acceptance rate: 0.3582171012734991| Log-Likelihood: -10858.990153093853| Proposal [ 0.06952746  0.14466855 -1.40396159  0.04520208  0.0170494 ]
# iteration: 49480| Acceptance rate: 0.3582255456750202| Log-Likelihood: -10862.216352825228| Proposal [ 0.0670352   0.2657696  -1.37523842  0.05722152  0.01808966]
# iteration: 49490| Acceptance rate: 0.3582743988684583| Log-Likelihood: -10861.971102060523| Proposal [ 0.0693529   0.14454377 -1.31189741  0.05498394  0.02203853]
# iteration: 49500| Acceptance rate: 0.3582222222222222| Log-Likelihood: -10861.940001381967| Proposal [ 0.06861142  0.12654491 -1.29198462  0.0452872   0.02017326]
# iteration: 49510| Acceptance rate: 0.3582306604726318| Log-Likelihood: -10861.616147074967| Proposal [ 0.07053181  0.30163858 -1.38566656  0.03831814  0.01887475]
# iteration: 49520| Acceptance rate: 0.35827948303715673| Log-Likelihood: -10862.435215104786| Proposal [ 0.06785223  0.18969714 -1.59958792  0.06550797  0.01429424]
# iteration: 49530| Acceptance rate: 0.35826771653543305| Log-Likelihood: -10860.068405475| Proposal [ 0.06445913  0.23782448 -1.89366117  0.02766252  0.01710531]
# iteration: 49540| Acceptance rate: 0.3581953976584578| Log-Likelihood: -10860.068405475| Proposal [ 0.06445913  0.23782448 -1.89366117  0.02766252  0.01710531]
# iteration: 49550| Acceptance rate: 0.35816347124117054| Log-Likelihood: -10861.171763087958| Proposal [ 0.06786497  0.29885433 -1.59173413  0.0488491   0.01828787]
# iteration: 49560| Acceptance rate: 0.35817191283292976| Log-Likelihood: -10862.394971052752| Proposal [ 0.07001368  0.18354103 -1.09554252  0.0414328   0.01679397]
# iteration: 49570| Acceptance rate: 0.3581400040346984| Log-Likelihood: -10862.467193828923| Proposal [ 0.06604746  0.20059067 -1.42488362  0.03324783  0.0171188 ]
# iteration: 49580| Acceptance rate: 0.3581686163775716| Log-Likelihood: -10863.043331220177| Proposal [ 0.06686674  0.28905231 -1.79194824  0.03809878  0.02224843]
# iteration: 49590| Acceptance rate: 0.35813672111312767| Log-Likelihood: -10862.351300170661| Proposal [ 0.06532669  0.38182857 -1.92937011  0.03485369  0.01895917]
# iteration: 49600| Acceptance rate: 0.3581048387096774| Log-Likelihood: -10861.644846199064| Proposal [ 0.07310314  0.32138808 -1.07325929  0.0337987   0.01548872]
# iteration: 49610| Acceptance rate: 0.3580931263858093| Log-Likelihood: -10862.203101569714| Proposal [ 0.07538001  0.27191532 -0.91351258  0.09177265  0.01493784]
# iteration: 49620| Acceptance rate: 0.35806126561870216| Log-Likelihood: -10865.143549627539| Proposal [ 0.08065905  0.21957071 -0.59151804  0.10338927  0.01602415]
# iteration: 49630| Acceptance rate: 0.35804956679427763| Log-Likelihood: -10860.139034758935| Proposal [ 0.07122494  0.18324469 -1.23149673  0.05735351  0.01532912]
# iteration: 49640| Acceptance rate: 0.358058017727639| Log-Likelihood: -10862.354276195028| Proposal [ 0.07465861  0.29410692 -0.99381876  0.06263313  0.01779228]
# iteration: 49650| Acceptance rate: 0.3580664652567976| Log-Likelihood: -10861.754565382333| Proposal [ 0.07140092  0.18534082 -1.14197589  0.07685334  0.02108163]
# iteration: 49660| Acceptance rate: 0.3580749093838099| Log-Likelihood: -10860.63182673388| Proposal [ 0.07018118  0.14228309 -1.20579639  0.08810633  0.01837033]
# iteration: 49670| Acceptance rate: 0.3580229514797665| Log-Likelihood: -10862.600589792455| Proposal [ 0.0667801   0.14393316 -1.6387272   0.05920313  0.01657063]
# iteration: 49680| Acceptance rate: 0.3580314009661836| Log-Likelihood: -10862.788858818063| Proposal [ 0.06984626  0.37934399 -1.51570204  0.00978656  0.01510244]
# iteration: 49690| Acceptance rate: 0.3580197222781244| Log-Likelihood: -10862.234322374114| Proposal [ 0.07103985  0.48173054 -1.7188399   0.02204329  0.01629537]
# iteration: 49700| Acceptance rate: 0.3580281690140845| Log-Likelihood: -10863.191083798882| Proposal [ 0.07525766  0.30439306 -0.89786509  0.01939916  0.01446984]
# iteration: 49710| Acceptance rate: 0.3580164956749145| Log-Likelihood: -10859.772428463637| Proposal [ 0.06942062  0.19295166 -1.38439601  0.04571073  0.01688067]
# iteration: 49720| Acceptance rate: 0.3579646017699115| Log-Likelihood: -10860.759035764482| Proposal [ 0.06609216  0.19765835 -1.64598957  0.03653727  0.01548165]
# iteration: 49730| Acceptance rate: 0.3579328373215363| Log-Likelihood: -10860.436235568346| Proposal [ 0.06421183  0.16065703 -1.71866094  0.0312084   0.01938084]
# iteration: 49740| Acceptance rate: 0.3579211901889827| Log-Likelihood: -10862.758902775697| Proposal [ 0.06514969  0.13546976 -1.5024864   0.03230866  0.02158623]
# iteration: 49750| Acceptance rate: 0.3578894472361809| Log-Likelihood: -10861.23514558974| Proposal [ 0.0632845   0.36813295 -1.97868223  0.02331833  0.01490042]
# iteration: 49760| Acceptance rate: 0.35785771704180064| Log-Likelihood: -10861.500349100761| Proposal [ 0.07583886  0.25460214 -0.89332074  0.04854301  0.01791577]
# iteration: 49770| Acceptance rate: 0.3578259995981515| Log-Likelihood: -10861.781791601974| Proposal [ 0.07515167  0.30818007 -1.18976796  0.04535139  0.0168558 ]
# iteration: 49780| Acceptance rate: 0.3578143832864604| Log-Likelihood: -10861.00976668173| Proposal [ 0.06778309  0.2418895  -1.63231803  0.02268329  0.01946329]
# iteration: 49790| Acceptance rate: 0.35786302470375575| Log-Likelihood: -10860.843544143552| Proposal [ 0.07197457  0.18223686 -1.15535252  0.08298233  0.01842855]
# iteration: 49800| Acceptance rate: 0.3578313253012048| Log-Likelihood: -10861.14317769685| Proposal [ 0.07286524  0.26916084 -1.15275054  0.12543275  0.01773941]
# iteration: 49810| Acceptance rate: 0.3578197149166834| Log-Likelihood: -10862.859278236208| Proposal [ 0.07829719  0.22352437 -0.91094507  0.11732545  0.01665411]
# iteration: 49820| Acceptance rate: 0.35778803693295863| Log-Likelihood: -10862.687243328412| Proposal [ 0.07653782  0.24955405 -0.88450806  0.15395251  0.01867315]
# iteration: 49830| Acceptance rate: 0.3577563716636564| Log-Likelihood: -10860.200619569763| Proposal [ 0.07280495  0.21211053 -1.14520299  0.084599    0.01941012]
# iteration: 49840| Acceptance rate: 0.35774478330658105| Log-Likelihood: -10861.265221300197| Proposal [ 0.06426525  0.27611233 -1.80266578  0.02549212  0.01849796]
# iteration: 49850| Acceptance rate: 0.35775325977933803| Log-Likelihood: -10861.0985985371| Proposal [ 0.07030586  0.29486116 -1.46997055  0.0213907   0.0171607 ]
# iteration: 49860| Acceptance rate: 0.3578219013237064| Log-Likelihood: -10862.607390668396| Proposal [ 0.07021806  0.34094102 -1.50510939  0.04832243  0.01441856]
# iteration: 49870| Acceptance rate: 0.35781030679767395| Log-Likelihood: -10860.487809104088| Proposal [ 0.06882571  0.26535283 -1.46180008  0.0468559   0.01694615]
# iteration: 49880| Acceptance rate: 0.3577586206896552| Log-Likelihood: -10860.565991060237| Proposal [ 0.06819128  0.25583061 -1.48367435  0.04051838  0.02039724]
# iteration: 49890| Acceptance rate: 0.3577069553016637| Log-Likelihood: -10861.414836258453| Proposal [ 0.06661036  0.35293365 -1.77018871  0.03155634  0.01828961]
# iteration: 49900| Acceptance rate: 0.35771543086172347| Log-Likelihood: -10863.200658015809| Proposal [ 0.07097642  0.36808892 -1.42070065  0.06365331  0.0194258 ]
# iteration: 49910| Acceptance rate: 0.3577639751552795| Log-Likelihood: -10864.272791759362| Proposal [ 0.07747321  0.44709984 -0.9765244   0.05066522  0.01811598]
# iteration: 49920| Acceptance rate: 0.35771233974358974| Log-Likelihood: -10862.242402712938| Proposal [ 0.07221994  0.42113448 -1.41090758  0.02130171  0.01515709]
# iteration: 49930| Acceptance rate: 0.3577208091327859| Log-Likelihood: -10862.456012696624| Proposal [ 0.06934639  0.2111393  -1.55723026  0.02074589  0.01327918]
# iteration: 49940| Acceptance rate: 0.3577292751301562| Log-Likelihood: -10861.654740226035| Proposal [ 0.07403233  0.22781533 -1.18969589  0.10262652  0.0148895 ]
# iteration: 49950| Acceptance rate: 0.35773773773773776| Log-Likelihood: -10862.300069032235| Proposal [ 0.06475232  0.18021645 -1.81860635  0.04265686  0.01428755]
# iteration: 49960| Acceptance rate: 0.3577662129703763| Log-Likelihood: -10863.394077251218| Proposal [ 0.07526624  0.13829778 -1.02625499  0.04437909  0.01826413]
# iteration: 49970| Acceptance rate: 0.357754652791675| Log-Likelihood: -10861.70451765592| Proposal [ 0.06664254  0.34678019 -1.80335035  0.03793012  0.01873813]
# iteration: 49980| Acceptance rate: 0.3577631052420968| Log-Likelihood: -10860.087506996764| Proposal [ 0.07258246  0.23485191 -1.22071206  0.06617309  0.01752042]
# iteration: 49990| Acceptance rate: 0.35773154630926185| Log-Likelihood: -10861.73313699623| Proposal [ 0.06109186  0.36216331 -1.97685917  0.02544942  0.01994028]
# 2832.131290899939

# %%
burn_in = 15000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10858.565535666565
# The Maximum Likelihood Estimate is [ 0.07026028  0.15565634 -1.30340572  0.05208826  0.01715839] w/ LL of -10858.565535666565

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5026.55103294518
# Root Mean Squared Error for beta 0.09503341909376341

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
import pickle

np.savez(f'../pmcmc_output/PMCMC.npz',distribution = pmcmc_output['MLE_particle_dist'], 
         observations = pmcmc_output['MLE_particle_observations'], 
         params = pmcmc_output['accepted_params'], 
         likelihood = pmcmc_output['Log Likelihood']
)

with open('../pmcmc_output/pmcmc_par.pickle', 'wb') as f:
    pickle.dump(pmcmc_params, f)
