# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
import jsonpickle

from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('../data_sets/ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('../data_sets/ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('../data_sets/ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0]),n = np.array([r]))
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

'''unpickle parameter sets'''
with open("../param_sets/SEIR_OU_model_params.json", "r+") as f:
    SEIR_model_json = f.read()
    SEIR_model_params = jsonpickle.decode(SEIR_model_json)

gamma = SEIR_model_params['gamma']
R = SEIR_model_params['R']

with open("../param_sets/SEIR_OU_process_params.json", "r+") as f:
    OU_process_json = f.read()
    SEIR_OU_process_params = jsonpickle.decode(OU_process_json)

lam = SEIR_OU_process_params['lambda']
mean_ou = SEIR_OU_process_params['mean_ou']
sig = SEIR_OU_process_params['sig']

T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':10_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 19.06678051900235

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0),color = 'orange')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    plt.show()

plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0),color = 'orange')
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10863.645024501251
# Root Mean Squared Error for the Data 5027.266064172513

# %%
pmcmc_rng = np.random.default_rng(0)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':50_000,
                'init_params':np.array([0.1,0.1,-0.7,0.01,0.01]),
                'prior':seir_prior,
                'init_cov':  np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1_000}

pf_params = {'num_particles':1000, 
                      'dt':0.1,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.0| Log-Likelihood: -14727.832166157325| Proposal [ 0.1   0.1  -0.7   0.01  0.01]
# iteration: 20| Acceptance rate: 0.05| Log-Likelihood: -12189.21840505298| Proposal [ 0.05644312  0.0449782  -0.82384401  0.24713694  0.0057988 ]
# iteration: 30| Acceptance rate: 0.06666666666666667| Log-Likelihood: -11978.748452788546| Proposal [ 0.04073489  0.00635116 -0.72806874  0.33303505  0.03316092]
# iteration: 40| Acceptance rate: 0.075| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 50| Acceptance rate: 0.06| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 60| Acceptance rate: 0.05| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 70| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 80| Acceptance rate: 0.0375| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 90| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 100| Acceptance rate: 0.03| Log-Likelihood: -10986.116488602942| Proposal [ 0.0557192   0.00349983 -0.78652961  0.49566503  0.14025446]
# iteration: 110| Acceptance rate: 0.03636363636363636| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 120| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 130| Acceptance rate: 0.03076923076923077| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 140| Acceptance rate: 0.02857142857142857| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 150| Acceptance rate: 0.02666666666666667| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 160| Acceptance rate: 0.025| Log-Likelihood: -10939.872320517914| Proposal [ 0.06907506  0.11762692 -0.80961068  0.46085099  0.15775173]
# iteration: 170| Acceptance rate: 0.029411764705882353| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 180| Acceptance rate: 0.027777777777777776| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 190| Acceptance rate: 0.02631578947368421| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 200| Acceptance rate: 0.025| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 210| Acceptance rate: 0.023809523809523808| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 220| Acceptance rate: 0.022727272727272728| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 230| Acceptance rate: 0.021739130434782608| Log-Likelihood: -10922.202996010838| Proposal [ 0.06930479  0.12340882 -0.81747493  0.412125    0.10205027]
# iteration: 240| Acceptance rate: 0.025| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 250| Acceptance rate: 0.024| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 260| Acceptance rate: 0.023076923076923078| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 270| Acceptance rate: 0.022222222222222223| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 280| Acceptance rate: 0.02142857142857143| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 290| Acceptance rate: 0.020689655172413793| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 300| Acceptance rate: 0.02| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 310| Acceptance rate: 0.01935483870967742| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 320| Acceptance rate: 0.01875| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 330| Acceptance rate: 0.01818181818181818| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 340| Acceptance rate: 0.01764705882352941| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 350| Acceptance rate: 0.017142857142857144| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 360| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 370| Acceptance rate: 0.016216216216216217| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 380| Acceptance rate: 0.015789473684210527| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 390| Acceptance rate: 0.015384615384615385| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 400| Acceptance rate: 0.015| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 410| Acceptance rate: 0.014634146341463415| Log-Likelihood: -10908.691373529287| Proposal [ 0.08218044  0.1314094  -0.87408817  0.37464297  0.01301782]
# iteration: 420| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 430| Acceptance rate: 0.01627906976744186| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 440| Acceptance rate: 0.015909090909090907| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 450| Acceptance rate: 0.015555555555555555| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 460| Acceptance rate: 0.015217391304347827| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 470| Acceptance rate: 0.014893617021276596| Log-Likelihood: -10908.069437022818| Proposal [ 0.06941628  0.16025422 -0.84931717  0.36678063  0.07363713]
# iteration: 480| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10894.321063888905| Proposal [ 0.07791174  0.20987764 -0.94359426  0.3891031   0.06464059]
# iteration: 490| Acceptance rate: 0.0163265306122449| Log-Likelihood: -10894.321063888905| Proposal [ 0.07791174  0.20987764 -0.94359426  0.3891031   0.06464059]
# iteration: 500| Acceptance rate: 0.016| Log-Likelihood: -10894.321063888905| Proposal [ 0.07791174  0.20987764 -0.94359426  0.3891031   0.06464059]
# iteration: 510| Acceptance rate: 0.01568627450980392| Log-Likelihood: -10894.321063888905| Proposal [ 0.07791174  0.20987764 -0.94359426  0.3891031   0.06464059]
# iteration: 520| Acceptance rate: 0.015384615384615385| Log-Likelihood: -10894.321063888905| Proposal [ 0.07791174  0.20987764 -0.94359426  0.3891031   0.06464059]
# iteration: 530| Acceptance rate: 0.016981132075471698| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 540| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 550| Acceptance rate: 0.016363636363636365| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 560| Acceptance rate: 0.01607142857142857| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 570| Acceptance rate: 0.015789473684210527| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 580| Acceptance rate: 0.015517241379310345| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 590| Acceptance rate: 0.015254237288135594| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 600| Acceptance rate: 0.015| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 610| Acceptance rate: 0.014754098360655738| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 620| Acceptance rate: 0.014516129032258065| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 630| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 640| Acceptance rate: 0.0140625| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 650| Acceptance rate: 0.013846153846153847| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 660| Acceptance rate: 0.013636363636363636| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 670| Acceptance rate: 0.013432835820895522| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 680| Acceptance rate: 0.013235294117647059| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 690| Acceptance rate: 0.013043478260869565| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 700| Acceptance rate: 0.012857142857142857| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 710| Acceptance rate: 0.01267605633802817| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 720| Acceptance rate: 0.0125| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 730| Acceptance rate: 0.012328767123287671| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 740| Acceptance rate: 0.012162162162162163| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 750| Acceptance rate: 0.012| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 760| Acceptance rate: 0.011842105263157895| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 770| Acceptance rate: 0.011688311688311689| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 780| Acceptance rate: 0.011538461538461539| Log-Likelihood: -10881.828689189933| Proposal [ 0.07768295  0.11930736 -1.03262209  0.44851039  0.01507288]
# iteration: 790| Acceptance rate: 0.012658227848101266| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 800| Acceptance rate: 0.0125| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 810| Acceptance rate: 0.012345679012345678| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 820| Acceptance rate: 0.012195121951219513| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 830| Acceptance rate: 0.012048192771084338| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 840| Acceptance rate: 0.011904761904761904| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 850| Acceptance rate: 0.011764705882352941| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 860| Acceptance rate: 0.011627906976744186| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 870| Acceptance rate: 0.011494252873563218| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 880| Acceptance rate: 0.011363636363636364| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 890| Acceptance rate: 0.011235955056179775| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 900| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 910| Acceptance rate: 0.01098901098901099| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 920| Acceptance rate: 0.010869565217391304| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 930| Acceptance rate: 0.010752688172043012| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 940| Acceptance rate: 0.010638297872340425| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 950| Acceptance rate: 0.010526315789473684| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 960| Acceptance rate: 0.010416666666666666| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 970| Acceptance rate: 0.010309278350515464| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 980| Acceptance rate: 0.01020408163265306| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 990| Acceptance rate: 0.010101010101010102| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 1000| Acceptance rate: 0.01| Log-Likelihood: -10865.820403588728| Proposal [ 0.07601705  0.29972935 -1.09196262  0.36047322  0.01335081]
# iteration: 1010| Acceptance rate: 0.01089108910891089| Log-Likelihood: -10863.4349392582| Proposal [ 0.07489811  0.30265744 -1.1063124   0.37670705  0.01553463]
# iteration: 1020| Acceptance rate: 0.011764705882352941| Log-Likelihood: -10863.20975430229| Proposal [ 0.07353274  0.29674936 -1.08480332  0.36675969  0.01421227]
# iteration: 1030| Acceptance rate: 0.020388349514563107| Log-Likelihood: -10864.435933551544| Proposal [ 0.07417556  0.29630131 -1.08423139  0.36618823  0.01340002]
# iteration: 1040| Acceptance rate: 0.025| Log-Likelihood: -10864.912906580095| Proposal [ 0.07497607  0.29696072 -1.08953394  0.3669771   0.01397349]
# iteration: 1050| Acceptance rate: 0.03238095238095238| Log-Likelihood: -10864.781281377425| Proposal [ 0.07365427  0.29586791 -1.08124871  0.36574691  0.01357897]
# iteration: 1060| Acceptance rate: 0.04150943396226415| Log-Likelihood: -10865.794542498094| Proposal [ 0.07197981  0.29461792 -1.07180781  0.36401733  0.01390386]
# iteration: 1070| Acceptance rate: 0.04953271028037383| Log-Likelihood: -10864.775874934474| Proposal [ 0.07333997  0.29534783 -1.0793538   0.36557428  0.01392682]
# iteration: 1080| Acceptance rate: 0.05555555555555555| Log-Likelihood: -10864.001113045395| Proposal [ 0.07354069  0.29565139 -1.08053136  0.36558182  0.01383375]
# iteration: 1090| Acceptance rate: 0.06330275229357799| Log-Likelihood: -10864.385972551334| Proposal [ 0.07467424  0.29640043 -1.08684088  0.36678428  0.01372019]
# iteration: 1100| Acceptance rate: 0.06818181818181818| Log-Likelihood: -10865.226118895438| Proposal [ 0.07577986  0.29702367 -1.09290958  0.36801332  0.01369063]
# iteration: 1110| Acceptance rate: 0.07477477477477477| Log-Likelihood: -10864.48140326389| Proposal [ 0.07560979  0.29702037 -1.09200187  0.36770765  0.01365916]
# iteration: 1120| Acceptance rate: 0.08125| Log-Likelihood: -10864.948783783457| Proposal [ 0.07286662  0.29498579 -1.07666058  0.36516678  0.01392527]
# iteration: 1130| Acceptance rate: 0.08761061946902655| Log-Likelihood: -10864.607600660034| Proposal [ 0.07331468  0.29514864 -1.07913201  0.36581733  0.01393888]
# iteration: 1140| Acceptance rate: 0.09385964912280702| Log-Likelihood: -10864.095878106544| Proposal [ 0.07549832  0.29681766 -1.09134997  0.3677697   0.0137078 ]
# iteration: 1150| Acceptance rate: 0.09739130434782609| Log-Likelihood: -10865.206335939623| Proposal [ 0.07618028  0.29729978 -1.09519091  0.36847766  0.01363503]
# iteration: 1160| Acceptance rate: 0.10258620689655172| Log-Likelihood: -10863.863415458629| Proposal [ 0.0750384   0.29650696 -1.08879227  0.36730932  0.01374145]
# iteration: 1170| Acceptance rate: 0.10854700854700855| Log-Likelihood: -10864.590455728088| Proposal [ 0.07373147  0.29557624 -1.08149488  0.36604338  0.01385953]
# iteration: 1180| Acceptance rate: 0.11271186440677966| Log-Likelihood: -10868.281648782557| Proposal [ 0.07059538  0.29339621 -1.06395848  0.36287991  0.01414377]
# iteration: 1190| Acceptance rate: 0.11512605042016806| Log-Likelihood: -10864.015144121991| Proposal [ 0.07357904  0.29547501 -1.08065585  0.36589639  0.01386902]
# iteration: 1200| Acceptance rate: 0.11916666666666667| Log-Likelihood: -10864.906889448674| Proposal [ 0.07296525  0.29503635 -1.0772444   0.36532163  0.0139213 ]
# iteration: 1210| Acceptance rate: 0.12644628099173555| Log-Likelihood: -10863.570412923706| Proposal [ 0.07414941  0.29587439 -1.08384641  0.36646896  0.0138158 ]
# iteration: 1220| Acceptance rate: 0.12868852459016394| Log-Likelihood: -10864.798304630796| Proposal [ 0.07611603  0.29728027 -1.09480633  0.36834512  0.01363888]
# iteration: 1230| Acceptance rate: 0.13252032520325202| Log-Likelihood: -10863.762672149765| Proposal [ 0.07352267  0.29542789 -1.08034078  0.36585272  0.01387626]
# iteration: 1240| Acceptance rate: 0.13629032258064516| Log-Likelihood: -10864.891161922355| Proposal [ 0.07536796  0.29675301 -1.09064651  0.36762961  0.01370162]
# iteration: 1250| Acceptance rate: 0.1384| Log-Likelihood: -10864.812846277162| Proposal [ 0.0725046   0.29469775 -1.07464687  0.36486149  0.01397469]
# iteration: 1260| Acceptance rate: 0.14126984126984127| Log-Likelihood: -10865.056986945998| Proposal [ 0.07593077  0.29715018 -1.09378084  0.368172    0.0136534 ]
# iteration: 1270| Acceptance rate: 0.14566929133858267| Log-Likelihood: -10864.693959341661| Proposal [ 0.0735834   0.29547017 -1.08065217  0.36588043  0.01387956]
# iteration: 1280| Acceptance rate: 0.15078125| Log-Likelihood: -10864.810640347498| Proposal [ 0.07305474  0.29508936 -1.07769674  0.36536957  0.01393104]
# iteration: 1290| Acceptance rate: 0.15348837209302327| Log-Likelihood: -10864.572801457321| Proposal [ 0.07500501  0.29649022 -1.08860161  0.36726214  0.01374239]
# iteration: 1300| Acceptance rate: 0.15538461538461537| Log-Likelihood: -10865.749873461267| Proposal [ 0.07573077  0.29700573 -1.09266242  0.36797878  0.01367323]
# iteration: 1310| Acceptance rate: 0.15954198473282444| Log-Likelihood: -10864.478278142211| Proposal [ 0.0748924   0.29640639 -1.08797604  0.36716252  0.01375281]
# iteration: 1320| Acceptance rate: 0.16515151515151516| Log-Likelihood: -10864.437149688933| Proposal [ 0.07369084  0.29554396 -1.08127155  0.36601179  0.01386471]
# iteration: 1330| Acceptance rate: 0.16842105263157894| Log-Likelihood: -10864.448174223277| Proposal [ 0.07280585  0.2949125  -1.07631789  0.36514056  0.01395021]
# iteration: 1340| Acceptance rate: 0.17164179104477612| Log-Likelihood: -10864.542297471547| Proposal [ 0.07362477  0.29550038 -1.08089952  0.36593852  0.01387063]
# iteration: 1350| Acceptance rate: 0.1748148148148148| Log-Likelihood: -10865.542983634308| Proposal [ 0.07590708  0.2971321  -1.09365581  0.36815894  0.01365417]
# iteration: 1360| Acceptance rate: 0.17941176470588235| Log-Likelihood: -10863.913330855705| Proposal [ 0.07365015  0.2955171  -1.08104048  0.36596444  0.01386892]
# iteration: 1370| Acceptance rate: 0.18321167883211678| Log-Likelihood: -10864.889215385057| Proposal [ 0.07265671  0.29480564 -1.07548216  0.36499349  0.01396492]
# iteration: 1380| Acceptance rate: 0.18478260869565216| Log-Likelihood: -10864.416919514766| Proposal [ 0.07292815  0.294998   -1.07699464  0.36525507  0.0139409 ]
# iteration: 1390| Acceptance rate: 0.1884892086330935| Log-Likelihood: -10863.997554017731| Proposal [ 0.07340958  0.29534297 -1.07968741  0.36572451  0.01389442]
# iteration: 1400| Acceptance rate: 0.19357142857142856| Log-Likelihood: -10864.818732901982| Proposal [ 0.07449159  0.29612143 -1.08574418  0.36677965  0.01378795]
# iteration: 1410| Acceptance rate: 0.19645390070921986| Log-Likelihood: -10865.842281027994| Proposal [ 0.07555139  0.2968817  -1.09166776  0.3678068   0.0136866 ]
# iteration: 1420| Acceptance rate: 0.2| Log-Likelihood: -10864.755391158089| Proposal [ 0.07585439  0.29709829 -1.09335801  0.36809789  0.01365879]
# iteration: 1430| Acceptance rate: 0.2034965034965035| Log-Likelihood: -10863.467422296637| Proposal [ 0.0748802   0.29639972 -1.08791076  0.36715087  0.01375239]
# iteration: 1440| Acceptance rate: 0.2048611111111111| Log-Likelihood: -10862.86562968048| Proposal [ 0.07451965  0.29614005 -1.08590173  0.36681     0.01378559]
# iteration: 1450| Acceptance rate: 0.20896551724137932| Log-Likelihood: -10864.44913629689| Proposal [ 0.07357337  0.29546227 -1.08060676  0.36588472  0.0138772 ]
# iteration: 1460| Acceptance rate: 0.213013698630137| Log-Likelihood: -10865.421231403523| Proposal [ 0.07251919  0.29470503 -1.07471227  0.36486209  0.01397885]
# iteration: 1470| Acceptance rate: 0.21768707482993196| Log-Likelihood: -10864.889017321642| Proposal [ 0.0731668   0.29517021 -1.07833472  0.36549177  0.0139161 ]
# iteration: 1480| Acceptance rate: 0.22162162162162163| Log-Likelihood: -10864.523773483254| Proposal [ 0.07393191  0.2957188  -1.08260981  0.36623217  0.01384339]
# iteration: 1490| Acceptance rate: 0.22416107382550335| Log-Likelihood: -10863.996062769675| Proposal [ 0.07402578  0.29578586 -1.08313207  0.36632082  0.01383519]
# iteration: 1500| Acceptance rate: 0.22533333333333333| Log-Likelihood: -10865.010723893804| Proposal [ 0.07259096  0.29475635 -1.07511285  0.36493127  0.01397221]
# iteration: 1510| Acceptance rate: 0.22913907284768212| Log-Likelihood: -10865.776676048754| Proposal [ 0.07640341  0.29749201 -1.09643086  0.36863457  0.0136055 ]
# iteration: 1520| Acceptance rate: 0.22960526315789473| Log-Likelihood: -10864.225834869572| Proposal [ 0.07370765  0.29555777 -1.08136329  0.36602268  0.01386326]
# iteration: 1530| Acceptance rate: 0.23333333333333334| Log-Likelihood: -10864.535225851934| Proposal [ 0.07349407  0.29540461 -1.08015276  0.36579719  0.01388766]
# iteration: 1540| Acceptance rate: 0.2357142857142857| Log-Likelihood: -10865.60492095417| Proposal [ 0.07221532  0.29448713 -1.07299847  0.36455054  0.01401159]
# iteration: 1550| Acceptance rate: 0.23870967741935484| Log-Likelihood: -10864.308923009685| Proposal [ 0.07441313  0.29606392 -1.08529343  0.36669193  0.01379895]
# iteration: 1560| Acceptance rate: 0.2403846153846154| Log-Likelihood: -10864.82460874599| Proposal [ 0.07487146  0.29639278 -1.08783473  0.36711356  0.01376001]
# iteration: 1570| Acceptance rate: 0.24331210191082803| Log-Likelihood: -10864.498486378532| Proposal [ 0.07406677  0.29581565 -1.08332873  0.36632441  0.01383882]
# iteration: 1580| Acceptance rate: 0.2468354430379747| Log-Likelihood: -10863.970059040805| Proposal [ 0.07459854  0.29619729 -1.08628233  0.36681903  0.0137924 ]
# iteration: 1590| Acceptance rate: 0.24968553459119497| Log-Likelihood: -10864.828546327799| Proposal [ 0.0724944   0.29468714 -1.07457947  0.36484454  0.01397991]
# iteration: 1600| Acceptance rate: 0.25375| Log-Likelihood: -10863.804751290367| Proposal [ 0.07497999  0.29647048 -1.08846692  0.36724704  0.01374359]
# iteration: 1610| Acceptance rate: 0.25838509316770186| Log-Likelihood: -10864.825171257306| Proposal [ 0.07289029  0.29497113 -1.07676573  0.36519907  0.01394845]
# iteration: 1620| Acceptance rate: 0.2611111111111111| Log-Likelihood: -10864.534802242344| Proposal [ 0.07430334  0.29598534 -1.08463112  0.36653184  0.013821  ]
# iteration: 1630| Acceptance rate: 0.2625766871165644| Log-Likelihood: -10864.372988488369| Proposal [ 0.07299517  0.29504673 -1.07733631  0.36528304  0.01394199]
# iteration: 1640| Acceptance rate: 0.2658536585365854| Log-Likelihood: -10864.538382189532| Proposal [ 0.07388551  0.29568572 -1.08227753  0.36610679  0.01386522]
# iteration: 1650| Acceptance rate: 0.2678787878787879| Log-Likelihood: -10865.390167834095| Proposal [ 0.07606199  0.2972479  -1.09435716  0.36812096  0.01367732]
# iteration: 1660| Acceptance rate: 0.26987951807228916| Log-Likelihood: -10863.555788111084| Proposal [ 0.07473521  0.29629547 -1.08700781  0.36690907  0.01378849]
# iteration: 1670| Acceptance rate: 0.27305389221556886| Log-Likelihood: -10864.039002250209| Proposal [ 0.07445234  0.29608966 -1.08565991  0.36689511  0.01376101]
# iteration: 1680| Acceptance rate: 0.2755952380952381| Log-Likelihood: -10864.726436642428| Proposal [ 0.07466466  0.29623947 -1.0870703   0.36734999  0.01368835]
# iteration: 1690| Acceptance rate: 0.2775147928994083| Log-Likelihood: -10865.62163410956| Proposal [ 0.07605802  0.29724509 -1.09434303  0.3681259   0.01367576]
# iteration: 1700| Acceptance rate: 0.2788235294117647| Log-Likelihood: -10864.170933463847| Proposal [ 0.0741942   0.29590215 -1.08443616  0.3668888   0.01373432]
# iteration: 1710| Acceptance rate: 0.2807017543859649| Log-Likelihood: -10864.318078865856| Proposal [ 0.0743205   0.29598211 -1.0860217   0.36799219  0.01351659]
# iteration: 1720| Acceptance rate: 0.28313953488372096| Log-Likelihood: -10866.157769007934| Proposal [ 0.07163006  0.29402925 -1.07290044  0.36752181  0.0133254 ]
# iteration: 1730| Acceptance rate: 0.2855491329479769| Log-Likelihood: -10865.050817823963| Proposal [ 0.07267066  0.29473794 -1.08185095  0.37202558  0.01249308]
# iteration: 1740| Acceptance rate: 0.28620689655172415| Log-Likelihood: -10865.269358868856| Proposal [ 0.07741874  0.29827942 -1.09710105  0.36403902  0.01467934]
# iteration: 1750| Acceptance rate: 0.2885714285714286| Log-Likelihood: -10865.5733801656| Proposal [ 0.07688342  0.29788957 -1.09459169  0.36405858  0.01461762]
# iteration: 1760| Acceptance rate: 0.28863636363636364| Log-Likelihood: -10867.64561207891| Proposal [ 0.07770756  0.29851911 -1.09599709  0.36128787  0.0152875 ]
# iteration: 1770| Acceptance rate: 0.28926553672316385| Log-Likelihood: -10865.482552638972| Proposal [ 0.0764028   0.29753774 -1.09249725  0.36425279  0.0145251 ]
# iteration: 1780| Acceptance rate: 0.29213483146067415| Log-Likelihood: -10864.043505794723| Proposal [ 0.07447571  0.29611499 -1.08510123  0.36614867  0.01391986]
# iteration: 1790| Acceptance rate: 0.293854748603352| Log-Likelihood: -10866.320528630851| Proposal [ 0.07788041  0.29875578 -1.08756294  0.3509732   0.01746935]
# iteration: 1800| Acceptance rate: 0.29555555555555557| Log-Likelihood: -10864.310378343473| Proposal [ 0.07517866  0.29658534 -1.09185688  0.36998192  0.01319166]
# iteration: 1810| Acceptance rate: 0.29668508287292816| Log-Likelihood: -10866.082288684607| Proposal [ 0.07807832  0.29885018 -1.09263898  0.35559173  0.01652203]
# iteration: 1820| Acceptance rate: 0.29725274725274725| Log-Likelihood: -10866.182104023314| Proposal [ 0.07781536  0.2986442  -1.09260901  0.35694255  0.01621048]
# iteration: 1830| Acceptance rate: 0.2983606557377049| Log-Likelihood: -10864.44547126475| Proposal [ 0.07557125  0.29692788 -1.08897387  0.36470061  0.01434152]
# iteration: 1840| Acceptance rate: 0.3| Log-Likelihood: -10865.114931184966| Proposal [ 0.07737084  0.29845743 -1.0791327   0.34425445  0.01882333]
# iteration: 1850| Acceptance rate: 0.30108108108108106| Log-Likelihood: -10864.280528748084| Proposal [ 0.07574541  0.29710278 -1.08578246  0.36022509  0.01529887]
# iteration: 1860| Acceptance rate: 0.30376344086021506| Log-Likelihood: -10863.634064510563| Proposal [ 0.07591181  0.29725849 -1.08368286  0.35700795  0.01599148]
# iteration: 1870| Acceptance rate: 0.3053475935828877| Log-Likelihood: -10863.613011629912| Proposal [ 0.07457002  0.29623901 -1.08094147  0.36101349  0.01500683]
# iteration: 1880| Acceptance rate: 0.3074468085106383| Log-Likelihood: -10864.211143323348| Proposal [ 0.07532979  0.29682162 -1.08205022  0.35825082  0.01566808]
# iteration: 1890| Acceptance rate: 0.30846560846560844| Log-Likelihood: -10862.70905304477| Proposal [ 0.07494952  0.2966183  -1.07413531  0.35142638  0.01705832]
# iteration: 1900| Acceptance rate: 0.31157894736842107| Log-Likelihood: -10863.680613021834| Proposal [ 0.07549627  0.2971264  -1.0675267   0.34117929  0.01926624]
# iteration: 1910| Acceptance rate: 0.312565445026178| Log-Likelihood: -10863.873930187949| Proposal [ 0.07535197  0.29705508 -1.06403816  0.33804867  0.01990723]
# iteration: 1920| Acceptance rate: 0.3145833333333333| Log-Likelihood: -10866.435955697094| Proposal [ 0.07650859  0.29813784 -1.04938871  0.3156253   0.02473455]
# iteration: 1930| Acceptance rate: 0.3155440414507772| Log-Likelihood: -10863.92306713796| Proposal [ 0.07550244  0.29720805 -1.06112314  0.33400614  0.02077125]
# iteration: 1940| Acceptance rate: 0.31597938144329896| Log-Likelihood: -10863.126027076301| Proposal [ 0.07487251  0.2965166  -1.07759031  0.35568426  0.01615695]
# iteration: 1950| Acceptance rate: 0.31794871794871793| Log-Likelihood: -10863.699321639657| Proposal [ 0.07457012  0.2962118  -1.08322861  0.36356316  0.01447201]
# iteration: 1960| Acceptance rate: 0.31887755102040816| Log-Likelihood: -10863.050652218035| Proposal [ 0.07398892  0.29582778 -1.07724863  0.35995386  0.01516624]
# iteration: 1970| Acceptance rate: 0.3208121827411167| Log-Likelihood: -10863.620329123265| Proposal [ 0.07477397  0.29662223 -1.0623403   0.33919752  0.01960392]
# iteration: 1980| Acceptance rate: 0.32323232323232326| Log-Likelihood: -10863.280352753069| Proposal [ 0.07369741  0.29565746 -1.07238812  0.35606823  0.01594971]
# iteration: 1990| Acceptance rate: 0.3256281407035176| Log-Likelihood: -10864.107392977037| Proposal [ 0.07456281  0.29649262 -1.05933604  0.33695893  0.02005066]
# iteration: 2000| Acceptance rate: 0.326| Log-Likelihood: -10862.074038690958| Proposal [ 0.07484292  0.29649659 -1.07731628  0.35553452  0.01618523]
# iteration: 2010| Acceptance rate: 0.32736318407960197| Log-Likelihood: -10868.366466697236| Proposal [ 0.07542509  0.29666801 -1.1010888   0.37897923  0.01133121]
# iteration: 2020| Acceptance rate: 0.3292079207920792| Log-Likelihood: -10865.251277886677| Proposal [ 0.07414172  0.29581144 -1.08859546  0.37180266  0.01269786]
# iteration: 2030| Acceptance rate: 0.3305418719211823| Log-Likelihood: -10863.611687846187| Proposal [ 0.07309025  0.29520426 -1.07046962  0.35712468  0.01566274]
# iteration: 2040| Acceptance rate: 0.3303921568627451| Log-Likelihood: -10864.876511783294| Proposal [ 0.0730369   0.29502913 -1.0815788   0.36979345  0.01300014]
# iteration: 2050| Acceptance rate: 0.3336585365853659| Log-Likelihood: -10863.325016218547| Proposal [ 0.07412758  0.29599534 -1.07232779  0.35373706  0.01648514]
# iteration: 2060| Acceptance rate: 0.33495145631067963| Log-Likelihood: -10863.755042952727| Proposal [ 0.07524178  0.29681254 -1.07703741  0.35312448  0.01673383]
# iteration: 2070| Acceptance rate: 0.3367149758454106| Log-Likelihood: -10864.855922646704| Proposal [ 0.07706523  0.2982992  -1.07229181  0.33823548  0.02005317]
# iteration: 2080| Acceptance rate: 0.33798076923076925| Log-Likelihood: -10864.353811451294| Proposal [ 0.07549318  0.29721121 -1.06021631  0.33304427  0.02097235]
# iteration: 2090| Acceptance rate: 0.3382775119617225| Log-Likelihood: -10863.09615724802| Proposal [ 0.07493741  0.29660649 -1.07431885  0.35169495  0.01700079]
# iteration: 2100| Acceptance rate: 0.34| Log-Likelihood: -10863.11122836277| Proposal [ 0.07425843  0.29605977 -1.0755      0.3565859   0.01590191]
# iteration: 2110| Acceptance rate: 0.3412322274881517| Log-Likelihood: -10864.577754027392| Proposal [ 0.075631    0.29733241 -1.05912121  0.33109774  0.02139545]
# iteration: 2120| Acceptance rate: 0.3410377358490566| Log-Likelihood: -10862.997667426664| Proposal [ 0.0740992   0.29604717 -1.0661177   0.34696205  0.01790328]
# iteration: 2130| Acceptance rate: 0.34131455399061034| Log-Likelihood: -10863.137034529547| Proposal [ 0.07385443  0.29582589 -1.06857835  0.35099399  0.01703115]
# iteration: 2140| Acceptance rate: 0.3429906542056075| Log-Likelihood: -10863.10497102532| Proposal [ 0.07471585  0.29649784 -1.06887573  0.34679171  0.01800535]
# iteration: 2150| Acceptance rate: 0.34325581395348836| Log-Likelihood: -10863.948566493264| Proposal [ 0.07279647  0.29499996 -1.06826788  0.35621619  0.01582186]
# iteration: 2160| Acceptance rate: 0.3449074074074074| Log-Likelihood: -10865.330077580924| Proposal [ 0.07457163  0.29661733 -1.04946676  0.325908    0.02236969]
# iteration: 2170| Acceptance rate: 0.3456221198156682| Log-Likelihood: -10863.391434308915| Proposal [ 0.07381576  0.29594186 -1.05638188  0.33759717  0.01983654]
# iteration: 2180| Acceptance rate: 0.3467889908256881| Log-Likelihood: -10864.771318779265| Proposal [ 0.07615333  0.29769552 -1.06300166  0.33267559  0.02112084]
# iteration: 2190| Acceptance rate: 0.34794520547945207| Log-Likelihood: -10863.882662774147| Proposal [ 0.07409811  0.29609168 -1.06235286  0.34276932  0.01878228]
# iteration: 2200| Acceptance rate: 0.3490909090909091| Log-Likelihood: -10863.830307130558| Proposal [ 0.07543991  0.29696058 -1.07764856  0.35276315  0.01683098]
# iteration: 2210| Acceptance rate: 0.3506787330316742| Log-Likelihood: -10863.960075040779| Proposal [ 0.07303211  0.29535613 -1.05399165  0.33905625  0.01944592]
# iteration: 2220| Acceptance rate: 0.3509009009009009| Log-Likelihood: -10863.02212345988| Proposal [ 0.07362431  0.29581187 -1.05470336  0.33673311  0.01999709]
# iteration: 2230| Acceptance rate: 0.34977578475336324| Log-Likelihood: -10863.09067499214| Proposal [ 0.07315611  0.29526712 -1.06951601  0.35571495  0.01596568]
# iteration: 2240| Acceptance rate: 0.35044642857142855| Log-Likelihood: -10864.492789684356| Proposal [ 0.07263281  0.29506023 -1.05254124  0.33954073  0.01930139]
# iteration: 2250| Acceptance rate: 0.3506666666666667| Log-Likelihood: -10862.745475003781| Proposal [ 0.07390161  0.29585183 -1.06950526  0.3517792   0.01687152]
# iteration: 2260| Acceptance rate: 0.35221238938053095| Log-Likelihood: -10863.656315673838| Proposal [ 0.07362641  0.29582783 -1.05351665  0.33539862  0.02027713]
# iteration: 2270| Acceptance rate: 0.35286343612334803| Log-Likelihood: -10863.453710410498| Proposal [ 0.07413486  0.2959512  -1.07649294  0.35834321  0.01551985]
# iteration: 2280| Acceptance rate: 0.35482456140350876| Log-Likelihood: -10865.637397239965| Proposal [ 0.07526262  0.29660165 -1.0960157   0.37417706  0.01232063]
# iteration: 2290| Acceptance rate: 0.3558951965065502| Log-Likelihood: -10862.731789957428| Proposal [ 0.07439753  0.29617543 -1.07499181  0.35528644  0.01618905]
# iteration: 2300| Acceptance rate: 0.35782608695652174| Log-Likelihood: -10865.027124619597| Proposal [ 0.07399301  0.29575605 -1.08348395  0.36688557  0.0137131 ]
# iteration: 2310| Acceptance rate: 0.3593073593073593| Log-Likelihood: -10862.19849336368| Proposal [ 0.07416709  0.29605196 -1.07018025  0.35113451  0.01703532]
# iteration: 2320| Acceptance rate: 0.3603448275862069| Log-Likelihood: -10864.071456445708| Proposal [ 0.07455082  0.29654428 -1.05419856  0.33129396  0.02123788]
# iteration: 2330| Acceptance rate: 0.36137339055793993| Log-Likelihood: -10865.252558942868| Proposal [ 0.07264988  0.29521798 -1.0404007   0.32591454  0.02216193]
# iteration: 2340| Acceptance rate: 0.36196581196581196| Log-Likelihood: -10863.114287631255| Proposal [ 0.07323545  0.29530619 -1.07139106  0.3573891   0.01562368]
# iteration: 2350| Acceptance rate: 0.3621276595744681| Log-Likelihood: -10863.176993550755| Proposal [ 0.07370714  0.29573436 -1.0665587   0.34951744  0.01732513]
# iteration: 2360| Acceptance rate: 0.36271186440677966| Log-Likelihood: -10863.833565533389| Proposal [ 0.07402127  0.29575493 -1.0854556   0.36893494  0.01328606]
# iteration: 2370| Acceptance rate: 0.36371308016877635| Log-Likelihood: -10864.063266485824| Proposal [ 0.07288599  0.29502805 -1.07175057  0.35962903  0.01511605]
# iteration: 2380| Acceptance rate: 0.36512605042016805| Log-Likelihood: -10865.663730849232| Proposal [ 0.07448027  0.29606553 -1.0895384   0.37107232  0.01288762]
# iteration: 2390| Acceptance rate: 0.36569037656903763| Log-Likelihood: -10863.98277192125| Proposal [ 0.07280219  0.2950211  -1.06681757  0.35456984  0.01616835]
# iteration: 2400| Acceptance rate: 0.36833333333333335| Log-Likelihood: -10863.668716566253| Proposal [ 0.07348422  0.29556782 -1.06606805  0.35014045  0.01716849]
# iteration: 2410| Acceptance rate: 0.36887966804979255| Log-Likelihood: -10862.739933495737| Proposal [ 0.07474436  0.29641882 -1.07745855  0.35621031  0.01603189]
# iteration: 2420| Acceptance rate: 0.3694214876033058| Log-Likelihood: -10862.395853166548| Proposal [ 0.07419721  0.29607644 -1.07036181  0.35117442  0.01702772]
# iteration: 2430| Acceptance rate: 0.37119341563786007| Log-Likelihood: -10864.188173136201| Proposal [ 0.07560544  0.29700181 -1.08518101  0.36028907  0.01526906]
# iteration: 2440| Acceptance rate: 0.3721311475409836| Log-Likelihood: -10863.31018950604| Proposal [ 0.07488136  0.29653434 -1.0768794   0.35484192  0.01633271]
# iteration: 2450| Acceptance rate: 0.3730612244897959| Log-Likelihood: -10862.463092462724| Proposal [ 0.07498456  0.29666024 -1.07313219  0.35012015  0.01733406]
# iteration: 2460| Acceptance rate: 0.37357723577235774| Log-Likelihood: -10863.452852203502| Proposal [ 0.07539007  0.29702615 -1.06926957  0.3436765   0.01872787]
# iteration: 2470| Acceptance rate: 0.3757085020242915| Log-Likelihood: -10863.276528026854| Proposal [ 0.0749538   0.2965574  -1.07952721  0.35741585  0.01580234]
# iteration: 2480| Acceptance rate: 0.37701612903225806| Log-Likelihood: -10863.490189507602| Proposal [ 0.07421912  0.2959983  -1.07744741  0.358974    0.01540279]
# iteration: 2490| Acceptance rate: 0.3783132530120482| Log-Likelihood: -10862.875718392605| Proposal [ 0.07493904  0.2966608  -1.0697675   0.34661319  0.01806798]
# iteration: 2500| Acceptance rate: 0.3788| Log-Likelihood: -10864.416474466005| Proposal [ 0.07467339  0.29630597 -1.08219898  0.36187039  0.01483747]
# iteration: 2510| Acceptance rate: 0.3800796812749004| Log-Likelihood: -10863.498142338234| Proposal [ 0.07320129  0.29529036 -1.0702787   0.35633163  0.01584371]
# iteration: 2520| Acceptance rate: 0.37976190476190474| Log-Likelihood: -10863.814254111672| Proposal [ 0.07364879  0.29562608 -1.07261057  0.35655975  0.01583372]
# iteration: 2530| Acceptance rate: 0.3798418972332016| Log-Likelihood: -10863.04745701509| Proposal [ 0.07369603  0.29574395 -1.06643161  0.34941201  0.01733235]
# iteration: 2540| Acceptance rate: 0.38228346456692913| Log-Likelihood: -10864.125838925518| Proposal [ 0.07485424  0.29674902 -1.05687365  0.33268143  0.02098054]
# iteration: 2550| Acceptance rate: 0.3835294117647059| Log-Likelihood: -10863.768548090462| Proposal [ 0.07601784  0.29747278 -1.07228446  0.34374687  0.01878857]
# iteration: 2560| Acceptance rate: 0.385546875| Log-Likelihood: -10864.065086504941| Proposal [ 0.0743489   0.29646607 -1.05428192  0.33234242  0.02093003]
# iteration: 2570| Acceptance rate: 0.38754863813229573| Log-Likelihood: -10862.966685548668| Proposal [ 0.07458582  0.29630617 -1.07456229  0.35384561  0.01652953]
# iteration: 2580| Acceptance rate: 0.3887596899224806| Log-Likelihood: -10863.621944888451| Proposal [ 0.07556638  0.29695518 -1.08336196  0.35851623  0.0156675 ]
# iteration: 2590| Acceptance rate: 0.39034749034749033| Log-Likelihood: -10863.089644548027| Proposal [ 0.07384892  0.29594433 -1.05927336  0.34063219  0.01919453]
# iteration: 2600| Acceptance rate: 0.39076923076923076| Log-Likelihood: -10862.825711261969| Proposal [ 0.07295838  0.29516365 -1.06675142  0.3536485   0.0163627 ]
# iteration: 2610| Acceptance rate: 0.3904214559386973| Log-Likelihood: -10863.80878514994| Proposal [ 0.07380595  0.29584191 -1.06225311  0.34422474  0.01846337]
# iteration: 2620| Acceptance rate: 0.3916030534351145| Log-Likelihood: -10863.453362443479| Proposal [ 0.0741217   0.29597286 -1.06657472  0.34746758  0.01787023]
# iteration: 2630| Acceptance rate: 0.3923954372623574| Log-Likelihood: -10864.070361706817| Proposal [ 0.07336532  0.29547216 -1.04984082  0.33293171  0.02092544]
# iteration: 2640| Acceptance rate: 0.3931818181818182| Log-Likelihood: -10864.279844772102| Proposal [ 0.07375619  0.29565537 -1.04823     0.32926678  0.02185257]
# iteration: 2650| Acceptance rate: 0.3939622641509434| Log-Likelihood: -10864.033437522323| Proposal [ 0.07452345  0.29615741 -1.08601488  0.36689516  0.01375545]
# iteration: 2660| Acceptance rate: 0.3951127819548872| Log-Likelihood: -10863.503921148145| Proposal [ 0.0738828   0.29560766 -1.07836769  0.36192353  0.01484247]
# iteration: 2670| Acceptance rate: 0.39588014981273406| Log-Likelihood: -10862.972132592786| Proposal [ 0.07465226  0.29638744 -1.07565095  0.35465407  0.01633269]
# iteration: 2680| Acceptance rate: 0.3962686567164179| Log-Likelihood: -10863.400874044255| Proposal [ 0.0753089   0.29700016 -1.06307661  0.33724635  0.02009752]
# iteration: 2690| Acceptance rate: 0.3973977695167286| Log-Likelihood: -10862.53888942387| Proposal [ 0.07519801  0.29724409 -1.07594246  0.35153526  0.01669303]
# iteration: 2700| Acceptance rate: 0.3962962962962963| Log-Likelihood: -10862.406512591288| Proposal [ 0.07500617  0.29684727 -1.06967335  0.34597945  0.01809986]
# iteration: 2710| Acceptance rate: 0.396309963099631| Log-Likelihood: -10862.458194424686| Proposal [ 0.07390585  0.29562997 -1.07075501  0.35342842  0.01669759]
# iteration: 2720| Acceptance rate: 0.39595588235294116| Log-Likelihood: -10863.266891918029| Proposal [ 0.0756865   0.29725491 -1.07600769  0.34952806  0.01746973]
# iteration: 2730| Acceptance rate: 0.3967032967032967| Log-Likelihood: -10864.086584427476| Proposal [ 0.07598945  0.29746942 -1.08528766  0.35816502  0.01561907]
# iteration: 2740| Acceptance rate: 0.3981751824817518| Log-Likelihood: -10863.618481296482| Proposal [ 0.0749408   0.29660125 -1.06741708  0.34410081  0.01866778]
# iteration: 2750| Acceptance rate: 0.39890909090909094| Log-Likelihood: -10863.464170111565| Proposal [ 0.07308597  0.29490825 -1.0600671   0.34609917  0.01831512]
# iteration: 2760| Acceptance rate: 0.3996376811594203| Log-Likelihood: -10863.58307187257| Proposal [ 0.07562853  0.29721252 -1.06990358  0.3431192   0.01886477]
# iteration: 2770| Acceptance rate: 0.4007220216606498| Log-Likelihood: -10863.941303255944| Proposal [ 0.07630867  0.29816682 -1.0738872   0.34336186  0.01850482]
# iteration: 2780| Acceptance rate: 0.4010791366906475| Log-Likelihood: -10862.958195458741| Proposal [ 0.07530205  0.29705609 -1.07123528  0.34616975  0.01809551]
# iteration: 2790| Acceptance rate: 0.4025089605734767| Log-Likelihood: -10863.008642114644| Proposal [ 0.07648713  0.29961393 -1.0787761   0.34606843  0.01684211]
# iteration: 2800| Acceptance rate: 0.40285714285714286| Log-Likelihood: -10863.4695212528| Proposal [ 0.07290208  0.29526857 -1.05900816  0.34523596  0.01807505]
# iteration: 2810| Acceptance rate: 0.402846975088968| Log-Likelihood: -10862.506769317217| Proposal [ 0.07432383  0.29834377 -1.06854573  0.34564525  0.01644986]
# iteration: 2820| Acceptance rate: 0.40425531914893614| Log-Likelihood: -10863.383461783755| Proposal [ 0.0753898   0.29898545 -1.07275031  0.34491341  0.01683563]
# iteration: 2830| Acceptance rate: 0.4045936395759717| Log-Likelihood: -10864.169040062101| Proposal [ 0.07277579  0.2944882  -1.05319294  0.34040913  0.01968651]
# iteration: 2840| Acceptance rate: 0.40492957746478875| Log-Likelihood: -10863.902197602592| Proposal [ 0.07331045  0.29039815 -1.08864365  0.38252609  0.0142436 ]
# iteration: 2850| Acceptance rate: 0.4049122807017544| Log-Likelihood: -10863.874075607073| Proposal [ 0.07523548  0.29506081 -1.08601049  0.36533078  0.01551063]
# iteration: 2860| Acceptance rate: 0.40559440559440557| Log-Likelihood: -10863.06897271425| Proposal [ 0.07482564  0.31053269 -1.03204166  0.28728185  0.01947746]
# iteration: 2870| Acceptance rate: 0.4059233449477352| Log-Likelihood: -10863.975897070035| Proposal [ 0.07365476  0.30828972 -1.02567252  0.28819487  0.02030288]
# iteration: 2880| Acceptance rate: 0.4065972222222222| Log-Likelihood: -10863.075334704154| Proposal [ 0.07530491  0.2970644  -1.07887996  0.3545501   0.01625854]
# iteration: 2890| Acceptance rate: 0.4072664359861592| Log-Likelihood: -10863.749466545192| Proposal [ 0.07543955  0.30428638 -1.05061372  0.31336095  0.01938168]
# iteration: 2900| Acceptance rate: 0.4072413793103448| Log-Likelihood: -10863.229817950933| Proposal [ 0.07452423  0.29737823 -1.06479341  0.3419501   0.01819912]
# iteration: 2910| Acceptance rate: 0.40756013745704467| Log-Likelihood: -10863.294237842558| Proposal [ 0.07442181  0.3012332  -1.04304022  0.31337403  0.02118317]
# iteration: 2920| Acceptance rate: 0.40821917808219177| Log-Likelihood: -10863.32999012122| Proposal [ 0.07549409  0.3024373  -1.05649974  0.32204537  0.0190522 ]
# iteration: 2930| Acceptance rate: 0.4085324232081911| Log-Likelihood: -10863.340624776913| Proposal [ 0.07531078  0.29301521 -1.08364138  0.36511284  0.0173048 ]
# iteration: 2940| Acceptance rate: 0.4098639455782313| Log-Likelihood: -10864.684152656637| Proposal [ 0.07325068  0.28631956 -1.0890194   0.38858422  0.01625239]
# iteration: 2950| Acceptance rate: 0.40983050847457625| Log-Likelihood: -10864.736937385107| Proposal [ 0.07255109  0.27792359 -1.10192445  0.41682754  0.01653002]
# iteration: 2960| Acceptance rate: 0.41047297297297297| Log-Likelihood: -10864.01175514829| Proposal [ 0.07235525  0.30397285 -1.03300837  0.30745867  0.01874158]
# iteration: 2970| Acceptance rate: 0.4121212121212121| Log-Likelihood: -10863.037432292525| Proposal [ 0.07393231  0.33342455 -0.97607281  0.19926771  0.0191384 ]
# iteration: 2980| Acceptance rate: 0.4134228187919463| Log-Likelihood: -10863.86094451622| Proposal [ 0.07452014  0.28648199 -1.1033411   0.39874719  0.01479746]
# ...
# iteration: 17030| Acceptance rate: 0.4038755137991779| Log-Likelihood: -10860.068714711448| Proposal [ 0.07431825  0.23310459 -1.01525305  0.07196264  0.01640105]
# iteration: 17040| Acceptance rate: 0.40387323943661974| Log-Likelihood: -10860.7664188732| Proposal [ 0.06795924  0.29040083 -1.66491321  0.03724946  0.01565799]
# iteration: 17050| Acceptance rate: 0.4038709677419355| Log-Likelihood: -10861.659898177015| Proposal [ 0.06926594  0.3425147  -1.64639417  0.03009352  0.01898893]
# iteration: 17060| Acceptance rate: 0.40398593200468935| Log-Likelihood: -10861.149570323598| Proposal [ 0.07161594  0.24285099 -1.26458375  0.04784137  0.02126349]
# iteration: 17070| Acceptance rate: 0.40398359695372| Log-Likelihood: -10867.8352448819| Proposal [ 0.07530868  0.41050783 -0.58044571  0.0606265   0.02439291]
# iteration: 17080| Acceptance rate: 0.40398126463700235| Log-Likelihood: -10860.877998389122| Proposal [ 0.07185857  0.18758631 -1.16297368  0.04600595  0.02019238]
# iteration: 17090| Acceptance rate: 0.40392042129900524| Log-Likelihood: -10859.791114969496| Proposal [ 0.07038019  0.14980567 -1.43813166  0.02910898  0.01703705]
# iteration: 17100| Acceptance rate: 0.40380116959064327| Log-Likelihood: -10861.598456832524| Proposal [ 0.07552505  0.11659507 -0.96873258  0.05082911  0.0182422 ]
# iteration: 17110| Acceptance rate: 0.4037405026300409| Log-Likelihood: -10864.492910913621| Proposal [ 0.07485008  0.38458911 -0.84262539  0.10626568  0.01392211]
# iteration: 17120| Acceptance rate: 0.40373831775700936| Log-Likelihood: -10862.703553639923| Proposal [ 0.07035121  0.3657769  -1.2038224   0.05342938  0.01580521]
# iteration: 17130| Acceptance rate: 0.4036193812025686| Log-Likelihood: -10861.908790407426| Proposal [ 0.07133882  0.22286571 -1.26582517  0.06038593  0.01264787]
# iteration: 17140| Acceptance rate: 0.40361726954492416| Log-Likelihood: -10860.032919142479| Proposal [ 0.07522733  0.18213217 -0.94326089  0.11183756  0.01447206]
# iteration: 17150| Acceptance rate: 0.40355685131195335| Log-Likelihood: -10862.096800574564| Proposal [ 0.07743962  0.28760929 -0.81251533  0.13737058  0.01773639]
# iteration: 17160| Acceptance rate: 0.4034965034965035| Log-Likelihood: -10861.947590849551| Proposal [ 0.07778844  0.20499247 -0.9026903   0.15843649  0.01320067]
# iteration: 17170| Acceptance rate: 0.40343622597553874| Log-Likelihood: -10862.757007795435| Proposal [ 0.0758343   0.33979005 -1.04612094  0.12632538  0.01727997]
# iteration: 17180| Acceptance rate: 0.4034342258440047| Log-Likelihood: -10860.784918298868| Proposal [ 0.07481918  0.20458865 -1.12469599  0.11816341  0.01477644]
# iteration: 17190| Acceptance rate: 0.40337405468295523| Log-Likelihood: -10862.204689237986| Proposal [ 0.0707397   0.09411269 -1.30543109  0.06783966  0.01379961]
# iteration: 17200| Acceptance rate: 0.40331395348837207| Log-Likelihood: -10863.20577438142| Proposal [ 0.06645709  0.0483645  -1.81988179  0.0283362   0.01790313]
# iteration: 17210| Acceptance rate: 0.4031377106333527| Log-Likelihood: -10860.438361782162| Proposal [ 0.06763521  0.24276667 -1.60414141  0.03566372  0.01896852]
# iteration: 17220| Acceptance rate: 0.4030778164924506| Log-Likelihood: -10860.115288367304| Proposal [ 0.07142143  0.19212745 -1.14924897  0.06329881  0.01542024]
# iteration: 17230| Acceptance rate: 0.40290191526407426| Log-Likelihood: -10860.351790865754| Proposal [ 0.07149806  0.2237227  -1.10257957  0.05514801  0.01857419]
# iteration: 17240| Acceptance rate: 0.40278422273781905| Log-Likelihood: -10862.465319921836| Proposal [ 0.06914227  0.19510415 -1.3513027   0.02063837  0.01526408]
# iteration: 17250| Acceptance rate: 0.4026666666666667| Log-Likelihood: -10860.938570476535| Proposal [ 0.07127314  0.24286452 -1.28219066  0.05721927  0.01417584]
# iteration: 17260| Acceptance rate: 0.4025492468134415| Log-Likelihood: -10861.133921825354| Proposal [ 0.06870277  0.16341597 -1.69762768  0.02377734  0.01382161]
# iteration: 17270| Acceptance rate: 0.402489866821077| Log-Likelihood: -10860.359974195788| Proposal [ 0.0698245   0.24243976 -1.49344629  0.03916487  0.01419525]
# iteration: 17280| Acceptance rate: 0.40260416666666665| Log-Likelihood: -10863.467417596465| Proposal [ 0.07178632  0.41632666 -0.95705443  0.0479152   0.01636057]
# iteration: 17290| Acceptance rate: 0.4026604973973395| Log-Likelihood: -10867.041574669158| Proposal [ 0.06959444  0.49056079 -0.78654375  0.01950711  0.02436658]
# iteration: 17300| Acceptance rate: 0.4025433526011561| Log-Likelihood: -10863.252939204765| Proposal [ 0.06714022  0.39628188 -1.47904761  0.01299098  0.01974722]
# iteration: 17310| Acceptance rate: 0.4025996533795494| Log-Likelihood: -10860.91210146213| Proposal [ 0.07115745  0.22338298 -1.41950319  0.03696032  0.01323387]
# iteration: 17320| Acceptance rate: 0.402540415704388| Log-Likelihood: -10862.509298827597| Proposal [ 0.07283809  0.3142218  -0.89873842  0.03820417  0.01701957]
# iteration: 17330| Acceptance rate: 0.4024235429890364| Log-Likelihood: -10862.419926024384| Proposal [ 0.07375221  0.40301859 -0.93776446  0.03497787  0.01620586]
# iteration: 17340| Acceptance rate: 0.40236447520184543| Log-Likelihood: -10860.152227688894| Proposal [ 0.07427028  0.11644201 -1.13432242  0.10033396  0.01531903]
# iteration: 17350| Acceptance rate: 0.4022478386167147| Log-Likelihood: -10860.814546979636| Proposal [ 0.07613353  0.13165512 -0.84605864  0.12322624  0.01639799]
# iteration: 17360| Acceptance rate: 0.4021889400921659| Log-Likelihood: -10860.028390089861| Proposal [ 0.0726769   0.11963274 -1.21143119  0.09302635  0.01552469]
# iteration: 17370| Acceptance rate: 0.40224525043177894| Log-Likelihood: -10861.49554482748| Proposal [ 0.06874319  0.27766897 -1.70485647  0.01864111  0.01956044]
# iteration: 17380| Acceptance rate: 0.4021288837744534| Log-Likelihood: -10860.9015827168| Proposal [ 0.07252016  0.25159952 -1.34157516  0.05173169  0.01521611]
# iteration: 17390| Acceptance rate: 0.4019551466359977| Log-Likelihood: -10861.200125703876| Proposal [ 0.07262633  0.25542324 -1.39355585  0.05186548  0.0146929 ]
# iteration: 17400| Acceptance rate: 0.4018390804597701| Log-Likelihood: -10860.85446067293| Proposal [ 0.07555741  0.24451126 -1.02352587  0.1037264   0.01461738]
# iteration: 17410| Acceptance rate: 0.40178058587018955| Log-Likelihood: -10860.43396546566| Proposal [ 0.07348829  0.14470129 -1.18790934  0.09384185  0.01650826]
# iteration: 17420| Acceptance rate: 0.40166475315729044| Log-Likelihood: -10859.480530337303| Proposal [ 0.07169987  0.15235562 -1.31823545  0.04949884  0.01816471]
# iteration: 17430| Acceptance rate: 0.4014916810097533| Log-Likelihood: -10859.230947334041| Proposal [ 0.07080976  0.15110191 -1.402157    0.03134341  0.01775547]
# iteration: 17440| Acceptance rate: 0.4014334862385321| Log-Likelihood: -10859.65835801358| Proposal [ 0.07033423  0.14633651 -1.57762495  0.02321135  0.01579737]
# iteration: 17450| Acceptance rate: 0.40131805157593126| Log-Likelihood: -10860.079244146538| Proposal [ 0.0741818   0.21918159 -1.03683717  0.08642224  0.01549591]
# iteration: 17460| Acceptance rate: 0.40131729667812144| Log-Likelihood: -10863.321607839383| Proposal [ 0.07521837  0.27879777 -0.65236369  0.05802046  0.01589104]
# iteration: 17470| Acceptance rate: 0.4012593016599886| Log-Likelihood: -10863.84903619655| Proposal [ 0.07685425  0.22523673 -0.72178103  0.07636821  0.01346696]
# iteration: 17480| Acceptance rate: 0.40131578947368424| Log-Likelihood: -10861.091990391036| Proposal [ 0.0732936   0.2464255  -1.26830617  0.0947961   0.01856676]
# iteration: 17490| Acceptance rate: 0.40125786163522015| Log-Likelihood: -10861.264819420172| Proposal [ 0.07564435  0.21376525 -0.81825016  0.06892769  0.01528316]
# iteration: 17500| Acceptance rate: 0.40131428571428573| Log-Likelihood: -10860.362300179877| Proposal [ 0.06969241  0.12621834 -1.85253751  0.02351941  0.01686321]
# iteration: 17510| Acceptance rate: 0.4011993146773272| Log-Likelihood: -10860.847682417932| Proposal [ 0.06993106  0.17881609 -1.96150047  0.02043059  0.01589747]
# iteration: 17520| Acceptance rate: 0.401027397260274| Log-Likelihood: -10860.338937159297| Proposal [ 0.07384118  0.21389005 -1.02722897  0.06062747  0.01455254]
# iteration: 17530| Acceptance rate: 0.40096976611523105| Log-Likelihood: -10859.57355300823| Proposal [ 0.07137647  0.20937471 -1.23297218  0.04286092  0.01616585]
# iteration: 17540| Acceptance rate: 0.4008551881413911| Log-Likelihood: -10860.462790419395| Proposal [ 0.07313394  0.13993203 -1.19618542  0.10167527  0.01718242]
# iteration: 17550| Acceptance rate: 0.40074074074074073| Log-Likelihood: -10859.799665468092| Proposal [ 0.07112667  0.15530113 -1.443643    0.04574438  0.01774421]
# iteration: 17560| Acceptance rate: 0.4006833712984055| Log-Likelihood: -10860.230341732324| Proposal [ 0.07409033  0.12098138 -1.1468149   0.07994083  0.01670373]
# iteration: 17570| Acceptance rate: 0.40068298235628913| Log-Likelihood: -10860.809843732048| Proposal [ 0.07472697  0.18818648 -0.90841849  0.05627467  0.01934271]
# iteration: 17580| Acceptance rate: 0.40051194539249146| Log-Likelihood: -10859.757356110938| Proposal [ 0.0734399   0.18426872 -1.03293602  0.08963105  0.01730389]
# iteration: 17590| Acceptance rate: 0.4004548038658329| Log-Likelihood: -10860.686745226929| Proposal [ 0.07207287  0.19252185 -1.44339401  0.04717525  0.01704432]
# iteration: 17600| Acceptance rate: 0.4003409090909091| Log-Likelihood: -10859.441246517434| Proposal [ 0.07383446  0.1182333  -1.18303048  0.06293017  0.01903035]
# iteration: 17610| Acceptance rate: 0.40022714366837026| Log-Likelihood: -10859.738637053739| Proposal [ 0.07395112  0.16500349 -0.96084903  0.09357352  0.01809955]
# iteration: 17620| Acceptance rate: 0.40011350737797957| Log-Likelihood: -10860.097185978473| Proposal [ 0.07068934  0.14813454 -1.51839306  0.04581167  0.01793052]
# iteration: 17630| Acceptance rate: 0.4| Log-Likelihood: -10860.255533781956| Proposal [ 0.07193261  0.17524401 -1.22137016  0.08458371  0.01947308]
# iteration: 17640| Acceptance rate: 0.4001700680272109| Log-Likelihood: -10860.496607398043| Proposal [ 0.06985042  0.23505991 -1.65808913  0.02190305  0.01603362]
# iteration: 17650| Acceptance rate: 0.4001699716713881| Log-Likelihood: -10861.224993389782| Proposal [ 0.07212911  0.21857895 -1.57987313  0.04102112  0.01772586]
# iteration: 17660| Acceptance rate: 0.4003397508493771| Log-Likelihood: -10859.910234042502| Proposal [ 0.07302153  0.18594263 -1.30991348  0.04469696  0.01766503]
# iteration: 17670| Acceptance rate: 0.4003961516694963| Log-Likelihood: -10860.718684487734| Proposal [ 0.06970944  0.31646149 -1.53655599  0.01826171  0.01437731]
# iteration: 17680| Acceptance rate: 0.4004524886877828| Log-Likelihood: -10860.294458546394| Proposal [ 0.07455047  0.16414993 -1.01558739  0.0560412   0.01504569]
# iteration: 17690| Acceptance rate: 0.4005087620124364| Log-Likelihood: -10861.016757316836| Proposal [ 0.07317209  0.32265137 -1.21667153  0.03335624  0.01593272]
# iteration: 17700| Acceptance rate: 0.4004519774011299| Log-Likelihood: -10862.494561597057| Proposal [ 0.0790491   0.30844619 -0.9340079   0.02595678  0.01927783]
# iteration: 17710| Acceptance rate: 0.40033879164313946| Log-Likelihood: -10862.884965573125| Proposal [ 0.07913101  0.33473074 -0.63487043  0.05202443  0.0164432 ]
# iteration: 17720| Acceptance rate: 0.4002257336343115| Log-Likelihood: -10862.620387318324| Proposal [ 0.07522431  0.37230376 -1.03784006  0.04351117  0.01531756]
# iteration: 17730| Acceptance rate: 0.4002820078962211| Log-Likelihood: -10860.920292283856| Proposal [ 0.06985184  0.29862997 -1.44136818  0.03209279  0.01645128]
# iteration: 17740| Acceptance rate: 0.4004509582863585| Log-Likelihood: -10861.539399786456| Proposal [ 0.07807062  0.24628126 -0.93727776  0.07565156  0.0200055 ]
# iteration: 17750| Acceptance rate: 0.4004507042253521| Log-Likelihood: -10861.306004635699| Proposal [ 0.07153407  0.23633542 -1.7473778   0.01918483  0.02096585]
# iteration: 17760| Acceptance rate: 0.4002815315315315| Log-Likelihood: -10859.89058974224| Proposal [ 0.07012899  0.26757963 -1.72643354  0.01953385  0.01871162]
# iteration: 17770| Acceptance rate: 0.40016882386043895| Log-Likelihood: -10861.081631873596| Proposal [ 0.067768    0.2732082  -1.62805062  0.02288827  0.01430217]
# iteration: 17780| Acceptance rate: 0.4001124859392576| Log-Likelihood: -10861.108308013923| Proposal [ 0.07763565  0.14546273 -0.89671851  0.0654992   0.01550641]
# iteration: 17790| Acceptance rate: 0.40016863406408093| Log-Likelihood: -10860.188797786| Proposal [ 0.07531504  0.22828427 -1.14299135  0.04148214  0.01700712]
# iteration: 17800| Acceptance rate: 0.4001123595505618| Log-Likelihood: -10861.75163041882| Proposal [ 0.07868839  0.2382746  -0.91176459  0.06332486  0.01464466]
# iteration: 17810| Acceptance rate: 0.3999438517686693| Log-Likelihood: -10861.330134430818| Proposal [ 0.07736786  0.26442577 -1.03237277  0.04718815  0.01403961]
# iteration: 17820| Acceptance rate: 0.3999438832772166| Log-Likelihood: -10859.425386880914| Proposal [ 0.07375803  0.19940052 -1.37639338  0.04509685  0.01700639]
# iteration: 17830| Acceptance rate: 0.3997195737521032| Log-Likelihood: -10859.425386880914| Proposal [ 0.07375803  0.19940052 -1.37639338  0.04509685  0.01700639]
# iteration: 17840| Acceptance rate: 0.39971973094170404| Log-Likelihood: -10861.00923520394| Proposal [ 0.07708569  0.16847307 -0.85606659  0.09003904  0.01644763]
# iteration: 17850| Acceptance rate: 0.3996078431372549| Log-Likelihood: -10861.533220482685| Proposal [ 0.07111116  0.1494843  -1.11121848  0.07203093  0.01319301]
# iteration: 17860| Acceptance rate: 0.399552071668533| Log-Likelihood: -10860.06909004016| Proposal [ 0.07446949  0.11237701 -1.05107044  0.07642611  0.01444888]
# iteration: 17870| Acceptance rate: 0.39938444320089533| Log-Likelihood: -10859.370058073435| Proposal [ 0.07324307  0.1639752  -1.18845525  0.06617382  0.01507888]
# iteration: 17880| Acceptance rate: 0.39927293064876956| Log-Likelihood: -10859.89460397491| Proposal [ 0.07314661  0.13837681 -1.15745989  0.07197758  0.01483541]
# iteration: 17890| Acceptance rate: 0.39927333705980994| Log-Likelihood: -10860.75021914119| Proposal [ 0.07401739  0.23241151 -1.11396392  0.06531763  0.01711294]
# iteration: 17900| Acceptance rate: 0.39932960893854746| Log-Likelihood: -10859.760565879958| Proposal [ 0.06935993  0.18687792 -1.46089111  0.05213025  0.01549912]
# iteration: 17910| Acceptance rate: 0.3993858179787828| Log-Likelihood: -10861.094165549606| Proposal [ 0.07276627  0.19801366 -1.44437147  0.01815725  0.01515672]
# iteration: 17920| Acceptance rate: 0.39927455357142855| Log-Likelihood: -10860.829083922717| Proposal [ 0.07770195  0.19012849 -1.047911    0.06274545  0.0165172 ]
# iteration: 17930| Acceptance rate: 0.39921918572225323| Log-Likelihood: -10860.335984795089| Proposal [ 0.07628463  0.14551503 -1.01892224  0.04569906  0.01465905]
# iteration: 17940| Acceptance rate: 0.3992196209587514| Log-Likelihood: -10859.548838512286| Proposal [ 0.06918562  0.18419079 -1.44485913  0.04610257  0.01628871]
# iteration: 17950| Acceptance rate: 0.3992757660167131| Log-Likelihood: -10860.963430207687| Proposal [ 0.0717838   0.27181015 -1.56443541  0.03692442  0.01888461]
# iteration: 17960| Acceptance rate: 0.39933184855233855| Log-Likelihood: -10862.744472772178| Proposal [ 0.06774919  0.35521841 -1.69184673  0.01696014  0.01439697]
# iteration: 17970| Acceptance rate: 0.39944351697273234| Log-Likelihood: -10860.870754839174| Proposal [ 0.07125071  0.24034816 -1.38854148  0.05071129  0.0134935 ]
# iteration: 17980| Acceptance rate: 0.39938820912124584| Log-Likelihood: -10859.697546622792| Proposal [ 0.07142839  0.21099523 -1.41551019  0.03851746  0.01548114]
# iteration: 17990| Acceptance rate: 0.3993885491939967| Log-Likelihood: -10861.91833415445| Proposal [ 0.07041954  0.39005186 -1.91354037  0.02521808  0.01820816]
# iteration: 18000| Acceptance rate: 0.3992777777777778| Log-Likelihood: -10861.65284665589| Proposal [ 0.07042823  0.41297805 -1.98477998  0.01623556  0.01674375]

# %%
burn_in = 20000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10858.430218349851
# The Maximum Likelihood Estimate is [ 0.07362342  0.14608916 -1.09395844  0.08291849  0.01756201] w/ LL of -10858.430218349851

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5026.622756209024
# Root Mean Squared Error for beta 0.09944834272923211

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
np.savez(f'../pmcmc_output/SEIR_OU_PMCMC.npz',distribution = pmcmc_output['MLE_particle_dist'], 
         observations = pmcmc_output['MLE_particle_observations'], 
         params = pmcmc_output['accepted_params'], 
         likelihood = pmcmc_output['Log Likelihood']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.savez(f'../pmcmc_output/SEIR_OU_PMCMC.npz',distribution = pmcmc_output['MLE_particle_dist'],
#       2          observations = pmcmc_output['MLE_particle_observations'],
#       3          params = pmcmc_output['accepted_params'],
#       4          likelihood = pmcmc_output['Log Likelihood']
#       5 )
#
# NameError: name 'np' is not defined
