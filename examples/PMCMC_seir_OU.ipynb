# %%
import sys
sys.path.append('../')

import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import pandas as pd
from particle_filter import particlefilter
from pmcmc import particlemcmc
from math_utils import nbinom_logpmf

# %%
'''Import data'''

data = pd.read_csv('..\\data_sets\\ou_data_nbinom.csv').to_numpy()
state = pd.read_csv('..\\data_sets\\ou_state_nbinom.csv').to_numpy()
betas = pd.read_csv('..\\data_sets\\ou_betas_nbinom.csv').to_numpy()

# %%
def SEIR_model(particles,observations,t,dt,model_params,rng):
    '''Definition of SEIR model as described in Calvetti's paper. Difference 
    is the use of Tau leaping to introduce stochasticity into the system and continuous log-normal OU process definition for beta.'''
    gamma,sig,mu,lam,_ = model_params

    A = np.exp(-lam * dt)
    M = mu * (np.exp(-lam * dt) - 1)
    C = sig * np.sqrt(1 - np.exp(-2 * lam * dt))

    '''Tau leaping. Non estimated parameters are hard coded. '''

    for index in range(particles.shape[0]):

        new_E = rng.poisson((particles[index,4,t] * (particles[index, 1, t] + 0.1 * particles[index, 2, t]) * particles[index, 0, t])/np.sum(particles[index,:,t]) * dt)
        new_I = rng.poisson((1/7 * particles[index,1,t]) * dt)
        new_ER = rng.poisson((gamma * particles[index,1,t]) * dt)
        new_IR = rng.poisson((gamma * particles[index,2,t]) * dt)
        new_D = rng.poisson((0.004 * particles[index,2,t]) * dt)

        particles[index,0,t] = np.maximum(0.,particles[index,0,t] - new_E) #S
        particles[index,1,t] = np.maximum(0.,particles[index,1,t] + new_E - new_I - new_ER) #E
        particles[index,2,t] = np.maximum(0.,particles[index,2,t] + new_I - new_IR - new_D) #I
        particles[index,3,t] = np.maximum(0.,particles[index,3,t] + new_ER + new_IR)
        particles[index,4,t] = np.exp(A * np.log(particles[index,4,t]) - M + C * rng.standard_normal())

        observations[index,0,t] = particles[index,2,t]

    return particles,observations

def SEIR_Obs(data_point, particle_observations, model_params):
    r = 1/model_params[4]
    weights = nbinom_logpmf(x = data_point,p = r/(r + particle_observations[:,0]),n = np.array([r]))
    weights[np.isinf(weights)] = -10_000
    return weights

# %%
'''True parameter values'''
rng = np.random.default_rng(0)

gamma = 1/14
R = 50
lam = 1/20
mean_ou = -1.1
sig = 0.2


T = 120
dt = 0.1
t_vec = np.arange(0,T,dt)

def SEIR_init(num_particles, model_dim, rng):
    particles_0 = np.zeros((num_particles,model_dim))
    particles_0[:,0] = 100_000
    E_I_init = rng.integers(1,5,size = (num_particles * 2)).reshape((num_particles,2))
    particles_0[:,0] -= np.sum(E_I_init,axis = 1)
    particles_0[:,1] = E_I_init[:,0]
    particles_0[:,2] = E_I_init[:,1]
    particles_0[:,4] = rng.uniform(0.,1., size = (num_particles,))
    

    return particles_0

pf_params = {'num_particles':1_000, 
                      'dt':dt,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init,
                      }

from time import perf_counter

t = perf_counter()
output = particlefilter(data = data,
        model_params= (gamma,sig,mean_ou,lam,1/R),
        pf_params = pf_params,
        rng = rng,
        req_jit=True
        )

print(perf_counter() - t)
# Out:
# 8.292081099934876

# %%
print(f" Log Likelihood : {np.sum(output['Log_likelihood'])}")

print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(output['particle_observations'][:,0,:]))**2))}")

for i in range(4):
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,i,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,i,:].T,95,axis = 1),alpha = 0.5)
    plt.plot(np.average(output['particle_distribution'][:,i,:],weights = np.exp(output['log_weights']),axis = 0))
    plt.plot(t_vec,state[i,:].T,'--')
    plt.show()

plt.plot(t_vec,betas,'--')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_distribution'][:,4,:].T,5,axis = 1),np.percentile(output['particle_distribution'][:,4,:].T,95,axis = 1),alpha = 0.5)
plt.plot(np.average(output['particle_distribution'][:,4,:],weights = np.exp(output['log_weights']),axis = 0))
plt.show()

plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T)
plt.fill_between(t_vec[::int(1/dt)],np.percentile(output['particle_observations'][:,0,:].T,5,axis = 1),np.percentile(output['particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()
# Out:
#  Log Likelihood : -10863.944277535322
# Root Mean Squared Error for the Data 5027.303251465589

# %%
pmcmc_rng = np.random.default_rng(0)

@nb.njit
def uniform_numba_logpdf(theta,min_val,max_val):

    if(theta < max_val and theta > min_val):
        return np.log(1/(max_val - min_val))
    
    return np.log(0.)

(gamma,sig,mean_ou,lam,1/R)

def seir_prior(theta):
    return uniform_numba_logpdf(theta[0],min_val= 1/28.,max_val= 1/7) + uniform_numba_logpdf(theta[1],min_val = 0.,max_val = 1.) + uniform_numba_logpdf(theta[2],min_val=-2,max_val=0.) + uniform_numba_logpdf(theta[3],min_val = 1/1000,max_val=1/2)


pmcmc_params = {'iterations':50_000,
                'init_params':np.array([0.1,0.1,-0.7,0.01,0.01]),
                'prior':seir_prior,
                'init_cov':  np.diag([0.01,0.01,0.01,0.01,0.01]),
                'burn_in':1_000}

pf_params = {'num_particles':1000, 
                      'dt':0.1,
                      'model':SEIR_model,
                      'observation_model':SEIR_Obs,
                      'model_dim':5,
                      'particle_initializer':SEIR_init
                      }

t = perf_counter()
pmcmc_output = particlemcmc(
                  data = data,
                  pmcmc_params=pmcmc_params,
                  pf_params=pf_params,
                  adaptive=True,
                  rng = rng,
                  req_jit=True
                  )
print(perf_counter() - t)
# Out:
# iteration: 10| Acceptance rate: 0.2| Log-Likelihood: -11165.923842634133| Proposal [ 0.08420432  0.02835682 -0.98225798  0.12148666  0.01618318]
# iteration: 20| Acceptance rate: 0.1| Log-Likelihood: -11165.923842634133| Proposal [ 0.08420432  0.02835682 -0.98225798  0.12148666  0.01618318]
# iteration: 30| Acceptance rate: 0.1| Log-Likelihood: -11072.91538636285| Proposal [ 0.06797006  0.11953067 -0.77424964  0.30597068  0.00567595]
# iteration: 40| Acceptance rate: 0.1| Log-Likelihood: -10919.355557103505| Proposal [ 0.0699948   0.19702088 -0.80478166  0.16003899  0.10704943]
# iteration: 50| Acceptance rate: 0.08| Log-Likelihood: -10919.355557103505| Proposal [ 0.0699948   0.19702088 -0.80478166  0.16003899  0.10704943]
# iteration: 60| Acceptance rate: 0.08333333333333333| Log-Likelihood: -10909.405417912323| Proposal [ 0.06674784  0.38068914 -0.911138    0.28120513  0.07206658]
# iteration: 70| Acceptance rate: 0.07142857142857142| Log-Likelihood: -10909.405417912323| Proposal [ 0.06674784  0.38068914 -0.911138    0.28120513  0.07206658]
# iteration: 80| Acceptance rate: 0.0625| Log-Likelihood: -10909.405417912323| Proposal [ 0.06674784  0.38068914 -0.911138    0.28120513  0.07206658]
# iteration: 90| Acceptance rate: 0.06666666666666667| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 100| Acceptance rate: 0.06| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 110| Acceptance rate: 0.05454545454545454| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 120| Acceptance rate: 0.05| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 130| Acceptance rate: 0.046153846153846156| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 140| Acceptance rate: 0.04285714285714286| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 150| Acceptance rate: 0.04| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 160| Acceptance rate: 0.0375| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 170| Acceptance rate: 0.03529411764705882| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 180| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 190| Acceptance rate: 0.031578947368421054| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 200| Acceptance rate: 0.03| Log-Likelihood: -10866.217291019826| Proposal [ 0.07934776  0.45202919 -0.88105036  0.19702831  0.01535247]
# iteration: 210| Acceptance rate: 0.03333333333333333| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 220| Acceptance rate: 0.031818181818181815| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 230| Acceptance rate: 0.030434782608695653| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 240| Acceptance rate: 0.029166666666666667| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 250| Acceptance rate: 0.028| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 260| Acceptance rate: 0.026923076923076925| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 270| Acceptance rate: 0.025925925925925925| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 280| Acceptance rate: 0.025| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 290| Acceptance rate: 0.02413793103448276| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 300| Acceptance rate: 0.023333333333333334| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 310| Acceptance rate: 0.02258064516129032| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 320| Acceptance rate: 0.021875| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 330| Acceptance rate: 0.021212121212121213| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 340| Acceptance rate: 0.020588235294117647| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 350| Acceptance rate: 0.02| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 360| Acceptance rate: 0.019444444444444445| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 370| Acceptance rate: 0.01891891891891892| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 380| Acceptance rate: 0.018421052631578946| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 390| Acceptance rate: 0.017948717948717947| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 400| Acceptance rate: 0.0175| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 410| Acceptance rate: 0.01707317073170732| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 420| Acceptance rate: 0.016666666666666666| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 430| Acceptance rate: 0.01627906976744186| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 440| Acceptance rate: 0.015909090909090907| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 450| Acceptance rate: 0.015555555555555555| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 460| Acceptance rate: 0.015217391304347827| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 470| Acceptance rate: 0.014893617021276596| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 480| Acceptance rate: 0.014583333333333334| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 490| Acceptance rate: 0.014285714285714285| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 500| Acceptance rate: 0.014| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 510| Acceptance rate: 0.013725490196078431| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 520| Acceptance rate: 0.013461538461538462| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 530| Acceptance rate: 0.013207547169811321| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 540| Acceptance rate: 0.012962962962962963| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 550| Acceptance rate: 0.012727272727272728| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 560| Acceptance rate: 0.0125| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 570| Acceptance rate: 0.012280701754385965| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 580| Acceptance rate: 0.01206896551724138| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 590| Acceptance rate: 0.011864406779661017| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 600| Acceptance rate: 0.011666666666666667| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 610| Acceptance rate: 0.011475409836065573| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 620| Acceptance rate: 0.01129032258064516| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 630| Acceptance rate: 0.011111111111111112| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 640| Acceptance rate: 0.0109375| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 650| Acceptance rate: 0.010769230769230769| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 660| Acceptance rate: 0.010606060606060607| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 670| Acceptance rate: 0.010447761194029851| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 680| Acceptance rate: 0.010294117647058823| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 690| Acceptance rate: 0.010144927536231883| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 700| Acceptance rate: 0.01| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 710| Acceptance rate: 0.009859154929577466| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 720| Acceptance rate: 0.009722222222222222| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 730| Acceptance rate: 0.009589041095890411| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 740| Acceptance rate: 0.00945945945945946| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 750| Acceptance rate: 0.009333333333333334| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 760| Acceptance rate: 0.009210526315789473| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 770| Acceptance rate: 0.00909090909090909| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 780| Acceptance rate: 0.008974358974358974| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 790| Acceptance rate: 0.008860759493670886| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 800| Acceptance rate: 0.00875| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 810| Acceptance rate: 0.008641975308641974| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 820| Acceptance rate: 0.00853658536585366| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 830| Acceptance rate: 0.008433734939759036| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 840| Acceptance rate: 0.008333333333333333| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 850| Acceptance rate: 0.00823529411764706| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 860| Acceptance rate: 0.00813953488372093| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 870| Acceptance rate: 0.008045977011494253| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 880| Acceptance rate: 0.007954545454545454| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 890| Acceptance rate: 0.007865168539325843| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 900| Acceptance rate: 0.0077777777777777776| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 910| Acceptance rate: 0.007692307692307693| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 920| Acceptance rate: 0.007608695652173913| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 930| Acceptance rate: 0.007526881720430108| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 940| Acceptance rate: 0.007446808510638298| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 950| Acceptance rate: 0.007368421052631579| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 960| Acceptance rate: 0.007291666666666667| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 970| Acceptance rate: 0.007216494845360825| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 980| Acceptance rate: 0.007142857142857143| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 990| Acceptance rate: 0.007070707070707071| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 1000| Acceptance rate: 0.007| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 1010| Acceptance rate: 0.006930693069306931| Log-Likelihood: -10864.341444993832| Proposal [ 0.07814925  0.41655333 -0.9253559   0.07930745  0.01588624]
# iteration: 1020| Acceptance rate: 0.011764705882352941| Log-Likelihood: -10863.860378082622| Proposal [ 0.07761786  0.41200579 -0.91626208  0.07796436  0.01703356]
# iteration: 1030| Acceptance rate: 0.019417475728155338| Log-Likelihood: -10863.70348828253| Proposal [ 0.07436816  0.39312456 -0.89539318  0.07203048  0.01833018]
# iteration: 1040| Acceptance rate: 0.023076923076923078| Log-Likelihood: -10863.2205701026| Proposal [ 0.07559617  0.39992525 -0.90267857  0.07445988  0.01776   ]
# iteration: 1050| Acceptance rate: 0.03142857142857143| Log-Likelihood: -10863.098639828466| Proposal [ 0.07462191  0.39425684 -0.89632471  0.07274908  0.01821684]
# iteration: 1060| Acceptance rate: 0.040566037735849055| Log-Likelihood: -10863.01120605402| Proposal [ 0.07594689  0.40163465 -0.90461302  0.07523404  0.01758843]
# iteration: 1070| Acceptance rate: 0.04672897196261682| Log-Likelihood: -10863.547578673672| Proposal [ 0.07737344  0.40956952 -0.91363626  0.07785571  0.01692088]
# iteration: 1080| Acceptance rate: 0.05555555555555555| Log-Likelihood: -10863.720784443143| Proposal [ 0.07689985  0.40702135 -0.91077728  0.07697436  0.01714115]
# iteration: 1090| Acceptance rate: 0.05963302752293578| Log-Likelihood: -10863.476171102539| Proposal [ 0.07722271  0.40872655 -0.91270494  0.07753776  0.01700165]
# iteration: 1100| Acceptance rate: 0.06636363636363636| Log-Likelihood: -10863.272256230313| Proposal [ 0.07667446  0.40588152 -0.90939214  0.07650883  0.01725938]
# iteration: 1110| Acceptance rate: 0.07387387387387387| Log-Likelihood: -10863.937370004067| Proposal [ 0.07723059  0.40879351 -0.91281595  0.07755871  0.01699502]
# iteration: 1120| Acceptance rate: 0.08214285714285714| Log-Likelihood: -10863.326481421502| Proposal [ 0.07782695  0.41190859 -0.91641963  0.07866983  0.01671648]
# iteration: 1130| Acceptance rate: 0.08672566371681416| Log-Likelihood: -10863.529245854877| Proposal [ 0.07691313  0.40710055 -0.91078071  0.07694117  0.01715288]
# iteration: 1140| Acceptance rate: 0.09210526315789473| Log-Likelihood: -10863.801237199152| Proposal [ 0.07760064  0.41074329 -0.91502062  0.07823163  0.01682716]
# iteration: 1150| Acceptance rate: 0.09913043478260869| Log-Likelihood: -10863.63572302942| Proposal [ 0.07761804  0.41084562 -0.91512718  0.07825968  0.01682034]
# iteration: 1160| Acceptance rate: 0.1060344827586207| Log-Likelihood: -10863.316598567444| Proposal [ 0.07623619  0.40365077 -0.9066964   0.07566101  0.01747369]
# iteration: 1170| Acceptance rate: 0.11025641025641025| Log-Likelihood: -10864.789319117275| Proposal [ 0.07927182  0.41957822 -0.92530131  0.08135861  0.01603969]
# iteration: 1180| Acceptance rate: 0.1152542372881356| Log-Likelihood: -10863.62544156904| Proposal [ 0.07908543  0.41858772 -0.92415136  0.08100965  0.01612773]
# iteration: 1190| Acceptance rate: 0.11848739495798319| Log-Likelihood: -10863.516958756994| Proposal [ 0.07660032  0.40560603 -0.90896889  0.07634501  0.01730063]
# iteration: 1200| Acceptance rate: 0.12416666666666666| Log-Likelihood: -10865.37553997024| Proposal [ 0.07959427  0.42132266 -0.92732044  0.08196184  0.01588707]
# iteration: 1210| Acceptance rate: 0.1305785123966942| Log-Likelihood: -10862.661957052032| Proposal [ 0.07677215  0.40652643 -0.91003609  0.07666631  0.01721949]
# iteration: 1220| Acceptance rate: 0.13278688524590163| Log-Likelihood: -10863.615577578701| Proposal [ 0.07748337  0.41024764 -0.9143861   0.07800153  0.01688362]
# iteration: 1230| Acceptance rate: 0.13739837398373983| Log-Likelihood: -10863.823839497038| Proposal [ 0.07741313  0.40988352 -0.91395712  0.07786858  0.01691708]
# iteration: 1240| Acceptance rate: 0.14112903225806453| Log-Likelihood: -10863.561063193485| Proposal [ 0.07683346  0.40684994 -0.91041219  0.07678119  0.01719051]
# iteration: 1250| Acceptance rate: 0.1472| Log-Likelihood: -10863.563087785038| Proposal [ 0.07866027  0.41640294 -0.9215837   0.08021114  0.01632783]
# iteration: 1260| Acceptance rate: 0.15158730158730158| Log-Likelihood: -10863.754303906975| Proposal [ 0.07531699  0.39890981 -0.9011313   0.07393469  0.01790657]
# iteration: 1270| Acceptance rate: 0.15669291338582678| Log-Likelihood: -10863.910387941209| Proposal [ 0.07819779  0.41398342 -0.918755    0.07934303  0.01654617]
# iteration: 1280| Acceptance rate: 0.16015625| Log-Likelihood: -10863.756749781849| Proposal [ 0.07792415  0.41256399 -0.91709092  0.07882921  0.01667516]
# iteration: 1290| Acceptance rate: 0.16434108527131783| Log-Likelihood: -10863.454816421| Proposal [ 0.07708711  0.40817282 -0.91196145  0.07725818  0.01707054]
# iteration: 1300| Acceptance rate: 0.16615384615384615| Log-Likelihood: -10863.589169454453| Proposal [ 0.07640567  0.40459884 -0.90778583  0.07597885  0.01739252]
# iteration: 1310| Acceptance rate: 0.17022900763358778| Log-Likelihood: -10863.571777760342| Proposal [ 0.076379    0.40444506 -0.90761126  0.075929    0.01740535]
# iteration: 1320| Acceptance rate: 0.1734848484848485| Log-Likelihood: -10863.940344976081| Proposal [ 0.07532576  0.3989526  -0.9011831   0.07395179  0.01790227]
# iteration: 1330| Acceptance rate: 0.17593984962406015| Log-Likelihood: -10863.442960323644| Proposal [ 0.0772643   0.40908804 -0.9130356   0.07759079  0.01698714]
# iteration: 1340| Acceptance rate: 0.1783582089552239| Log-Likelihood: -10863.019642599878| Proposal [ 0.07608978  0.40294429 -0.90585203  0.07538591  0.0175417 ]
# iteration: 1350| Acceptance rate: 0.17925925925925926| Log-Likelihood: -10863.989099979319| Proposal [ 0.0749185   0.39681    -0.89868221  0.07318717  0.01809486]
# iteration: 1360| Acceptance rate: 0.18455882352941178| Log-Likelihood: -10863.377574963095| Proposal [ 0.07514557  0.39799244 -0.90006672  0.07361348  0.01798775]
# iteration: 1370| Acceptance rate: 0.18832116788321168| Log-Likelihood: -10863.278541487443| Proposal [ 0.07358581  0.38981114 -0.89050874  0.07068552  0.01872465]
# iteration: 1380| Acceptance rate: 0.19057971014492753| Log-Likelihood: -10864.693193675272| Proposal [ 0.07168304  0.37982989 -0.87884807  0.06711359  0.01962364]
# iteration: 1390| Acceptance rate: 0.19640287769784173| Log-Likelihood: -10864.061068042116| Proposal [ 0.07225603  0.38282971 -0.88235467  0.06818923  0.01935304]
# iteration: 1400| Acceptance rate: 0.2007142857142857| Log-Likelihood: -10864.20990104882| Proposal [ 0.07918792  0.41921376 -0.92485267  0.08120182  0.01607756]
# iteration: 1410| Acceptance rate: 0.20212765957446807| Log-Likelihood: -10863.23842814931| Proposal [ 0.07697661  0.407607   -0.91129543  0.07705069  0.01712247]
# iteration: 1420| Acceptance rate: 0.20492957746478874| Log-Likelihood: -10863.327258910427| Proposal [ 0.07562115  0.40049527 -0.9029876   0.07450622  0.01776289]
# iteration: 1430| Acceptance rate: 0.2083916083916084| Log-Likelihood: -10863.208417301905| Proposal [ 0.0755712   0.40022728 -0.90267675  0.07441246  0.01778662]
# iteration: 1440| Acceptance rate: 0.2111111111111111| Log-Likelihood: -10864.30139157565| Proposal [ 0.07418523  0.3929601  -0.89418577  0.07181071  0.01844137]
# iteration: 1450| Acceptance rate: 0.21517241379310345| Log-Likelihood: -10863.419766523995| Proposal [ 0.07503962  0.39746401 -0.89943953  0.07341466  0.01803719]
# iteration: 1460| Acceptance rate: 0.2191780821917808| Log-Likelihood: -10863.452392300771| Proposal [ 0.07582963  0.40162678 -0.90429609  0.07489773  0.01766353]
# iteration: 1470| Acceptance rate: 0.22380952380952382| Log-Likelihood: -10864.002935097084| Proposal [ 0.07342061  0.3890357  -0.88957027  0.07037564  0.01880064]
# iteration: 1480| Acceptance rate: 0.22635135135135134| Log-Likelihood: -10864.481899232318| Proposal [ 0.07194889  0.38133352 -0.88056592  0.06761301  0.01949555]
# iteration: 1490| Acceptance rate: 0.22885906040268456| Log-Likelihood: -10864.090602202787| Proposal [ 0.07288532  0.38621875 -0.88628266  0.0693708   0.01905374]
# iteration: 1500| Acceptance rate: 0.23266666666666666| Log-Likelihood: -10864.72041975001| Proposal [ 0.07122456  0.37756086 -0.87614894  0.0662534   0.01983714]
# iteration: 1510| Acceptance rate: 0.23642384105960265| Log-Likelihood: -10863.793539038621| Proposal [ 0.07256198  0.38446208 -0.88425212  0.06876364  0.01920788]
# iteration: 1520| Acceptance rate: 0.2388157894736842| Log-Likelihood: -10865.59459792907| Proposal [ 0.07041596  0.37331937 -0.87119379  0.06473548  0.02021917]
# iteration: 1530| Acceptance rate: 0.24052287581699347| Log-Likelihood: -10863.427909461996| Proposal [ 0.07390086  0.39143112 -0.89241296  0.07127682  0.01857655]
# iteration: 1540| Acceptance rate: 0.2422077922077922| Log-Likelihood: -10863.904801628514| Proposal [ 0.07823049  0.41394736 -0.91878712  0.07940378  0.01653544]
# iteration: 1550| Acceptance rate: 0.24258064516129033| Log-Likelihood: -10863.807325281026| Proposal [ 0.07337072  0.38868982 -0.88919633  0.07028176  0.01882612]
# iteration: 1560| Acceptance rate: 0.24487179487179486| Log-Likelihood: -10863.8339162824| Proposal [ 0.07405964  0.39221092 -0.89334299  0.07157472  0.01850274]
# iteration: 1570| Acceptance rate: 0.24713375796178344| Log-Likelihood: -10864.240257343414| Proposal [ 0.07320106  0.38820235 -0.88848273  0.06996444  0.01889715]
# iteration: 1580| Acceptance rate: 0.25| Log-Likelihood: -10863.52795633144| Proposal [ 0.07280102  0.38582985 -0.88580922  0.06921269  0.01909236]
# iteration: 1590| Acceptance rate: 0.2528301886792453| Log-Likelihood: -10864.023135898095| Proposal [ 0.07253402  0.38473082 -0.88441736  0.06871237  0.01921167]
# iteration: 1600| Acceptance rate: 0.255625| Log-Likelihood: -10864.060108559397| Proposal [ 0.07870003  0.41685836 -0.92202742  0.08028649  0.01630346]
# iteration: 1610| Acceptance rate: 0.25527950310559006| Log-Likelihood: -10864.406702745542| Proposal [ 0.07840814  0.4158275  -0.92064407  0.07974002  0.01643002]
# iteration: 1620| Acceptance rate: 0.2580246913580247| Log-Likelihood: -10863.754872957512| Proposal [ 0.07625452  0.40577273 -0.9084531   0.07570091  0.01741934]
# iteration: 1630| Acceptance rate: 0.2607361963190184| Log-Likelihood: -10863.369195200128| Proposal [ 0.07519878  0.40057258 -0.90225717  0.07372008  0.01791047]
# iteration: 1640| Acceptance rate: 0.2621951219512195| Log-Likelihood: -10863.053570488662| Proposal [ 0.0748445   0.39761562 -0.89919597  0.0730518   0.01810275]
# iteration: 1650| Acceptance rate: 0.26666666666666666| Log-Likelihood: -10863.705209741374| Proposal [ 0.07609332  0.40592762 -0.90827593  0.07540123  0.01747283]
# iteration: 1660| Acceptance rate: 0.2692771084337349| Log-Likelihood: -10864.01883992731| Proposal [ 0.07880603  0.42017508 -0.92491398  0.08049355  0.01619081]
# iteration: 1670| Acceptance rate: 0.27065868263473053| Log-Likelihood: -10863.716979667512| Proposal [ 0.07354181  0.3938331  -0.89368501  0.07061532  0.01864906]
# iteration: 1680| Acceptance rate: 0.27440476190476193| Log-Likelihood: -10863.687776205796| Proposal [ 0.07368477  0.39893929 -0.89809089  0.07089642  0.01848278]
# iteration: 1690| Acceptance rate: 0.2757396449704142| Log-Likelihood: -10863.970140560452| Proposal [ 0.07241041  0.40988634 -0.90456811  0.06855573  0.01868524]
# iteration: 1700| Acceptance rate: 0.2776470588235294| Log-Likelihood: -10863.458364629478| Proposal [ 0.07549401  0.39805597 -0.90077238  0.0742624   0.01786313]
# iteration: 1710| Acceptance rate: 0.28128654970760236| Log-Likelihood: -10863.376549969524| Proposal [ 0.07458906  0.44428774 -0.93653353  0.07271261  0.01713526]
# iteration: 1720| Acceptance rate: 0.2837209302325581| Log-Likelihood: -10863.790845076397| Proposal [ 0.0757886   0.41641166 -0.9161987   0.07486452  0.01734295]
# iteration: 1730| Acceptance rate: 0.28670520231213875| Log-Likelihood: -10864.192006186062| Proposal [ 0.07553499  0.42086982 -0.91933477  0.07440536  0.01733157]
# iteration: 1740| Acceptance rate: 0.2885057471264368| Log-Likelihood: -10864.61364857728| Proposal [ 0.08081191  0.35159124 -0.8731086   0.08402777  0.01703604]
# iteration: 1750| Acceptance rate: 0.29085714285714287| Log-Likelihood: -10863.211472368761| Proposal [ 0.07712048  0.3251449  -0.84474838  0.07707758  0.01894057]
# iteration: 1760| Acceptance rate: 0.29318181818181815| Log-Likelihood: -10862.395454137966| Proposal [ 0.07752555  0.26148055 -0.79392328  0.07764569  0.02024029]
# iteration: 1770| Acceptance rate: 0.296045197740113| Log-Likelihood: -10862.759492566158| Proposal [ 0.07780801  0.23305164 -0.77141852  0.07808852  0.02078475]
# iteration: 1780| Acceptance rate: 0.298876404494382| Log-Likelihood: -10863.138913117331| Proposal [ 0.07628066  0.29319104 -0.81728012  0.07542057  0.01996172]
# iteration: 1790| Acceptance rate: 0.3005586592178771| Log-Likelihood: -10865.800132535209| Proposal [ 0.07551334  0.18747695 -0.730182    0.073683    0.02262898]
# iteration: 1800| Acceptance rate: 0.3011111111111111| Log-Likelihood: -10862.747122616274| Proposal [ 0.07713547  0.23331498 -0.7703691   0.07683711  0.02101656]
# iteration: 1810| Acceptance rate: 0.3027624309392265| Log-Likelihood: -10866.325425578534| Proposal [ 0.08002703  0.13955736 -0.69982893  0.08194678  0.02211921]
# iteration: 1820| Acceptance rate: 0.3027472527472527| Log-Likelihood: -10866.601087425135| Proposal [ 0.08000209  0.138695   -0.69908333  0.08189782  0.02214757]
# iteration: 1830| Acceptance rate: 0.30327868852459017| Log-Likelihood: -10862.394310419619| Proposal [ 0.07723899  0.31255377 -0.8347687   0.07726143  0.01918404]
# iteration: 1840| Acceptance rate: 0.30543478260869567| Log-Likelihood: -10863.302048070347| Proposal [ 0.0750812   0.26806143 -0.79466638  0.07311393  0.02095535]
# iteration: 1850| Acceptance rate: 0.3081081081081081| Log-Likelihood: -10862.998270029486| Proposal [ 0.07918594  0.2028781  -0.7495569   0.08056584  0.02098144]
# iteration: 1860| Acceptance rate: 0.30913978494623656| Log-Likelihood: -10862.51093680816| Proposal [ 0.0780334   0.30471571 -0.82990926  0.07871759  0.01908082]
# iteration: 1870| Acceptance rate: 0.31122994652406416| Log-Likelihood: -10863.674660210729| Proposal [ 0.0787525   0.36974055 -0.88394743  0.08024648  0.01735282]
# iteration: 1880| Acceptance rate: 0.31329787234042555| Log-Likelihood: -10863.255326131397| Proposal [ 0.07306766  0.32921699 -0.84043869  0.06954373  0.02028119]
# iteration: 1890| Acceptance rate: 0.3148148148148148| Log-Likelihood: -10862.614738020484| Proposal [ 0.07666631  0.28312132 -0.80984519  0.07610917  0.02005359]
# iteration: 1900| Acceptance rate: 0.3157894736842105| Log-Likelihood: -10862.394976069574| Proposal [ 0.07654752  0.27621915 -0.80402929  0.07586783  0.02025203]
# iteration: 1910| Acceptance rate: 0.31884816753926704| Log-Likelihood: -10863.007551728197| Proposal [ 0.07833362  0.30203818 -0.82830323  0.07926873  0.01903536]
# iteration: 1920| Acceptance rate: 0.31979166666666664| Log-Likelihood: -10862.738125864493| Proposal [ 0.07915737  0.18475424 -0.73481764  0.08045968  0.02140232]
# iteration: 1930| Acceptance rate: 0.3207253886010363| Log-Likelihood: -10862.350415054052| Proposal [ 0.07769228  0.27970254 -0.80900099  0.07800937  0.01976834]
# iteration: 1940| Acceptance rate: 0.32268041237113404| Log-Likelihood: -10862.171313660492| Proposal [ 0.0774565   0.31059233 -0.83358783  0.07766065  0.0191516 ]
# iteration: 1950| Acceptance rate: 0.3230769230769231| Log-Likelihood: -10862.805257436661| Proposal [ 0.08034788  0.26338956 -0.80076944  0.08290604  0.01919916]
# iteration: 1960| Acceptance rate: 0.325| Log-Likelihood: -10863.399527010894| Proposal [ 0.0811899   0.25988428 -0.7995099   0.08446353  0.0189809 ]
# iteration: 1970| Acceptance rate: 0.32639593908629444| Log-Likelihood: -10862.503553164286| Proposal [ 0.07771955  0.26681714 -0.79861131  0.07802252  0.02005074]
# iteration: 1980| Acceptance rate: 0.3292929292929293| Log-Likelihood: -10862.02085797541| Proposal [ 0.07804703  0.27669945 -0.8072333   0.07866112  0.01971098]
# iteration: 1990| Acceptance rate: 0.33115577889447234| Log-Likelihood: -10864.056473650244| Proposal [ 0.08120649  0.31630558 -0.84525868  0.08465927  0.01769627]
# iteration: 2000| Acceptance rate: 0.3335| Log-Likelihood: -10862.68091117346| Proposal [ 0.07689392  0.27705035 -0.80535336  0.07651519  0.02011072]
# iteration: 2010| Acceptance rate: 0.3353233830845771| Log-Likelihood: -10862.759296208165| Proposal [ 0.07607576  0.27276885 -0.80034726  0.0749794   0.02049703]
# iteration: 2020| Acceptance rate: 0.33564356435643566| Log-Likelihood: -10863.847120673701| Proposal [ 0.07489373  0.42525955 -0.92169012  0.07322421  0.01745879]
# iteration: 2030| Acceptance rate: 0.3369458128078818| Log-Likelihood: -10862.901150561256| Proposal [ 0.07582269  0.31358578 -0.83294694  0.07462745  0.0196614 ]
# iteration: 2040| Acceptance rate: 0.33872549019607845| Log-Likelihood: -10864.005870959547| Proposal [ 0.07915935  0.35941999 -0.87634868  0.08097382  0.01744288]
# iteration: 2050| Acceptance rate: 0.3404878048780488| Log-Likelihood: -10864.71299141545| Proposal [ 0.07256039  0.49426332 -0.97322503  0.06908141  0.0167198 ]
# iteration: 2060| Acceptance rate: 0.341747572815534| Log-Likelihood: -10864.307464736463| Proposal [ 0.0728633   0.45033639 -0.93820265  0.06951693  0.01760829]
# iteration: 2070| Acceptance rate: 0.34251207729468597| Log-Likelihood: -10862.316832184699| Proposal [ 0.07659368  0.28799866 -0.81366239  0.07598813  0.01996873]
# iteration: 2080| Acceptance rate: 0.34375| Log-Likelihood: -10863.12529709522| Proposal [ 0.07853694  0.30323995 -0.82966151  0.07965072  0.01893623]
# iteration: 2090| Acceptance rate: 0.345933014354067| Log-Likelihood: -10862.86395636088| Proposal [ 0.07617943  0.33981733 -0.85487667  0.07536815  0.01894072]
# iteration: 2100| Acceptance rate: 0.34714285714285714| Log-Likelihood: -10862.527531658416| Proposal [ 0.07888563  0.24153955 -0.78032144  0.08011962  0.02021136]
# iteration: 2110| Acceptance rate: 0.34834123222748814| Log-Likelihood: -10862.5411804077| Proposal [ 0.07884441  0.21529577 -0.75898248  0.07996607  0.02082073]
# iteration: 2120| Acceptance rate: 0.34952830188679246| Log-Likelihood: -10863.2690201285| Proposal [ 0.0763601   0.23361994 -0.76917033  0.07539404  0.02128375]
# iteration: 2130| Acceptance rate: 0.3511737089201878| Log-Likelihood: -10863.411176059535| Proposal [ 0.0755859   0.28133588 -0.80637826  0.07409209  0.02047602]
# iteration: 2140| Acceptance rate: 0.3532710280373832| Log-Likelihood: -10862.868403988643| Proposal [ 0.07649332  0.2752762  -0.80317445  0.07576378  0.02029253]
# iteration: 2150| Acceptance rate: 0.3553488372093023| Log-Likelihood: -10862.963240452194| Proposal [ 0.07553293  0.26633552 -0.79412865  0.07394949  0.02083471]
# iteration: 2160| Acceptance rate: 0.35694444444444445| Log-Likelihood: -10862.561196830882| Proposal [ 0.07661134  0.27290388 -0.80147129  0.07597667  0.02030458]
# iteration: 2170| Acceptance rate: 0.3580645161290323| Log-Likelihood: -10862.13488891718| Proposal [ 0.07692733  0.24992854 -0.78344608  0.07649792  0.02071359]
# iteration: 2180| Acceptance rate: 0.3596330275229358| Log-Likelihood: -10862.93016449513| Proposal [ 0.07517601  0.29215395 -0.81438573  0.07336018  0.02037571]
# iteration: 2190| Acceptance rate: 0.36118721461187214| Log-Likelihood: -10862.844659754783| Proposal [ 0.07558468  0.27430314 -0.80068792  0.07406891  0.02063581]
# iteration: 2200| Acceptance rate: 0.36272727272727273| Log-Likelihood: -10863.89751938658| Proposal [ 0.07369245  0.30761927 -0.82413918  0.07064293  0.0205497 ]
# iteration: 2210| Acceptance rate: 0.36425339366515835| Log-Likelihood: -10866.442524964337| Proposal [ 0.06600145  0.53236682 -0.99181743  0.05697988  0.01817506]
# iteration: 2220| Acceptance rate: 0.3653153153153153| Log-Likelihood: -10862.663528708294| Proposal [ 0.07767452  0.28286656 -0.81151971  0.07798595  0.01970295]
# iteration: 2230| Acceptance rate: 0.3650224215246637| Log-Likelihood: -10862.912062081788| Proposal [ 0.07677391  0.23611642 -0.77198097  0.07617143  0.02108083]
# iteration: 2240| Acceptance rate: 0.36607142857142855| Log-Likelihood: -10862.52819216378| Proposal [ 0.07786828  0.2820852  -0.81124794  0.07834449  0.01965216]
# iteration: 2250| Acceptance rate: 0.3671111111111111| Log-Likelihood: -10862.343991389454| Proposal [ 0.0779235   0.31199342 -0.83556656  0.07853532  0.01895485]
# iteration: 2260| Acceptance rate: 0.368141592920354| Log-Likelihood: -10862.692350925461| Proposal [ 0.07629216  0.30810291 -0.82937976  0.07548571  0.0196197 ]
# iteration: 2270| Acceptance rate: 0.36916299559471366| Log-Likelihood: -10862.654549687295| Proposal [ 0.07794621  0.34047245 -0.8586805   0.07866103  0.01830137]
# iteration: 2280| Acceptance rate: 0.36929824561403507| Log-Likelihood: -10862.808168118614| Proposal [ 0.07578624  0.33765105 -0.85236499  0.07463035  0.0191289 ]
# iteration: 2290| Acceptance rate: 0.37117903930131| Log-Likelihood: -10862.768742555229| Proposal [ 0.0791712   0.19976101 -0.74700068  0.08052935  0.02105731]
# iteration: 2300| Acceptance rate: 0.37217391304347824| Log-Likelihood: -10863.551021533383| Proposal [ 0.0790836   0.33881574 -0.85945548  0.08077441  0.01793685]
# iteration: 2310| Acceptance rate: 0.37272727272727274| Log-Likelihood: -10862.147184921827| Proposal [ 0.07707595  0.29638386 -0.82135046  0.07691096  0.01960821]
# iteration: 2320| Acceptance rate: 0.3732758620689655| Log-Likelihood: -10863.028791954954| Proposal [ 0.07555454  0.28856099 -0.81218301  0.07405458  0.02032332]
# iteration: 2330| Acceptance rate: 0.3738197424892704| Log-Likelihood: -10863.262026727229| Proposal [ 0.07486094  0.33197549 -0.84605009  0.07289038  0.01958461]
# iteration: 2340| Acceptance rate: 0.3752136752136752| Log-Likelihood: -10862.397954449152| Proposal [ 0.07876114  0.32695762 -0.84925252  0.08013907  0.01831958]
# iteration: 2350| Acceptance rate: 0.37617021276595747| Log-Likelihood: -10862.80714649715| Proposal [ 0.07581664  0.29582993 -0.81855301  0.07456415  0.02006595]
# iteration: 2360| Acceptance rate: 0.37796610169491524| Log-Likelihood: -10862.632946348522| Proposal [ 0.07722226  0.30047    -0.82492715  0.07719553  0.0194639 ]
# iteration: 2370| Acceptance rate: 0.3789029535864979| Log-Likelihood: -10862.55819592432| Proposal [ 0.07671452  0.30758535 -0.8297441   0.07627086  0.01948213]
# iteration: 2380| Acceptance rate: 0.37899159663865545| Log-Likelihood: -10862.359499716944| Proposal [ 0.07976808  0.25291433 -0.79115563  0.08179708  0.0196417 ]
# iteration: 2390| Acceptance rate: 0.37949790794979077| Log-Likelihood: -10863.602315481536| Proposal [ 0.07575834  0.27347972 -0.80033848  0.07439007  0.0205931 ]
# iteration: 2400| Acceptance rate: 0.38166666666666665| Log-Likelihood: -10864.023875665334| Proposal [ 0.07380439  0.30033083 -0.81845535  0.07082986  0.02067527]
# iteration: 2410| Acceptance rate: 0.3825726141078838| Log-Likelihood: -10862.745354521121| Proposal [ 0.07909413  0.27672119 -0.8091783   0.08061187  0.01934042]
# iteration: 2420| Acceptance rate: 0.3834710743801653| Log-Likelihood: -10864.574114302553| Proposal [ 0.07245613  0.39944377 -0.89622063  0.06860979  0.01890564]
# iteration: 2430| Acceptance rate: 0.38436213991769547| Log-Likelihood: -10863.855369140723| Proposal [ 0.08118461  0.2213079  -0.76818309  0.08434253  0.0198573 ]
# iteration: 2440| Acceptance rate: 0.38524590163934425| Log-Likelihood: -10862.529093214285| Proposal [ 0.07943515  0.31025145 -0.83696492  0.08134546  0.01845997]
# iteration: 2450| Acceptance rate: 0.3853061224489796| Log-Likelihood: -10862.613934015182| Proposal [ 0.07946602  0.19550514 -0.74408205  0.08106625  0.02104961]
# iteration: 2460| Acceptance rate: 0.3849593495934959| Log-Likelihood: -10863.292147653248| Proposal [ 0.07996248  0.23257177 -0.77502977  0.08209959  0.02003405]
# iteration: 2470| Acceptance rate: 0.38582995951417004| Log-Likelihood: -10863.475934971042| Proposal [ 0.07578309  0.279549   -0.80530835  0.07445383  0.02044677]
# iteration: 2480| Acceptance rate: 0.38629032258064516| Log-Likelihood: -10863.127989113891| Proposal [ 0.07867447  0.22005659 -0.76251238  0.07966393  0.02077294]
# iteration: 2490| Acceptance rate: 0.38795180722891565| Log-Likelihood: -10862.940004274958| Proposal [ 0.07739475  0.34067726 -0.85783515  0.0776345   0.01849162]
# iteration: 2500| Acceptance rate: 0.388| Log-Likelihood: -10862.626962956301| Proposal [ 0.07796103  0.20890751 -0.752161    0.07830244  0.0212778 ]
# iteration: 2510| Acceptance rate: 0.3888446215139442| Log-Likelihood: -10862.33266292852| Proposal [ 0.07605079  0.28451662 -0.80984358  0.07496681  0.02023951]
# iteration: 2520| Acceptance rate: 0.3900793650793651| Log-Likelihood: -10862.954590429841| Proposal [ 0.07566967  0.29198105 -0.81517684  0.07427897  0.02020508]
# iteration: 2530| Acceptance rate: 0.39090909090909093| Log-Likelihood: -10862.758333674967| Proposal [ 0.07755917  0.30810392 -0.8317285   0.0778455   0.01917183]
# iteration: 2540| Acceptance rate: 0.39173228346456695| Log-Likelihood: -10862.694191631039| Proposal [ 0.07800512  0.28176249 -0.81121973  0.07859877  0.01961118]
# iteration: 2550| Acceptance rate: 0.39254901960784316| Log-Likelihood: -10863.34494139674| Proposal [ 0.07861501  0.3544904  -0.87126786  0.07994794  0.0177473 ]
# iteration: 2560| Acceptance rate: 0.39453125| Log-Likelihood: -10863.427284650623| Proposal [ 0.08070352  0.20730542 -0.75597394  0.08340513  0.02034461]
# iteration: 2570| Acceptance rate: 0.3949416342412451| Log-Likelihood: -10862.62853954678| Proposal [ 0.07688485  0.37232855 -0.88244937  0.07677873  0.01795481]
# iteration: 2580| Acceptance rate: 0.39689922480620154| Log-Likelihood: -10863.129043745474| Proposal [ 0.07683622  0.29455551 -0.81945644  0.07645874  0.01973428]
# iteration: 2590| Acceptance rate: 0.3969111969111969| Log-Likelihood: -10863.226096097202| Proposal [ 0.07638435  0.26792356 -0.79699915  0.07553964  0.02049774]
# iteration: 2600| Acceptance rate: 0.3976923076923077| Log-Likelihood: -10863.006227990703| Proposal [ 0.07921795  0.29800382 -0.8266507   0.08090489  0.0188143 ]
# iteration: 2610| Acceptance rate: 0.3992337164750958| Log-Likelihood: -10863.84789867123| Proposal [ 0.07664064  0.44134153 -0.93779907  0.07652769  0.01647739]
# iteration: 2620| Acceptance rate: 0.4| Log-Likelihood: -10863.94939047024| Proposal [ 0.07755231  0.41942133 -0.92166384  0.07816224  0.01665218]
# iteration: 2630| Acceptance rate: 0.4011406844106464| Log-Likelihood: -10863.659608132351| Proposal [ 0.0805308   0.25450436 -0.79356826  0.08322614  0.01933709]
# iteration: 2640| Acceptance rate: 0.4018939393939394| Log-Likelihood: -10862.827328054635| Proposal [ 0.0774286   0.21157916 -0.75322867  0.0773201   0.02140583]
# iteration: 2650| Acceptance rate: 0.40226415094339624| Log-Likelihood: -10864.333479092586| Proposal [ 0.0817668   0.23742293 -0.78210174  0.08547697  0.01928705]
# iteration: 2660| Acceptance rate: 0.40338345864661657| Log-Likelihood: -10862.659636793964| Proposal [ 0.07867005  0.24133111 -0.77965834  0.07971915  0.02029262]
# iteration: 2670| Acceptance rate: 0.4041198501872659| Log-Likelihood: -10864.792478548983| Proposal [ 0.07758799  0.16039557 -0.71208289  0.07746656  0.02250943]
# iteration: 2680| Acceptance rate: 0.40373134328358207| Log-Likelihood: -10862.47267045346| Proposal [ 0.0780083   0.26268439 -0.79575786  0.07854891  0.02004249]
# iteration: 2690| Acceptance rate: 0.40483271375464686| Log-Likelihood: -10863.057686700266| Proposal [ 0.07705025  0.35391371 -0.86806843  0.07702971  0.01831288]
# iteration: 2700| Acceptance rate: 0.4059259259259259| Log-Likelihood: -10863.821492972509| Proposal [ 0.0809041   0.22691583 -0.77172801  0.08384295  0.01983105]
# iteration: 2710| Acceptance rate: 0.4062730627306273| Log-Likelihood: -10862.52784649575| Proposal [ 0.07997055  0.22441079 -0.76780131  0.08209915  0.0202184 ]
# iteration: 2720| Acceptance rate: 0.4073529411764706| Log-Likelihood: -10863.922548978624| Proposal [ 0.08133276  0.23069537 -0.77597554  0.08464714  0.01959249]
# iteration: 2730| Acceptance rate: 0.4065934065934066| Log-Likelihood: -10863.247885035702| Proposal [ 0.08019182  0.22234592 -0.76701824  0.08249876  0.02018529]
# iteration: 2740| Acceptance rate: 0.40766423357664233| Log-Likelihood: -10863.027786177787| Proposal [ 0.07901458  0.2276288  -0.76885838  0.08032515  0.02048259]
# iteration: 2750| Acceptance rate: 0.4087272727272727| Log-Likelihood: -10864.273507047323| Proposal [ 0.07913926  0.15858145 -0.71309026  0.08035575  0.02200363]
# iteration: 2760| Acceptance rate: 0.4097826086956522| Log-Likelihood: -10862.123433570849| Proposal [ 0.07585854  0.29572825 -0.81759934  0.07465461  0.02005681]
# iteration: 2770| Acceptance rate: 0.4104693140794224| Log-Likelihood: -10863.288028052677| Proposal [ 0.07683915  0.20325217 -0.74431016  0.07621234  0.02180675]
# iteration: 2780| Acceptance rate: 0.41079136690647483| Log-Likelihood: -10862.759558214313| Proposal [ 0.07838629  0.22177913 -0.76266982  0.07914168  0.02083826]
# iteration: 2790| Acceptance rate: 0.4118279569892473| Log-Likelihood: -10862.519333077922| Proposal [ 0.07939075  0.25079654 -0.78880947  0.08108721  0.01982283]
# iteration: 2800| Acceptance rate: 0.4125| Log-Likelihood: -10862.778376285118| Proposal [ 0.07771185  0.20563297 -0.7473522   0.07785143  0.0214461 ]
# iteration: 2810| Acceptance rate: 0.4131672597864769| Log-Likelihood: -10862.551251491577| Proposal [ 0.07862119  0.28104012 -0.81185929  0.07974293  0.0194095 ]
# iteration: 2820| Acceptance rate: 0.41382978723404257| Log-Likelihood: -10862.360762733617| Proposal [ 0.07714215  0.25799601 -0.78939729  0.07693481  0.0204583 ]
# iteration: 2830| Acceptance rate: 0.415547703180212| Log-Likelihood: -10862.960121467788| Proposal [ 0.07973902  0.25948986 -0.79720388  0.08175188  0.01950019]
# iteration: 2840| Acceptance rate: 0.4154929577464789| Log-Likelihood: -10862.681890325899| Proposal [ 0.07599222  0.25603103 -0.78580691  0.07478559  0.02090883]
# iteration: 2850| Acceptance rate: 0.4164912280701754| Log-Likelihood: -10862.060637563936| Proposal [ 0.07864716  0.23912463 -0.77879041  0.07965717  0.0203473 ]
# iteration: 2860| Acceptance rate: 0.41748251748251747| Log-Likelihood: -10862.67817279322| Proposal [ 0.07908577  0.31161832 -0.84070227  0.08065489  0.01854086]
# iteration: 2870| Acceptance rate: 0.4181184668989547| Log-Likelihood: -10862.289721584826| Proposal [ 0.07788532  0.2219151  -0.76759762  0.07813214  0.02099185]
# iteration: 2880| Acceptance rate: 0.41805555555555557| Log-Likelihood: -10863.780820586906| Proposal [ 0.07595142  0.23215046 -0.76952842  0.07459752  0.02145332]
# iteration: 2890| Acceptance rate: 0.4183391003460208| Log-Likelihood: -10862.46936521257| Proposal [ 0.07672704  0.25077065 -0.79036348  0.07603896  0.02074183]
# iteration: 2900| Acceptance rate: 0.4189655172413793| Log-Likelihood: -10863.726879008276| Proposal [ 0.0730923   0.31721986 -0.84369898  0.06938079  0.02049844]
# iteration: 2910| Acceptance rate: 0.41993127147766324| Log-Likelihood: -10862.130920097523| Proposal [ 0.07700694  0.29285329 -0.82308574  0.07670891  0.01969585]
# iteration: 2920| Acceptance rate: 0.4195205479452055| Log-Likelihood: -10862.035655416541| Proposal [ 0.07790964  0.26381303 -0.80173949  0.07829822  0.02003313]
# iteration: 2930| Acceptance rate: 0.4197952218430034| Log-Likelihood: -10863.713509279416| Proposal [ 0.08085986  0.27952301 -0.81569609  0.08389559  0.01864932]
# iteration: 2940| Acceptance rate: 0.42142857142857143| Log-Likelihood: -10864.941459070998| Proposal [ 0.08022842  0.36004424 -0.87799542  0.08297923  0.01705385]
# iteration: 2950| Acceptance rate: 0.42338983050847456| Log-Likelihood: -10862.383306520302| Proposal [ 0.0784168   0.22639021 -0.77138641  0.0791461   0.02070548]
# iteration: 2960| Acceptance rate: 0.4246621621621622| Log-Likelihood: -10864.478928842855| Proposal [ 0.08134963  0.22217278 -0.77664911  0.08455252  0.01975288]
# iteration: 2970| Acceptance rate: 0.4249158249158249| Log-Likelihood: -10865.046753927472| Proposal [ 0.07653267  0.46900513 -0.9630617   0.07636685  0.01587776]
# iteration: 2980| Acceptance rate: 0.4248322147651007| Log-Likelihood: -10863.37979750059| Proposal [ 0.07659548  0.36027309 -0.87139928  0.07621443  0.01833297]
# ...
# iteration: 49030| Acceptance rate: 0.3608606975321232| Log-Likelihood: -10863.461044460748| Proposal [ 0.07351062  0.29162508 -1.35562982  0.01107785  0.01475212]
# iteration: 49040| Acceptance rate: 0.3608686786296901| Log-Likelihood: -10861.86448728673| Proposal [ 0.07480984  0.15941868 -1.30099932  0.04135114  0.01374679]
# iteration: 49050| Acceptance rate: 0.3608766564729867| Log-Likelihood: -10860.707903078292| Proposal [ 0.07647357  0.27439321 -0.97205179  0.05006857  0.01665811]
# iteration: 49060| Acceptance rate: 0.36090501426824295| Log-Likelihood: -10862.292911533632| Proposal [ 0.07126907  0.46935546 -1.58256583  0.02246537  0.01605177]
# iteration: 49070| Acceptance rate: 0.3609333605054004| Log-Likelihood: -10865.416728740416| Proposal [ 0.071662    0.5479062  -1.18542443  0.00409367  0.01361111]
# iteration: 49080| Acceptance rate: 0.36092094539527303| Log-Likelihood: -10862.413265966046| Proposal [ 0.07199621  0.34452001 -1.33052128  0.08388479  0.01690779]
# iteration: 49090| Acceptance rate: 0.36090853534324707| Log-Likelihood: -10860.831026883014| Proposal [ 0.07858607  0.1768585  -0.82954838  0.13986034  0.01676527]
# iteration: 49100| Acceptance rate: 0.36091649694501016| Log-Likelihood: -10860.44223993394| Proposal [ 0.07576491  0.18435274 -1.03907797  0.09024769  0.01740055]
# iteration: 49110| Acceptance rate: 0.36086336794950113| Log-Likelihood: -10861.353378738626| Proposal [ 0.07792954  0.181271   -0.76481562  0.08829501  0.01554134]
# iteration: 49120| Acceptance rate: 0.3608102605863192| Log-Likelihood: -10860.545452335606| Proposal [ 0.07542322  0.14973936 -0.89521672  0.11360472  0.01645883]
# iteration: 49130| Acceptance rate: 0.3608182373295339| Log-Likelihood: -10865.363330728032| Proposal [ 0.06317185  0.22956926 -1.87115692  0.05235505  0.02264053]
# iteration: 49140| Acceptance rate: 0.3607855107855108| Log-Likelihood: -10864.8169569597| Proposal [ 0.06644604  0.16447628 -1.68144385  0.05657922  0.02335806]
# iteration: 49150| Acceptance rate: 0.36075279755849443| Log-Likelihood: -10860.764536608502| Proposal [ 0.07042208  0.18050682 -1.53929777  0.0392932   0.01720846]
# iteration: 49160| Acceptance rate: 0.36069975589910497| Log-Likelihood: -10861.2980889942| Proposal [ 0.06959719  0.39948402 -1.7567833   0.01873576  0.01596329]
# iteration: 49170| Acceptance rate: 0.3607280862314419| Log-Likelihood: -10860.577282258271| Proposal [ 0.0698657   0.19504679 -1.18998405  0.03569227  0.01642112]
# iteration: 49180| Acceptance rate: 0.3607157381049207| Log-Likelihood: -10860.737851397584| Proposal [ 0.07475099  0.2357009  -1.08117313  0.06591157  0.0145267 ]
# iteration: 49190| Acceptance rate: 0.3607033949989835| Log-Likelihood: -10860.029482202892| Proposal [ 0.06968521  0.21994355 -1.83742658  0.02104693  0.01723623]
# iteration: 49200| Acceptance rate: 0.36063008130081303| Log-Likelihood: -10860.029482202892| Proposal [ 0.06968521  0.21994355 -1.83742658  0.02104693  0.01723623]
# iteration: 49210| Acceptance rate: 0.36059743954480794| Log-Likelihood: -10860.919892237982| Proposal [ 0.07119197  0.28656034 -1.54556985  0.02471453  0.0182588 ]
# iteration: 49220| Acceptance rate: 0.3605851279967493| Log-Likelihood: -10861.475871104125| Proposal [ 0.0711679   0.22345472 -1.34749787  0.06518873  0.01997387]
# iteration: 49230| Acceptance rate: 0.3605525086329474| Log-Likelihood: -10861.448414153585| Proposal [ 0.07481323  0.20347317 -1.18859154  0.10854497  0.01695877]
# iteration: 49240| Acceptance rate: 0.36054021121039803| Log-Likelihood: -10861.020438580954| Proposal [ 0.06994571  0.19939551 -1.69853225  0.04148938  0.01500283]
# iteration: 49250| Acceptance rate: 0.36056852791878174| Log-Likelihood: -10862.046038345745| Proposal [ 0.07044846  0.280194   -1.73576108  0.04569051  0.01884048]
# iteration: 49260| Acceptance rate: 0.36057653268371903| Log-Likelihood: -10861.226085504422| Proposal [ 0.07286702  0.22733574 -1.10366438  0.06301651  0.01959477]
# iteration: 49270| Acceptance rate: 0.360564237872945| Log-Likelihood: -10861.230878764136| Proposal [ 0.06860599  0.29644262 -1.50022462  0.03301568  0.01801034]
# iteration: 49280| Acceptance rate: 0.36051136363636366| Log-Likelihood: -10862.272617295346| Proposal [ 0.06596927  0.18457628 -1.96803433  0.03904541  0.01600973]
# iteration: 49290| Acceptance rate: 0.36051937512680055| Log-Likelihood: -10861.13939722494| Proposal [ 0.07373198  0.17450755 -0.93384198  0.11228493  0.01673818]
# iteration: 49300| Acceptance rate: 0.3604665314401623| Log-Likelihood: -10861.04576337219| Proposal [ 0.07606466  0.23342317 -0.96556768  0.08494797  0.01493525]
# iteration: 49310| Acceptance rate: 0.36045426891097143| Log-Likelihood: -10860.524440497375| Proposal [ 0.07513507  0.23226404 -0.92190367  0.10996414  0.01616302]
# iteration: 49320| Acceptance rate: 0.3603811841038118| Log-Likelihood: -10860.524440497375| Proposal [ 0.07513507  0.23226404 -0.92190367  0.10996414  0.01616302]
# iteration: 49330| Acceptance rate: 0.36038921548753294| Log-Likelihood: -10861.518841269972| Proposal [ 0.07627066  0.2225143  -1.12513369  0.03623291  0.01444312]
# iteration: 49340| Acceptance rate: 0.3603972436157276| Log-Likelihood: -10860.347280732378| Proposal [ 0.06785363  0.23790075 -1.84525655  0.02558477  0.02033627]
# iteration: 49350| Acceptance rate: 0.3604255319148936| Log-Likelihood: -10862.035758510123| Proposal [ 0.06951971  0.31408748 -1.79406233  0.04016269  0.01474925]
# iteration: 49360| Acceptance rate: 0.36045380875202593| Log-Likelihood: -10862.992308557741| Proposal [ 0.06906648  0.32855596 -1.55618747  0.04928808  0.02092508]
# iteration: 49370| Acceptance rate: 0.36040105327121735| Log-Likelihood: -10862.553648919502| Proposal [ 0.07168972  0.25888539 -1.69556981  0.01472543  0.02129789]
# iteration: 49380| Acceptance rate: 0.36036857027136493| Log-Likelihood: -10861.739373385517| Proposal [ 0.07409976  0.07099211 -1.08283884  0.08204216  0.02082265]
# iteration: 49390| Acceptance rate: 0.3603563474387528| Log-Likelihood: -10861.375251626041| Proposal [ 0.07515398  0.27411276 -1.01322964  0.07506815  0.01712987]
# iteration: 49400| Acceptance rate: 0.3603238866396761| Log-Likelihood: -10859.945014911114| Proposal [ 0.07464028  0.22739277 -1.12435716  0.05123224  0.01608939]
# iteration: 49410| Acceptance rate: 0.3603319166160696| Log-Likelihood: -10860.671164573076| Proposal [ 0.07231705  0.13052638 -1.21351595  0.05587783  0.01984398]
# iteration: 49420| Acceptance rate: 0.3602994738972076| Log-Likelihood: -10859.633476243202| Proposal [ 0.06789904  0.12142449 -1.81146527  0.0218598   0.01709689]
# iteration: 49430| Acceptance rate: 0.360307505563423| Log-Likelihood: -10862.314962215052| Proposal [ 0.07339139  0.33232772 -1.02080479  0.09279015  0.01707494]
# iteration: 49440| Acceptance rate: 0.3603155339805825| Log-Likelihood: -10859.98636128319| Proposal [ 0.06899495  0.23447313 -1.42006884  0.0417693   0.016843  ]
# iteration: 49450| Acceptance rate: 0.3603235591506572| Log-Likelihood: -10860.75478452151| Proposal [ 0.07139305  0.23889114 -1.15902921  0.03954779  0.01556779]
# iteration: 49460| Acceptance rate: 0.36029114435907805| Log-Likelihood: -10860.320419460724| Proposal [ 0.07338258  0.23361813 -0.97501618  0.06982407  0.01561046]
# iteration: 49470| Acceptance rate: 0.3602991712148777| Log-Likelihood: -10860.386698568007| Proposal [ 0.07207099  0.20863069 -1.20577023  0.10400938  0.01705183]
# iteration: 49480| Acceptance rate: 0.36024656426839125| Log-Likelihood: -10860.610814692594| Proposal [ 0.07284457  0.16818255 -1.15828464  0.11267274  0.01526145]
# iteration: 49490| Acceptance rate: 0.3602545968882603| Log-Likelihood: -10860.929898189304| Proposal [ 0.07316644  0.22435527 -1.16436683  0.12013781  0.01863378]
# iteration: 49500| Acceptance rate: 0.36024242424242425| Log-Likelihood: -10859.336021678346| Proposal [ 0.07579783  0.15048808 -1.07712234  0.08642863  0.01644067]
# iteration: 49510| Acceptance rate: 0.3602302565138356| Log-Likelihood: -10863.49925237818| Proposal [ 0.07715377  0.33683066 -1.10015484  0.09575585  0.01652525]
# iteration: 49520| Acceptance rate: 0.36023828756058157| Log-Likelihood: -10862.138048111568| Proposal [ 0.07399145  0.27041298 -1.13744008  0.14334813  0.01983961]
# iteration: 49530| Acceptance rate: 0.3602665051483949| Log-Likelihood: -10862.067245386215| Proposal [ 0.07892997  0.23463202 -0.84001803  0.16271018  0.01920876]
# iteration: 49540| Acceptance rate: 0.3602139685102947| Log-Likelihood: -10861.31069580201| Proposal [ 0.07821727  0.20508736 -0.90567589  0.12879005  0.01908294]
# iteration: 49550| Acceptance rate: 0.3602219979818365| Log-Likelihood: -10862.465933189325| Proposal [ 0.07822816  0.25357127 -0.98305311  0.14121809  0.0173451 ]
# iteration: 49560| Acceptance rate: 0.3602502017756255| Log-Likelihood: -10865.024578462988| Proposal [ 0.07963617  0.2598355  -0.60760597  0.23480825  0.01625744]
# iteration: 49570| Acceptance rate: 0.36023804720597136| Log-Likelihood: -10862.160286761577| Proposal [ 0.07045397  0.20393783 -1.21743993  0.13363838  0.01537492]
# iteration: 49580| Acceptance rate: 0.3602258975393304| Log-Likelihood: -10861.080136665112| Proposal [ 0.07513783  0.19425793 -0.92518983  0.1748551   0.01302772]
# iteration: 49590| Acceptance rate: 0.36023391812865496| Log-Likelihood: -10863.676164345687| Proposal [ 0.06874015  0.25338581 -1.50861425  0.01109037  0.01698189]
# iteration: 49600| Acceptance rate: 0.36024193548387096| Log-Likelihood: -10860.843299355298| Proposal [ 0.07657542  0.25547807 -0.98126235  0.09360348  0.01734322]
# iteration: 49610| Acceptance rate: 0.3602096351542028| Log-Likelihood: -10860.42948128454| Proposal [ 0.0742401   0.1824661  -1.24657467  0.04583659  0.02020197]
# iteration: 49620| Acceptance rate: 0.3601975010076582| Log-Likelihood: -10860.083118658551| Proposal [ 0.07171253  0.12419007 -1.24258694  0.05198513  0.01616497]
# iteration: 49630| Acceptance rate: 0.3601652226475922| Log-Likelihood: -10860.275168620201| Proposal [ 0.0706931   0.15152295 -1.38464328  0.06994454  0.01798472]
# iteration: 49640| Acceptance rate: 0.3601531023368251| Log-Likelihood: -10860.830482292384| Proposal [ 0.07482523  0.11723131 -1.07414855  0.10685786  0.01950006]
# iteration: 49650| Acceptance rate: 0.36012084592145016| Log-Likelihood: -10863.274846333856| Proposal [ 0.06928895  0.23712924 -1.56839607  0.05878918  0.02280695]
# iteration: 49660| Acceptance rate: 0.3601490132903745| Log-Likelihood: -10862.503305594842| Proposal [ 0.07582859  0.27524504 -1.07942403  0.19469751  0.01514702]
# iteration: 49670| Acceptance rate: 0.3601771693174955| Log-Likelihood: -10861.674698639963| Proposal [ 0.07135903  0.12669225 -1.16471126  0.11542009  0.01355714]
# iteration: 49680| Acceptance rate: 0.3601449275362319| Log-Likelihood: -10859.968934919087| Proposal [ 0.07346146  0.22026799 -1.18549672  0.05474378  0.01616151]
# iteration: 49690| Acceptance rate: 0.3600724491849467| Log-Likelihood: -10859.968934919087| Proposal [ 0.07346146  0.22026799 -1.18549672  0.05474378  0.01616151]
# iteration: 49700| Acceptance rate: 0.3600603621730382| Log-Likelihood: -10859.76397785594| Proposal [ 0.07453676  0.20504037 -1.17593938  0.04975236  0.01591686]
# iteration: 49710| Acceptance rate: 0.360028163347415| Log-Likelihood: -10859.40675642219| Proposal [ 0.0734393   0.13283389 -1.14896008  0.06929238  0.01866289]
# iteration: 49720| Acceptance rate: 0.3599758648431215| Log-Likelihood: -10859.92289938436| Proposal [ 0.0746121   0.17860796 -1.07965824  0.11819404  0.01760389]
# iteration: 49730| Acceptance rate: 0.3599839131309069| Log-Likelihood: -10862.744085346205| Proposal [ 0.0690778   0.26276758 -1.78395662  0.04714502  0.01867624]
# iteration: 49740| Acceptance rate: 0.35993164455166865| Log-Likelihood: -10859.813642176729| Proposal [ 0.06933382  0.22054518 -1.59747234  0.03994896  0.01670905]
# iteration: 49750| Acceptance rate: 0.35991959798994977| Log-Likelihood: -10860.394065978075| Proposal [ 0.07268498  0.21361276 -1.29564663  0.08867153  0.01756442]
# iteration: 49760| Acceptance rate: 0.35986736334405145| Log-Likelihood: -10860.178330123297| Proposal [ 0.07300047  0.18713368 -1.34247226  0.0449333   0.01660757]
# iteration: 49770| Acceptance rate: 0.35983524211372314| Log-Likelihood: -10864.128426963352| Proposal [ 0.07419704  0.20795223 -1.23311673  0.05190588  0.01202263]
# iteration: 49780| Acceptance rate: 0.35984331056649255| Log-Likelihood: -10860.472882137636| Proposal [ 0.0725519   0.19810882 -1.19802053  0.05926563  0.01504097]
# iteration: 49790| Acceptance rate: 0.3598714601325567| Log-Likelihood: -10862.173234203492| Proposal [ 0.07639088  0.21502701 -0.88532296  0.18535635  0.01963064]
# iteration: 49800| Acceptance rate: 0.35989959839357427| Log-Likelihood: -10862.23848639696| Proposal [ 0.0758006   0.31702154 -0.97387113  0.29130392  0.01627144]
# iteration: 49810| Acceptance rate: 0.3598674964866493| Log-Likelihood: -10862.751202429716| Proposal [ 0.07183113  0.23636578 -1.28164663  0.15542873  0.01596316]
# iteration: 49820| Acceptance rate: 0.35985547972701726| Log-Likelihood: -10861.983192007398| Proposal [ 0.07196144  0.32854851 -1.17642178  0.13862161  0.01528495]
# iteration: 49830| Acceptance rate: 0.3598233995584989| Log-Likelihood: -10860.1676455809| Proposal [ 0.06696149  0.2037121  -1.63563241  0.02470081  0.01716306]
# iteration: 49840| Acceptance rate: 0.3597712680577849| Log-Likelihood: -10860.639395542006| Proposal [ 0.06616369  0.24762134 -1.65536249  0.0449099   0.01644755]
# iteration: 49850| Acceptance rate: 0.3597793380140421| Log-Likelihood: -10859.932259043817| Proposal [ 0.07235254  0.19671926 -1.18184208  0.06591441  0.02038086]
# iteration: 49860| Acceptance rate: 0.35974729241877257| Log-Likelihood: -10860.607829750405| Proposal [ 0.06696505  0.21258114 -1.48148335  0.03559941  0.01497438]
# iteration: 49870| Acceptance rate: 0.35967515540405054| Log-Likelihood: -10860.607829750405| Proposal [ 0.06696505  0.21258114 -1.48148335  0.03559941  0.01497438]
# iteration: 49880| Acceptance rate: 0.3596431435445068| Log-Likelihood: -10860.738134552477| Proposal [ 0.07224658  0.13828103 -1.29305457  0.06668504  0.01990342]
# iteration: 49890| Acceptance rate: 0.35961114451793946| Log-Likelihood: -10860.480627427594| Proposal [ 0.0720497   0.12727144 -1.23983902  0.08094562  0.01442886]
# iteration: 49900| Acceptance rate: 0.35961923847695393| Log-Likelihood: -10862.727901668048| Proposal [ 0.06414019  0.14427275 -1.66774313  0.02992946  0.01792149]
# iteration: 49910| Acceptance rate: 0.3595471849328792| Log-Likelihood: -10862.727901668048| Proposal [ 0.06414019  0.14427275 -1.66774313  0.02992946  0.01792149]
# iteration: 49920| Acceptance rate: 0.35947516025641024| Log-Likelihood: -10862.727901668048| Proposal [ 0.06414019  0.14427275 -1.66774313  0.02992946  0.01792149]
# iteration: 49930| Acceptance rate: 0.3594432205087122| Log-Likelihood: -10860.87059601384| Proposal [ 0.06812506  0.10299149 -1.43086528  0.04185691  0.01616854]
# iteration: 49940| Acceptance rate: 0.3594513416099319| Log-Likelihood: -10862.211008509887| Proposal [ 0.0647939   0.1722391  -1.56722542  0.04669918  0.01483848]
# iteration: 49950| Acceptance rate: 0.35943943943943946| Log-Likelihood: -10864.843400399775| Proposal [ 0.06535622  0.3058207  -1.56400375  0.02638865  0.01206306]
# iteration: 49960| Acceptance rate: 0.35940752602081666| Log-Likelihood: -10864.559853004548| Proposal [ 0.06443893  0.29220307 -1.56136751  0.04256866  0.01201452]
# iteration: 49970| Acceptance rate: 0.35939563738242947| Log-Likelihood: -10863.554048147229| Proposal [ 0.07893894  0.34959518 -0.87470931  0.17233205  0.0148592 ]
# iteration: 49980| Acceptance rate: 0.35938375350140056| Log-Likelihood: -10860.369333235338| Proposal [ 0.07580295  0.18012901 -1.03564714  0.05879786  0.01622203]
# iteration: 49990| Acceptance rate: 0.35939187837567516| Log-Likelihood: -10861.87670894387| Proposal [ 0.07407525  0.23176759 -0.90147858  0.07779976  0.01607283]
# 19213.536705999984

# %%
burn_in = 20000

MLE = np.argmax(pmcmc_output['Log Likelihood'])

print(pmcmc_output['Log Likelihood'][MLE])

print(f"The Maximum Likelihood Estimate is {pmcmc_output['accepted_params'][:,MLE]} w/ LL of {pmcmc_output['Log Likelihood'][MLE]}")

plt.title("PMCMC Likelihood")
plt.ylabel("Magnitude")
plt.xlabel("Iterations")
plt.plot(pmcmc_output['Log Likelihood'][burn_in:])
# Out:
# -10858.430218349851
# The Maximum Likelihood Estimate is [ 0.07362342  0.14608916 -1.09395844  0.08291849  0.01756201] w/ LL of -10858.430218349851

# %%
plt.title(f"Distribution of $\\gamma$ w/ mean: {np.mean(pmcmc_output['accepted_params'][0,burn_in:])} and std: {np.std(pmcmc_output['accepted_params'][0,burn_in:])}")
plt.hist(pmcmc_output['accepted_params'][0,burn_in:],density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\sigma$ w/ mean: {np.mean((pmcmc_output['accepted_params'][1,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][1,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][1,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\mu$ w/ mean: {np.mean((pmcmc_output['accepted_params'][2,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][2,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][2,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of $\\lambda$ w/ mean: {np.mean((pmcmc_output['accepted_params'][3,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][3,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][3,burn_in:]),density=True,bins = 50)
plt.show()

plt.title(f"Distribution of 1/R w/ mean: {np.mean((pmcmc_output['accepted_params'][4,burn_in:]))} and std: {np.std((pmcmc_output['accepted_params'][4,burn_in:]))}")
plt.hist((pmcmc_output['accepted_params'][4,burn_in:]),density=True,bins = 50)
plt.show()

# %%
Labels = ['S','E','I','R']
for i in range(4):
    plt.title(f"Particle Distribution of {Labels[i]}")
    plt.xlabel('Time (Days)')
    plt.plot(t_vec,state[i,:].T,'--',color = 'black')
    #plt.plot(t_vec[::int(1/dt)],[i,:,MLE])
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,i,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
    plt.show()

# %%
print(f"Root Mean Squared Error for the Data {np.sqrt(np.mean((data - np.mean(pmcmc_output['MLE_particle_observations'][:,0,:]))**2))}")
print(f"Root Mean Squared Error for beta {np.sqrt(np.mean((betas - np.mean(pmcmc_output['MLE_particle_dist'][:,4,:]))**2))}")
plt.title("Particle Distribution of $\\beta_t$")
plt.xlabel("Time (Days)")
plt.plot(t_vec,betas,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,95,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,25,axis = 1),np.percentile(pmcmc_output['MLE_particle_dist'][:,4,:].T,75,axis = 1),alpha = 0.5,color = 'steelblue') 
plt.show()
# Out:
# Root Mean Squared Error for the Data 5026.622756209024
# Root Mean Squared Error for beta 0.09944834272923211

# %%
plt.title("Fit to Data")
plt.xlabel('Time (Days)')
plt.plot(t_vec[::int(1/dt)],data.T,'--',color = 'black')
plt.fill_between(t_vec[::int(1/dt)],np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,5,axis = 1),np.percentile(pmcmc_output['MLE_particle_observations'][:,0,:].T,95,axis = 1),alpha = 0.5)
plt.show()

# %%
import pickle

np.savez(f'../pmcmc_output/PMCMC.npz',distribution = pmcmc_output['MLE_particle_dist'], 
         observations = pmcmc_output['MLE_particle_observations'], 
         params = pmcmc_output['accepted_params'], 
         likelihood = pmcmc_output['Log Likelihood']
)

with open('../pmcmc_output/pmcmc_par.pickle', 'wb') as f:
    pickle.dump(pmcmc_params, f)
